# %% [markdown]
# *MeNu GUIDE*
# # Integrate Ontology and Database Info - Markers

# %%
import rdflib
import pandas as pd
from rdflib import URIRef, Literal, Namespace, RDF, XSD
import os

# %%
MeNuGUIDE = Namespace("http://MeNuGUIDE.local/")
ChEBI = Namespace("http://purl.obolibrary.org/obo/chebi/")
OBO = Namespace("http://purl.obolibrary.org/obo/")
GO = Namespace("http://www.geneontology.org/formats/oboInOwl#")
FOBI = Namespace("http://purl.obolibrary.org/obo/FOBI_")

# %%
MeNuGUIDE.Measurement
# Out:
# rdflib.term.URIRef('http://MeNuGUIDE.local/Measurement')

# %% [markdown]
# ## Load Graph

# %%
markerdb_folder = "/path/to/markerdb/data/folder/"
ontology_folder = "/path/to/ontologies/"
processed_data_folder = "/path/to/processed/data/folder/"

# %%
onto_graph = rdflib.Graph()
onto_graph.parse(os.path.join(ontology_folder, "merged_with_foods_compounds_reactions.ttl"), format="turtle")
# Out:
# <Graph identifier=Na02196d5e708470a901ab294d3182d1d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Prepare MarkerDB Data
# ### Chemical References

# %%
chemical_references = pd.read_csv(os.path.join(markerdb_folder, "markerdb_chemical_associations.csv"))

# %%
chemical_references
# Out:
#       markerdb_id      name_markerdb  condition_id            condition  \
# 0               1  1-Methylhistidine           251              Obesity
# 1               1  1-Methylhistidine             1               Normal
# 2               1  1-Methylhistidine            33  Alzheimer's Disease
# 3               1  1-Methylhistidine            34            Pregnancy
# 4               1  1-Methylhistidine             1               Normal
# ...           ...                ...           ...                  ...
# 3766         5017          Triclosan             1               Normal
# 3767         5017          Triclosan          6689   Triclosan Exposure
# 3768         5017          Triclosan             1               Normal
# 3769         5017          Triclosan          6689   Triclosan Exposure
# 3770         5017          Triclosan             1               Normal
#
#                    cohort     sex sample_type  \
# 0     Adult: >=18 yrs old    Both       Urine
# 1     Adult: >=18 yrs old    Both       Urine
# 2     Adult: >=18 yrs old    Both       Urine
# 3     Adult: >=18 yrs old  Female       Blood
# 4     Adult: >=18 yrs old    Both       Blood
# ...                   ...     ...         ...
# 3766                  All    Both       Urine
# 3767                  All    Both       Urine
# 3768                  All    Both       Urine
# 3769                  All    Both       Urine
# 3770                  All    Both       Urine
#
#                                     concentration                  unit  \
# 0           10.9 (0.80-21.0) umol/mmol creatinine  umol/mmol creatinine
# 1          85.8 (17.7-153.8) umol/mmol creatinine  umol/mmol creatinine
# 2           15.7 (11.7-19.7) umol/mmol creatinine  umol/mmol creatinine
# 3                                         50.0 uM                    uM
# 4                                         12.7 uM                    uM
# ...                                           ...                   ...
# 3766  0.0059 (0.0052-0.0068) umol/mmol creatinine  umol/mmol creatinine
# 3767        0.25 (0.20-0.31) umol/mmol creatinine  umol/mmol creatinine
# 3768  0.0052 (0.0046-0.0059) umol/mmol creatinine  umol/mmol creatinine
# 3769        0.14 (0.11-0.17) umol/mmol creatinine  umol/mmol creatinine
# 3770  0.0038 (0.0035-0.0042) umol/mmol creatinine  umol/mmol creatinine
#
#                                notes  reference_id  \
# 0                                NaN           654
# 1                                NaN        367200
# 2                                NaN           129
# 3                                NaN        367357
# 4                                NaN        116748
# ...                              ...           ...
# 3766                             NaN        367558
# 3767  Total population (2011 - 2012)        367558
# 3768                             NaN        367558
# 3769  Total population (2013 - 2014)        367558
# 3770                             NaN        367558
#
#                                          reference_name   pubmed_id
# 0     Tuma, P., Samcova, E. & Balinova, P. Determina...  15899597.0
# 1     David F. Putnam Composition and Concentrative ...         NaN
# 2     Fonteh, A. N., Harrington, R. J., Tsai, A., Li...  17031479.0
# 3                                                   NaN  22494326.0
# 4     Dohm, G. L., Williams, R. T., Kasperek, G. J. ...   7061274.0
# ...                                                 ...         ...
# 3766  National Health and Nutrition Examination Surv...         NaN
# 3767  National Health and Nutrition Examination Surv...         NaN
# 3768  National Health and Nutrition Examination Surv...         NaN
# 3769  National Health and Nutrition Examination Surv...         NaN
# 3770  National Health and Nutrition Examination Surv...         NaN
#
# [3771 rows x 13 columns]

# %%
conditions = list(chemical_references.condition.unique())

# %%
exposures = []
diseases = []

for condition in conditions:
    if 'exposure' in condition.lower():
        exposures.append(condition)
    else:
        diseases.append(condition)

# %%
len(exposures)
# Out:
# 59

# %%
len(diseases)
# Out:
# 293

# %%
def find_term(search_term, label_type=''):
    query = f"""
    SELECT ?entity ?label
    WHERE {{
      # ?entity rdfs:label "{search_term}"{label_type} .
    }}
    """
    
    query_2 = f"""
    SELECT ?entity ?label
    WHERE {{
      # ?entity rdfs:label ?label .
      FILTER (LCASE(STR(?label)) = LCASE("{search_term}"))
    }}
    """
    
    # Execute the query
    results = onto_graph.query(query_2)
    return list(results)

def find_term_by_synonym(search_term):
    query = f"""
    SELECT ?entity ?label
    WHERE {{
      # ?entity <http://www.geneontology.org/formats/obolnOwl#hasExactSynonym> ?label .
      FILTER (LCASE(STR(?label)) = LCASE("{search_term}"))
    }}
    """
    
    results = onto_graph.query(query)
    return list(results)

# %%
matched_diseases = {}
unmatched_diseases = [] 

for disease in diseases:
    print(disease)
    matches = find_term(disease)
    matches.extend(find_term_by_synonym(disease))
    
    if matches:
        matched_diseases[disease] = matches
    else:
        unmatched_diseases.append(disease)
# Out:
# Obesity
# Normal
# Alzheimer's Disease
# Pregnancy
# Preeclampsia/Eclampsia
# Chronic Kidney Disease
# Leukemia
# Pyruvate Dehydrogenase Deficiency
# Prolactinoma
# Fumarase Deficiency
# Pyruvate Carboxylase Deficiency
# Diabetes Mellitus Type 2
# Meningitis
# Anoxia
# Medium Chain Acyl Co A Dehydrogenase Deficiency
# Pyruvate Dehydrogenase Phosphatase Deficiency
# Long Chain 3 Hydroxyacyl Co A Dehydrogenase Deficiency
# 3 Hydroxyacyl Co A Dehydrogenase Deficiency
# 3 Hydroxy 3 Methylglutaryl Co A Lyase Deficiency
# Carnitine Palmitoyltransferase I Deficiency
# Schizophrenia
# Eosinophilic Esophagitis
# 11 Beta Hydroxylase Deficiency
# Congenital Adrenal Hyperplaia due to 17-alpha-Hydroxylase Deficiency
# Maple Syrup Urine Disease
# Phenylketonuria
# Lung Cancer
# Parkinson's Disease
# Mild Metachromatic Leukodystrophy
# Myocardial Infarction
# Head Injury
# Carnosinuria
# Lewy Body Dementia
# Lipoid Congenital Adrenal Hyperplasia
# Antenatal Bartter Syndrome Type 2
# Type 4B Bartter Syndrome
# Antenatal Bartter Syndrome Type 1
# Congenital Adrenal Insufficiency with 46,XY Sex Reversal
# Corticosterone Methyloxidase Type I Deficiency
# A.I.D.S.
# Ulcerative Colitis
# Irritable Bowel Syndrome
# Crohn's Disease
# Propionic Acidemia
# Argininosuccinic Aciduria
# Peritoneal Dialysis
# Hemodialysis
# Hyperoxalemia
# Adenylosuccinate Lyase Deficiency
# Sepsis
# Adult Onset Type II Citrullinemia
# N Acetylglutamate Synthase Deficiency
# Sulfite Oxidase Deficiency
# Classic Citrullinemia
# Rheumatoid Arthritis
# Polycystic Ovary Syndrome
# Congenital Adrenal Hyperplasia
# Cerebral Vasospasm
# Lathosterolosis
# Lecithin:Cholesterol Acyltransferase Deficiency
# Glucose 6 Phosphate Dehydrogenase Deficiency
# Crigler Najjar Syndrome
# Growth Hormone Deficiency
# Donohue Syndrome
# Congenital Bile Acid Synthesis Defect
# Progressive Familial Intrahepatic Cholestasis
# Dyserythropoietic Congenital Anemia Type II
# Dihydropyrimidinase Deficiency
# GABA-Transaminase Deficiency
# Ketosis
# Glucose Transporter Type 1 Deficiency Syndrome
# Succinyl Co A:3 Oxoacid Co A Transferase Deficiency
# Oculocerebrorenal Syndrome
# Stress
# Functional Hypothalamic Amenorrhea
# Benign Gynecological Diseases
# Antley Bixler Syndrome With Genital Anomalies And Disordered Steroidogenesis
# Isolated ACTH Deficiency
# Proprotein Convertase 1/3 Deficiency
# Apparent Mineralocorticoid Excess
# Glucocorticoid Resistance
# Aromatase Deficiency
# Rhabdomyolysis
# Uremia
# Hypercholesterolemia
# Smith Lemli Opitz Syndrome
# Addison's Disease
# Zellweger Syndrome
# Adrenoleukodystrophy
# Peroxisomal Diogenesis Disorder
# Anemia
# Refsum Disease
# Pyridoxine Dependent Epilepsy
# Infantile Refsum Disease
# Purine Nucleoside Phosphorylase Deficiency
# Aromatic L Amino Acid Decarboxylase Deficiency
# Vitiligo
# Hypothyroidism
# Encephalitis
# Congenital Dopamine Beta-Hydroxylase Deficiency
# 21 Hydroxylase Deficiency
# Beta Ureidopropionase Deficiency
# Canavan Disease
# Amish Type Microcephaly
# Spina Bifida
# Small Bowel Bacterial Overgrowth Syndrome
# Cystathioninuria
# Adenosine Deaminase Deficiency
# Ethanol Consumption
# Epilepsy
# Febrile Seizures
# Hepatic Encephalopathy
# Glycolic Aciduria
# D 2 Hydroxyglutaric Aciduria
# Primary Hyperoxaluria Type I
# Brunner Syndrome
# Celiac Disease
# Urocanase Deficiency
# Sepiapterin Reductase Deficiency
# Friedreich's Ataxia
# Hereditary Folate Malabsorption
# Fanconi Syndrome
# Lipodystrophy
# Fructose 1,6 Bisphosphatase Deficiency
# Familial Hyperinsulinemic Hypoglycemia
# Acute Myelogenous Leukemia
# Autosomal Dominant Polycystic Kidney Disease
# Hyperammonemia due to Carbamoyl Phosphate Synthetase I Deficiency
# Phosphoserine Aminotransferase Deficiency
# Phosphoserine Phosphatase Deficiency
# D Glyceric Acidemia
# Glucoglycinuria
# Multiple Sclerosis
# Alkaptonuria
# Glycogen Storage Disease
# Alpha 1 Antitrypsin Deficiency
# Intrahepatic Biliary Hypoplasia
# Portal Vein Obstruction
# Hepatobiliary Diseases
# Chronic Active Hepatitis
# Glutaric Acidemia Type 2
# Heart Failure
# X-Linked Ichthyosis
# Idiopathic Oro Facial Pain
# Phosphoribosylpyrophosphate Synthetase Superactivity
# Xanthinuria Type 1
# Lesch Nyhan Syndrome
# Hydrocephalus
# Hawkinsinuria
# Hyperphenylalaninemia
# Bacterial Infections
# Paraquat Poisoning
# Pearson Marrow Pancreas Syndrome
# Iminoglycinuria
# Hyperprolinemia Type I
# Glutathione Synthetase Deficiency
# Histidinemia
# Dengue Fever
# L 2 Hydroxyglutaric Aciduria
# Cystinuria
# Lysinuric Protein Intolerance
# Adult Type Lactose Intolerance
# Phosphoglycerate Dehydrogenase Deficiency
# Type V 3-Methylglutaconic Aciduria
# Coenzyme Q10 Deficiency
# Cytochrome C Oxidase Deficiency
# Leber Optic Atrophy And Dystonia
# Leigh Syndrome
# Mitochondrial Phosphate Carrier Deficiency
# G.R.A.C.I.L.E. Syndrome
# Hereditary Fructose Intolerance
# Hereditary Myopathy With Lactic Acidosis
# Acute Infantile Liver Failure
# M.L.A.S.A.
# Cirrhosis
# Molybdenum Cofactor Deficiency
# Acute Seizures
# cblB Deficiency Methylmalonic Aciduria
# Transcobalamin Ii Deficiency
# Malonyl Co A Decarboxylase Deficiency
# cblA Deficiency Methylmalonic Aciduria
# Ribose 5 Phosphate Isomerase Deficiency
# Subarachnoid Hemorrhage
# Heat Stress
# Alpha Aminoadipic Aciduria
# Ornithine Transcarbamylase Deficiency
# Orotic Aciduria
# Mevalonic Aciduria
# Sodium Nitrate Consumption
# Amyotrophic Lateral Sclerosis
# Hepatic Coma
# Methylmalonic Acidemia
# Sickle Cell Anemia
# Brown Vialetto Van Laere Syndrome
# Porphyria
# Combined Pituitary Hormone Deficiency
# Pendred Syndrome
# Congenital Nongoitrous Hypothyroidism
# Sarcosinemia
# Congenital Disorder of Glycosylation Type 1A
# Cachexia
# Degenerative Disc Disease
# Argininemia
# Endometrial Cancer
# Menkes Disease
# Aldosterone Biosynthesis Defects
# Aldehyde Dehydrogenase Deficiency
# 2 Methylbutyryl Co A Dehydrogenase Deficiency
# Biotinidase Deficiency
# 3-Methylglutaconic Aciduria Type I
# Ovarian Cancer
# Glutaryl Co A Dehydrogenase Deficiency (Gdhd)
# Carnitine Acylcarnitine Translocase Deficiency
# Segawa Syndrome
# Aspartylglucosaminuria
# Familial Mediterranean Fever
# Cystic Fibrosis
# Prostate Cancer
# Aminoacylase I Deficiency
# Stroke
# Rachialgia
# Type 4A Bartter Syndrome
# Type I Autosonal Dominant Pseudyhopoaldosteronism
# Liver Disease
# Peripheral Neuropathy
# Hyperthyroidism
# Paget's Disease
# Vitamin B12 Deficiency
# Glutaric Acidemia I
# Isobutyryl Co A Dehydrogenase Deficiency
# Ethylmaonic Encephalopathy
# Congenital Glutamine Defficiency
# Isovaleric Acidemia
# Homocystinuria
# Iron Deficiency
# Glycine N Methyltransferase Deficiency
# Methionine Adenosyltransferase Deficiency
# Pellagra
# Succinic Semialdehyde Dehydrogenase Deficiency
# Malaria
# Prolidase Deficiency
# Carcinoid Tumors
# Bipolar Disorder
# Alpha Methylacyl Co A Racemase Deficiency
# Rhizomelic Chondrodysplasia Punctata
# Hypertension
# CNS Infections
# Sitosterolemia
# Nephrotic Syndrome
# Kynureninase Deficiency
# Mastocytosis
# Dermal Fibroproliferative Disorder
# Trimethylaminuria
# Acute Liver Disease
# Smoking
# Beta Thalassemia
# Cerebrotendinous Xanthomatosis
# Eczema
# Breast Cancer
# Rett Syndrome
# Pancreatic Cancer
# Mild Cognitive Impairment
# Neuroborreliosis
# Alcoholism
# Sjogren Larsson Syndrome
# Pentosuria
# Asthma
# Abetalipoproteinemia
# Familial Isolated Deficiency of Vitamin E
# Narcolepsy
# Hypoxic Ischemic Encephalopathy
# Motor Neuron Disease
# Tert Amyl Methyl Ether Exposed
# D Bifunctional Protein Deficiency
# Megaloblastic Anemia 1
# Adrenomyeloneuropathy
# Autism
# Desmosterolosis
# Prader Willi Syndrome
# Cardiopulmonary Resuscitation
# Coronary Heart Disease
# Cervical Cancer
# Stomach Cancer
# Gamma Glutamyltransferase Deficiency
# Macular Degeneration
# Prepartum Depression
# Angina
# Coronary Artery Disease
# Hypobetalipoproteinemia
# Kidney Transplantation
# Reye's Syndrome
# Rhinitis
# Vertebral Osteoporosis

# %%
len(matched_diseases)
# Out:
# 143

# %%
len(unmatched_diseases)
# Out:
# 150

# %%
matched_diseases_copy = matched_diseases.copy()

# %%
matched_diseases_copy
# Out:
# {'Obesity': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9970'),
#    rdflib.term.Literal('obesity', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001513'),
#    rdflib.term.Literal('Obesity'))],
#  'Normal': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/PATO_0000461'),
#    rdflib.term.Literal('normal'))],
#  "Alzheimer's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10652'),
#    rdflib.term.Literal("Alzheimer's disease", lang='en'))],
#  'Chronic Kidney Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_784'),
#    rdflib.term.Literal('chronic kidney disease', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012622'),
#    rdflib.term.Literal('Chronic kidney disease'))],
#  'Leukemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001909'),
#    rdflib.term.Literal('Leukemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1240'),
#    rdflib.term.Literal('leukemia', lang='en'))],
#  'Prolactinoma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5394'),
#    rdflib.term.Literal('prolactinoma', lang='en'))],
#  'Fumarase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111261'),
#    rdflib.term.Literal('fumarase deficiency', lang='en'))],
#  'Meningitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031110'),
#    rdflib.term.Literal('meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0019173'),
#    rdflib.term.Literal('meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001287'),
#    rdflib.term.Literal('Meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9471'),
#    rdflib.term.Literal('meningitis', lang='en'))],
#  'Anoxia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0002316'),
#    rdflib.term.Literal('anoxia'))],
#  'Carnitine Palmitoyltransferase I Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090129'),
#    rdflib.term.Literal('carnitine palmitoyltransferase I deficiency', lang='en'))],
#  'Schizophrenia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100753'),
#    rdflib.term.Literal('Schizophrenia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5419'),
#    rdflib.term.Literal('schizophrenia', lang='en'))],
#  'Eosinophilic Esophagitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13922'),
#    rdflib.term.Literal('eosinophilic esophagitis', lang='en'))],
#  'Maple Syrup Urine Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9269'),
#    rdflib.term.Literal('maple syrup urine disease', lang='en'))],
#  'Phenylketonuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9281'),
#    rdflib.term.Literal('phenylketonuria', lang='en'))],
#  'Lung Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1324'),
#    rdflib.term.Literal('lung cancer', lang='en'))],
#  "Parkinson's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14330'),
#    rdflib.term.Literal("Parkinson's disease", lang='en'))],
#  'Myocardial Infarction': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001658'),
#    rdflib.term.Literal('Myocardial infarction')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5844'),
#    rdflib.term.Literal('myocardial infarction', lang='en'))],
#  'Carnosinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003167'),
#    rdflib.term.Literal('Carnosinuria'))],
#  'Lewy Body Dementia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12217'),
#    rdflib.term.Literal('Lewy body dementia', lang='en'))],
#  'Ulcerative Colitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8577'),
#    rdflib.term.Literal('ulcerative colitis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100279'),
#    rdflib.term.Literal('Ulcerative colitis'))],
#  'Irritable Bowel Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9778'),
#    rdflib.term.Literal('irritable bowel syndrome', lang='en'))],
#  "Crohn's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#    rdflib.term.Literal("Crohn's disease")),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8778'),
#    rdflib.term.Literal("Crohn's disease", lang='en'))],
#  'Propionic Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14701'),
#    rdflib.term.Literal('propionic acidemia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003571'),
#    rdflib.term.Literal('Propionic acidemia'))],
#  'Argininosuccinic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14755'),
#    rdflib.term.Literal('argininosuccinic aciduria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0025630'),
#    rdflib.term.Literal('Argininosuccinic aciduria'))],
#  'Sepsis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005044'),
#    rdflib.term.Literal('sepsis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100806'),
#    rdflib.term.Literal('Sepsis'))],
#  'Sulfite Oxidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003643'),
#    rdflib.term.Literal('Sulfite oxidase deficiency'))],
#  'Classic Citrullinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0070340'),
#    rdflib.term.Literal('classic citrullinemia', lang='en'))],
#  'Rheumatoid Arthritis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7148'),
#    rdflib.term.Literal('rheumatoid arthritis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0003561'),
#    rdflib.term.Literal('rheumatoid arthritis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001370'),
#    rdflib.term.Literal('Rheumatoid arthritis'))],
#  'Polycystic Ovary Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_11612'),
#    rdflib.term.Literal('polycystic ovary syndrome', lang='en'))],
#  'Congenital Adrenal Hyperplasia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050811'),
#    rdflib.term.Literal('congenital adrenal hyperplasia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0008258'),
#    rdflib.term.Literal('Congenital adrenal hyperplasia'))],
#  'Donohue Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050470'),
#    rdflib.term.Literal('Donohue syndrome', lang='en'))],
#  'Congenital Bile Acid Synthesis Defect': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050674'),
#    rdflib.term.Literal('congenital bile acid synthesis defect', lang='en'))],
#  'Progressive Familial Intrahepatic Cholestasis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0070221'),
#    rdflib.term.Literal('progressive familial intrahepatic cholestasis', lang='en'))],
#  'Dihydropyrimidinase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111629'),
#    rdflib.term.Literal('dihydropyrimidinase deficiency', lang='en'))],
#  'Ketosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0030970'),
#    rdflib.term.Literal('ketosis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001946'),
#    rdflib.term.Literal('Ketosis'))],
#  'Oculocerebrorenal Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1056'),
#    rdflib.term.Literal('oculocerebrorenal syndrome', lang='en'))],
#  'Proprotein Convertase 1/3 Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111698'),
#    rdflib.term.Literal('proprotein convertase 1/3 deficiency', lang='en'))],
#  'Rhabdomyolysis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031112'),
#    rdflib.term.Literal('rhabdomyolysis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003201'),
#    rdflib.term.Literal('Rhabdomyolysis'))],
#  'Uremia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4676'),
#    rdflib.term.Literal('uremia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0009644'),
#    rdflib.term.Literal('uremia'))],
#  'Hypercholesterolemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003124'),
#    rdflib.term.Literal('Hypercholesterolemia'))],
#  "Addison's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13774'),
#    rdflib.term.Literal("Addison's disease", lang='en'))],
#  'Zellweger Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_905'),
#    rdflib.term.Literal('Zellweger syndrome', lang='en'))],
#  'Adrenoleukodystrophy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10588'),
#    rdflib.term.Literal('adrenoleukodystrophy', lang='en'))],
#  'Anemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCBITaxon_12939'),
#    rdflib.term.Literal('Anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001903'),
#    rdflib.term.Literal('Anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0001577'),
#    rdflib.term.Literal('anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000208'),
#    rdflib.term.Literal('anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2355'),
#    rdflib.term.Literal('anemia', lang='en'))],
#  'Refsum Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10582'),
#    rdflib.term.Literal('Refsum disease', lang='en'))],
#  'Infantile Refsum Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050444'),
#    rdflib.term.Literal('infantile Refsum disease', lang='en'))],
#  'Purine Nucleoside Phosphorylase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5813'),
#    rdflib.term.Literal('purine nucleoside phosphorylase deficiency', lang='en'))],
#  'Vitiligo': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12306'),
#    rdflib.term.Literal('vitiligo', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001045'),
#    rdflib.term.Literal('Vitiligo'))],
#  'Hypothyroidism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1459'),
#    rdflib.term.Literal('hypothyroidism', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000821'),
#    rdflib.term.Literal('Hypothyroidism'))],
#  'Encephalitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000090'),
#    rdflib.term.Literal('encephalitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9588'),
#    rdflib.term.Literal('encephalitis', lang='en'))],
#  'Canavan Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3613'),
#    rdflib.term.Literal('Canavan disease', lang='en'))],
#  'Spina Bifida': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0003054'),
#    rdflib.term.Literal('spina bifida')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080016'),
#    rdflib.term.Literal('spina bifida', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002414'),
#    rdflib.term.Literal('Spina bifida'))],
#  'Cystathioninuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090142'),
#    rdflib.term.Literal('cystathioninuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003153'),
#    rdflib.term.Literal('Cystathioninuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0030689'),
#    rdflib.term.Literal('cystathioninuria'))],
#  'Adenosine Deaminase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5810'),
#    rdflib.term.Literal('adenosine deaminase deficiency', lang='en'))],
#  'Epilepsy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1826'),
#    rdflib.term.Literal('epilepsy', lang='en'))],
#  'Febrile Seizures': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0012011'),
#    rdflib.term.Literal('febrile seizures'))],
#  'Hepatic Encephalopathy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13413'),
#    rdflib.term.Literal('hepatic encephalopathy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002480'),
#    rdflib.term.Literal('Hepatic encephalopathy'))],
#  'Brunner Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060693'),
#    rdflib.term.Literal('Brunner Syndrome', lang='en'))],
#  'Celiac Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10608'),
#    rdflib.term.Literal('celiac disease', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002608'),
#    rdflib.term.Literal('Celiac disease'))],
#  'Urocanase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112180'),
#    rdflib.term.Literal('urocanase deficiency', lang='en'))],
#  'Sepiapterin Reductase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111168'),
#    rdflib.term.Literal('sepiapterin reductase deficiency', lang='en'))],
#  'Hereditary Folate Malabsorption': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111678'),
#    rdflib.term.Literal('hereditary folate malabsorption', lang='en'))],
#  'Fanconi Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1062'),
#    rdflib.term.Literal('Fanconi syndrome', lang='en'))],
#  'Lipodystrophy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0011174'),
#    rdflib.term.Literal('lipodystrophy')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_811'),
#    rdflib.term.Literal('lipodystrophy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0009125'),
#    rdflib.term.Literal('Lipodystrophy'))],
#  'Autosomal Dominant Polycystic Kidney Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_898'),
#    rdflib.term.Literal('autosomal dominant polycystic kidney disease', lang='en'))],
#  'Multiple Sclerosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2377'),
#    rdflib.term.Literal('multiple sclerosis', lang='en'))],
#  'Alkaptonuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9270'),
#    rdflib.term.Literal('alkaptonuria', lang='en'))],
#  'Glycogen Storage Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2747'),
#    rdflib.term.Literal('glycogen storage disease', lang='en'))],
#  'Chronic Active Hepatitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0200120'),
#    rdflib.term.Literal('Chronic active hepatitis'))],
#  'Heart Failure': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000292'),
#    rdflib.term.Literal('heart failure'))],
#  'X-Linked Ichthyosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1700'),
#    rdflib.term.Literal('X-linked ichthyosis', lang='en'))],
#  'Phosphoribosylpyrophosphate Synthetase Superactivity': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111260'),
#    rdflib.term.Literal('phosphoribosylpyrophosphate synthetase superactivity', lang='en'))],
#  'Hydrocephalus': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000051'),
#    rdflib.term.Literal('hydrocephalus')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10908'),
#    rdflib.term.Literal('hydrocephalus', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000238'),
#    rdflib.term.Literal('Hydrocephalus'))],
#  'Hawkinsinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0034457'),
#    rdflib.term.Literal('Hawkinsinuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111362'),
#    rdflib.term.Literal('hawkinsinuria', lang='en'))],
#  'Hyperphenylalaninemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0004923'),
#    rdflib.term.Literal('Hyperphenylalaninemia'))],
#  'Iminoglycinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112265'),
#    rdflib.term.Literal('iminoglycinuria', lang='en'))],
#  'Glutathione Synthetase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080699'),
#    rdflib.term.Literal('glutathione synthetase deficiency', lang='en'))],
#  'Histidinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060168'),
#    rdflib.term.Literal('histidinemia', lang='en'))],
#  'Cystinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9266'),
#    rdflib.term.Literal('cystinuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0020400'),
#    rdflib.term.Literal('cystinuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003131'),
#    rdflib.term.Literal('Cystinuria'))],
#  'Lysinuric Protein Intolerance': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060439'),
#    rdflib.term.Literal('lysinuric protein intolerance', lang='en'))],
#  'Cirrhosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001394'),
#    rdflib.term.Literal('Cirrhosis'))],
#  'Molybdenum Cofactor Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003570'),
#    rdflib.term.Literal('Molybdenum cofactor deficiency')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111165'),
#    rdflib.term.Literal('molybdenum cofactor deficiency', lang='en'))],
#  'Transcobalamin Ii Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050818'),
#    rdflib.term.Literal('transcobalamin II deficiency', lang='en'))],
#  'Subarachnoid Hemorrhage': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002138'),
#    rdflib.term.Literal('Subarachnoid hemorrhage')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031109'),
#    rdflib.term.Literal('subarachnoid hemorrhage'))],
#  'Orotic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050833'),
#    rdflib.term.Literal('orotic aciduria', lang='en'))],
#  'Mevalonic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050452'),
#    rdflib.term.Literal('mevalonic aciduria', lang='en'))],
#  'Amyotrophic Lateral Sclerosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0007354'),
#    rdflib.term.Literal('Amyotrophic lateral sclerosis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_332'),
#    rdflib.term.Literal('amyotrophic lateral sclerosis', lang='en'))],
#  'Hepatic Coma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12550'),
#    rdflib.term.Literal('hepatic coma', lang='en'))],
#  'Methylmalonic Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002912'),
#    rdflib.term.Literal('Methylmalonic acidemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14749'),
#    rdflib.term.Literal('methylmalonic acidemia', lang='en'))],
#  'Sickle Cell Anemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10923'),
#    rdflib.term.Literal('sickle cell anemia', lang='en'))],
#  'Porphyria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005654'),
#    rdflib.term.Literal('porphyria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13268'),
#    rdflib.term.Literal('porphyria', lang='en'))],
#  'Pendred Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060744'),
#    rdflib.term.Literal('Pendred Syndrome', lang='en'))],
#  'Sarcosinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112307'),
#    rdflib.term.Literal('sarcosinemia', lang='en'))],
#  'Cachexia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005150'),
#    rdflib.term.Literal('cachexia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000402'),
#    rdflib.term.Literal('cachexia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0004326'),
#    rdflib.term.Literal('Cachexia'))],
#  'Degenerative Disc Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_90'),
#    rdflib.term.Literal('degenerative disc disease', lang='en'))],
#  'Endometrial Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1380'),
#    rdflib.term.Literal('endometrial cancer', lang='en'))],
#  'Menkes Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1838'),
#    rdflib.term.Literal('Menkes disease', lang='en'))],
#  'Biotinidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_856'),
#    rdflib.term.Literal('biotinidase deficiency', lang='en'))],
#  'Ovarian Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2394'),
#    rdflib.term.Literal('ovarian cancer', lang='en'))],
#  'Aspartylglucosaminuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050461'),
#    rdflib.term.Literal('aspartylglucosaminuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0011516'),
#    rdflib.term.Literal('aspartylglucosaminuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012068'),
#    rdflib.term.Literal('Aspartylglucosaminuria'))],
#  'Familial Mediterranean Fever': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2987'),
#    rdflib.term.Literal('familial Mediterranean fever', lang='en'))],
#  'Cystic Fibrosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1485'),
#    rdflib.term.Literal('cystic fibrosis', lang='en'))],
#  'Prostate Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012125'),
#    rdflib.term.Literal('Prostate cancer')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10283'),
#    rdflib.term.Literal('prostate cancer', lang='en'))],
#  'Stroke': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001297'),
#    rdflib.term.Literal('Stroke'))],
#  'Liver Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_409'),
#    rdflib.term.Literal('liver disease', lang='en'))],
#  'Peripheral Neuropathy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0009830'),
#    rdflib.term.Literal('Peripheral neuropathy'))],
#  'Hyperthyroidism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7998'),
#    rdflib.term.Literal('hyperthyroidism', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000836'),
#    rdflib.term.Literal('Hyperthyroidism'))],
#  'Vitamin B12 Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050731'),
#    rdflib.term.Literal('vitamin B12 deficiency', lang='en'))],
#  'Glutaric Acidemia I': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111254'),
#    rdflib.term.Literal('glutaric acidemia I', lang='en'))],
#  'Isovaleric Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14753'),
#    rdflib.term.Literal('isovaleric acidemia', lang='en'))],
#  'Homocystinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9263'),
#    rdflib.term.Literal('homocystinuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002156'),
#    rdflib.term.Literal('Homocystinuria'))],
#  'Pellagra': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8457'),
#    rdflib.term.Literal('pellagra', lang='en'))],
#  'Succinic Semialdehyde Dehydrogenase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060175'),
#    rdflib.term.Literal('succinic semialdehyde dehydrogenase deficiency', lang='en'))],
#  'Malaria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12365'),
#    rdflib.term.Literal('malaria', lang='en'))],
#  'Prolidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111540'),
#    rdflib.term.Literal('prolidase deficiency', lang='en'))],
#  'Bipolar Disorder': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/NBO_0000258'),
#    rdflib.term.Literal('bipolar disorder')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3312'),
#    rdflib.term.Literal('bipolar disorder', lang='en'))],
#  'Rhizomelic Chondrodysplasia Punctata': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2580'),
#    rdflib.term.Literal('rhizomelic chondrodysplasia punctata', lang='en'))],
#  'Hypertension': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0000231'),
#    rdflib.term.Literal('hypertension')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10763'),
#    rdflib.term.Literal('hypertension', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000822'),
#    rdflib.term.Literal('Hypertension'))],
#  'Sitosterolemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090019'),
#    rdflib.term.Literal('sitosterolemia', lang='en'))],
#  'Nephrotic Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1184'),
#    rdflib.term.Literal('nephrotic syndrome', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000100'),
#    rdflib.term.Literal('Nephrotic syndrome'))],
#  'Mastocytosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_350'),
#    rdflib.term.Literal('mastocytosis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100495'),
#    rdflib.term.Literal('Mastocytosis'))],
#  'Trimethylaminuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080361'),
#    rdflib.term.Literal('trimethylaminuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003614'),
#    rdflib.term.Literal('Trimethylaminuria'))],
#  'Beta Thalassemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12241'),
#    rdflib.term.Literal('beta thalassemia', lang='en'))],
#  'Cerebrotendinous Xanthomatosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4810'),
#    rdflib.term.Literal('cerebrotendinous xanthomatosis', lang='en'))],
#  'Eczema': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000289'),
#    rdflib.term.Literal('eczema'))],
#  'Breast Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1612'),
#    rdflib.term.Literal('breast cancer', lang='en'))],
#  'Rett Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1206'),
#    rdflib.term.Literal('Rett syndrome', lang='en'))],
#  'Pancreatic Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1793'),
#    rdflib.term.Literal('pancreatic cancer', lang='en'))],
#  'Mild Cognitive Impairment': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080832'),
#    rdflib.term.Literal('mild cognitive impairment', lang='en'))],
#  'Pentosuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111258'),
#    rdflib.term.Literal('pentosuria', lang='en'))],
#  'Asthma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002099'),
#    rdflib.term.Literal('Asthma')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2841'),
#    rdflib.term.Literal('asthma', lang='en'))],
#  'Abetalipoproteinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1386'),
#    rdflib.term.Literal('abetalipoproteinemia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0008181'),
#    rdflib.term.Literal('Abetalipoproteinemia'))],
#  'Familial Isolated Deficiency of Vitamin E': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090028'),
#    rdflib.term.Literal('familial isolated deficiency of vitamin E', lang='en'))],
#  'Narcolepsy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8986'),
#    rdflib.term.Literal('narcolepsy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005279'),
#    rdflib.term.Literal('narcolepsy')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0030050'),
#    rdflib.term.Literal('Narcolepsy'))],
#  'Motor Neuron Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_231'),
#    rdflib.term.Literal('motor neuron disease', lang='en'))],
#  'Autism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000717'),
#    rdflib.term.Literal('Autism'))],
#  'Cervical Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4362'),
#    rdflib.term.Literal('cervical cancer', lang='en'))],
#  'Stomach Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012126'),
#    rdflib.term.Literal('Stomach cancer')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10534'),
#    rdflib.term.Literal('stomach cancer', lang='en'))],
#  'Macular Degeneration': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000608'),
#    rdflib.term.Literal('Macular degeneration')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4448'),
#    rdflib.term.Literal('macular degeneration', lang='en'))],
#  'Angina': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0006112'),
#    rdflib.term.Literal('angina'))],
#  'Coronary Artery Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3393'),
#    rdflib.term.Literal('coronary artery disease', lang='en'))],
#  'Hypobetalipoproteinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1390'),
#    rdflib.term.Literal('hypobetalipoproteinemia', lang='en'))],
#  'Rhinitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0001867'),
#    rdflib.term.Literal('rhinitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012384'),
#    rdflib.term.Literal('Rhinitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4483'),
#    rdflib.term.Literal('rhinitis', lang='en'))]}

# %%
unmatched_diseases
# Out:
# ['Pregnancy',
#  'Preeclampsia/Eclampsia',
#  'Pyruvate Dehydrogenase Deficiency',
#  'Pyruvate Carboxylase Deficiency',
#  'Diabetes Mellitus Type 2',
#  'Medium Chain Acyl Co A Dehydrogenase Deficiency',
#  'Pyruvate Dehydrogenase Phosphatase Deficiency',
#  'Long Chain 3 Hydroxyacyl Co A Dehydrogenase Deficiency',
#  '3 Hydroxyacyl Co A Dehydrogenase Deficiency',
#  '3 Hydroxy 3 Methylglutaryl Co A Lyase Deficiency',
#  '11 Beta Hydroxylase Deficiency',
#  'Congenital Adrenal Hyperplaia due to 17-alpha-Hydroxylase Deficiency',
#  'Mild Metachromatic Leukodystrophy',
#  'Head Injury',
#  'Lipoid Congenital Adrenal Hyperplasia',
#  'Antenatal Bartter Syndrome Type 2',
#  'Type 4B Bartter Syndrome',
#  'Antenatal Bartter Syndrome Type 1',
#  'Congenital Adrenal Insufficiency with 46,XY Sex Reversal',
#  'Corticosterone Methyloxidase Type I Deficiency',
#  'A.I.D.S.',
#  'Peritoneal Dialysis',
#  'Hemodialysis',
#  'Hyperoxalemia',
#  'Adenylosuccinate Lyase Deficiency',
#  'Adult Onset Type II Citrullinemia',
#  'N Acetylglutamate Synthase Deficiency',
#  'Cerebral Vasospasm',
#  'Lathosterolosis',
#  'Lecithin:Cholesterol Acyltransferase Deficiency',
#  'Glucose 6 Phosphate Dehydrogenase Deficiency',
#  'Crigler Najjar Syndrome',
#  'Growth Hormone Deficiency',
#  'Dyserythropoietic Congenital Anemia Type II',
#  'GABA-Transaminase Deficiency',
#  'Glucose Transporter Type 1 Deficiency Syndrome',
#  'Succinyl Co A:3 Oxoacid Co A Transferase Deficiency',
#  'Stress',
#  'Functional Hypothalamic Amenorrhea',
#  'Benign Gynecological Diseases',
#  'Antley Bixler Syndrome With Genital Anomalies And Disordered Steroidogenesis',
#  'Isolated ACTH Deficiency',
#  'Apparent Mineralocorticoid Excess',
#  'Glucocorticoid Resistance',
#  'Aromatase Deficiency',
#  'Smith Lemli Opitz Syndrome',
#  'Peroxisomal Diogenesis Disorder',
#  'Pyridoxine Dependent Epilepsy',
#  'Aromatic L Amino Acid Decarboxylase Deficiency',
#  'Congenital Dopamine Beta-Hydroxylase Deficiency',
#  '21 Hydroxylase Deficiency',
#  'Beta Ureidopropionase Deficiency',
#  'Amish Type Microcephaly',
#  'Small Bowel Bacterial Overgrowth Syndrome',
#  'Ethanol Consumption',
#  'Glycolic Aciduria',
#  'D 2 Hydroxyglutaric Aciduria',
#  'Primary Hyperoxaluria Type I',
#  "Friedreich's Ataxia",
#  'Fructose 1,6 Bisphosphatase Deficiency',
#  'Familial Hyperinsulinemic Hypoglycemia',
#  'Acute Myelogenous Leukemia',
#  'Hyperammonemia due to Carbamoyl Phosphate Synthetase I Deficiency',
#  'Phosphoserine Aminotransferase Deficiency',
#  'Phosphoserine Phosphatase Deficiency',
#  'D Glyceric Acidemia',
#  'Glucoglycinuria',
#  'Alpha 1 Antitrypsin Deficiency',
#  'Intrahepatic Biliary Hypoplasia',
#  'Portal Vein Obstruction',
#  'Hepatobiliary Diseases',
#  'Glutaric Acidemia Type 2',
#  'Idiopathic Oro Facial Pain',
#  'Xanthinuria Type 1',
#  'Lesch Nyhan Syndrome',
#  'Bacterial Infections',
#  'Paraquat Poisoning',
#  'Pearson Marrow Pancreas Syndrome',
#  'Hyperprolinemia Type I',
#  'Dengue Fever',
#  'L 2 Hydroxyglutaric Aciduria',
#  'Adult Type Lactose Intolerance',
#  'Phosphoglycerate Dehydrogenase Deficiency',
#  'Type V 3-Methylglutaconic Aciduria',
#  'Coenzyme Q10 Deficiency',
#  'Cytochrome C Oxidase Deficiency',
#  'Leber Optic Atrophy And Dystonia',
#  'Leigh Syndrome',
#  'Mitochondrial Phosphate Carrier Deficiency',
#  'G.R.A.C.I.L.E. Syndrome',
#  'Hereditary Fructose Intolerance',
#  'Hereditary Myopathy With Lactic Acidosis',
#  'Acute Infantile Liver Failure',
#  'M.L.A.S.A.',
#  'Acute Seizures',
#  'cblB Deficiency Methylmalonic Aciduria',
#  'Malonyl Co A Decarboxylase Deficiency',
#  'cblA Deficiency Methylmalonic Aciduria',
#  'Ribose 5 Phosphate Isomerase Deficiency',
#  'Heat Stress',
#  'Alpha Aminoadipic Aciduria',
#  'Ornithine Transcarbamylase Deficiency',
#  'Sodium Nitrate Consumption',
#  'Brown Vialetto Van Laere Syndrome',
#  'Combined Pituitary Hormone Deficiency',
#  'Congenital Nongoitrous Hypothyroidism',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Argininemia',
#  'Aldosterone Biosynthesis Defects',
#  'Aldehyde Dehydrogenase Deficiency',
#  '2 Methylbutyryl Co A Dehydrogenase Deficiency',
#  '3-Methylglutaconic Aciduria Type I',
#  'Glutaryl Co A Dehydrogenase Deficiency (Gdhd)',
#  'Carnitine Acylcarnitine Translocase Deficiency',
#  'Segawa Syndrome',
#  'Aminoacylase I Deficiency',
#  'Rachialgia',
#  'Type 4A Bartter Syndrome',
#  'Type I Autosonal Dominant Pseudyhopoaldosteronism',
#  "Paget's Disease",
#  'Isobutyryl Co A Dehydrogenase Deficiency',
#  'Ethylmaonic Encephalopathy',
#  'Congenital Glutamine Defficiency',
#  'Iron Deficiency',
#  'Glycine N Methyltransferase Deficiency',
#  'Methionine Adenosyltransferase Deficiency',
#  'Carcinoid Tumors',
#  'Alpha Methylacyl Co A Racemase Deficiency',
#  'CNS Infections',
#  'Kynureninase Deficiency',
#  'Dermal Fibroproliferative Disorder',
#  'Acute Liver Disease',
#  'Smoking',
#  'Neuroborreliosis',
#  'Alcoholism',
#  'Sjogren Larsson Syndrome',
#  'Hypoxic Ischemic Encephalopathy',
#  'Tert Amyl Methyl Ether Exposed',
#  'D Bifunctional Protein Deficiency',
#  'Megaloblastic Anemia 1',
#  'Adrenomyeloneuropathy',
#  'Desmosterolosis',
#  'Prader Willi Syndrome',
#  'Cardiopulmonary Resuscitation',
#  'Coronary Heart Disease',
#  'Gamma Glutamyltransferase Deficiency',
#  'Prepartum Depression',
#  'Kidney Transplantation',
#  "Reye's Syndrome",
#  'Vertebral Osteoporosis']

# %%
def get_all_triples_for_iri(iri_to_check):
    sparql_query = f"""
    SELECT ?s ?p ?o
    WHERE {{
        {{ <{iri_to_check}> ?p ?o . }}
        UNION
        {{ ?s ?p <{iri_to_check}> . }}
    }}
    """
    
    # Execute the SPARQL query
    results = onto_graph.query(sparql_query)
    return list(results)

# %%
for result in get_all_triples_for_iri(URIRef("http://purl.obolibrary.org/obo/DOID_10591")):
    print(result)
# Out:
# (None, rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('pre-eclampsia', lang='en'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000115'), rdflib.term.Literal('A hypertension occurring during pregnancy characterized by large amounts of protein in the urine (proteinuria) and edema, usually by the last trimester of pregnancy.', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasAlternativeId'), rdflib.term.Literal('DOID:12684'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('ICD10CM:O14'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MESH:D011225'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MIM:189800'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MIM:609402'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MIM:609403'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MIM:609404'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('MIM:614592'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('NCI:C85021'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('ORDO:275555'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('SNOMEDCT_US_2023_03_01:6758009'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('UMLS_CUI:C0032914'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('gestational hypertension', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('hypertension induced by pregnancy', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('pre-eclamptic toxaemia', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('preeclampsia', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('preeclampsia/eclampsia', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('pregnancy associated hypertension', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('pregnancy toxemia', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('proteinuric hypertension of pregnancy', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'), rdflib.term.Literal('toxaemia of pregnancy', lang='en'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasOBONamespace'), rdflib.term.Literal('disease_ontology'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#id'), rdflib.term.Literal('DOID:10591'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#inSubset'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/doid#DO_rare_slim'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#inSubset'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/doid#NCIthesaurus'))
# (None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Xref MGI.\nOMIM mapping confirmed by DO. [SN].', lang='en'))
# (None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10763'))
# (None, rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100602'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10590'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), None)
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13129'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), None)
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13593'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), None)
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100602'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), None)
# (rdflib.term.BNode('nb0771658bf1348c387e48e927dfcc4e1b2443422'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#annotatedSource'), None)

# %%
unmatched_diseases_df = pd.DataFrame(unmatched_diseases, columns=['disease'])
unmatched_diseases_df['uri'] = ''

# %%
unmatched_diseases.to_csv(os.path.join(markerdb_folder, "diseases_to_match_manually.csv"))

# %% [markdown]
# $\rightarrow$ Manual matching

# %%
manually_matched_diseases = pd.read_csv(os.path.join(markerdb_folder, "manually_matched_diseases.csv"), sep=';')

# %%
matched_diseases_copy
# Out:
# {'Obesity': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9970'),
#    rdflib.term.Literal('obesity', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001513'),
#    rdflib.term.Literal('Obesity'))],
#  'Normal': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/PATO_0000461'),
#    rdflib.term.Literal('normal'))],
#  "Alzheimer's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10652'),
#    rdflib.term.Literal("Alzheimer's disease", lang='en'))],
#  'Chronic Kidney Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_784'),
#    rdflib.term.Literal('chronic kidney disease', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012622'),
#    rdflib.term.Literal('Chronic kidney disease'))],
#  'Leukemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001909'),
#    rdflib.term.Literal('Leukemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1240'),
#    rdflib.term.Literal('leukemia', lang='en'))],
#  'Prolactinoma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5394'),
#    rdflib.term.Literal('prolactinoma', lang='en'))],
#  'Fumarase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111261'),
#    rdflib.term.Literal('fumarase deficiency', lang='en'))],
#  'Meningitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031110'),
#    rdflib.term.Literal('meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0019173'),
#    rdflib.term.Literal('meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001287'),
#    rdflib.term.Literal('Meningitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9471'),
#    rdflib.term.Literal('meningitis', lang='en'))],
#  'Anoxia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0002316'),
#    rdflib.term.Literal('anoxia'))],
#  'Carnitine Palmitoyltransferase I Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090129'),
#    rdflib.term.Literal('carnitine palmitoyltransferase I deficiency', lang='en'))],
#  'Schizophrenia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100753'),
#    rdflib.term.Literal('Schizophrenia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5419'),
#    rdflib.term.Literal('schizophrenia', lang='en'))],
#  'Eosinophilic Esophagitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13922'),
#    rdflib.term.Literal('eosinophilic esophagitis', lang='en'))],
#  'Maple Syrup Urine Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9269'),
#    rdflib.term.Literal('maple syrup urine disease', lang='en'))],
#  'Phenylketonuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9281'),
#    rdflib.term.Literal('phenylketonuria', lang='en'))],
#  'Lung Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1324'),
#    rdflib.term.Literal('lung cancer', lang='en'))],
#  "Parkinson's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14330'),
#    rdflib.term.Literal("Parkinson's disease", lang='en'))],
#  'Myocardial Infarction': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001658'),
#    rdflib.term.Literal('Myocardial infarction')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5844'),
#    rdflib.term.Literal('myocardial infarction', lang='en'))],
#  'Carnosinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003167'),
#    rdflib.term.Literal('Carnosinuria'))],
#  'Lewy Body Dementia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12217'),
#    rdflib.term.Literal('Lewy body dementia', lang='en'))],
#  'Ulcerative Colitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8577'),
#    rdflib.term.Literal('ulcerative colitis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100279'),
#    rdflib.term.Literal('Ulcerative colitis'))],
#  'Irritable Bowel Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9778'),
#    rdflib.term.Literal('irritable bowel syndrome', lang='en'))],
#  "Crohn's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#    rdflib.term.Literal("Crohn's disease")),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8778'),
#    rdflib.term.Literal("Crohn's disease", lang='en'))],
#  'Propionic Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14701'),
#    rdflib.term.Literal('propionic acidemia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003571'),
#    rdflib.term.Literal('Propionic acidemia'))],
#  'Argininosuccinic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14755'),
#    rdflib.term.Literal('argininosuccinic aciduria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0025630'),
#    rdflib.term.Literal('Argininosuccinic aciduria'))],
#  'Sepsis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005044'),
#    rdflib.term.Literal('sepsis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100806'),
#    rdflib.term.Literal('Sepsis'))],
#  'Sulfite Oxidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003643'),
#    rdflib.term.Literal('Sulfite oxidase deficiency'))],
#  'Classic Citrullinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0070340'),
#    rdflib.term.Literal('classic citrullinemia', lang='en'))],
#  'Rheumatoid Arthritis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7148'),
#    rdflib.term.Literal('rheumatoid arthritis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0003561'),
#    rdflib.term.Literal('rheumatoid arthritis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001370'),
#    rdflib.term.Literal('Rheumatoid arthritis'))],
#  'Polycystic Ovary Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_11612'),
#    rdflib.term.Literal('polycystic ovary syndrome', lang='en'))],
#  'Congenital Adrenal Hyperplasia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050811'),
#    rdflib.term.Literal('congenital adrenal hyperplasia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0008258'),
#    rdflib.term.Literal('Congenital adrenal hyperplasia'))],
#  'Donohue Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050470'),
#    rdflib.term.Literal('Donohue syndrome', lang='en'))],
#  'Congenital Bile Acid Synthesis Defect': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050674'),
#    rdflib.term.Literal('congenital bile acid synthesis defect', lang='en'))],
#  'Progressive Familial Intrahepatic Cholestasis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0070221'),
#    rdflib.term.Literal('progressive familial intrahepatic cholestasis', lang='en'))],
#  'Dihydropyrimidinase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111629'),
#    rdflib.term.Literal('dihydropyrimidinase deficiency', lang='en'))],
#  'Ketosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0030970'),
#    rdflib.term.Literal('ketosis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001946'),
#    rdflib.term.Literal('Ketosis'))],
#  'Oculocerebrorenal Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1056'),
#    rdflib.term.Literal('oculocerebrorenal syndrome', lang='en'))],
#  'Proprotein Convertase 1/3 Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111698'),
#    rdflib.term.Literal('proprotein convertase 1/3 deficiency', lang='en'))],
#  'Rhabdomyolysis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031112'),
#    rdflib.term.Literal('rhabdomyolysis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003201'),
#    rdflib.term.Literal('Rhabdomyolysis'))],
#  'Uremia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4676'),
#    rdflib.term.Literal('uremia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0009644'),
#    rdflib.term.Literal('uremia'))],
#  'Hypercholesterolemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003124'),
#    rdflib.term.Literal('Hypercholesterolemia'))],
#  "Addison's Disease": [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13774'),
#    rdflib.term.Literal("Addison's disease", lang='en'))],
#  'Zellweger Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_905'),
#    rdflib.term.Literal('Zellweger syndrome', lang='en'))],
#  'Adrenoleukodystrophy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10588'),
#    rdflib.term.Literal('adrenoleukodystrophy', lang='en'))],
#  'Anemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCBITaxon_12939'),
#    rdflib.term.Literal('Anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001903'),
#    rdflib.term.Literal('Anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0001577'),
#    rdflib.term.Literal('anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000208'),
#    rdflib.term.Literal('anemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2355'),
#    rdflib.term.Literal('anemia', lang='en'))],
#  'Refsum Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10582'),
#    rdflib.term.Literal('Refsum disease', lang='en'))],
#  'Infantile Refsum Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050444'),
#    rdflib.term.Literal('infantile Refsum disease', lang='en'))],
#  'Purine Nucleoside Phosphorylase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5813'),
#    rdflib.term.Literal('purine nucleoside phosphorylase deficiency', lang='en'))],
#  'Vitiligo': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12306'),
#    rdflib.term.Literal('vitiligo', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001045'),
#    rdflib.term.Literal('Vitiligo'))],
#  'Hypothyroidism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1459'),
#    rdflib.term.Literal('hypothyroidism', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000821'),
#    rdflib.term.Literal('Hypothyroidism'))],
#  'Encephalitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000090'),
#    rdflib.term.Literal('encephalitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9588'),
#    rdflib.term.Literal('encephalitis', lang='en'))],
#  'Canavan Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3613'),
#    rdflib.term.Literal('Canavan disease', lang='en'))],
#  'Spina Bifida': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0003054'),
#    rdflib.term.Literal('spina bifida')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080016'),
#    rdflib.term.Literal('spina bifida', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002414'),
#    rdflib.term.Literal('Spina bifida'))],
#  'Cystathioninuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090142'),
#    rdflib.term.Literal('cystathioninuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003153'),
#    rdflib.term.Literal('Cystathioninuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0030689'),
#    rdflib.term.Literal('cystathioninuria'))],
#  'Adenosine Deaminase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_5810'),
#    rdflib.term.Literal('adenosine deaminase deficiency', lang='en'))],
#  'Epilepsy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1826'),
#    rdflib.term.Literal('epilepsy', lang='en'))],
#  'Febrile Seizures': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0012011'),
#    rdflib.term.Literal('febrile seizures'))],
#  'Hepatic Encephalopathy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13413'),
#    rdflib.term.Literal('hepatic encephalopathy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002480'),
#    rdflib.term.Literal('Hepatic encephalopathy'))],
#  'Brunner Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060693'),
#    rdflib.term.Literal('Brunner Syndrome', lang='en'))],
#  'Celiac Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10608'),
#    rdflib.term.Literal('celiac disease', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002608'),
#    rdflib.term.Literal('Celiac disease'))],
#  'Urocanase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112180'),
#    rdflib.term.Literal('urocanase deficiency', lang='en'))],
#  'Sepiapterin Reductase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111168'),
#    rdflib.term.Literal('sepiapterin reductase deficiency', lang='en'))],
#  'Hereditary Folate Malabsorption': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111678'),
#    rdflib.term.Literal('hereditary folate malabsorption', lang='en'))],
#  'Fanconi Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1062'),
#    rdflib.term.Literal('Fanconi syndrome', lang='en'))],
#  'Lipodystrophy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0011174'),
#    rdflib.term.Literal('lipodystrophy')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_811'),
#    rdflib.term.Literal('lipodystrophy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0009125'),
#    rdflib.term.Literal('Lipodystrophy'))],
#  'Autosomal Dominant Polycystic Kidney Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_898'),
#    rdflib.term.Literal('autosomal dominant polycystic kidney disease', lang='en'))],
#  'Multiple Sclerosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2377'),
#    rdflib.term.Literal('multiple sclerosis', lang='en'))],
#  'Alkaptonuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9270'),
#    rdflib.term.Literal('alkaptonuria', lang='en'))],
#  'Glycogen Storage Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2747'),
#    rdflib.term.Literal('glycogen storage disease', lang='en'))],
#  'Chronic Active Hepatitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0200120'),
#    rdflib.term.Literal('Chronic active hepatitis'))],
#  'Heart Failure': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000292'),
#    rdflib.term.Literal('heart failure'))],
#  'X-Linked Ichthyosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1700'),
#    rdflib.term.Literal('X-linked ichthyosis', lang='en'))],
#  'Phosphoribosylpyrophosphate Synthetase Superactivity': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111260'),
#    rdflib.term.Literal('phosphoribosylpyrophosphate synthetase superactivity', lang='en'))],
#  'Hydrocephalus': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000051'),
#    rdflib.term.Literal('hydrocephalus')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10908'),
#    rdflib.term.Literal('hydrocephalus', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000238'),
#    rdflib.term.Literal('Hydrocephalus'))],
#  'Hawkinsinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0034457'),
#    rdflib.term.Literal('Hawkinsinuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111362'),
#    rdflib.term.Literal('hawkinsinuria', lang='en'))],
#  'Hyperphenylalaninemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0004923'),
#    rdflib.term.Literal('Hyperphenylalaninemia'))],
#  'Iminoglycinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112265'),
#    rdflib.term.Literal('iminoglycinuria', lang='en'))],
#  'Glutathione Synthetase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080699'),
#    rdflib.term.Literal('glutathione synthetase deficiency', lang='en'))],
#  'Histidinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060168'),
#    rdflib.term.Literal('histidinemia', lang='en'))],
#  'Cystinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9266'),
#    rdflib.term.Literal('cystinuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0020400'),
#    rdflib.term.Literal('cystinuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003131'),
#    rdflib.term.Literal('Cystinuria'))],
#  'Lysinuric Protein Intolerance': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060439'),
#    rdflib.term.Literal('lysinuric protein intolerance', lang='en'))],
#  'Cirrhosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001394'),
#    rdflib.term.Literal('Cirrhosis'))],
#  'Molybdenum Cofactor Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003570'),
#    rdflib.term.Literal('Molybdenum cofactor deficiency')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111165'),
#    rdflib.term.Literal('molybdenum cofactor deficiency', lang='en'))],
#  'Transcobalamin Ii Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050818'),
#    rdflib.term.Literal('transcobalamin II deficiency', lang='en'))],
#  'Subarachnoid Hemorrhage': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002138'),
#    rdflib.term.Literal('Subarachnoid hemorrhage')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0031109'),
#    rdflib.term.Literal('subarachnoid hemorrhage'))],
#  'Orotic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050833'),
#    rdflib.term.Literal('orotic aciduria', lang='en'))],
#  'Mevalonic Aciduria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050452'),
#    rdflib.term.Literal('mevalonic aciduria', lang='en'))],
#  'Amyotrophic Lateral Sclerosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0007354'),
#    rdflib.term.Literal('Amyotrophic lateral sclerosis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_332'),
#    rdflib.term.Literal('amyotrophic lateral sclerosis', lang='en'))],
#  'Hepatic Coma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12550'),
#    rdflib.term.Literal('hepatic coma', lang='en'))],
#  'Methylmalonic Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002912'),
#    rdflib.term.Literal('Methylmalonic acidemia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14749'),
#    rdflib.term.Literal('methylmalonic acidemia', lang='en'))],
#  'Sickle Cell Anemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10923'),
#    rdflib.term.Literal('sickle cell anemia', lang='en'))],
#  'Porphyria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005654'),
#    rdflib.term.Literal('porphyria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_13268'),
#    rdflib.term.Literal('porphyria', lang='en'))],
#  'Pendred Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060744'),
#    rdflib.term.Literal('Pendred Syndrome', lang='en'))],
#  'Sarcosinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0112307'),
#    rdflib.term.Literal('sarcosinemia', lang='en'))],
#  'Cachexia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005150'),
#    rdflib.term.Literal('cachexia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000402'),
#    rdflib.term.Literal('cachexia')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0004326'),
#    rdflib.term.Literal('Cachexia'))],
#  'Degenerative Disc Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_90'),
#    rdflib.term.Literal('degenerative disc disease', lang='en'))],
#  'Endometrial Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1380'),
#    rdflib.term.Literal('endometrial cancer', lang='en'))],
#  'Menkes Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1838'),
#    rdflib.term.Literal('Menkes disease', lang='en'))],
#  'Biotinidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_856'),
#    rdflib.term.Literal('biotinidase deficiency', lang='en'))],
#  'Ovarian Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2394'),
#    rdflib.term.Literal('ovarian cancer', lang='en'))],
#  'Aspartylglucosaminuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050461'),
#    rdflib.term.Literal('aspartylglucosaminuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0011516'),
#    rdflib.term.Literal('aspartylglucosaminuria')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012068'),
#    rdflib.term.Literal('Aspartylglucosaminuria'))],
#  'Familial Mediterranean Fever': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2987'),
#    rdflib.term.Literal('familial Mediterranean fever', lang='en'))],
#  'Cystic Fibrosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1485'),
#    rdflib.term.Literal('cystic fibrosis', lang='en'))],
#  'Prostate Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012125'),
#    rdflib.term.Literal('Prostate cancer')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10283'),
#    rdflib.term.Literal('prostate cancer', lang='en'))],
#  'Stroke': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0001297'),
#    rdflib.term.Literal('Stroke'))],
#  'Liver Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_409'),
#    rdflib.term.Literal('liver disease', lang='en'))],
#  'Peripheral Neuropathy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0009830'),
#    rdflib.term.Literal('Peripheral neuropathy'))],
#  'Hyperthyroidism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_7998'),
#    rdflib.term.Literal('hyperthyroidism', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000836'),
#    rdflib.term.Literal('Hyperthyroidism'))],
#  'Vitamin B12 Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0050731'),
#    rdflib.term.Literal('vitamin B12 deficiency', lang='en'))],
#  'Glutaric Acidemia I': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111254'),
#    rdflib.term.Literal('glutaric acidemia I', lang='en'))],
#  'Isovaleric Acidemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_14753'),
#    rdflib.term.Literal('isovaleric acidemia', lang='en'))],
#  'Homocystinuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_9263'),
#    rdflib.term.Literal('homocystinuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002156'),
#    rdflib.term.Literal('Homocystinuria'))],
#  'Pellagra': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8457'),
#    rdflib.term.Literal('pellagra', lang='en'))],
#  'Succinic Semialdehyde Dehydrogenase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0060175'),
#    rdflib.term.Literal('succinic semialdehyde dehydrogenase deficiency', lang='en'))],
#  'Malaria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12365'),
#    rdflib.term.Literal('malaria', lang='en'))],
#  'Prolidase Deficiency': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111540'),
#    rdflib.term.Literal('prolidase deficiency', lang='en'))],
#  'Bipolar Disorder': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/NBO_0000258'),
#    rdflib.term.Literal('bipolar disorder')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3312'),
#    rdflib.term.Literal('bipolar disorder', lang='en'))],
#  'Rhizomelic Chondrodysplasia Punctata': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2580'),
#    rdflib.term.Literal('rhizomelic chondrodysplasia punctata', lang='en'))],
#  'Hypertension': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0000231'),
#    rdflib.term.Literal('hypertension')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10763'),
#    rdflib.term.Literal('hypertension', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000822'),
#    rdflib.term.Literal('Hypertension'))],
#  'Sitosterolemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090019'),
#    rdflib.term.Literal('sitosterolemia', lang='en'))],
#  'Nephrotic Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1184'),
#    rdflib.term.Literal('nephrotic syndrome', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000100'),
#    rdflib.term.Literal('Nephrotic syndrome'))],
#  'Mastocytosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_350'),
#    rdflib.term.Literal('mastocytosis', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100495'),
#    rdflib.term.Literal('Mastocytosis'))],
#  'Trimethylaminuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080361'),
#    rdflib.term.Literal('trimethylaminuria', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0003614'),
#    rdflib.term.Literal('Trimethylaminuria'))],
#  'Beta Thalassemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_12241'),
#    rdflib.term.Literal('beta thalassemia', lang='en'))],
#  'Cerebrotendinous Xanthomatosis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4810'),
#    rdflib.term.Literal('cerebrotendinous xanthomatosis', lang='en'))],
#  'Eczema': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/SYMP_0000289'),
#    rdflib.term.Literal('eczema'))],
#  'Breast Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1612'),
#    rdflib.term.Literal('breast cancer', lang='en'))],
#  'Rett Syndrome': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1206'),
#    rdflib.term.Literal('Rett syndrome', lang='en'))],
#  'Pancreatic Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1793'),
#    rdflib.term.Literal('pancreatic cancer', lang='en'))],
#  'Mild Cognitive Impairment': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0080832'),
#    rdflib.term.Literal('mild cognitive impairment', lang='en'))],
#  'Pentosuria': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0111258'),
#    rdflib.term.Literal('pentosuria', lang='en'))],
#  'Asthma': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0002099'),
#    rdflib.term.Literal('Asthma')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_2841'),
#    rdflib.term.Literal('asthma', lang='en'))],
#  'Abetalipoproteinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1386'),
#    rdflib.term.Literal('abetalipoproteinemia', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0008181'),
#    rdflib.term.Literal('Abetalipoproteinemia'))],
#  'Familial Isolated Deficiency of Vitamin E': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_0090028'),
#    rdflib.term.Literal('familial isolated deficiency of vitamin E', lang='en'))],
#  'Narcolepsy': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8986'),
#    rdflib.term.Literal('narcolepsy', lang='en')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0005279'),
#    rdflib.term.Literal('narcolepsy')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0030050'),
#    rdflib.term.Literal('Narcolepsy'))],
#  'Motor Neuron Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_231'),
#    rdflib.term.Literal('motor neuron disease', lang='en'))],
#  'Autism': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000717'),
#    rdflib.term.Literal('Autism'))],
#  'Cervical Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4362'),
#    rdflib.term.Literal('cervical cancer', lang='en'))],
#  'Stomach Cancer': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012126'),
#    rdflib.term.Literal('Stomach cancer')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_10534'),
#    rdflib.term.Literal('stomach cancer', lang='en'))],
#  'Macular Degeneration': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0000608'),
#    rdflib.term.Literal('Macular degeneration')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4448'),
#    rdflib.term.Literal('macular degeneration', lang='en'))],
#  'Angina': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0006112'),
#    rdflib.term.Literal('angina'))],
#  'Coronary Artery Disease': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_3393'),
#    rdflib.term.Literal('coronary artery disease', lang='en'))],
#  'Hypobetalipoproteinemia': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_1390'),
#    rdflib.term.Literal('hypobetalipoproteinemia', lang='en'))],
#  'Rhinitis': [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/MP_0001867'),
#    rdflib.term.Literal('rhinitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0012384'),
#    rdflib.term.Literal('Rhinitis')),
#   (rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_4483'),
#    rdflib.term.Literal('rhinitis', lang='en'))]}

# %%
multiple_matches_count = 0

matched_diseases_cleaned = []

for disease, matches in matched_diseases_copy.items():
    if len(matches) > 1:
        multiple_matches_count += 1
        found_doid_term = False
        found_hp_term = False
        for match in matches:
            match_uri = match[0]
            if 'DOID'  in match_uri:
                found_doid_term = match_uri
            if 'HP_' in match_uri:
                found_hp_term = match_uri
        
        if found_doid_term:
            matched_diseases_cleaned.append([disease, found_doid_term])
        elif found_hp_term:
            matched_diseases_cleaned.append([disease, found_hp_term])
    else:
        matched_diseases_cleaned.append([disease, matches[0][0]])
        
multiple_matches_count
# Out:
# 49

# %%
matched_diseases_cleaned_df = pd.DataFrame(matched_diseases_cleaned, columns=['disease', 'uri'])

# %%
manually_matched_diseases = manually_matched_diseases[manually_matched_diseases.uri.notna()]

# %%
matched_disease_uris = pd.concat([matched_diseases_cleaned_df, manually_matched_diseases])

# %%
chemical_references_with_uri = pd.merge(chemical_references, matched_disease_uris, left_on='condition', right_on='disease', how='inner')

# %%
chemical_references_with_uri
# Out:
#       markerdb_id      name_markerdb  condition_id               condition  \
# 0               1  1-Methylhistidine           251                 Obesity
# 1               1  1-Methylhistidine             1                  Normal
# 2               1  1-Methylhistidine            33     Alzheimer's Disease
# 3               1  1-Methylhistidine             1                  Normal
# 4               1  1-Methylhistidine          5988  Preeclampsia/Eclampsia
# ...           ...                ...           ...                     ...
# 3094         5017          Triclosan             1                  Normal
# 3095         5017          Triclosan             1                  Normal
# 3096         5017          Triclosan             1                  Normal
# 3097         5017          Triclosan             1                  Normal
# 3098         5017          Triclosan             1                  Normal
#
#                    cohort     sex sample_type  \
# 0     Adult: >=18 yrs old    Both       Urine
# 1     Adult: >=18 yrs old    Both       Urine
# 2     Adult: >=18 yrs old    Both       Urine
# 3     Adult: >=18 yrs old    Both       Blood
# 4     Adult: >=18 yrs old  Female       Blood
# ...                   ...     ...         ...
# 3094                  All    Both       Urine
# 3095                  All    Both       Urine
# 3096                  All    Both       Urine
# 3097                  All    Both       Urine
# 3098                  All    Both       Urine
#
#                                     concentration                  unit notes  \
# 0           10.9 (0.80-21.0) umol/mmol creatinine  umol/mmol creatinine   NaN
# 1          85.8 (17.7-153.8) umol/mmol creatinine  umol/mmol creatinine   NaN
# 2           15.7 (11.7-19.7) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3                                         12.7 uM                    uM   NaN
# 4                                         50.7 uM                    uM   NaN
# ...                                           ...                   ...   ...
# 3094  0.0070 (0.0063-0.0079) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3095  0.0061 (0.0054-0.0068) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3096  0.0059 (0.0052-0.0068) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3097  0.0052 (0.0046-0.0059) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3098  0.0038 (0.0035-0.0042) umol/mmol creatinine  umol/mmol creatinine   NaN
#
#       reference_id                                     reference_name  \
# 0              654  Tuma, P., Samcova, E. & Balinova, P. Determina...
# 1           367200  David F. Putnam Composition and Concentrative ...
# 2              129  Fonteh, A. N., Harrington, R. J., Tsai, A., Li...
# 3           116748  Dohm, G. L., Williams, R. T., Kasperek, G. J. ...
# 4           367357                                                NaN
# ...            ...                                                ...
# 3094        367558  National Health and Nutrition Examination Surv...
# 3095        367558  National Health and Nutrition Examination Surv...
# 3096        367558  National Health and Nutrition Examination Surv...
# 3097        367558  National Health and Nutrition Examination Surv...
# 3098        367558  National Health and Nutrition Examination Surv...
#
#        pubmed_id                 disease  \
# 0     15899597.0                 Obesity
# 1            NaN                  Normal
# 2     17031479.0     Alzheimer's Disease
# 3      7061274.0                  Normal
# 4     22494326.0  Preeclampsia/Eclampsia
# ...          ...                     ...
# 3094         NaN                  Normal
# 3095         NaN                  Normal
# 3096         NaN                  Normal
# 3097         NaN                  Normal
# 3098         NaN                  Normal
#
#                                               uri
# 0        http://purl.obolibrary.org/obo/DOID_9970
# 1     http://purl.obolibrary.org/obo/PATO_0000461
# 2       http://purl.obolibrary.org/obo/DOID_10652
# 3     http://purl.obolibrary.org/obo/PATO_0000461
# 4       http://purl.obolibrary.org/obo/DOID_10591
# ...                                           ...
# 3094  http://purl.obolibrary.org/obo/PATO_0000461
# 3095  http://purl.obolibrary.org/obo/PATO_0000461
# 3096  http://purl.obolibrary.org/obo/PATO_0000461
# 3097  http://purl.obolibrary.org/obo/PATO_0000461
# 3098  http://purl.obolibrary.org/obo/PATO_0000461
#
# [3099 rows x 15 columns]

# %%
compound_identifiers = pd.read_csv(os.path.join(processed_data_folder, "compounds_all_databases_merged_ids.csv"), dtype={'markerdb_id': 'string', 'kegg_id': 'string', 'vmh_id': 'string'})
compound_identifiers = compound_identifiers[compound_identifiers.markerdb_id.notna()]

# %%
compound_identifiers
# Out:
#         Unnamed: 0     menuguide_id                      name      hmdb_id  \
# 13              13      compound_14               cortexolone  HMDB0000015
# 33              33      compound_34                   12-hete  HMDB0006111
# 46              46      compound_47          propylene glycol  HMDB0001881
# 76              76      compound_77    17-hydroxyprogesterone  HMDB0000374
# 110            110     compound_111      1-methylnicotinamide  HMDB0000699
# ...            ...              ...                       ...          ...
# 403982      403982  compound_403983              22:1-18:3-pc  HMDB0008567
# 404070      404070  compound_404071   17a-hydroxypregnenolone  HMDB0000363
# 404192      404192  compound_404193            norepinephrine  HMDB0000216
# 404256      404256  compound_404257               acetic acid  HMDB0000042
# 404768      404768  compound_404769  18-hydroxycorticosterone  HMDB0000319
#
#          foodb_id  chebi_id  markerdb_id kegg_id  exposome_explorer_id  \
# 13      FDB021872   86600.0  MDB00000009  C05488                   NaN
# 33      FDB001435   19138.0  MDB00001296  C14777                   NaN
# 46      FDB008274   28972.0  MDB00000688  C02912                   NaN
# 76      FDB021992   17252.0  MDB00000222  C01176                   NaN
# 110     FDB022188   16797.0  MDB00000374  C02918                   NaN
# ...           ...       ...          ...     ...                   ...
# 403982  FDB025757  191356.0  MDB00002859    <NA>                   NaN
# 404070  FDB030278   28750.0  MDB00000219  C05138                   NaN
# 404192  FDB097324   18357.0  MDB00000136  C00547                2076.0
# 404256  FDB019725   15366.0  MDB00000029  C00033                1819.0
# 404768  FDB021945   16485.0  MDB00000199  C01124                   NaN
#
#               vmh_id  foodb_id_internal
# 13         11docrtsl            22035.0
# 33         12harachd             1435.0
# 46           12ppd_r             8275.0
# 76       17ahprgstrn            22155.0
# 110           1mncam            22351.0
# ...              ...                ...
# 403982          <NA>            25920.0
# 404070  17ahprgnlone            30441.0
# 404192        nrpphr           125156.0
# 404256            ac            19732.0
# 404768        m00429            22108.0
#
# [878 rows x 11 columns]

# %%
chemical_references_with_uri
# Out:
#       markerdb_id      name_markerdb  condition_id               condition  \
# 0               1  1-Methylhistidine           251                 Obesity
# 1               1  1-Methylhistidine             1                  Normal
# 2               1  1-Methylhistidine            33     Alzheimer's Disease
# 3               1  1-Methylhistidine             1                  Normal
# 4               1  1-Methylhistidine          5988  Preeclampsia/Eclampsia
# ...           ...                ...           ...                     ...
# 3094         5017          Triclosan             1                  Normal
# 3095         5017          Triclosan             1                  Normal
# 3096         5017          Triclosan             1                  Normal
# 3097         5017          Triclosan             1                  Normal
# 3098         5017          Triclosan             1                  Normal
#
#                    cohort     sex sample_type  \
# 0     Adult: >=18 yrs old    Both       Urine
# 1     Adult: >=18 yrs old    Both       Urine
# 2     Adult: >=18 yrs old    Both       Urine
# 3     Adult: >=18 yrs old    Both       Blood
# 4     Adult: >=18 yrs old  Female       Blood
# ...                   ...     ...         ...
# 3094                  All    Both       Urine
# 3095                  All    Both       Urine
# 3096                  All    Both       Urine
# 3097                  All    Both       Urine
# 3098                  All    Both       Urine
#
#                                     concentration                  unit notes  \
# 0           10.9 (0.80-21.0) umol/mmol creatinine  umol/mmol creatinine   NaN
# 1          85.8 (17.7-153.8) umol/mmol creatinine  umol/mmol creatinine   NaN
# 2           15.7 (11.7-19.7) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3                                         12.7 uM                    uM   NaN
# 4                                         50.7 uM                    uM   NaN
# ...                                           ...                   ...   ...
# 3094  0.0070 (0.0063-0.0079) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3095  0.0061 (0.0054-0.0068) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3096  0.0059 (0.0052-0.0068) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3097  0.0052 (0.0046-0.0059) umol/mmol creatinine  umol/mmol creatinine   NaN
# 3098  0.0038 (0.0035-0.0042) umol/mmol creatinine  umol/mmol creatinine   NaN
#
#       reference_id                                     reference_name  \
# 0              654  Tuma, P., Samcova, E. & Balinova, P. Determina...
# 1           367200  David F. Putnam Composition and Concentrative ...
# 2              129  Fonteh, A. N., Harrington, R. J., Tsai, A., Li...
# 3           116748  Dohm, G. L., Williams, R. T., Kasperek, G. J. ...
# 4           367357                                                NaN
# ...            ...                                                ...
# 3094        367558  National Health and Nutrition Examination Surv...
# 3095        367558  National Health and Nutrition Examination Surv...
# 3096        367558  National Health and Nutrition Examination Surv...
# 3097        367558  National Health and Nutrition Examination Surv...
# 3098        367558  National Health and Nutrition Examination Surv...
#
#        pubmed_id                 disease  \
# 0     15899597.0                 Obesity
# 1            NaN                  Normal
# 2     17031479.0     Alzheimer's Disease
# 3      7061274.0                  Normal
# 4     22494326.0  Preeclampsia/Eclampsia
# ...          ...                     ...
# 3094         NaN                  Normal
# 3095         NaN                  Normal
# 3096         NaN                  Normal
# 3097         NaN                  Normal
# 3098         NaN                  Normal
#
#                                               uri
# 0        http://purl.obolibrary.org/obo/DOID_9970
# 1     http://purl.obolibrary.org/obo/PATO_0000461
# 2       http://purl.obolibrary.org/obo/DOID_10652
# 3     http://purl.obolibrary.org/obo/PATO_0000461
# 4       http://purl.obolibrary.org/obo/DOID_10591
# ...                                           ...
# 3094  http://purl.obolibrary.org/obo/PATO_0000461
# 3095  http://purl.obolibrary.org/obo/PATO_0000461
# 3096  http://purl.obolibrary.org/obo/PATO_0000461
# 3097  http://purl.obolibrary.org/obo/PATO_0000461
# 3098  http://purl.obolibrary.org/obo/PATO_0000461
#
# [3099 rows x 15 columns]

# %%
markerdb_id_len = 8
markerdb_id_initials = "MDB"

def format_markerdb_id(markerdb_id):
    markerdb_id = str(markerdb_id)
    number_count = len(markerdb_id)
    
    markerdb_id_formatted = f"{markerdb_id_initials}{'0'*(markerdb_id_len-number_count)}{markerdb_id}"
    return markerdb_id_formatted

chemical_references_with_uri.loc[:, 'markerdb_id'] = chemical_references_with_uri.markerdb_id.apply(format_markerdb_id)
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_12306/3235644950.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['MDB00000001' 'MDB00000001' 'MDB00000001' ... 'MDB00005017' 'MDB00005017'
#  'MDB00005017']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   chemical_references_with_uri.loc[:, 'markerdb_id'] = chemical_references_with_uri.markerdb_id.apply(format_markerdb_id)

# %%
measurements_with_ids = pd.merge(chemical_references_with_uri, compound_identifiers, on='markerdb_id', how='inner')

# %%
measurements_with_ids = measurements_with_ids[['menuguide_id', 'uri', 'cohort', 'sample_type', 'sex', 'concentration', 'unit', 'reference_name', 'pubmed_id']]
measurements_with_ids
# Out:
#        menuguide_id                                          uri  \
# 0     compound_6317     http://purl.obolibrary.org/obo/DOID_9970
# 1     compound_6317  http://purl.obolibrary.org/obo/PATO_0000461
# 2     compound_6317    http://purl.obolibrary.org/obo/DOID_10652
# 3     compound_6317  http://purl.obolibrary.org/obo/PATO_0000461
# 4     compound_6317    http://purl.obolibrary.org/obo/DOID_10591
# ...             ...                                          ...
# 2982  compound_5681     http://purl.obolibrary.org/obo/DOID_9970
# 2983  compound_5681  http://purl.obolibrary.org/obo/PATO_0000461
# 2984  compound_5680     http://purl.obolibrary.org/obo/DOID_9970
# 2985  compound_5680  http://purl.obolibrary.org/obo/PATO_0000461
# 2986  compound_5680  http://purl.obolibrary.org/obo/PATO_0000461
#
#                         cohort sample_type     sex  \
# 0          Adult: >=18 yrs old       Urine    Both
# 1          Adult: >=18 yrs old       Urine    Both
# 2          Adult: >=18 yrs old       Urine    Both
# 3          Adult: >=18 yrs old       Blood    Both
# 4          Adult: >=18 yrs old       Blood  Female
# ...                        ...         ...     ...
# 2982  Adolescent:13-18 yrs old       Urine    Both
# 2983  Adolescent:13-18 yrs old       Urine    Both
# 2984  Adolescent:13-18 yrs old       Urine    Both
# 2985       Adult: >=18 yrs old       Urine    Both
# 2986       Adult: >=18 yrs old       Blood    Both
#
#                                      concentration                  unit  \
# 0            10.9 (0.80-21.0) umol/mmol creatinine  umol/mmol creatinine
# 1           85.8 (17.7-153.8) umol/mmol creatinine  umol/mmol creatinine
# 2            15.7 (11.7-19.7) umol/mmol creatinine  umol/mmol creatinine
# 3                                          12.7 uM                    uM
# 4                                          50.7 uM                    uM
# ...                                            ...                   ...
# 2982         0.36 (0.32-0.40) umol/mmol creatinine  umol/mmol creatinine
# 2983         0.23 (0.20-0.26) umol/mmol creatinine  umol/mmol creatinine
# 2984            2.2 (2.1-2.3) umol/mmol creatinine  umol/mmol creatinine
# 2985  0.0023 (0.00090-0.0058) umol/mmol creatinine  umol/mmol creatinine
# 2986                                       15.4 uM                    uM
#
#                                          reference_name   pubmed_id
# 0     Tuma, P., Samcova, E. & Balinova, P. Determina...  15899597.0
# 1     David F. Putnam Composition and Concentrative ...         NaN
# 2     Fonteh, A. N., Harrington, R. J., Tsai, A., Li...  17031479.0
# 3     Dohm, G. L., Williams, R. T., Kasperek, G. J. ...   7061274.0
# 4                                                   NaN  22494326.0
# ...                                                 ...         ...
# 2982                                                NaN  26910390.0
# 2983                                                NaN  26910390.0
# 2984                                                NaN  26910390.0
# 2985                                                NaN  24023812.0
# 2986                                      Molecular You         NaN
#
# [2987 rows x 9 columns]

# %%
measurements_with_ids = measurements_with_ids.reset_index(drop=True)
measurements_with_ids = measurements_with_ids.reset_index(names='menuguide_measurement_id')
measurements_with_ids
# Out:
#       menuguide_measurement_id   menuguide_id  \
# 0                            0  compound_6317
# 1                            1  compound_6317
# 2                            2  compound_6317
# 3                            3  compound_6317
# 4                            4  compound_6317
# ...                        ...            ...
# 2982                      2982  compound_5681
# 2983                      2983  compound_5681
# 2984                      2984  compound_5680
# 2985                      2985  compound_5680
# 2986                      2986  compound_5680
#
#                                               uri                    cohort  \
# 0        http://purl.obolibrary.org/obo/DOID_9970       Adult: >=18 yrs old
# 1     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2       http://purl.obolibrary.org/obo/DOID_10652       Adult: >=18 yrs old
# 3     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 4       http://purl.obolibrary.org/obo/DOID_10591       Adult: >=18 yrs old
# ...                                           ...                       ...
# 2982     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2983  http://purl.obolibrary.org/obo/PATO_0000461  Adolescent:13-18 yrs old
# 2984     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2985  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2986  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
#
#      sample_type     sex                                 concentration  \
# 0          Urine    Both         10.9 (0.80-21.0) umol/mmol creatinine
# 1          Urine    Both        85.8 (17.7-153.8) umol/mmol creatinine
# 2          Urine    Both         15.7 (11.7-19.7) umol/mmol creatinine
# 3          Blood    Both                                       12.7 uM
# 4          Blood  Female                                       50.7 uM
# ...          ...     ...                                           ...
# 2982       Urine    Both         0.36 (0.32-0.40) umol/mmol creatinine
# 2983       Urine    Both         0.23 (0.20-0.26) umol/mmol creatinine
# 2984       Urine    Both            2.2 (2.1-2.3) umol/mmol creatinine
# 2985       Urine    Both  0.0023 (0.00090-0.0058) umol/mmol creatinine
# 2986       Blood    Both                                       15.4 uM
#
#                       unit                                     reference_name  \
# 0     umol/mmol creatinine  Tuma, P., Samcova, E. & Balinova, P. Determina...
# 1     umol/mmol creatinine  David F. Putnam Composition and Concentrative ...
# 2     umol/mmol creatinine  Fonteh, A. N., Harrington, R. J., Tsai, A., Li...
# 3                       uM  Dohm, G. L., Williams, R. T., Kasperek, G. J. ...
# 4                       uM                                                NaN
# ...                    ...                                                ...
# 2982  umol/mmol creatinine                                                NaN
# 2983  umol/mmol creatinine                                                NaN
# 2984  umol/mmol creatinine                                                NaN
# 2985  umol/mmol creatinine                                                NaN
# 2986                    uM                                      Molecular You
#
#        pubmed_id
# 0     15899597.0
# 1            NaN
# 2     17031479.0
# 3      7061274.0
# 4     22494326.0
# ...          ...
# 2982  26910390.0
# 2983  26910390.0
# 2984  26910390.0
# 2985  24023812.0
# 2986         NaN
#
# [2987 rows x 10 columns]

# %%
measurements_with_ids.loc[:, 'menuguide_measurement_id'] = measurements_with_ids.menuguide_measurement_id.apply(lambda x: f"measurement_{x}")
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_12306/4259413560.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['measurement_0' 'measurement_1' 'measurement_2' ... 'measurement_2984'
#  'measurement_2985' 'measurement_2986']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   measurements_with_ids.loc[:, 'menuguide_measurement_id'] = measurements_with_ids.menuguide_measurement_id.apply(lambda x: f"measurement_{x}")

# %%
measurements_with_ids
# Out:
#      menuguide_measurement_id   menuguide_id  \
# 0               measurement_0  compound_6317
# 1               measurement_1  compound_6317
# 2               measurement_2  compound_6317
# 3               measurement_3  compound_6317
# 4               measurement_4  compound_6317
# ...                       ...            ...
# 2982         measurement_2982  compound_5681
# 2983         measurement_2983  compound_5681
# 2984         measurement_2984  compound_5680
# 2985         measurement_2985  compound_5680
# 2986         measurement_2986  compound_5680
#
#                                               uri                    cohort  \
# 0        http://purl.obolibrary.org/obo/DOID_9970       Adult: >=18 yrs old
# 1     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2       http://purl.obolibrary.org/obo/DOID_10652       Adult: >=18 yrs old
# 3     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 4       http://purl.obolibrary.org/obo/DOID_10591       Adult: >=18 yrs old
# ...                                           ...                       ...
# 2982     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2983  http://purl.obolibrary.org/obo/PATO_0000461  Adolescent:13-18 yrs old
# 2984     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2985  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2986  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
#
#      sample_type     sex                                 concentration  \
# 0          Urine    Both         10.9 (0.80-21.0) umol/mmol creatinine
# 1          Urine    Both        85.8 (17.7-153.8) umol/mmol creatinine
# 2          Urine    Both         15.7 (11.7-19.7) umol/mmol creatinine
# 3          Blood    Both                                       12.7 uM
# 4          Blood  Female                                       50.7 uM
# ...          ...     ...                                           ...
# 2982       Urine    Both         0.36 (0.32-0.40) umol/mmol creatinine
# 2983       Urine    Both         0.23 (0.20-0.26) umol/mmol creatinine
# 2984       Urine    Both            2.2 (2.1-2.3) umol/mmol creatinine
# 2985       Urine    Both  0.0023 (0.00090-0.0058) umol/mmol creatinine
# 2986       Blood    Both                                       15.4 uM
#
#                       unit                                     reference_name  \
# 0     umol/mmol creatinine  Tuma, P., Samcova, E. & Balinova, P. Determina...
# 1     umol/mmol creatinine  David F. Putnam Composition and Concentrative ...
# 2     umol/mmol creatinine  Fonteh, A. N., Harrington, R. J., Tsai, A., Li...
# 3                       uM  Dohm, G. L., Williams, R. T., Kasperek, G. J. ...
# 4                       uM                                                NaN
# ...                    ...                                                ...
# 2982  umol/mmol creatinine                                                NaN
# 2983  umol/mmol creatinine                                                NaN
# 2984  umol/mmol creatinine                                                NaN
# 2985  umol/mmol creatinine                                                NaN
# 2986                    uM                                      Molecular You
#
#        pubmed_id
# 0     15899597.0
# 1            NaN
# 2     17031479.0
# 3      7061274.0
# 4     22494326.0
# ...          ...
# 2982  26910390.0
# 2983  26910390.0
# 2984  26910390.0
# 2985  24023812.0
# 2986         NaN
#
# [2987 rows x 10 columns]

# %%
chemical_references_with_uri.cohort.unique()
# Out:
# array(['Adult: >=18 yrs old', 'Infant: 1 wk-2 yrs old',
#        'Children: 2-17 yrs old', 'Newborn: 0 day-1 wk', 'Unknown',
#        'Adolescent:13-18 yrs old', 'Elderly: 65-100+ yrs old', 'All'],
#       dtype=object)

# %%
chemical_references_with_uri.sex.unique()
# Out:
# array(['Both', 'Female', 'Male', 'Unknown'], dtype=object)

# %%
measurements_with_ids.unit.unique()
# Out:
# array(['umol/mmol creatinine', 'uM', 'nmol/g wet feces'], dtype=object)

# %%
measurements_with_ids.loc[:, 'concentration'] = measurements_with_ids.concentration.apply(lambda x: float(x.split(' ')[0]))

# %%
measurements_with_ids.loc[:, 'pubmed_id'] = measurements_with_ids.pubmed_id.apply(lambda x: f"PMID:{str(x).strip('.0')}" if pd.notna(x) else x)
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_12306/3955911148.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['PMID:15899597' nan 'PMID:17031479' ... 'PMID:2691039' 'PMID:24023812'
#  nan]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   measurements_with_ids.loc[:, 'pubmed_id'] = measurements_with_ids.pubmed_id.apply(lambda x: f"PMID:{str(x).strip('.0')}" if pd.notna(x) else x)

# %%
measurements_with_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2987 entries, 0 to 2986
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   menuguide_measurement_id  2987 non-null   object
#  1   menuguide_id              2987 non-null   object
#  2   uri                       2987 non-null   object
#  3   cohort                    2987 non-null   object
#  4   sample_type               2987 non-null   object
#  5   sex                       2987 non-null   object
#  6   concentration             2987 non-null   object
#  7   unit                      2987 non-null   object
#  8   reference_name            1510 non-null   object
#  9   pubmed_id                 2481 non-null   object
# dtypes: object(10)
# memory usage: 233.5+ KB

# %%
query = f"""
    SELECT ?entity ?label
    WHERE {{
      # ?entity rdfs:label "HasBiomarker" .
    }}
    """
    
    # Execute the query
results = onto_graph.query(query)
list(results)
# Out:
# [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/FOBI_00423'), None)]

# %%
sample_type_dict = {
    "Urine": "http://purl.obolibrary.org/obo/UBERON_0001088",
    "Blood": "http://purl.obolibrary.org/obo/UBERON_0000178",
    "Cerebrospinal_Fluid": "http://purl.obolibrary.org/obo/UBERON_0001359",
    "Cellular_Cytoplasm": "http://purl.obolibrary.org/obo/GO_0005737",
    "Saliva": "http://purl.obolibrary.org/obo/UBERON_0001836",
    "Feces": "http://purl.obolibrary.org/obo/UBERON_0001988",
    "Sweat": "http://purl.obolibrary.org/obo/UBERON_0001089",
    "Serum": "http://purl.obolibrary.org/obo/UBERON_0001977"
}

# %%
def add_measurement_to_graph(row):
    measurement = URIRef(MeNuGUIDE[row['menuguide_measurement_id']])
    compound = URIRef(MeNuGUIDE[row['menuguide_id']])
    condition = URIRef(row['uri'])
    cohort = row['cohort']
    sample_type = URIRef(sample_type_dict[row['sample_type']])
    sex = row['sex']
    concentration = Literal(row['concentration'], datatype=XSD.float)
    unit = Literal(row['unit'])
    reference = row['pubmed_id'] if pd.notna(row['pubmed_id']) else row['reference_name']
    
    onto_graph.add((measurement, RDF.type, MeNuGUIDE.Measurement))
    onto_graph.add((condition, RDF.type, MeNuGUIDE.Condition))
    
    # hasMeasurement - MeNuGUIDE.hasMeasurement
    onto_graph.add((condition, MeNuGUIDE.hasMeasurement, measurement))
    
    # isMeasurementOf - MeNuGUIDE.isMeasurementOf
    onto_graph.add((measurement, MeNuGUIDE.isMeasurementOf, condition))
    
    # amount - MeNuGUIDE.amount
    onto_graph.add((measurement, MeNuGUIDE.amount, concentration))
    
    # unit - MeNuGUIDE.unit
    onto_graph.add((measurement, MeNuGUIDE.unit, unit))
    
    # hasCohort - MeNuGUIDE.hasCohort
    if cohort != 'All' and cohort != 'Unknown':
        onto_graph.add((measurement, MeNuGUIDE.hasCohort, Literal(cohort)))
    
    # hasSex - MeNuGUIDE.hasSex
    if sex != 'Unknown' and sex != 'Both':
        onto_graph.add((measurement, MeNuGUIDE.hasSex, Literal(sex)))
    
    # hasSampleType - MeNuGUIDE.hasSampleType
    onto_graph.add((measurement, MeNuGUIDE.hasSampleType, sample_type))
    
    # reference or PMID - MeNuGUIDE.hasReference
    if pd.notna(reference):
        onto_graph.add((measurement, MeNuGUIDE.hasReference, Literal(reference)))
    
    # BiomarkerOf - http://purl.obolibrary.org/obo/FOBI_00422
    onto_graph.add((compound, OBO.FOBI_00422, measurement))
    
    # HasBiomarker - http://purl.obolibrary.org/obo/FOBI_00423
    onto_graph.add((measurement, OBO.FOBI_00423, compound))

# %%
measurements_with_ids.apply(add_measurement_to_graph, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2982    None
# 2983    None
# 2984    None
# 2985    None
# 2986    None
# Length: 2987, dtype: object

# %%
measurements_with_ids
# Out:
#      menuguide_measurement_id   menuguide_id  \
# 0               measurement_0  compound_6317
# 1               measurement_1  compound_6317
# 2               measurement_2  compound_6317
# 3               measurement_3  compound_6317
# 4               measurement_4  compound_6317
# ...                       ...            ...
# 2982         measurement_2982  compound_5681
# 2983         measurement_2983  compound_5681
# 2984         measurement_2984  compound_5680
# 2985         measurement_2985  compound_5680
# 2986         measurement_2986  compound_5680
#
#                                               uri                    cohort  \
# 0        http://purl.obolibrary.org/obo/DOID_9970       Adult: >=18 yrs old
# 1     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2       http://purl.obolibrary.org/obo/DOID_10652       Adult: >=18 yrs old
# 3     http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 4       http://purl.obolibrary.org/obo/DOID_10591       Adult: >=18 yrs old
# ...                                           ...                       ...
# 2982     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2983  http://purl.obolibrary.org/obo/PATO_0000461  Adolescent:13-18 yrs old
# 2984     http://purl.obolibrary.org/obo/DOID_9970  Adolescent:13-18 yrs old
# 2985  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
# 2986  http://purl.obolibrary.org/obo/PATO_0000461       Adult: >=18 yrs old
#
#      sample_type     sex concentration                  unit  \
# 0          Urine    Both          10.9  umol/mmol creatinine
# 1          Urine    Both          85.8  umol/mmol creatinine
# 2          Urine    Both          15.7  umol/mmol creatinine
# 3          Blood    Both          12.7                    uM
# 4          Blood  Female          50.7                    uM
# ...          ...     ...           ...                   ...
# 2982       Urine    Both          0.36  umol/mmol creatinine
# 2983       Urine    Both          0.23  umol/mmol creatinine
# 2984       Urine    Both           2.2  umol/mmol creatinine
# 2985       Urine    Both        0.0023  umol/mmol creatinine
# 2986       Blood    Both          15.4                    uM
#
#                                          reference_name      pubmed_id
# 0     Tuma, P., Samcova, E. & Balinova, P. Determina...  PMID:15899597
# 1     David F. Putnam Composition and Concentrative ...            NaN
# 2     Fonteh, A. N., Harrington, R. J., Tsai, A., Li...  PMID:17031479
# 3     Dohm, G. L., Williams, R. T., Kasperek, G. J. ...   PMID:7061274
# 4                                                   NaN  PMID:22494326
# ...                                                 ...            ...
# 2982                                                NaN   PMID:2691039
# 2983                                                NaN   PMID:2691039
# 2984                                                NaN   PMID:2691039
# 2985                                                NaN  PMID:24023812
# 2986                                      Molecular You            NaN
#
# [2987 rows x 10 columns]

# %%
for result in get_all_triples_for_iri(URIRef(MeNuGUIDE.measurement_1)):
    print(result)
# Out:
# (None, rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://MeNuGUIDE.local/Measurement'))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/isMeasurementOf'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/PATO_0000461'))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/amount'), rdflib.term.Literal('85.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/unit'), rdflib.term.Literal('umol/mmol creatinine'))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/hasCohort'), rdflib.term.Literal('Adult: >=18 yrs old'))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/hasSampleType'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/UBERON_0001088'))
# (None, rdflib.term.URIRef('http://MeNuGUIDE.local/hasReference'), rdflib.term.Literal('David F. Putnam Composition and Concentrative Properties of Human Urine. NASA Contractor Report. July 1971'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/FOBI_00423'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_6317'))
# (rdflib.term.URIRef('http://purl.obolibrary.org/obo/PATO_0000461'), rdflib.term.URIRef('http://MeNuGUIDE.local/hasMeasurement'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_6317'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/FOBI_00422'), None)

# %%
onto_graph.serialize(destination=os.path.join(ontology_folder, "merged_with_foods_compounds_reactions_biomarkers.ttl"), format="turtle")
# Out:
# <Graph identifier=Na02196d5e708470a901ab294d3182d1d (<class 'rdflib.graph.Graph'>)>

# %%
query = f"""
    SELECT ?entity ?label ?predicate ?object
    WHERE {{
      # ?entity rdfs:label "Crohn's disease" .
      # ?entity ?predicate ?object
    }}
    """
    
    # Execute the query
results = onto_graph.query(query)
list(results)
# Out:
# [(rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal("Crohn's disease")),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000115'),
#   rdflib.term.Literal("A chronic granulomatous inflammatory disease of the intestines that may affect any part of the gastrointestinal tract from mouth to anus, causing a wide variety of symptoms. It primarily causes abdominal pain, diarrhea which may be bloody, vomiting, or weight loss, but may also cause complications outside of the gastrointestinal tract such as skin rashes, arthritis, inflammation of the eye, tiredness, and lack of concentration. Crohn's disease is thought to be an autoimmune disease, in which the body's immune system attacks the gastrointestinal tract, causing inflammation.")),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://purl.org/dc/terms/creator'),
#   rdflib.term.URIRef('https://orcid.org/0009-0006-4530-3154')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#creation_date'),
#   rdflib.term.Literal('2010-08-10T09:26:05Z')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'),
#   rdflib.term.Literal('MSH:D003424')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'),
#   rdflib.term.Literal('SNOMEDCT_US:34000006')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'),
#   rdflib.term.Literal('UMLS:C0010346')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'),
#   rdflib.term.Literal('Granulomatous enteritis and colitis')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasExactSynonym'),
#   rdflib.term.Literal('Morbus Crohn')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#id'),
#   rdflib.term.Literal('HP:0100280')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#   rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0004386')),
#  (rdflib.term.URIRef('http://purl.obolibrary.org/obo/HP_0100280'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'),
#   rdflib.term.URIRef('http://purl.obolibrary.org/obo/DOID_8778'))]
