# %% [markdown]
# *MeNu GUIDE*
# # Integrate Ontology and Database Info - Foods

# %%
import rdflib
import os
import pandas as pd
from rdflib import URIRef, Literal, Namespace, RDF, XSD
from rdflib.plugins.sparql import prepareQuery

# %% [markdown]
# ## Define Namespaces

# %%
MeNuGUIDE = Namespace("http://MeNuGUIDE.local/")
ChEBI = Namespace("http://purl.obolibrary.org/obo/chebi/")
OBO = Namespace("http://purl.obolibrary.org/obo/")
GO = Namespace("http://www.geneontology.org/formats/oboInOwl#")
FOBI = Namespace("http://purl.obolibrary.org/obo/FOBI_")

# %% [markdown]
# ## Load Graph

# %%
foodb_folder = "/path/to/downloaded/FooDB/data/"
ontology_folder = "/path/to/ontologies/"
processed_data_folder = "/path/to/processed/data/folder/"

# %%
# Load the merged ontology RDF file
onto_graph = rdflib.Graph()
onto_graph.parse(os.path.join(ontology_folder, "merged_with_database_compounds.ttl"), format="turtle")
# Out:
# <Graph identifier=Na5625b5f59c14ee8b73a915ebca55f5d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Find food IRIs

# %%
foods = pd.read_csv(os.path.join(foodb_folder, 'foods_to_map.csv'))

# %% [markdown]
# #### Match via scientific name

# %%
def find_term(search_term):
    query = f"""
    SELECT ?entity ?label
    WHERE {{
      # ?entity rdfs:label "{search_term}".
    }}
    """
    
    # Execute the query
    results = onto_graph.query(query)
    return results

# %%
scientific_name_matches = {}

for idx, row in foods.iterrows():
    if pd.notna(row['name_scientific']):
        print(idx)
        matches = find_term(row['name_scientific'])
        if matches:
            scientific_name_matches[row['name_scientific']] = matches

# %%
print(f"Foods with scientific names: {len(foods[foods.name_scientific.notna()])}\nFoods that could be matched via scientific name: {len(scientific_name_matches)}")

# %%
for name, match in scientific_name_matches.items():
    scientific_name_matches[name] = list(match)

# %%
for name, match in scientific_name_matches.items():
    if len(match) > 1:
        print(f"{name}:\n{match}\n")
        scientific_name_matches[name] = [match[1]]

# %%
matches_dict = {}

for name, match in scientific_name_matches.items():
    matches_dict[name] = match[0][0]

# %%
foods['ncbi_uri'] = foods.name_scientific.apply(lambda x: str(matches_dict[x]) if x in matches_dict else None)

# %% [markdown]
# #### Match via name

# %%
name_uri_dict = {}

def get_food_via_name(food):
    name_query = f"""
        SELECT ?iri
        WHERE {{
          # ?iri rdfs:label "{food.lower()}"@en .
        }}
        """
    
    results = onto_graph.query(name_query)
    
    if results:
        result = str(list(results)[0][0])
        name_uri_dict[food] = result
    
foods['name'].apply(get_food_via_name)

# %%
foods['foodon_uri'] = foods['name'].apply(lambda x: str(name_uri_dict[x]) if x in name_uri_dict else None)

# %%
foods[foods.name_scientific.notna() & foods.name_scientific.str.startswith("Capsicum annuum 'Ja")]

# %%
foods.loc[954, 'name_scientific'] = "Capsicum annuum Jalapeno"

# %% [markdown]
# #### Match via scientific name & synonyms in ontology

# %%
name_scientific_uri_dict = {}

def get_food_via_scientific_name(food):
    if pd.notna(food):
        name_query = f"""
            SELECT ?iri
            WHERE {{
              # ?iri <http://www.geneontology.org/formats/oboInOwl#hasSynonym> '{food.lower()}'@en .
            }}
            """
        
        results = onto_graph.query(name_query)

        if results:
            result = list(results)
                
            name_scientific_uri_dict[food] = result
    
foods['name_scientific'].apply(get_food_via_scientific_name)

# %%
def get_label(iri):
    test_query = f"""
        SELECT ?o
        WHERE {{
            <{iri}> rdfs:label ?o .
        }}
        """
    
    results = list(onto_graph.query(test_query))
    return results[0][0]

for name, match in name_scientific_uri_dict.items():
    updated_match = []
        
    for entry in match:
        label = get_label(entry[0])
        updated_match.append((entry[0], label))
        
    name_scientific_uri_dict[name] = updated_match

# %%
name_dict = foods[['name', 'name_scientific']].set_index('name_scientific').to_dict()
name_dict = name_dict['name']

# %%
ncbi_tax_dict = {}
foodon_dict = {}

for name, match in name_scientific_uri_dict.items():
    for entry in match:
        uri = entry[0]
        
        if 'FOODON' in uri:
            if name not in foodon_dict:
                foodon_dict[name] = [uri]
            else:
                foodon_dict[name].append(uri)
                
        elif 'NCBITaxon' in uri:
            if name not in ncbi_tax_dict:
                ncbi_tax_dict[name] = [uri]
            else:
                ncbi_tax_dict[name].append(uri)
        else:
            print(f"{name_dict[name]} - {name}: {entry}")

# %%
foods['ncbi_uri'] = foods.apply(lambda row: (ncbi_tax_dict[row['name_scientific']] if row['name_scientific'] in ncbi_tax_dict else None) if pd.isna(row['ncbi_uri']) else row['ncbi_uri'], axis=1)

# %%
def merge_foodon_matches(row):
    if row['name_scientific'] in foodon_dict:
        uris = set()
        if pd.notna(row['foodon_uri']):
            uris.add(row['foodon_uri'])
        for uri in foodon_dict[row['name_scientific']]:
            uris.add(uri)
        return list(uris)
    else:
        if pd.notna(row['foodon_uri']):
            return [row['foodon_uri']]
        else:
            return None

foods['foodon_uri'] = foods.apply(merge_foodon_matches, axis=1)

# %%
unmatched_foods = foods[foods.ncbi_uri.isna() & foods.foodon_uri.isna()]
unmatched_foods

# %%
unmatched_foods.to_csv(os.path.join(foodb_folder, "foods_to_map_manually.csv"), index=False)

# %% [markdown]
# #### Manual matching

# %%
manually_matched_foods = pd.read_csv(os.path.join(foodb_folder, "foods_mapped_manually.csv"), sep=';')

# %%
manually_matched_foods.loc[:, 'foodon_uri'] = manually_matched_foods.foodon_uri.apply(lambda x: [x] if pd.notna(x) else x)

# %%
automatically_matched_foods = foods[foods.ncbi_uri.notna() | foods.foodon_uri.notna()]

# %%
duplicated_names = set(manually_matched_foods.name.unique()) - set(unmatched_foods.name.unique())

# %%
automatically_matched_foods = automatically_matched_foods[~automatically_matched_foods.name.isin(duplicated_names)]

# %%
foods_matched = pd.concat([automatically_matched_foods, manually_matched_foods])

# %% [markdown]
# ### Clean up matched foods and add identifiers

# %%
foods_matched = foods_matched[~(foods_matched.foodon_uri.isna() & foods_matched.ncbi_uri.isna())]

# %%
foods_matched = foods_matched.reset_index(drop=True)

# %%
foods_matched = foods_matched.reset_index(names='menuguide_id')
foods_matched.loc[:, 'menuguide_id'] = foods_matched.menuguide_id.apply(lambda x: f"food_{x}")

# %%
foods_matched.loc[:, 'foodon_uri'] = foods_matched.foodon_uri.apply(lambda x: None if (type(x) == float and pd.isna(x)) else x)
foods_matched.loc[:, 'ncbi_uri'] = foods_matched.ncbi_uri.apply(lambda x: None if (type(x) == float and pd.isna(x)) else x)

# %%
foods_matched.loc[987, 'ncbi_uri'] = None

# %%
foods_matched.to_csv(os.path.join(foodb_folder, "foods_matched_to_onto.csv"), index=False)

# %%
foods_matched = pd.read_csv(os.path.join(foodb_folder, "foods_matched_to_onto.csv"))

# %% [markdown]
# ### Add foods to graph

# %%
foods_matched
# Out:
#     menuguide_id    id              name                  name_scientific  \
# 0         food_0     2     Savoy cabbage   Brassica oleracea var. sabauda
# 1         food_1     3     Silver linden                   Tilia argentea
# 2         food_2     4              Kiwi              Actinidia chinensis
# 3         food_3     5            Allium                           Allium
# 4         food_4     6      Garden onion                      Allium cepa
# ..           ...   ...               ...                              ...
# 985     food_985  1014              Goji                              NaN
# 986     food_986  1015        Monk fruit             Siraitia grosvenorii
# 987     food_987  1016  Cantaloupe melon  Cucumis melo var. cantalupensis
# 988     food_988  1017          Hawthorn                        Crataegus
# 989     food_989  1024     Tostada shell                              NaN
#
#                                            description food_type  \
# 0    Savoy cabbage (Brassica oleracea convar. capit...    Type 1
# 1    Tilia tomentosa (Silver Lime in the UK and Sil...    Type 1
# 2    The kiwifruit, often shortened to kiwi in many...    Type 1
# 3    Allium haematochiton is a species of wild onio...    Type 1
# 4    The onion (Allium cepa) (Latin 'cepa' = onion)...    Type 1
# ..                                                 ...       ...
# 985  Goji, goji berry or wolfberry is the fruit of ...    Type 1
# 986  Siraitia grosvenorii (monk fruit or luo han gu...    Type 1
# 987  The cantaloupe, rockmelon (Australia), sweet m...    Type 1
# 988  Crataegus commonly called hawthorn, quickthorn...    Type 1
# 989                                                NaN    Type 2
#
#      ncbi_taxonomy_id  public_id  \
# 0           1216010.0  FOOD00002
# 1                 NaN  FOOD00003
# 2              3625.0  FOOD00004
# 3              4678.0  FOOD00005
# 4              4679.0  FOOD00006
# ..                ...        ...
# 985               NaN  FOOD00982
# 986               NaN  FOOD00983
# 987               NaN  FOOD00984
# 988               NaN  FOOD00985
# 989               NaN  FOOD00992
#
#                                              ncbi_uri  \
# 0    http://purl.obolibrary.org/obo/NCBITaxon_1216010
# 1                                                 NaN
# 2       http://purl.obolibrary.org/obo/NCBITaxon_3625
# 3       http://purl.obolibrary.org/obo/NCBITaxon_4678
# 4       http://purl.obolibrary.org/obo/NCBITaxon_4679
# ..                                                ...
# 985                                               NaN
# 986     http://purl.obolibrary.org/obo/NCBITaxon_3650
# 987
# 988    http://purl.obolibrary.org/obo/NCBITaxon_23159
# 989                                               NaN
#
#                                             foodon_uri
# 0    [rdflib.term.URIRef('http://purl.obolibrary.or...
# 1    [rdflib.term.URIRef('http://purl.obolibrary.or...
# 2    [rdflib.term.URIRef('http://purl.obolibrary.or...
# 3    [rdflib.term.URIRef('http://purl.obolibrary.or...
# 4    [rdflib.term.URIRef('http://purl.obolibrary.or...
# ..                                                 ...
# 985  ['http://purl.obolibrary.org/obo/FOODON_000043...
# 986                                                NaN
# 987  ['http://purl.obolibrary.org/obo/FOODON_034114...
# 988  ['http://purl.obolibrary.org/obo/FOODON_034117...
# 989  ['http://purl.obolibrary.org/obo/FOODON_000025...
#
# [990 rows x 10 columns]

# %%
def reformat_uri(uris):
    if type(uris) == str:
        if uris == ' ':
            return float('NaN')
        elif 'rdflib' in uris:
            if ',' in uris:
                uris = uris.split(',')
                cleaned_uris = []
                for uri in uris:
                    uri_temp = uri.split("'")[1]
                    cleaned_uris.append(uri_temp)
                return cleaned_uris
            else:
                return [uris.split("'")[1]]
        else:
            if '[' in uris:
                uris = uris.split("'")[1]
                return [uris]
            else:
                return [uris]
    else:
        if pd.isna(uris):
            return float('NaN')
        else:
            print(uris)

foods_matched.loc[:, "ncbi_uri"] = foods_matched.ncbi_uri.apply(reformat_uri)
foods_matched.loc[:, "foodon_uri"] = foods_matched.foodon_uri.apply(reformat_uri)

# %%
def add_triple_property(subject, predicate, object, prefix=''):
    if pd.notna(object):
        if prefix:
            object = prefix + object
        onto_graph.add((subject, predicate, Literal(object)))
        
def class_exists(iri):
    # SPARQL query to check if the IRI exists in the graph
    query = prepareQuery(
        """ASK
           WHERE {
              VALUES ?iri_to_check { <""" + str(iri) + """> }
              # ?iri_to_check ?p ?o .
           }""",
    )
    
    exists = onto_graph.query(query)
    return exists
        
def add_identifier(subject, object_uri):
    if pd.notna(object_uri):
        iri_to_check = URIRef(object_uri)
        
        if class_exists(iri_to_check):
            onto_graph.add((subject, RDF.type, iri_to_check))

def add_food_to_graph(row):
    print(f"{row.name}: {row['name']}")
    
    food_name = row['name'].lower()
    scientific_name = row['name_scientific'].lower() if pd.notna(row['name_scientific']) else None
    description = row['description']
    foodb_id = row['public_id']
    foodon_connections = row['foodon_uri']
    ncbi_uri = row['ncbi_uri']
    
    instance_uri = URIRef(MeNuGUIDE[row['menuguide_id']])
    onto_graph.add((instance_uri, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(food_name)))
    onto_graph.add((instance_uri, RDF.type, MeNuGUIDE.Food))
    
    # Description - http://purl.org/dc/terms/description or http://purl.obolibrary.org/obo/IAO_0000115 (used in ChEBI ontology)
    add_triple_property(instance_uri, OBO.IAO_0000115, description)
    
    # foodb_id - http://www.geneontology.org/formats/oboInOwl#hasDbXref 
    add_triple_property(instance_uri, GO.hasDbXref, foodb_id, 'FooDB:')
    
    # Scientific name - http://www.geneontology.org/formats/oboInOwl#hasSynonym    
    add_triple_property(instance_uri, GO.hasSynonym, scientific_name)
    
    # ncbi - rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type')
    add_identifier(instance_uri, ncbi_uri)
    
    # other foodon identifiers - rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type')
    if type(foodon_connections) == list:
        for item in foodon_connections:
            add_identifier(instance_uri, item)

# %%
len(onto_graph)
# Out:
# 22955648

# %%
foods_matched.apply(add_food_to_graph, axis=1)
# Out:
# 0: Savoy cabbage
# 1: Silver linden
# 2: Kiwi
# 3: Allium
# 4: Garden onion
# 5: Leek
# 6: Garlic
# 7: Chives
# 8: Cashew nut
# 9: Pineapple
# 10: Dill
# 11: Custard apple
# 12: Wild celery
# 13: Peanut
# 14: Burdock
# 15: Horseradish
# 16: Tarragon
# 17: Mugwort
# 18: Asparagus
# 19: Oat
# 20: Star fruit
# 21: Brazil nut
# 22: Common beet
# 23: Borage
# 24: Chinese mustard
# 25: Swede
# 26: Rape
# 27: Common cabbage
# 28: Cauliflower
# 29: Brussel sprouts
# 30: Kohlrabi
# 31: Broccoli
# 32: Chinese cabbage
# 33: Turnip
# 34: Pigeon pea
# 35: Tea
# 36: Capers
# 37: Pepper
# 38: Papaya
# 39: Safflower
# 40: Caraway
# 41: Pecan nut
# 42: Chestnut
# 43: Roman camomile
# 44: Chickpea
# 45: Endive
# 46: Chicory
# 47: Chinese cinnamon
# 48: Ceylon cinnamon
# 49: Watermelon
# 50: Lime
# 51: Lemon
# 52: Pummelo
# 53: Mandarin orange (Clementine, Tangerine)
# 54: Sweet orange
# 55: Coffee
# 56: Arabica coffee
# 57: Coriander
# 58: Common hazelnut
# 59: Saffron
# 60: Muskmelon
# 61: Cucumber
# 62: Cucurbita
# 63: Cumin
# 64: Turmeric
# 65: Quince
# 66: Lemon grass
# 67: Wild carrot
# 68: Japanese persimmon
# 69: Cardamom
# 70: Black crowberry
# 71: Loquat
# 72: Wax apple
# 73: Common buckwheat
# 74: Fig
# 75: Fennel
# 76: Strawberry
# 77: Soy bean
# 78: Sunflower
# 79: Sea-buckthornberry
# 80: Barley
# 81: Hyssop
# 82: Star anise
# 83: Swamp cabbage
# 84: Sweet potato
# 85: Black walnut
# 86: Common walnut
# 87: Lettuce
# 88: Grass pea
# 89: Sweet bay
# 90: Lentils
# 91: Garden cress
# 92: Lovage
# 93: Flaxseed
# 94: Mexican oregano
# 95: Lichee
# 96: Lupine
# 97: Apple
# 98: Mango
# 99: German camomile
# 100: Lemon balm
# 101: Mentha
# 102: Orange mint
# 103: Spearmint
# 104: Peppermint
# 105: Medlar
# 106: Bitter gourd
# 107: Mulberry
# 108: Black mulberry
# 109: Nutmeg
# 110: Sweet basil
# 111: Evening primrose
# 112: Olive
# 113: Sweet marjoram
# 114: Pot marjoram
# 115: Common oregano
# 116: Rice
# 117: Millet
# 118: Poppy
# 119: Passion fruit
# 120: Parsnip
# 121: Avocado
# 122: Parsley
# 123: Scarlet bean
# 124: Lima bean
# 125: Common bean
# 126: Date
# 127: Black chokeberry
# 128: Anise
# 129: Pine nut
# 130: Pepper (Spice)
# 131: Pistachio
# 132: Common pea
# 133: Purslane
# 134: Prunus (Cherry, Plum)
# 135: Apricot
# 136: Sweet cherry
# 137: Sour cherry
# 138: European plum
# 139: Almond
# 140: Peach
# 141: Guava
# 142: Pomegranate
# 143: Pear
# 144: Radish
# 145: Garden rhubarb
# 146: Blackcurrant
# 147: Redcurrant
# 148: Gooseberry
# 149: Watercress
# 150: Rosemary
# 151: Rubus (Blackberry, Raspberry)
# 152: Cloudberry
# 153: Red raspberry
# 154: Black raspberry
# 155: Sorrel
# 156: Common sage
# 157: Black elderberry
# 158: Summer savory
# 159: Winter savory
# 160: Rye
# 161: Sesame
# 162: Garden tomato
# 163: Eggplant
# 164: Potato
# 165: Rowanberry
# 166: Sorghum
# 167: Spinach
# 168: Cloves
# 169: Tamarind
# 170: Dandelion
# 171: Cocoa bean
# 172: Common thyme
# 173: Linden
# 174: Small-leaf linden
# 175: Fenugreek
# 176: Common wheat
# 177: Vaccinium (Blueberry, Cranberry, Huckleberry)
# 178: Lowbush blueberry
# 179: Highbush blueberry
# 180: American cranberry
# 181: Bilberry
# 182: Lingonberry
# 183: Vanilla
# 184: Common verbena
# 185: Broad bean
# 186: Adzuki bean
# 187: Gram bean
# 188: Mung bean
# 189: Climbing bean
# 190: Cowpea
# 191: Muscadine grape
# 192: Common grape
# 193: Corn
# 194: Ginger
# 195: Arctic blackberry
# 196: Banana
# 197: Bayberry
# 198: Elliott's blueberry
# 199: Bog bilberry
# 200: Celeriac
# 201: Celery stalks
# 202: Chinese chives
# 203: European cranberry
# 204: Ginseng
# 205: Cascade huckleberry
# 206: Oval-leaf huckleberry
# 207: Red huckleberry
# 208: Longan
# 209: Macadamia nut (M. tetraphylla)
# 210: Summer grape
# 211: Fox grape
# 212: Nectarine
# 213: Peach (var.)
# 214: Pepper (C. chinense)
# 215: Pepper (Capsicum)
# 216: Rambutan
# 217: Annual wild rice
# 218: Tronchuda cabbage
# 219: Welsh onion
# 220: Hard wheat
# 221: Shallot
# 222: Black cabbage
# 223: Celery leaves
# 224: Chicory leaves
# 225: Komatsuna
# 226: Napa cabbage
# 227: Grapefruit
# 228: Kai-lan
# 229: Black radish
# 230: Radish (var.)
# 231: Sweet rowanberry
# 232: Skunk currant
# 233: Breakfast cereal
# 234: Pasta
# 235: Fortified wine
# 236: Abalone
# 237: Abiyuch
# 238: Acerola
# 239: Acorn
# 240: Winter squash
# 241: Red king crab
# 242: Alfalfa
# 243: Allspice
# 244: Amaranth
# 245: Arrowhead
# 246: Arrowroot
# 247: Asian pear
# 248: Atlantic herring
# 249: Atlantic mackerel
# 250: Painted comber
# 251: Atlantic pollock
# 252: Atlantic wolffish
# 253: Bamboo shoots
# 254: Striped bass
# 255: Beech nut
# 256: Beluga whale
# 257: Bison
# 258: Alaska blackfish
# 259: Blue crab
# 260: Blue mussel
# 261: Northern bluefin tuna
# 262: Bluefish
# 263: Wild boar
# 264: Bowhead whale
# 265: Breadfruit
# 266: Breadnut tree seed
# 267: Buffalo
# 268: Burbot
# 269: Giant butterbur
# 270: American butterfish
# 271: Butternut
# 272: Butternut squash
# 273: Calabash
# 274: Cardoon
# 275: Natal plum
# 276: Carob
# 277: Common carp
# 278: Cassava
# 279: Channel catfish
# 280: Chayote
# 281: Cherimoya
# 282: Chervil
# 283: Chia
# 284: Chicken
# 285: Chinese chestnut
# 286: Chinese water chestnut
# 287: Garland chrysanthemum
# 288: Cisco
# 289: Nuttall cockle
# 290: Coconut
# 291: Pacific cod
# 292: Atlantic cod
# 293: Common octopus
# 294: Corn salad
# 295: Cottonseed
# 296: Catjang pea
# 297: Malus (Crab apple)
# 298: Squashberry
# 299: Atlantic croaker
# 300: Cusk
# 301: Cuttlefish
# 302: Mule deer
# 303: Devilfish
# 304: Dock
# 305: Dolphin fish
# 306: Freshwater drum
# 307: Mallard duck
# 308: Dungeness crab
# 309: Durian
# 310: Eastern oyster
# 311: Freshwater eel
# 312: Elderberry
# 313: Elk
# 314: Emu
# 315: Oregon yampah
# 316: European anchovy
# 317: European chestnut
# 318: Turbot
# 319: Fireweed
# 320: Florida pompano
# 321: Ginkgo nuts
# 322: Greylag goose
# 323: Grape
# 324: Greenland halibut/turbot
# 325: Groundcherry
# 326: Grouper
# 327: Guinea hen
# 328: Haddock
# 329: Hippoglossus (Common halibut)
# 330: Hazelnut
# 331: Hickory nut
# 332: Horse
# 333: Horseradish tree
# 334: Hyacinth bean
# 335: Irish moss
# 336: Pacific jack mackerel
# 337: Jackfruit
# 338: Japanese chestnut
# 339: Java plum
# 340: Jerusalem artichoke
# 341: Jujube
# 342: Jute
# 343: Kale
# 344: Kelp
# 345: King mackerel
# 346: Kumquat
# 347: Lambsquarters
# 348: Leather chiton
# 349: Wild leek
# 350: Common ling
# 351: Lingcod
# 352: American lobster
# 353: Loganberry
# 354: Lotus
# 355: Sacred lotus
# 356: White lupine
# 357: Malabar spinach
# 358: Mammee apple
# 359: Purple mangosteen
# 360: Alpine sweetvetch
# 361: Milkfish
# 362: Monkfish
# 363: Moth bean
# 364: Mountain yam
# 365: Striped mullet
# 366: White mustard
# 367: Mustard spinach
# 368: New Zealand spinach
# 369: Ocean pout
# 370: North Pacific giant octopus
# 371: Ohelo berry
# 372: Okra
# 373: Tunicate
# 374: Ostrich
# 375: Spotted seal
# 376: Pacific herring
# 377: Pacific oyster
# 378: Pacific rockfish
# 379: Velvet duck
# 380: Pepper (C. frutescens)
# 381: Common persimmon
# 382: Pheasant
# 383: Northern pike
# 384: Pili nut
# 385: Pitanga
# 386: French plantain
# 387: American pokeweed
# 388: Opium poppy
# 389: Prairie turnip
# 390: Prickly pear
# 391: Quinoa
# 392: Rainbow smelt
# 393: Rainbow trout
# 394: Malabar plum
# 395: Rose hip
# 396: Roselle
# 397: Orange roughy
# 398: Sablefish
# 399: Pink salmon
# 400: Chum salmon
# 401: Coho salmon
# 402: Sockeye salmon
# 403: Chinook salmon
# 404: Atlantic salmon
# 405: Salmonberry
# 406: Common salsify
# 407: Sapodilla
# 408: Mamey sapote
# 409: Spanish mackerel
# 410: Pacific sardine
# 411: Scallop
# 412: Scup
# 413: Sea cucumber
# 414: Steller sea lion
# 415: Bearded seal
# 416: Ringed seal
# 417: American shad
# 418: Shark
# 419: Sheefish
# 420: Sheep (Mutton, Lamb)
# 421: Sheepshead
# 422: Hedge mustard
# 423: Skipjack tuna
# 424: Snapper
# 425: Soursop
# 426: Spelt
# 427: Spirulina
# 428: Squab
# 429: Strawberry guava
# 430: Greater sturgeon
# 431: White sucker
# 432: Sugar apple
# 433: Pumpkinseed sunfish
# 434: Swordfish
# 435: Taro
# 436: Teff
# 437: Tilefish
# 438: Towel gourd
# 439: Salmonidae (Salmon, Trout)
# 440: Turkey
# 441: Cattle (Beef, Veal)
# 442: Walleye
# 443: Alaska pollock
# 444: Wasabi
# 445: Wax gourd
# 446: Whelk
# 447: Coalfish pollock
# 448: Broad whitefish
# 449: Whitefish
# 450: Whiting
# 451: Wild rice
# 452: Tea leaf willow
# 453: Winged bean
# 454: Yam
# 455: Jicama
# 456: Yautia
# 457: Yellowfin tuna
# 458: Yellowtail amberjack
# 459: Pollock
# 460: Albacore tuna
# 461: Gadus (Common cod)
# 462: Atlantic halibut
# 463: Pacific halibut
# 464: Pacific salmon
# 465: Smelt
# 466: Clupeinae (Herring, Sardine, Sprat)
# 467: Spiny lobster
# 468: Snow crab
# 469: Deer
# 470: Macadamia nut
# 471: Percoidei (Bass and others)
# 472: Perciformes
# 473: Rabbit
# 474: Domestic goat
# 475: Beefalo
# 476: Bivalvia (Clam, Mussel, Oyster)
# 477: Squid
# 478: Shrimp
# 479: Crayfish
# 480: Flatfish
# 481: Walrus
# 482: Quail
# 483: Boysenberry
# 484: Persian lime
# 485: Feijoa
# 486: Rowal
# 487: Jew's ear
# 488: Common mushroom
# 489: Wakame
# 490: Enokitake
# 491: Epazote
# 492: Oyster mushroom
# 493: Cloud ear fungus
# 494: Maitake
# 495: Ostrich fern
# 496: Spot croaker
# 497: Tinda
# 498: Atlantic menhaden
# 499: Wheat
# 500: Common chokecherry
# 501: Narrowleaf cattail
# 502: Jellyfish
# 503: Anchovy
# 504: Blue whiting
# 505: Carp bream
# 506: Sturgeon
# 507: Cinnamon
# 508: Crab
# 509: Common dab
# 510: Spiny dogfish
# 511: Anatidae
# 512: Anguilliformes
# 513: Garfish
# 514: Gadiformes
# 515: Lake trout
# 516: Lemon sole
# 517: Clawed lobster
# 518: Lumpsucker
# 519: Scombridae (Bonito, Mackerel, Tuna)
# 520: Norway haddock
# 521: Norway lobster
# 522: Norway pout
# 523: Persimmon
# 524: Pleuronectidae (Dab, Halibut, Plaice)
# 525: Rock ptarmigan
# 526: Pacific ocean perch
# 527: Black salsify
# 528: True seal
# 529: Red algae
# 530: Kombu
# 531: Snail
# 532: Catfish
# 533: Walnut
# 534: Cetacea (Dolphin, Porpoise, Whale)
# 535: Columbidae (Dove, Pigeon)
# 536: Conch
# 537: Grape wine
# 538: Cheese
# 539: Bean
# 540: Vodka
# 541: Ice cream
# 542: Gin
# 543: Vinegar
# 544: Rum
# 545: Port wine
# 546: Vermouth
# 547: Sherry
# 548: Madeira wine
# 549: Nougat
# 550: Toffee
# 551: Pizza
# 552: Pastry
# 553: Chewing gum
# 554: Marzipan
# 555: Salad dressing
# 556: Sauce
# 557: Butter
# 558: Butter substitute
# 559: Sugar
# 560: Meatball
# 561: Pate
# 562: Sugar substitute
# 563: Casein
# 564: Leavening agent
# 565: Marshmallow
# 566: Dumpling
# 567: Syrup
# 568: Remoulade
# 569: Chocolate spread
# 570: Curry powder
# 571: Lard
# 572: Cocoa butter
# 573: Chocolate
# 574: Kefir
# 575: Soy sauce
# 576: Miso
# 577: Tofu
# 578: Zwieback
# 579: Cichlidae (Tilapia)
# 580: Green turtle
# 581: Energy drink
# 582: Burrito
# 583: Taco
# 584: Tortilla
# 585: Nachos
# 586: Salad
# 587: Cream substitute
# 588: Dulce de leche
# 589: Egg roll
# 590: Heart of palm
# 591: Potato chip
# 592: Tortilla chip
# 593: Corn chip
# 594: Stew
# 595: Gelatin dessert
# 596: Frybread
# 597: Morchella (Morel)
# 598: Pancake
# 599: Pudding
# 600: Waffle
# 601: Meatloaf
# 602: Sake
# 603: Bulgur
# 604: Chimichanga
# 605: Quesadilla
# 606: Hot dog
# 607: Enchilada
# 608: Nutritional drink
# 609: Adobo
# 610: Macaroni and cheese
# 611: Horned melon
# 612: Hushpuppy
# 613: Relish
# 614: Fruit salad
# 615: Soy yogurt
# 616: Babassu palm
# 617: Cupuaçu
# 618: Shea tree
# 619: Cooking oil
# 620: Pie crust
# 621: Pie filling
# 622: Pie
# 623: Shortening
# 624: Soy cream
# 625: Ice cream cone
# 626: Cracker
# 627: Naranjilla
# 628: Scrapple
# 629: Succotash
# 630: Tamale
# 631: Rice cake
# 632: Evaporated milk
# 633: Flour
# 634: Akutaq
# 635: Dough
# 636: Pita bread
# 637: Focaccia
# 638: Bagel
# 639: French toast
# 640: Wheat bread
# 641: Potato bread
# 642: Cornbread
# 643: Multigrain bread
# 644: Rice bread
# 645: Raisin bread
# 646: Trail mix
# 647: Horchata
# 648: Soft drink
# 649: Frozen yogurt
# 650: Milkshake
# 651: Chocolate mousse
# 652: Empanada
# 653: Ascidians
# 654: Gefilte fish
# 655: Yellow pond-lily
# 656: Fudge
# 657: Candy bar
# 658: Margarine
# 659: Hummus
# 660: Milk substitute
# 661: Pepper (C. pubescens)
# 662: Cabbage
# 663: Green bell pepper
# 664: Yellow bell pepper
# 665: Orange bell pepper
# 666: Red bell pepper
# 667: Italian sweet red pepper
# 668: Yellow wax bean
# 669: Green bean
# 670: Saskatoon berry
# 671: Nanking cherry
# 672: Japanese pumpkin
# 673: Castanospermum australe
# 674: Gentiana lutea
# 675: Juniperus communis
# 676: Rabbiteye blueberry
# 677: Blackberry
# 678: Olive oil
# 679: Red wine
# 680: Rapeseed oil
# 681: Soybean oil
# 682: Guarana
# 683: Mate
# 684: White wine
# 685: Rosé wine
# 686: White mulberry
# 687: Canola oil
# 688: White grape juice
# 689: Crosne
# 690: Red clover
# 691: Partridge berry
# 692: Mikan
# 693: Mozzarella cheese
# 694: Cheddar Cheese
# 695: Almond milk
# 696: Coconut milk
# 697: Coconut oil
# 698: Peanut oil
# 699: Cottonseed oil
# 700: Corn oil
# 701: Avocado oil
# 702: Sesame oil
# 703: Swiss cheese
# 704: Cottage cheese
# 705: Clam
# 706: Sour cream
# 707: Whole wheat bread
# 708: Jalapeno pepper
# 709: Plantain
# 710: Clementine
# 711: White onion
# 712: Red onion
# 713: Red grape
# 714: Black plum
# 715: Green lentil
# 716: Acorn squash
# 717: Japanese sea bass
# 718: Water spinach
# 719: Pitaya
# 720: Lantern fruit
# 721: White bread
# 722: Cape gooseberry
# 723: Herbal tea
# 724: Fish oil
# 725: Taco shell
# 726: Angelica
# 727: Lemon verbena
# 728: Robusta coffee
# 729: Globe artichoke
# 730: Rocket salad (ssp.)
# 731: Tartary buckwheat
# 732: Black huckleberry
# 733: Cornmint
# 734: Cherry tomato
# 735: Garden tomato (var.)
# 736: Sparkleberry
# 737: Canada blueberry
# 738: Buffalo currant
# 739: Deerberry
# 740: Evergreen huckleberry
# 741: Garden onion (var.)
# 742: Pepper (C. baccatum)
# 743: Red rice
# 744: Swiss chard
# 745: Lemon thyme
# 746: Japanese walnut
# 747: Rocket salad
# 748: Carrot
# 749: Triticale
# 750: Half-highbush blueberry
# 751: Pak choy
# 752: Chicory roots
# 753: Grapefruit/Pummelo hybrid
# 754: Jostaberry
# 755: Italian oregano
# 756: Oxheart cabbage
# 757: Daikon radish
# 758: Red beetroot
# 759: Pineappple sage
# 760: Beer
# 761: Other bread
# 762: Other soy product
# 763: Other cereal product
# 764: Biscuit
# 765: Sourdough
# 766: Spirit
# 767: Other alcoholic beverage
# 768: Agar
# 769: Rapini
# 770: Chinese broccoli
# 771: Alaska blueberry
# 772: Nopal
# 773: Colorado pinyon
# 774: Plains prickly pear
# 775: European rabbit
# 776: Sea trout
# 777: Sesbania flower
# 778: Mexican groundcherry
# 779: Black-eyed pea
# 780: Domestic pig
# 781: Alaska wild rhubarb
# 782: Oriental wheat
# 783: Yardlong bean
# 784: Shiitake
# 785: Purple laver
# 786: Sourdock
# 787: Agave
# 788: Chanterelle
# 789: Charr
# 790: True frog
# 791: Mountain hare
# 792: Marine mussel
# 793: Oil palm
# 794: True oyster
# 795: Sago palm
# 796: Pikeperch
# 797: True sole
# 798: Thistle
# 799: Thunnus
# 800: Berry wine
# 801: Other wine
# 802: Apple cider
# 803: Liquor
# 804: Milk (Cow)
# 805: Eggs
# 806: Yogurt
# 807: Whisky
# 808: Honey
# 809: Liquorice
# 810: Cake
# 811: Ymer
# 812: Other snack food
# 813: Crisp bread
# 814: Dragée
# 815: Salt
# 816: Cream
# 817: Sausage
# 818: Mustard
# 819: Meat bouillon
# 820: Whey
# 821: Fruit preserve
# 822: Gelatin
# 823: Water
# 824: Other fish product
# 825: Milk (Human)
# 826: Other beverage
# 827: Baby food
# 828: Soup
# 829: Other vegetable product
# 830: Tallow
# 831: Fruit gum
# 832: Other candy
# 833: Meringue
# 834: Other animal fat
# 835: Other cocoa product
# 836: Cocoa powder
# 837: Cocoa liquor
# 838: Hot chocolate
# 839: Dried milk
# 840: Milk (Other mammals)
# 841: Buttermilk
# 842: Other fermented milk
# 843: Roe
# 844: Icing
# 845: Snack bar
# 846: Hamburger
# 847: Baked beans
# 848: Chili
# 849: Processed cheese
# 850: Topping
# 851: Sweet custard
# 852: Popcorn
# 853: Hibiscus tea
# 854: Junket
# 855: Falafel
# 856: Other frozen dessert
# 857: Lasagna
# 858: Pectin
# 859: Soy milk
# 860: Cocktail
# 861: Couscous
# 862: Coffee substitute
# 863: Coffee mocha
# 864: Semolina
# 865: Tapioca pearl
# 866: Tostada
# 867: Baked potato
# 868: Spread
# 869: Egg substitute
# 870: Other sandwich
# 871: Ketchup
# 872: Breakfast sandwich
# 873: Butterfat
# 874: Fruit juice
# 875: Other fruit product
# 876: Vegetarian food
# 877: Veggie burger
# 878: Cold cut
# 879: Mixed nuts
# 880: Canola
# 881: Oil-seed Camellia
# 882: Ucuhuba
# 883: Phyllo dough
# 884: Molasses
# 885: Nance
# 886: Natto
# 887: Ravioli
# 888: Other pasta dish
# 889: Tree fern
# 890: Other bread product
# 891: Piki bread
# 892: Rye bread
# 893: Oat bread
# 894: Corn grits
# 895: Pan dulce
# 896: Wonton wrapper
# 897: Greenthread tea
# 898: Fruit-flavor drink
# 899: Vegetable juice
# 900: Dripping
# 901: Pupusa
# 902: Arepa
# 903: Fish burger
# 904: Pot pie
# 905: Stuffing
# 906: Edible shell
# 907: Condensed milk
# 908: Margarine-like spread
# 909: Potato puffs
# 910: Potato gratin
# 911: Soft-necked garlic
# 912: Chinese bayberry
# 913: Mushrooms
# 914: Alcoholic beverages
# 915: Onion-family vegetables
# 916: Pomes
# 917: Brassicas
# 918: Cereals and cereal products
# 919: Citrus
# 920: Cocoa and cocoa products
# 921: Coffee and coffee products
# 922: Crustaceans
# 923: Milk and milk products
# 924: Fats and oils
# 925: Fishes
# 926: Herbs and Spices
# 927: Pulses
# 928: Mollusks
# 929: Nuts
# 930: Beverages
# 931: Fruits
# 932: Green vegetables
# 933: Root vegetables
# 934: Sunburst squash (pattypan squash)
# 935: Green zucchini
# 936: Yellow zucchini
# 937: White cabbage
# 938: Romaine lettuce
# 939: Cow milk, pasteurized, vitamin A + D added, 0% fat
# 940: Cow milk, pasteurized, vitamin A + D added, 1% fat
# 941: Cow milk, pasteurized, vitamin A + D added, 2% fat
# 942: Cow milk, pasteurized, vitamin D added, 3.25% fat
# 943: Albizia gummifera
# 944: Mundu
# 945: Yali pear
# 946: Asparagus racemosus
# 947: Evergreen blackberry
# 948: Asparagus fern
# 949: Thornless blackberry
# 950: Tropical highland blackberry
# 951: Andean blackberry
# 952: Black tea
# 953: Green tea
# 954: Macroalgae
# 955: linseed oil
# 956: Sour orange
# 957: Egg yolk
# 958: Dessert wine
# 959: Red champagne
# 960: Red tea
# 961: White champagne
# 962: Red grape juice
# 963: Plain cream cheese
# 964: Parmesan cheese
# 965: Salted butter
# 966: Sunflower oil
# 967: Grapeseed oil
# 968: Monterey Jack cheese
# 969: Blue cheese
# 970: Greek feta cheese
# 971: Eddoe
# 972: Green apple
# 973: Green onion
# 974: Green grape
# 975: Green cabbage
# 976: Black raisin
# 977: Cannellini bean
# 978: Cubanelle pepper
# 979: Iceberg lettuce
# 980: Pea shoots
# 981: Yau choy
# 982: Chineese plum
# 983: Green plum
# 984: Wampee
# 985: Goji
# 986: Monk fruit
# 987: Cantaloupe melon
# 988: Hawthorn
# 989: Tostada shell
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 985    None
# 986    None
# 987    None
# 988    None
# 989    None
# Length: 990, dtype: object

# %%
len(onto_graph)
# Out:
# 22961549

# %% [markdown]
# ## Add Food Compound Relations to Graph
# ### Clean up content table

# %%
food_content = pd.read_csv(os.path.join(foodb_folder, 'foodb_metabolite_food_relations.csv'))

# %%
food_ids = foods_matched[['menuguide_id', 'id']]

# %%
food_ids.rename(columns={'id': 'food_id'}, inplace=True)
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_9575/3079229746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_ids.rename(columns={'id': 'food_id'}, inplace=True)

# %%
food_content_merge = food_content.merge(food_ids, on='food_id', how='left', suffixes=('_compound', '_food'))

# %%
food_content_merge = food_content_merge[food_content_merge.menuguide_id_food.notna()] 
food_content_merge = food_content_merge[['menuguide_id_compound', 'menuguide_id_food', 'content', 'unit', 'min_content', 'max_content', 'citation']]

# %%
def adjust_units(unit):
    if ' g' in unit:
        unit = unit.replace(' g', 'g')
    
    if ' 100' in unit:
        unit = unit.replace(' 1', '1')
        
    if 'freshweight' in unit:
        unit = unit.replace('freshweight', 'fresh weight')
        
    if 'Fresh' in unit:
        unit = unit.replace('Fresh', 'fresh')
        
    return unit
        

food_content_merge.loc[:, 'unit'] = food_content_merge.unit.apply(adjust_units)

# %%
food_content_merge = food_content_merge.drop_duplicates(subset=['menuguide_id_compound', 'menuguide_id_food', 'content', 'unit'])

# %%
food_content_merge = food_content_merge.reset_index(drop=True)

# %%
food_content_merge = food_content_merge.reset_index(names='menuguide_id')

# %%
food_content_merge.loc[:, 'menuguide_id'] = food_content_merge.menuguide_id.apply(lambda x: f"content_{x}")
food_content_merge
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_9575/469818662.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['content_0' 'content_1' 'content_2' ... 'content_223537' 'content_223538'
#  'content_223539']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   food_content_merge.loc[:, 'menuguide_id'] = food_content_merge.menuguide_id.apply(lambda x: f"content_{x}")
#           menuguide_id menuguide_id_compound menuguide_id_food  content  \
# 0            content_0       compound_168666          food_242     1.08
# 1            content_1       compound_401782          food_242     0.58
# 2            content_2         compound_4138          food_242     1.80
# 3            content_3         compound_4138          food_242     1.80
# 4            content_4          compound_900          food_242    26.00
# ...                ...                   ...               ...      ...
# 223535  content_223535       compound_398532          food_804   993.00
# 223536  content_223536       compound_398536          food_804   993.00
# 223537  content_223537       compound_398543          food_804   993.00
# 223538  content_223538       compound_398565          food_804   993.00
# 223539  content_223539       compound_398573          food_804   993.00
#
#            unit  min_content  max_content       citation
# 0       mg/100g          NaN          NaN            DTU
# 1       mg/100g          NaN          NaN            DTU
# 2            NE          NaN          NaN            DTU
# 3       mg/100g          NaN          NaN            DTU
# 4       mg/100g          NaN          NaN            DTU
# ...         ...          ...          ...            ...
# 223535       uM        942.0       1044.0  PMID:30994344
# 223536       uM        942.0       1044.0  PMID:30994344
# 223537       uM        942.0       1044.0  PMID:30994344
# 223538       uM        942.0       1044.0  PMID:30994344
# 223539       uM        942.0       1044.0  PMID:30994344
#
# [223540 rows x 8 columns]

# %% [markdown]
# ### Add content to graph

# %%
def add_food_content_to_graph(row):
    compound = URIRef(MeNuGUIDE[row['menuguide_id_compound']])
    food = URIRef(MeNuGUIDE[row['menuguide_id_food']])
    quantity = Literal(row['content'], datatype=XSD.float)
    unit = Literal(row['unit'])
    min_content = Literal(row['min_content'], datatype=XSD.float) if pd.notna(row['min_content']) else None
    max_content = Literal(row['max_content'], datatype=XSD.float) if pd.notna(row['max_content']) else None
    citation = Literal(row['citation'])
    
    #content = BNode()
    content = URIRef(MeNuGUIDE[row['menuguide_id']])
    onto_graph.add((content, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(row['menuguide_id'])))
    
    onto_graph.add((content, RDF.type, MeNuGUIDE.Content))
    
    onto_graph.add((food, MeNuGUIDE.hasContent, content))
    onto_graph.add((content, MeNuGUIDE.isContentOf, food))
    
    onto_graph.add((content, MeNuGUIDE.hasCompound, compound))
    onto_graph.add((compound, MeNuGUIDE.isCompoundOf, content))
    
    onto_graph.add((content, MeNuGUIDE.amount, quantity))
    onto_graph.add((content, MeNuGUIDE.unit, unit))
    
    if min_content:
        onto_graph.add((content, MeNuGUIDE.minimumAmount, min_content))
        
    if max_content:
        onto_graph.add((content, MeNuGUIDE.maximumAmount, max_content))
        
    if citation:
        onto_graph.add((content, MeNuGUIDE.hasReference, citation))

# %%
len(onto_graph)
# Out:
# 22961549

# %%
food_content_merge.apply(add_food_content_to_graph, axis=1)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 223535    None
# 223536    None
# 223537    None
# 223538    None
# 223539    None
# Length: 223540, dtype: object

# %%
len(onto_graph)
# Out:
# 25019335

# %%
onto_graph.serialize(destination=os.path.join(ontology_folder, "merged_with_foods_and_compounds.ttl"),
    format="turtle")
# Out:
# <Graph identifier=Na5625b5f59c14ee8b73a915ebca55f5d (<class 'rdflib.graph.Graph'>)>
