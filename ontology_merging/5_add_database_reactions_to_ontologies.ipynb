# %% [markdown]
# *MeNu GUIDE*
# # Integrate Ontology and Database Info - Reactions

# %%
import rdflib
import pandas as pd
from rdflib import URIRef, Literal, Namespace, RDF
from rdflib.plugins.sparql import prepareQuery
import re
import os

# %%
MeNuGUIDE = Namespace("http://MeNuGUIDE.local/")
ChEBI = Namespace("http://purl.obolibrary.org/obo/chebi/")
OBO = Namespace("http://purl.obolibrary.org/obo/")
GO = Namespace("http://www.geneontology.org/formats/oboInOwl#")
FOBI = Namespace("http://purl.obolibrary.org/obo/FOBI_")

# %% [markdown]
# ## Load Graph

# %%
kegg_folder = "/path/to/kegg/data/folder/"
vmh_folder = "/path/to/vmh/data/folder/"
ontology_folder = "/path/to/ontologies/"
processed_data_folder = "/path/to/processed/data/folder/"

# %%
onto_graph = rdflib.Graph()
onto_graph.parse(os.path.join(ontology_folder, "merged_with_foods_and_compounds.ttl"), format="turtle")
# Out:
# <Graph identifier=N05dff0e96c2649b7a861678b835c583e (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Prepare reactions data

# %%
reactions = pd.read_csv(os.path.join(processed_data_folder, "reactions_kegg_vmh.csv"))

# %%
reactions.loc[:, 'description'] = reactions.apply(lambda row: row['kegg_reaction_name'] if pd.notna(row['kegg_reaction_name']) else row['description'], axis=1)

# %%
vmh_reaction_enzymes  = reactions[['menuguide_id', 'ecnumber']]

# %%
reactions = reactions[['menuguide_id', 'vmh_reaction_id', 'kegg_reaction_id', 'description']]

# %%
reactions
# Out:
#          menuguide_id vmh_reaction_id kegg_reaction_id  \
# 0          reaction_0             NaN           R00001
# 1          reaction_1             NaN           R00002
# 2          reaction_2           PPAer           R00004
# 3          reaction_3            PPAm           R00004
# 4          reaction_4            PPAn           R00004
# ...               ...             ...              ...
# 27197  reaction_27198            H2SO              NaN
# 27198  reaction_27199        ASPNH4Li              NaN
# 27199  reaction_27200           NO2t3              NaN
# 27200  reaction_27201          ICDHyr              NaN
# 27201  reaction_27202        BTCOADHi              NaN
#
#                                              description
# 0                     polyphosphate polyphosphohydrolase
# 1      Reduced ferredoxin:dinitrogen oxidoreductase (...
# 2                           diphosphate phosphohydrolase
# 3                           diphosphate phosphohydrolase
# 4                           diphosphate phosphohydrolase
# ...                                                  ...
# 27197                         Hydrogen sulfide oxidation
# 27198  L Aspartate ammonia ligase ADP forming, irreve...
# 27199          nitrite transport out via proton antiport
# 27200                    isocitrate dehydrogenase (NADP)
# 27201  Conversion of crotonoyl-CoA to butyryl-CoA by ...
#
# [27202 rows x 4 columns]

# %%
duplicated_reactions = set(reactions[(reactions.kegg_reaction_id.notna()) & (reactions.kegg_reaction_id.duplicated())].kegg_reaction_id.unique())

# %%
duplicates_cleaned = []

for duplicate in duplicated_reactions:
    affected_rows = reactions[reactions.kegg_reaction_id == duplicate]
    vmh_ids = list(affected_rows.vmh_reaction_id.unique())
    menuguide_id = list(affected_rows.menuguide_id)[0]
    description = list(affected_rows.description)[0]
    duplicates_cleaned.append({'menuguide_id': menuguide_id, 'vmh_reaction_id': vmh_ids, 'kegg_reaction_id': duplicate, 'description': description})

# %%
reactions_not_duplicated = reactions[~reactions.kegg_reaction_id.isin(duplicated_reactions)]

# %%
reactions_duplicates_cleaned = pd.DataFrame(duplicates_cleaned)

# %%
reactions = pd.concat([reactions_not_duplicated, reactions_duplicates_cleaned])

# %%
reactions
# Out:
#       menuguide_id                                    vmh_reaction_id  \
# 0       reaction_0                                                NaN
# 1       reaction_1                                                NaN
# 7       reaction_7                                                NaN
# 8       reaction_8                                                NaN
# 9       reaction_9                                                NaN
# ..             ...                                                ...
# 199  reaction_3997                              [PI345P3P, PI345P3Pn]
# 200  reaction_5079                       [C2M26DCOAHLm, C2M26DCOAHLx]
# 201  reaction_1932  [HMR_3538, HMR_3539, HMR_3540, HMR_3541, HMR_3...
# 202  reaction_7182                              [PI345P5P, PI345P5Pn]
# 203   reaction_140                                    [NDPK2n, NDPK2]
#
#     kegg_reaction_id                                        description
# 0             R00001                 polyphosphate polyphosphohydrolase
# 1             R00002  Reduced ferredoxin:dinitrogen oxidoreductase (...
# 7             R00005                  urea-1-carboxylate amidohydrolase
# 8             R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# 9             R00008  4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# ..               ...                                                ...
# 199           R04513  Phosphatidylinositol-3,4,5-trisphosphate 3-pho...
# 200           R06411  3-hydroxy-2,6-dimethyl-5-methylene-heptanoyl-C...
# 201           R02115                         Steryl-ester acylhydrolase
# 202           R09827  1-phosphatidyl-1D-myo-inositol-3,4,5-trisphosp...
# 203           R00156                         ATP:UDP phosphotransferase
#
# [26789 rows x 4 columns]

# %%
reactions = reactions.reset_index(drop=True)

# %%
reactions = reactions.drop(columns='menuguide_id')

# %%
reactions = reactions.reset_index(names='menuguide_id')

# %%
reactions.loc[:, "menuguide_id"] = reactions.menuguide_id.apply(lambda x: f"reaction_{x}")
# Out:
# /var/folders/t7/3lkh5kq93tq79dxpjy9vqc_m0000gn/T/ipykernel_11413/634851196.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['reaction_0' 'reaction_1' 'reaction_2' ... 'reaction_26786'
#  'reaction_26787' 'reaction_26788']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   reactions.loc[:, "menuguide_id"] = reactions.menuguide_id.apply(lambda x: f"reaction_{x}")

# %%
reactions
# Out:
#          menuguide_id                                    vmh_reaction_id  \
# 0          reaction_0                                                NaN
# 1          reaction_1                                                NaN
# 2          reaction_2                                                NaN
# 3          reaction_3                                                NaN
# 4          reaction_4                                                NaN
# ...               ...                                                ...
# 26784  reaction_26784                              [PI345P3P, PI345P3Pn]
# 26785  reaction_26785                       [C2M26DCOAHLm, C2M26DCOAHLx]
# 26786  reaction_26786  [HMR_3538, HMR_3539, HMR_3540, HMR_3541, HMR_3...
# 26787  reaction_26787                              [PI345P5P, PI345P5Pn]
# 26788  reaction_26788                                    [NDPK2n, NDPK2]
#
#       kegg_reaction_id                                        description
# 0               R00001                 polyphosphate polyphosphohydrolase
# 1               R00002  Reduced ferredoxin:dinitrogen oxidoreductase (...
# 2               R00005                  urea-1-carboxylate amidohydrolase
# 3               R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# 4               R00008  4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# ...                ...                                                ...
# 26784           R04513  Phosphatidylinositol-3,4,5-trisphosphate 3-pho...
# 26785           R06411  3-hydroxy-2,6-dimethyl-5-methylene-heptanoyl-C...
# 26786           R02115                         Steryl-ester acylhydrolase
# 26787           R09827  1-phosphatidyl-1D-myo-inositol-3,4,5-trisphosp...
# 26788           R00156                         ATP:UDP phosphotransferase
#
# [26789 rows x 4 columns]

# %%
reactions_vmh = {}

def get_vmh_reaction_id(row):
    if type(row['vmh_reaction_id']) == list:
        for reaction_id in row['vmh_reaction_id']:
            reactions_vmh[reaction_id] = row['menuguide_id']
    elif pd.notna(row['vmh_reaction_id']):
        reactions_vmh[row['vmh_reaction_id']] = row['menuguide_id']

reactions.apply(get_vmh_reaction_id, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 26784    None
# 26785    None
# 26786    None
# 26787    None
# 26788    None
# Length: 26789, dtype: object

# %%
reactions_kegg = reactions[reactions.kegg_reaction_id.notna()]
reactions_kegg = reactions_kegg.set_index('kegg_reaction_id')['menuguide_id']
reactions_kegg_to_menuguide_id = reactions_kegg.to_dict()

# %%
reactions_dict = {}

def add_to_reaction_dict(row):
    key = row['menuguide_id']
    
    reactions_dict[key] = {}
    
    if pd.notna(row['kegg_reaction_id']):
        reactions_dict[key].update({'kegg_id': row['kegg_reaction_id']})
        
    if type(row['vmh_reaction_id']) == list or pd.notna(row['vmh_reaction_id']):
        reactions_dict[key].update({'vmh_id': row['vmh_reaction_id']})
        
    if pd.notna(row['description']):
        reactions_dict[key].update({'description': row['description']})

reactions.apply(add_to_reaction_dict, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 26784    None
# 26785    None
# 26786    None
# 26787    None
# 26788    None
# Length: 26789, dtype: object

# %% [markdown]
# ### Add substrates

# %%
kegg_substrates = pd.read_csv(os.path.join(kegg_folder, "kegg_reaction_substrates.csv"))
vmh_substrates = pd.read_csv(os.path.join(vmh_folder, "vmh_reaction_substrates.csv"))
compound_identifiers = pd.read_csv(os.path.join(processed_data_folder, "compounds_all_databases_merged_ids.csv"), dtype={'markerdb_id': 'string', 'kegg_id': 'string', 'vmh_id': 'string'})

# %%
kegg_substrates = kegg_substrates.merge(compound_identifiers, left_on='substrate', right_on='kegg_id', how='left')[['substrate', 'reaction_id', 'menuguide_id']]
unmatched_kegg_reactions = set(kegg_substrates[kegg_substrates.menuguide_id.isna()].reaction_id.unique())
kegg_substrates = kegg_substrates[kegg_substrates.menuguide_id.notna()]

# %%
vmh_substrates.loc[:, "substrate"] = vmh_substrates.substrate.str.lower()
vmh_substrates = vmh_substrates.merge(compound_identifiers, left_on='substrate', right_on='vmh_id', how='left')[['substrate', 'reaction_abbreviation', 'menuguide_id']]
unmatched_vmh_reactions = set(vmh_substrates[vmh_substrates.substrate.isna()].reaction_abbreviation.unique())
vmh_substrates = vmh_substrates[vmh_substrates.substrate.notna()]

# %%
for reaction in unmatched_kegg_reactions:
    menuguide_reaction_id = reactions_kegg[reaction]
    if menuguide_reaction_id in reactions_dict:
        del(reactions_dict[menuguide_reaction_id])
        print(f"Reaction {reaction} deleted.")
# Out:
# Reaction R13111 deleted.
# Reaction R13106 deleted.
# Reaction R13132 deleted.
# Reaction R13122 deleted.
# Reaction R13125 deleted.
# Reaction R13131 deleted.
# Reaction R13130 deleted.
# Reaction R13123 deleted.
# Reaction R13109 deleted.
# Reaction R13133 deleted.
# Reaction R13134 deleted.
# Reaction R13121 deleted.
# Reaction R13129 deleted.
# Reaction R13117 deleted.

# %%
for reaction in unmatched_vmh_reactions:
    menuguide_reaction_id = reactions_vmh[reaction]
    del(reactions_dict[menuguide_reaction_id])
    print(f"Reaction {reaction} deleted.")
# Out:
# Reaction dreplication deleted.
# Reaction pbiosynthesis deleted.
# Reaction rtranscription deleted.

# %%
vmh_substrates['menuguide_reaction_id'] = vmh_substrates.reaction_abbreviation.apply(lambda x: reactions_vmh[x])
kegg_substrates['menuguide_reaction_id'] = kegg_substrates.reaction_id.apply(lambda x: reactions_kegg[x])

# %%
def add_to_reaction_dict(row):
    reaction_id = row['menuguide_reaction_id']
    substrate_id = row['menuguide_id']
    if reaction_id in reactions_dict:
        entry = reactions_dict[reaction_id]
        if 'substrates' in entry:
            entry['substrates'].add(substrate_id)
        else:
            entry['substrates'] = {substrate_id}

# %%
kegg_substrates.apply(add_to_reaction_dict, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 37048    None
# 37049    None
# 37050    None
# 37051    None
# 37052    None
# Length: 37039, dtype: object

# %%
vmh_substrates.apply(add_to_reaction_dict, axis=1)
# Out:
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 1289969    None
# 1289970    None
# 1289971    None
# 1289972    None
# 1289973    None
# Length: 93397, dtype: object

# %% [markdown]
# ### Add products

# %%
kegg_products = pd.read_csv(os.path.join(kegg_folder, "kegg_reaction_products.csv"))
vmh_products = pd.read_csv(os.path.join(vmh_folder, "vmh_reaction_products.csv"))

# %%
vmh_products
# Out:
#           product reaction_abbreviation
# 0      10fthf5glu          10FTHF5GLUtl
# 1      10fthf5glu          10FTHF5GLUtm
# 2      10fthf6glu          10FTHF6GLUtl
# 3      10fthf6glu          10FTHF6GLUtm
# 4      10fthf7glu          10FTHF7GLUtl
# ...           ...                   ...
# 44597         co2                ICDHyr
# 44598       nadph                ICDHyr
# 44599       btcoa              BTCOADHi
# 44600       fdxrd              BTCOADHi
# 44601         nad              BTCOADHi
#
# [44602 rows x 2 columns]

# %%
kegg_products = kegg_products.merge(compound_identifiers, left_on='product', right_on='kegg_id', how='left')[['product', 'reaction_id', 'menuguide_id']]
unmatched_kegg_reactions = set(kegg_products[kegg_products.menuguide_id.isna()].reaction_id.unique())
kegg_products = kegg_products[kegg_products.menuguide_id.notna()]

# %%
vmh_products.loc[:, "products"] = vmh_products['product'].str.lower()

# %%
compound_identifiers_vmh = compound_identifiers[compound_identifiers.vmh_id.notna()]

# %%
vmh_products = vmh_products.merge(compound_identifiers_vmh, left_on='products', right_on='vmh_id', how='left')[['products', 'reaction_abbreviation', 'menuguide_id']]

# %%
unmatched_vmh_reactions = set(vmh_products[vmh_products['products'].isna()].reaction_abbreviation.unique())

# %%
vmh_products = vmh_products[vmh_products['products'].notna()]

# %%
for reaction in unmatched_kegg_reactions:
    menuguide_reaction_id = reactions_kegg[reaction]
    if menuguide_reaction_id in reactions_dict:
        del(reactions_dict[menuguide_reaction_id])
        print(f"Reaction {reaction} deleted.")
# Out:
# Reaction R13102 deleted.
# Reaction R13141 deleted.
# Reaction R13110 deleted.
# Reaction R13108 deleted.
# Reaction R13115 deleted.
# Reaction R11151 deleted.
# Reaction R13104 deleted.
# Reaction R13124 deleted.
# Reaction R13100 deleted.
# Reaction R13099 deleted.
# Reaction R13128 deleted.
# Reaction R11152 deleted.
# Reaction R13103 deleted.
# Reaction R13101 deleted.

# %%
for reaction in unmatched_vmh_reactions:
    menuguide_reaction_id = reactions_vmh[reaction]
    del(reactions_dict[menuguide_reaction_id])
    print(f"Reaction {reaction} deleted.")
# Out:
# Reaction EX_co2[e] deleted.
# Reaction EX_HC01943(e) deleted.
# Reaction EX_lstnm5[e] deleted.
# Reaction EX_7klitchol(e) deleted.
# Reaction EX_lneldc(e) deleted.
# Reaction EX_fdp(e) deleted.
# Reaction EX_lpchol_hs(e) deleted.
# Reaction EX_sql(e) deleted.
# Reaction EX_proargasp[e] deleted.
# Reaction DM_akg[c] deleted.
# Reaction EX_glucys[e] deleted.
# Reaction EX_4hbz(e) deleted.
# Reaction EX_fucacngalacglcgalgluside_hs(e) deleted.
# Reaction EX_3hpp(e) deleted.
# Reaction EX_bgly(e) deleted.
# Reaction EX_eandrstrn[e] deleted.
# Reaction EX_34dhoxmand[e] deleted.
# Reaction EX_MGlcn131(e) deleted.
# Reaction DM_tudca3s[c] deleted.
# Reaction EX_bvite[e] deleted.
# Reaction EX_lyslyslys[e] deleted.
# Reaction EX_succ[e] deleted.
# Reaction EX_c6dc(e) deleted.
# Reaction sink_HC02194[c] deleted.
# Reaction EX_MGlcn17_rl(e) deleted.
# Reaction DM_pe_hs(r) deleted.
# Reaction EX_HC00001[e] deleted.
# Reaction EX_glyc[e] deleted.
# Reaction EX_sT_antigen(e) deleted.
# Reaction EX_ahdt[e] deleted.
# Reaction EX_abt_D(e) deleted.
# Reaction sink_25hvitd2[c] deleted.
# Reaction EX_mdzglc[e] deleted.
# Reaction EX_MGlcn65(e) deleted.
# Reaction EX_sphmyln181161_hs[e] deleted.
# Reaction EX_fucfucgalacglcgalgluside_hs[e] deleted.
# Reaction EX_MGlcn75(e) deleted.
# Reaction DM_core8_g_ deleted.
# Reaction EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs(e) deleted.
# Reaction EX_docohxeth(e) deleted.
# Reaction EX_MGlcn188(e) deleted.
# Reaction sink_25hvitd2(c) deleted.
# Reaction EX_thyox_L[e] deleted.
# Reaction EX_glyphe[e] deleted.
# Reaction EX_deoxfvs[e] deleted.
# Reaction EX_acnam[e] deleted.
# Reaction EX_trpilelys[e] deleted.
# Reaction EX_CE4890[e] deleted.
# Reaction EX_ivcrn(e) deleted.
# Reaction EX_sTn_antigen(e) deleted.
# Reaction EX_Lcystin[e] deleted.
# Reaction EX_MGlcn137(e) deleted.
# Reaction EX_bildglcur(e) deleted.
# Reaction EX_eaflatoxin[e] deleted.
# Reaction EX_imp[e] deleted.
# Reaction EX_HC02200[e] deleted.
# Reaction EX_apoC_Lys[e] deleted.
# Reaction EX_MGlcn86(e) deleted.
# Reaction EX_dttp[e] deleted.
# Reaction EX_aspasnglu[e] deleted.
# Reaction EX_tyrleuarg[e] deleted.
# Reaction EX_estriolglc(e) deleted.
# Reaction EX_c8dc(e) deleted.
# Reaction EX_carn(e) deleted.
# Reaction EX_magpalm_hs[e] deleted.
# Reaction EX_metglntyr[e] deleted.
# Reaction sink_thf[c] deleted.
# Reaction EX_MGlcn42_rl(e) deleted.
# Reaction EX_HC02220(e) deleted.
# Reaction EX_pe14_hs(e) deleted.
# Reaction EX_trp_L(e) deleted.
# Reaction EX_cspg_b_degr(e) deleted.
# Reaction EX_txa2(e) deleted.
# Reaction EX_pear_hs[e] deleted.
# Reaction EX_cl(e) deleted.
# Reaction EX_pep[e] deleted.
# Reaction EX_11_cis_retfa(e) deleted.
# Reaction EX_pheleuasp[e] deleted.
# Reaction EX_fdp[e] deleted.
# Reaction EX_MGlcn148_rl(e) deleted.
# Reaction EX_hg2(e) deleted.
# Reaction EX_s2l2n2m2m(e) deleted.
# Reaction EX_Rtotal3[e] deleted.
# Reaction EX_c10crn[e] deleted.
# Reaction EX_mepi[e] deleted.
# Reaction EX_ibupgluc[e] deleted.
# Reaction EX_hdcea(e) deleted.
# Reaction DM_m_em_3gacpail_prot_hs_r_ deleted.
# Reaction EX_mthgxl(e) deleted.
# Reaction EX_pe17_hs[e] deleted.
# Reaction EX_MGlcn57_rl(e) deleted.
# Reaction EX_hisasp[e] deleted.
# Reaction EX_sphmyln181201_hs(e) deleted.
# Reaction EX_tetdece1crn[e] deleted.
# Reaction EX_tag_hs[e] deleted.
# Reaction EX_MGlcn78(e) deleted.
# Reaction EX_mercplaccys[e] deleted.
# Reaction EX_MGlcn151_rl(e) deleted.
# Reaction EX_andrstrn[e] deleted.
# Reaction EX_HC02206[e] deleted.
# Reaction EX_CE5868[e] deleted.
# Reaction EX_mi1p_D[e] deleted.
# Reaction EX_hom_L(e) deleted.
# Reaction EX_trpglyval[e] deleted.
# Reaction EX_xolest204_hs[e] deleted.
# Reaction EX_eic21114tr[e] deleted.
# Reaction EX_M00010[e] deleted.
# Reaction EX_5aptn(e) deleted.
# Reaction EX_lthstrl(e) deleted.
# Reaction EX_adp[e] deleted.
# Reaction EX_4hatvlac[e] deleted.
# Reaction EX_fucacngal14acglcgalgluside_hs[e] deleted.
# Reaction EX_CE1243[e] deleted.
# Reaction EX_estrone(e) deleted.
# Reaction sink_pmtcoa[c] deleted.
# Reaction EX_cysasnmet[e] deleted.
# Reaction EX_pe12_hs[e] deleted.
# Reaction EX_hdd2crn[e] deleted.
# Reaction EX_CE5788(e) deleted.
# Reaction EX_am9csa[e] deleted.
# Reaction EX_magarachi_hs(e) deleted.
# Reaction EX_dca[e] deleted.
# Reaction EX_23cump(e) deleted.
# Reaction EX_pe2linl_hs(e) deleted.
# Reaction EX_cca_d3[e] deleted.
# Reaction EX_asnphecys[e] deleted.
# Reaction EX_lysgluglu[e] deleted.
# Reaction EX_2hibup_R[e] deleted.
# Reaction EX_MGlcn101(e) deleted.
# Reaction EX_CE1918(e) deleted.
# Reaction EX_pcresol(e) deleted.
# Reaction EX_xoldiolone(e) deleted.
# Reaction EX_prpp(e) deleted.
# Reaction EX_tsul[e] deleted.
# Reaction EX_argsuc[e] deleted.
# Reaction DM_HQN deleted.
# Reaction sink_Tyr_ggn[c] deleted.
# Reaction EX_acngalacglcgal14acglcgalgluside_hs(e) deleted.
# Reaction EX_progly[e] deleted.
# Reaction EX_MGlcn98_rl(e) deleted.
# Reaction EX_MGlcn51(e) deleted.
# Reaction EX_HC02206(e) deleted.
# Reaction EX_tchola[e] deleted.
# Reaction EX_34hpl[e] deleted.
# Reaction EX_dmhptcrn(e) deleted.
# Reaction EX_glymet(e) deleted.
# Reaction EX_mn2(e) deleted.
# Reaction EX_dad_2(e) deleted.
# Reaction EX_CE4843[e] deleted.
# Reaction EX_CE1943(e) deleted.
# Reaction EX_MGlcn129_rl(e) deleted.
# Reaction sink_pheme(c) deleted.
# Reaction EX_cortsn(e) deleted.
# Reaction EX_mqn11[e] deleted.
# Reaction EX_M02382[e] deleted.
# Reaction sink_lys_L[c] deleted.
# Reaction EX_pe161_hs(e) deleted.
# Reaction EX_ddecrn(e) deleted.
# Reaction EX_galside_hs[e] deleted.
# Reaction EX_glytyrlys[e] deleted.
# Reaction EX_pcholdoc_hs[e] deleted.
# Reaction EX_acorn(e) deleted.
# Reaction EX_3pg(e) deleted.
# Reaction sink_dd2coa(c) deleted.
# Reaction sink_gln_L[c] deleted.
# Reaction EX_18harachd[e] deleted.
# Reaction EX_pcholn281_hs(e) deleted.
# Reaction EX_aspprolys[e] deleted.
# Reaction EX_MGlcn183(e) deleted.
# Reaction EX_2pg[e] deleted.
# Reaction EX_2mcit[e] deleted.
# Reaction DM_gdca3s[c] deleted.
# Reaction EX_4abut(e) deleted.
# Reaction sink_dchac[c] deleted.
# Reaction EX_MGlcn156_rl(e) deleted.
# Reaction EX_MGlcn175_rl(e) deleted.
# Reaction EX_ditp[e] deleted.
# Reaction EX_M02909[e] deleted.
# Reaction EX_lmn30(e) deleted.
# Reaction EX_fum(e) deleted.
# Reaction EX_MGlcn117_rl(e) deleted.
# Reaction EX_3aib[e] deleted.
# Reaction EX_leuktrB4[e] deleted.
# Reaction EX_tagat_D[e] deleted.
# Reaction EX_lnlc[e] deleted.
# Reaction EX_so3(e) deleted.
# Reaction EX_crn[e] deleted.
# Reaction EX_5a2opntn[e] deleted.
# Reaction EX_pcholpalme_hs(e) deleted.
# Reaction EX_CE7081[e] deleted.
# Reaction EX_prgnlones[e] deleted.
# Reaction DM_6hddopaqn[c] deleted.
# Reaction DM_hyochol[c] deleted.
# Reaction EX_estroneglc(e) deleted.
# Reaction EX_metsox_R_L(e) deleted.
# Reaction EX_CE2047(e) deleted.
# Reaction EX_dopa4glcur[e] deleted.
# Reaction EX_dmhptcrn[e] deleted.
# Reaction EX_3moxtyr[e] deleted.
# Reaction EX_pcholn203_hs(e) deleted.
# Reaction EX_MGlcn161(e) deleted.
# Reaction EX_dcyt(e) deleted.
# Reaction EX_CE1918[e] deleted.
# Reaction EX_cspg_c(e) deleted.
# Reaction EX_MGlcn157(e) deleted.
# Reaction EX_sbt_D(e) deleted.
# Reaction EX_dca24g[e] deleted.
# Reaction EX_C05957[e] deleted.
# Reaction EX_trpglugly[e] deleted.
# Reaction EX_HC02192(e) deleted.
# Reaction sink_vitd3(c) deleted.
# Reaction EX_trpiletrp[e] deleted.
# Reaction DM_dgtp_m_ deleted.
# Reaction EX_lnlccrn(e) deleted.
# Reaction EX_asplysglu[e] deleted.
# Reaction EX_mvlac(e) deleted.
# Reaction sink_Ser_Gly_Ala_X_Gly(r) deleted.
# Reaction EX_galfucgalacglcgal14acglcgalgluside_hs[e] deleted.
# Reaction EX_glz[e] deleted.
# Reaction EX_progly(e) deleted.
# Reaction EX_triodthy[e] deleted.
# Reaction EX_MGlcn191(e) deleted.
# Reaction EX_MGlcn109(e) deleted.
# Reaction EX_adpoh[e] deleted.
# Reaction EX_dmgly[e] deleted.
# Reaction EX_lyx_L(e) deleted.
# Reaction EX_MGlcn163_rl(e) deleted.
# Reaction EX_2omfuc(e) deleted.
# Reaction EX_leuktrC4(e) deleted.
# Reaction EX_MGlcn187_rl(e) deleted.
# Reaction EX_sphgn(e) deleted.
# Reaction EX_N1aspmd[e] deleted.
# Reaction EX_gm1_hs[e] deleted.
# Reaction EX_eandrstrn(e) deleted.
# Reaction EX_ribflv(e) deleted.
# Reaction EX_n5m2masn[e] deleted.
# Reaction sink_tetdece1coa[c] deleted.
# Reaction EX_pcholeic_hs[e] deleted.
# Reaction EX_odecrn(e) deleted.
# Reaction EX_carn[e] deleted.
# Reaction EX_c16dc(e) deleted.
# Reaction DM_T_antigen_g_ deleted.
# Reaction EX_vitd3(e) deleted.
# Reaction DM_lca24g[c] deleted.
# Reaction EX_5htrp(e) deleted.
# Reaction DM_gca3s[c] deleted.
# Reaction EX_tmao(e) deleted.
# Reaction DM_ascb_L(c) deleted.
# Reaction EX_acglu[e] deleted.
# Reaction EX_cytd[e] deleted.
# Reaction EX_galmannan(e) deleted.
# Reaction EX_dopa(e) deleted.
# Reaction EX_xol7ah3[e] deleted.
# Reaction EX_rbt[e] deleted.
# Reaction EX_xoltri25(e) deleted.
# Reaction EX_3ivcrn(e) deleted.
# Reaction EX_7ohocata(e) deleted.
# Reaction EX_pmeth(e) deleted.
# Reaction EX_ile_L(e) deleted.
# Reaction EX_pcholn224_hs[e] deleted.
# Reaction EX_ametam[e] deleted.
# Reaction EX_nmn(e) deleted.
# Reaction EX_M01819[e] deleted.
# Reaction EX_4hpro[e] deleted.
# Reaction sink_c81coa[c] deleted.
# Reaction EX_argglygly[e] deleted.
# Reaction EX_c51crn(e) deleted.
# Reaction EX_mev_R(e) deleted.
# Reaction EX_MGlcn71_rl(e) deleted.
# Reaction EX_urcan[e] deleted.
# Reaction DM_kdn_c_ deleted.
# Reaction EX_xol7aone[e] deleted.
# Reaction EX_chtn(e) deleted.
# Reaction EX_3ispvs[e] deleted.
# Reaction EX_dsT_antigen(e) deleted.
# Reaction EX_2hibup_S[e] deleted.
# Reaction EX_MGlcn45_rl(e) deleted.
# Reaction sink_crvnc[c] deleted.
# Reaction EX_mqn8(e) deleted.
# Reaction EX_C14768(e) deleted.
# Reaction EX_lstnm4[e] deleted.
# Reaction EX_tyrargser[e] deleted.
# Reaction EX_gluilelys[e] deleted.
# Reaction EX_HC01444(e) deleted.
# Reaction EX_hspg_degr_15(e) deleted.
# Reaction EX_fuc_L(e) deleted.
# Reaction EX_MGlcn26_rl(e) deleted.
# Reaction EX_nrpphrsf(e) deleted.
# Reaction EX_lnlncg[e] deleted.
# Reaction EX_gudac[e] deleted.
# Reaction EX_7dhchsterol[e] deleted.
# Reaction EX_acmana[e] deleted.
# Reaction EX_CE4723[e] deleted.
# Reaction EX_nwharg(e) deleted.
# Reaction EX_3hpp[e] deleted.
# Reaction EX_MGlcn14(e) deleted.
# Reaction EX_cinnm(e) deleted.
# Reaction EX_leuleutrp[e] deleted.
# Reaction EX_tmdm3[e] deleted.
# Reaction EX_leuktrB4wcooh(e) deleted.
# Reaction EX_MGlcn40_rl(e) deleted.
# Reaction EX_pcholet_hs[e] deleted.
# Reaction EX_mg2(e) deleted.
# Reaction EX_Lcyst[e] deleted.
# Reaction EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[e] deleted.
# Reaction EX_MGlcn151(e) deleted.
# Reaction EX_strch1[e] deleted.
# Reaction EX_docosdiac(e) deleted.
# Reaction DM_tym[c] deleted.
# Reaction EX_arach[e] deleted.
# Reaction EX_MGlcn142_rl(e) deleted.
# Reaction EX_MGlcn128(e) deleted.
# Reaction DM_bandmt[c] deleted.
# Reaction EX_glgchlo[e] deleted.
# Reaction EX_thrargtyr[e] deleted.
# Reaction EX_paf_hs(e) deleted.
# Reaction EX_pcholole_hs[e] deleted.
# Reaction EX_HC00342[e] deleted.
# Reaction EX_glygly[e] deleted.
# Reaction EX_4hdebrisoquine(e) deleted.
# Reaction EX_C14770(e) deleted.
# Reaction EX_lac_D[e] deleted.
# Reaction EX_q10[e] deleted.
# Reaction EX_MGlcn146_rl(e) deleted.
# Reaction EX_hyptaur[e] deleted.
# Reaction EX_hishislys[e] deleted.
# Reaction EX_cbl2(e) deleted.
# Reaction EX_56dthm[e] deleted.
# Reaction EX_MGlcn187(e) deleted.
# Reaction DM_dopa[c] deleted.
# Reaction EX_2hb(e) deleted.
# Reaction sink_crvnc(c) deleted.
# Reaction EX_xtsn(e) deleted.
# Reaction EX_normete_L(e) deleted.
# Reaction EX_xylu_D[e] deleted.
# Reaction EX_13_cis_retnglc[e] deleted.
# Reaction EX_HC01944(e) deleted.
# Reaction EX_txa2[e] deleted.
# Reaction EX_desfvs[e] deleted.
# Reaction EX_gam(e) deleted.
# Reaction EX_decdicrn[e] deleted.
# Reaction EX_3ityr_L(e) deleted.
# Reaction EX_xolest204_hs(e) deleted.
# Reaction EX_avite1[e] deleted.
# Reaction EX_gq1balpha_hs(e) deleted.
# Reaction EX_gluside_hs[e] deleted.
# Reaction EX_MGlcn190_rl(e) deleted.
# Reaction sink_thr_L[c] deleted.
# Reaction EX_cysglutrp[e] deleted.
# Reaction EX_CE2006[e] deleted.
# Reaction EX_aicar(e) deleted.
# Reaction EX_MGlcn22_rl(e) deleted.
# Reaction EX_pail_hs[e] deleted.
# Reaction EX_3hanthrn[e] deleted.
# Reaction EX_C10164(e) deleted.
# Reaction EX_csn(e) deleted.
# Reaction sink_cys_L[c] deleted.
# Reaction EX_achom_L(e) deleted.
# Reaction EX_3ttetddcoacrn(e) deleted.
# Reaction EX_isoprene(e) deleted.
# Reaction sink_decdicoa[c] deleted.
# Reaction EX_2hatvlac[e] deleted.
# Reaction EX_6thf[e] deleted.
# Reaction EX_3hpvs[e] deleted.
# Reaction EX_sucsal(e) deleted.
# Reaction EX_leuproarg[e] deleted.
# Reaction EX_vitd3[e] deleted.
# Reaction EX_2hydog[e] deleted.
# Reaction EX_pydx5p[e] deleted.
# Reaction EX_5hoxindoa(e) deleted.
# Reaction EX_pe_hs[e] deleted.
# Reaction EX_im4ac(e) deleted.
# Reaction EX_tymsf[e] deleted.
# Reaction EX_MGlcn112(e) deleted.
# Reaction EX_MGlcn98(e) deleted.
# Reaction sink_pro_L[c] deleted.
# Reaction EX_pac[e] deleted.
# Reaction EX_lneldccrn(e) deleted.
# Reaction EX_3hadpac(e) deleted.
# Reaction EX_M01989[e] deleted.
# Reaction EX_CE4970[e] deleted.
# Reaction EX_crmp_hs[e] deleted.
# Reaction EX_MGlcn41_rl(e) deleted.
# Reaction EX_pchol2ole_hs[e] deleted.
# Reaction EX_L2aadp(e) deleted.
# Reaction EX_s2l2fn2m2masn(e) deleted.
# Reaction EX_aprgstrn[e] deleted.
# Reaction EX_icit(e) deleted.
# Reaction EX_MGlcn173(e) deleted.
# Reaction EX_c4crn[e] deleted.
# Reaction EX_13dampp(e) deleted.
# Reaction EX_agam1b6agal(e) deleted.
# Reaction EX_retinol_cis_11[e] deleted.
# Reaction EX_CE5025(e) deleted.
# Reaction EX_MGlcn45(e) deleted.
# Reaction EX_phacgly(e) deleted.
# Reaction EX_acn23acngalgbside_hs(e) deleted.
# Reaction EX_o2[e] deleted.
# Reaction EX_pydam[e] deleted.
# Reaction EX_5fthf(e) deleted.
# Reaction sink_dgchol[c] deleted.
# Reaction EX_pcrn(e) deleted.
# Reaction EX_c10crn(e) deleted.
# Reaction EX_trpleuval[e] deleted.
# Reaction EX_pchol2ste_hs(e) deleted.
# Reaction EX_stacmp[ev] deleted.
# Reaction EX_pheacgly[e] deleted.
# Reaction EX_leuleu[e] deleted.
# Reaction EX_MGlcn61_rl(e) deleted.
# Reaction EX_MGlcn71(e) deleted.
# Reaction EX_forglu[e] deleted.
# Reaction EX_ileargile[e] deleted.
# Reaction EX_orn[e] deleted.
# Reaction EX_MGlcn70(e) deleted.
# Reaction EX_glygn5(e) deleted.
# Reaction EX_c6crn(e) deleted.
# Reaction EX_clpnd[e] deleted.
# Reaction EX_MGlcn144(e) deleted.
# Reaction EX_MGlcn13_rl(e) deleted.
# Reaction EX_dha(e) deleted.
# Reaction EX_3hpppnohgluc(e) deleted.
# Reaction EX_serargala[e] deleted.
# Reaction EX_ethmalac(e) deleted.
# Reaction EX_adn(e) deleted.
# Reaction EX_M00021[e] deleted.
# Reaction EX_thrmetarg[e] deleted.
# Reaction EX_orot(e) deleted.
# Reaction EX_glypro(e) deleted.
# Reaction EX_alaargcys[e] deleted.
# Reaction EX_Rtotal2(e) deleted.
# Reaction EX_CE5788[e] deleted.
# Reaction EX_estroneglc[e] deleted.
# Reaction EX_mepi(e) deleted.
# Reaction EX_C05302[e] deleted.
# Reaction EX_gluglu[e] deleted.
# Reaction EX_provalgln[e] deleted.
# Reaction EX_MGlcn17(e) deleted.
# Reaction EX_leuktrD4[e] deleted.
# Reaction EX_MGlcn144_rl(e) deleted.
# Reaction EX_3thexddcoacrn(e) deleted.
# Reaction EX_1hibupglu_S[e] deleted.
# Reaction EX_9_cis_retfa[e] deleted.
# Reaction EX_MGlcn5(e) deleted.
# Reaction EX_oxyp7rb[e] deleted.
# Reaction EX_M00503[e] deleted.
# Reaction EX_glutar(e) deleted.
# Reaction EX_dsmsterol(e) deleted.
# Reaction EX_coprost(e) deleted.
# Reaction EX_oleth[e] deleted.
# Reaction EX_cspg_b[e] deleted.
# Reaction EX_MGlcn47_rl(e) deleted.
# Reaction EX_core7(e) deleted.
# Reaction EX_fucfucfucgalacglcgal14acglcgalgluside_hs[e] deleted.
# Reaction EX_didecaeth[e] deleted.
# Reaction EX_pailste_hs(e) deleted.
# Reaction EX_biomass(e) deleted.
# Reaction EX_acgam[e] deleted.
# Reaction EX_acnacngalgbside_hs[e] deleted.
# Reaction EX_retfa(e) deleted.
# Reaction EX_fad(e) deleted.
# Reaction EX_amp(e) deleted.
# Reaction EX_tiggly[e] deleted.
# Reaction DM_srtn[c] deleted.
# Reaction EX_MGlcn110_rl(e) deleted.
# Reaction EX_MGlcn64_rl(e) deleted.
# Reaction EX_strdnc[e] deleted.
# Reaction EX_cyssermet[e] deleted.
# Reaction EX_sTn_antigen[e] deleted.
# Reaction EX_MGlcn116(e) deleted.
# Reaction EX_paf_hs[e] deleted.
# Reaction EX_MGlcn159(e) deleted.
# Reaction EX_am1alcs[e] deleted.
# Reaction EX_arachd(e) deleted.
# Reaction EX_tetdecaeth[e] deleted.
# Reaction EX_lca3s[e] deleted.
# Reaction EX_MGlcn130(e) deleted.
# Reaction EX_proproarg[e] deleted.
# Reaction EX_CE2172[e] deleted.
# Reaction DM_CE5026[c] deleted.
# Reaction EX_glygn4(e) deleted.
# Reaction EX_prgnlones(e) deleted.
# Reaction EX_glygn4[e] deleted.
# Reaction EX_trpthrile[e] deleted.
# Reaction EX_aact(e) deleted.
# Reaction EX_argargmet[e] deleted.
# Reaction EX_HC01444[e] deleted.
# Reaction EX_subgly(e) deleted.
# Reaction EX_cl[e] deleted.
# Reaction EX_CE7082[e] deleted.
# Reaction sink_C02528[c] deleted.
# Reaction EX_orn_D[e] deleted.
# Reaction EX_MGlcn12_rl(e) deleted.
# Reaction EX_am1c4n9cs[e] deleted.
# Reaction EX_hcys_L(e) deleted.
# Reaction EX_taxol[e] deleted.
# Reaction EX_co[e] deleted.
# Reaction EX_dca3g[e] deleted.
# Reaction EX_ch4s(e) deleted.
# Reaction EX_HC00005[e] deleted.
# Reaction EX_retn(e) deleted.
# Reaction EX_nfdlac[e] deleted.
# Reaction EX_ttdcrn[e] deleted.
# Reaction EX_ileasnhis[e] deleted.
# Reaction EX_MGlcn182_rl(e) deleted.
# Reaction EX_MGlcn23(e) deleted.
# Reaction EX_MGlcn163(e) deleted.
# Reaction EX_MGlcn67(e) deleted.
# Reaction sink_c226coa(c) deleted.
# Reaction EX_glyc_R[e] deleted.
# Reaction EX_M00019[e] deleted.
# Reaction EX_galgluside_hs(e) deleted.
# Reaction EX_acgly(e) deleted.
# Reaction EX_3mlda[e] deleted.
# Reaction EX_4mop[e] deleted.
# Reaction EX_HC02154[e] deleted.
# Reaction EX_pheglnphe[e] deleted.
# Reaction EX_M01881[e] deleted.
# Reaction DM_na1(x) deleted.
# Reaction EX_vallystyr[e] deleted.
# Reaction EX_MGlcn62_rl(e) deleted.
# Reaction EX_3mob(e) deleted.
# Reaction EX_man(e) deleted.
# Reaction EX_fvs[e] deleted.
# Reaction EX_C09642(e) deleted.
# Reaction EX_normete_L[e] deleted.
# Reaction EX_sphmyln181161_hs(e) deleted.
# Reaction EX_24nph(e) deleted.
# Reaction EX_c4dc[e] deleted.
# Reaction EX_duri(e) deleted.
# Reaction EX_M00228[e] deleted.
# Reaction EX_3hibup_R[e] deleted.
# Reaction DM_clpni16(c) deleted.
# Reaction EX_cynt[e] deleted.
# Reaction EX_pcholn204_hs(e) deleted.
# Reaction EX_arggluglu[e] deleted.
# Reaction EX_argglupro[e] deleted.
# Reaction EX_MGlcn87(e) deleted.
# Reaction EX_C05300(e) deleted.
# Reaction EX_tre[e] deleted.
# Reaction EX_uchol[e] deleted.
# Reaction EX_hco3[e] deleted.
# Reaction EX_gq1b_hs[e] deleted.
# Reaction EX_core2_rl(e) deleted.
# Reaction EX_3octdece1crn[e] deleted.
# Reaction EX_mso3(e) deleted.
# Reaction DM_hca24g[c] deleted.
# Reaction EX_12dhchol[e] deleted.
# Reaction EX_MGlcn170_rl(e) deleted.
# Reaction EX_MGlcn55_rl(e) deleted.
# Reaction EX_M01235[e] deleted.
# Reaction EX_CE2838[e] deleted.
# Reaction EX_am1ccs[e] deleted.
# Reaction DM_cbl1[m] deleted.
# Reaction DM_pcreat[c] deleted.
# Reaction EX_pcholar_hs(e) deleted.
# Reaction EX_eic21114tr(e) deleted.
# Reaction EX_gq1balpha_hs[e] deleted.
# Reaction EX_CE5791[e] deleted.
# Reaction EX_dcmp(e) deleted.
# Reaction sink_HC02192[c] deleted.
# Reaction EX_dpcoa[e] deleted.
# Reaction EX_pro_L[e] deleted.
# Reaction EX_valleuphe[e] deleted.
# Reaction EX_thyox_L(e) deleted.
# Reaction EX_17ahprgstrn[e] deleted.
# Reaction EX_3hdececrn(e) deleted.
# Reaction EX_M00510[e] deleted.
# Reaction EX_Tyr_ggn[e] deleted.
# Reaction EX_pa_hs(e) deleted.
# Reaction EX_apio-D(e) deleted.
# Reaction EX_dcyt[e] deleted.
# Reaction sink_cholate(c) deleted.
# Reaction EX_ethamp[e] deleted.
# Reaction EX_2omxyl(e) deleted.
# Reaction EX_pe226_hs[e] deleted.
# Reaction EX_CE5869[e] deleted.
# Reaction EX_oaa(e) deleted.
# Reaction EX_MGlcn39_rl(e) deleted.
# Reaction EX_isobut(e) deleted.
# Reaction EX_acthr_L[e] deleted.
# Reaction EX_leuktrB4wcooh[e] deleted.
# Reaction EX_HC01577[e] deleted.
# Reaction EX_rbflvrd(e) deleted.
# Reaction EX_tyr_L[e] deleted.
# Reaction EX_13_cis_retnglc(e) deleted.
# Reaction EX_3uib(e) deleted.
# Reaction sink_btn(c) deleted.
# Reaction sink_fe3(c) deleted.
# Reaction EX_pcholn205_hs[e] deleted.
# Reaction EX_adpglc[e] deleted.
# Reaction EX_pheacgly(e) deleted.
# Reaction EX_histrphis[e] deleted.
# Reaction EX_ppiogly(e) deleted.
# Reaction EX_citr_L[e] deleted.
# Reaction EX_pe17_hs(e) deleted.
# Reaction sink_tmndnc(c) deleted.
# Reaction EX_csasulp[e] deleted.
# Reaction EX_chsterols(e) deleted.
# Reaction EX_MGlcn69(e) deleted.
# Reaction EX_HC00319[e] deleted.
# Reaction sink_trp_L[c] deleted.
# Reaction EX_mlthf[e] deleted.
# Reaction EX_glntrpglu[e] deleted.
# Reaction EX_cspg_c[e] deleted.
# Reaction EX_CE1943[e] deleted.
# Reaction EX_dgsn[e] deleted.
# Reaction sink_HC02198[c] deleted.
# Reaction DM_hca6g[c] deleted.
# Reaction EX_galt(e) deleted.
# Reaction EX_alaglu(e) deleted.
# Reaction EX_HC01700[e] deleted.
# Reaction EX_am1a4ncs[e] deleted.
# Reaction EX_uchol(e) deleted.
# Reaction EX_MGlcn126_rl(e) deleted.
# Reaction EX_sphmyln18117_hs[e] deleted.
# Reaction EX_glysar[e] deleted.
# Reaction EX_docosac[e] deleted.
# Reaction EX_MGlcn165(e) deleted.
# Reaction EX_glygly(e) deleted.
# Reaction EX_crvsm24[e] deleted.
# Reaction EX_methsucc[e] deleted.
# Reaction EX_MGlcn29(e) deleted.
# Reaction sink_lnlc[c] deleted.
# Reaction EX_mqn7(e) deleted.
# Reaction EX_CE4877(e) deleted.
# Reaction EX_3hmp(e) deleted.
# Reaction DM_lca3s[c] deleted.
# Reaction EX_MGlcn191_rl(e) deleted.
# Reaction EX_anth(e) deleted.
# Reaction EX_vacc[e] deleted.
# Reaction EX_dgmp(e) deleted.
# Reaction EX_MGlcn36_rl(e) deleted.
# Reaction EX_ahandrostan[e] deleted.
# Reaction EX_alagln(e) deleted.
# Reaction EX_acnacngal14acglcgalgluside_hs(e) deleted.
# Reaction EX_3hmp[e] deleted.
# Reaction EX_thmmp(e) deleted.
# Reaction EX_thm(e) deleted.
# Reaction EX_tetpent6(e) deleted.
# Reaction sink_tdchola[c] deleted.
# Reaction EX_CE4877[e] deleted.
# Reaction EX_Ser_Thr(e) deleted.
# Reaction EX_CE2250[e] deleted.
# Reaction EX_glcn[e] deleted.
# Reaction EX_c8dc[e] deleted.
# Reaction DM_7dhchol[c] deleted.
# Reaction EX_trypta(e) deleted.
# Reaction EX_cmpacna[e] deleted.
# Reaction EX_glyclt(e) deleted.
# Reaction EX_chsterols[e] deleted.
# Reaction EX_3mglutac(e) deleted.
# Reaction EX_7dhf[e] deleted.
# Reaction EX_lmn2(e) deleted.
# Reaction EX_MGlcn25(e) deleted.
# Reaction EX_carveol(e) deleted.
# Reaction EX_MGlcn9(e) deleted.
# Reaction EX_pcholn224_hs(e) deleted.
# Reaction EX_ac(e) deleted.
# Reaction EX_gpi_sig[e] deleted.
# Reaction EX_pcresol[e] deleted.
# Reaction EX_MGlcn192(e) deleted.
# Reaction EX_MGlcn78_rl(e) deleted.
# Reaction EX_ga1_hs(e) deleted.
# Reaction EX_3hadpac[e] deleted.
# Reaction EX_CE4881[e] deleted.
# Reaction EX_trpglngln[e] deleted.
# Reaction EX_mvlac[e] deleted.
# Reaction EX_atp[e] deleted.
# Reaction EX_aracheth(e) deleted.
# Reaction DM_ca3s[c] deleted.
# Reaction EX_tyrcysthr[e] deleted.
# Reaction EX_dhcinnm(e) deleted.
# Reaction EX_retinol(e) deleted.
# Reaction sink_11_cis_retfa[c] deleted.
# Reaction EX_k[e] deleted.
# Reaction EX_C14826(e) deleted.
# Reaction EX_3hpppn[e] deleted.
# Reaction EX_serlyshis[e] deleted.
# Reaction EX_M01207[e] deleted.
# Reaction DM_13_cis_retn_n_ deleted.
# Reaction EX_crm_hs[e] deleted.
# Reaction EX_chol(e) deleted.
# Reaction EX_MGlcn167(e) deleted.
# Reaction EX_pectingchol[e] deleted.
# Reaction EX_alltn(e) deleted.
# Reaction EX_mlthf(e) deleted.
# Reaction EX_gd1c_hs(e) deleted.
# Reaction EX_MGlcn194_rl(e) deleted.
# Reaction EX_his_L[e] deleted.
# Reaction EX_CE2516[e] deleted.
# Reaction EX_hisglugln[e] deleted.
# Reaction EX_MGlcn27(e) deleted.
# Reaction EX_tetdecaeth(e) deleted.
# Reaction DM_anth deleted.
# Reaction EX_sphmyln18115_hs(e) deleted.
# Reaction DM_tcdca3s[c] deleted.
# Reaction EX_M02723[e] deleted.
# Reaction EX_HC00009(e) deleted.
# Reaction EX_cyan(e) deleted.
# Reaction EX_acac(e) deleted.
# Reaction EX_am4n9cs[e] deleted.
# Reaction EX_lstnm7[e] deleted.
# Reaction EX_hiscyscys[e] deleted.
# Reaction EX_MGlcn133_rl(e) deleted.
# Reaction EX_M01569[e] deleted.
# Reaction EX_C06314[e] deleted.
# Reaction EX_M02446[e] deleted.
# Reaction EX_HC02192[e] deleted.
# Reaction EX_MGlcn39(e) deleted.
# Reaction EX_pser_L[e] deleted.
# Reaction EX_omeprazole[e] deleted.
# Reaction EX_10fthf6glu[e] deleted.
# Reaction EX_CE6205[e] deleted.
# Reaction EX_crvs[e] deleted.
# Reaction EX_HC02214[e] deleted.
# Reaction EX_pcholn1836_hs(e) deleted.
# Reaction sink_coa(c) deleted.
# Reaction EX_galam[e] deleted.
# Reaction EX_trpglupro[e] deleted.
# Reaction EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs[e] deleted.
# Reaction EX_M02447[e] deleted.
# Reaction EX_MGlcn173_rl(e) deleted.
# Reaction EX_5g2oxpt(e) deleted.
# Reaction EX_dhea(e) deleted.
# Reaction EX_lipoate[e] deleted.
# Reaction EX_succ(e) deleted.
# Reaction EX_for[e] deleted.
# Reaction EX_etha[e] deleted.
# Reaction EX_acgalglcur(e) deleted.
# Reaction EX_M00234[e] deleted.
# Reaction EX_gltdechol[e] deleted.
# Reaction EX_crvsm23[e] deleted.
# Reaction EX_pydx(e) deleted.
# Reaction EX_MGlcn147_rl(e) deleted.
# Reaction EX_q10h2[e] deleted.
# Reaction EX_arachcoa[e] deleted.
# Reaction EX_pcholmyr_hs(e) deleted.
# Reaction EX_CE5797[e] deleted.
# Reaction EX_trptyrtyr[e] deleted.
# Reaction EX_MGlcn80(e) deleted.
# Reaction DM_na1[g] deleted.
# Reaction EX_HC00460[e] deleted.
# Reaction EX_2hyoxplac[e] deleted.
# Reaction EX_MGlcn59(e) deleted.
# Reaction EX_pchol_hs(e) deleted.
# Reaction EX_agal1b6agal(e) deleted.
# Reaction EX_sprm(e) deleted.
# Reaction EX_5cysgly34dhphe(e) deleted.
# Reaction EX_lnlnca[e] deleted.
# Reaction DM_coprost[c] deleted.
# Reaction EX_cspg_e(e) deleted.
# Reaction EX_MGlcn108_rl(e) deleted.
# Reaction EX_CE2705[e] deleted.
# Reaction EX_MGlcn105_rl(e) deleted.
# Reaction EX_phephe[e] deleted.
# Reaction EX_butso3(e) deleted.
# Reaction EX_12htacr[e] deleted.
# Reaction EX_MGlcn76_rl(e) deleted.
# Reaction EX_gm3_hs[e] deleted.
# Reaction EX_CE2176[e] deleted.
# Reaction EX_nwharg[e] deleted.
# Reaction EX_bildglcur[e] deleted.
# Reaction EX_leutrp[e] deleted.
# Reaction EX_dcmp[e] deleted.
# Reaction EX_HC02208[e] deleted.
# Reaction EX_HC01104[e] deleted.
# Reaction EX_ppa[e] deleted.
# Reaction sink_retinol(c) deleted.
# Reaction EX_MGlcn139_rl(e) deleted.
# Reaction EX_pcholn201_hs(e) deleted.
# Reaction EX_glc_D[e] deleted.
# Reaction EX_levantttr(e) deleted.
# Reaction EX_leuktrF4(e) deleted.
# Reaction EX_nacvanala[e] deleted.
# Reaction EX_CE5025[e] deleted.
# Reaction EX_lca3g[e] deleted.
# Reaction EX_MGlcn132_rl(e) deleted.
# Reaction EX_MGlcn91(e) deleted.
# Reaction EX_tripvs[e] deleted.
# Reaction EX_docteteth[e] deleted.
# Reaction EX_MGlcn13(e) deleted.
# Reaction EX_glycys(e) deleted.
# Reaction EX_M03134(e) deleted.
# Reaction EX_pe2linl_hs[e] deleted.
# Reaction EX_MGlcn57(e) deleted.
# Reaction EX_thymd(e) deleted.
# Reaction EX_prostgd2[e] deleted.
# Reaction EX_tdechola[e] deleted.
# Reaction DM_teich_45_BS(c) deleted.
# Reaction EX_sfcys[e] deleted.
# Reaction EX_dopa4sf(e) deleted.
# Reaction EX_alaleu(e) deleted.
# Reaction EX_rhamnogalurII(e) deleted.
# Reaction EX_thrnt[e] deleted.
# Reaction EX_c6dc[e] deleted.
# Reaction sink_lnlccoa[c] deleted.
# Reaction EX_CE6031(e) deleted.
# Reaction EX_tauribup_S[e] deleted.
# Reaction sink_tdechola[c] deleted.
# Reaction DM_sph1p[n] deleted.
# Reaction EX_MGlcn147(e) deleted.
# Reaction EX_glygn2(e) deleted.
# Reaction EX_gd1b_hs(e) deleted.
# Reaction EX_cholate[e] deleted.
# Reaction EX_56dura(e) deleted.
# Reaction EX_ile_L[e] deleted.
# Reaction EX_psyl[e] deleted.
# Reaction sink_gchola(c) deleted.
# Reaction EX_hpdca[e] deleted.
# Reaction EX_ptvstm3[e] deleted.
# Reaction EX_pheleuhis[e] deleted.
# Reaction EX_gln_L(e) deleted.
# Reaction EX_15dap(e) deleted.
# Reaction sink_xoldiolone[c] deleted.
# Reaction DM_dctp_n_ deleted.
# Reaction EX_fol[e] deleted.
# Reaction EX_M03153[e] deleted.
# Reaction EX_gchola(e) deleted.
# Reaction EX_asp_L(e) deleted.
# Reaction EX_pcreat(e) deleted.
# Reaction EX_lvstacid[e] deleted.
# Reaction sink_fad[c] deleted.
# Reaction EX_MGlcn140_rl(e) deleted.
# Reaction EX_4abutn(e) deleted.
# Reaction EX_hspg_degr_1(e) deleted.
# Reaction EX_ps_hs(e) deleted.
# Reaction EX_btd_RR(e) deleted.
# Reaction EX_ppi[e] deleted.
# Reaction EX_M03044[e] deleted.
# Reaction sink_stcoa(c) deleted.
# Reaction EX_csa[e] deleted.
# Reaction EX_MGlcn70_rl(e) deleted.
# Reaction EX_xmp[e] deleted.
# Reaction EX_hom_L[e] deleted.
# Reaction EX_sucaceto[e] deleted.
# Reaction EX_dhpppn(e) deleted.
# Reaction EX_magarachi_hs[e] deleted.
# Reaction EX_gua[e] deleted.
# Reaction EX_thr_L[e] deleted.
# Reaction EX_T4hcinnm[e] deleted.
# Reaction EX_MGlcn60_rl(e) deleted.
# Reaction EX_avite2[e] deleted.
# Reaction EX_tlacfvs[e] deleted.
# Reaction DM_mi145p[c] deleted.
# Reaction EX_trplys[e] deleted.
# Reaction EX_7dhchol[e] deleted.
# Reaction EX_crtsl(e) deleted.
# Reaction EX_amylose300(e) deleted.
# Reaction EX_HC00009[e] deleted.
# Reaction EX_digalsgalside_hs[e] deleted.
# Reaction DM_CE5025[c] deleted.
# Reaction EX_malt[e] deleted.
# Reaction EX_dodecanac(e) deleted.
# Reaction EX_MGlcn92_rl(e) deleted.
# Reaction sink_HC02195(c) deleted.
# Reaction EX_pheme(e) deleted.
# Reaction EX_25hvitd2[e] deleted.
# Reaction EX_oagt3_hs(e) deleted.
# Reaction EX_chsterol(e) deleted.
# Reaction EX_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs[e] deleted.
# Reaction EX_CE7172[e] deleted.
# Reaction EX_CE7090[e] deleted.
# Reaction EX_M03131[e] deleted.
# Reaction EX_retnglc(e) deleted.
# Reaction EX_man6p(e) deleted.
# Reaction EX_CE5853[e] deleted.
# Reaction EX_gncore1(e) deleted.
# Reaction EX_1ohmdz[e] deleted.
# Reaction EX_MGlcn10(e) deleted.
# Reaction DM_datp_n_ deleted.
# Reaction EX_glygn5[e] deleted.
# Reaction EX_gdp(e) deleted.
# Reaction EX_13ppd(e) deleted.
# Reaction EX_smvacid[e] deleted.
# Reaction EX_ivcrn[e] deleted.
# Reaction EX_MGlcn141_rl(e) deleted.
# Reaction EX_nadh[e] deleted.
# Reaction EX_acmpglut[e] deleted.
# Reaction EX_lneldc[e] deleted.
# Reaction EX_HC00003(e) deleted.
# Reaction EX_camp[e] deleted.
# Reaction EX_M00260[e] deleted.
# Reaction sink_pydxn[c] deleted.
# Reaction EX_orot5p[e] deleted.
# Reaction EX_pcholn281_hs[e] deleted.
# Reaction EX_andrstrnglc(e) deleted.
# Reaction sink_dmbzid deleted.
# Reaction EX_sarcs[e] deleted.
# Reaction EX_leuktrB4woh[e] deleted.
# Reaction EX_acn13acngalgbside_hs(e) deleted.
# Reaction EX_MGlcn159_rl(e) deleted.
# Reaction EX_1a25dhvitd3(e) deleted.
# Reaction EX_tyr_L(e) deleted.
# Reaction EX_CE1261(e) deleted.
# Reaction EX_HC01852[e] deleted.
# Reaction EX_C14770[e] deleted.
# Reaction EX_M02047[e] deleted.
# Reaction EX_fvstetglu[e] deleted.
# Reaction EX_4mcat(e) deleted.
# Reaction DM_gcdca3s[c] deleted.
# Reaction EX_hdca6g[e] deleted.
# Reaction EX_12harachd[e] deleted.
# Reaction EX_alaala(e) deleted.
# Reaction EX_pcollg5hlys[e] deleted.
# Reaction EX_pcholpalm_hs(e) deleted.
# Reaction EX_c8crn(e) deleted.
# Reaction EX_orot5p(e) deleted.
# Reaction DM_4glu56dihdind[c] deleted.
# Reaction DM_5MTR deleted.
# Reaction EX_spmd(e) deleted.
# Reaction sink_odecoa[c] deleted.
# Reaction EX_6melvst[e] deleted.
# Reaction EX_MGlcn72(e) deleted.
# Reaction EX_34hpp[e] deleted.
# Reaction EX_3ddcrn[e] deleted.
# Reaction EX_MGlcn35_rl(e) deleted.
# Reaction EX_yvite[e] deleted.
# Reaction EX_peste_hs(e) deleted.
# Reaction EX_5cysdopa(e) deleted.
# Reaction EX_xyl_D(e) deleted.
# Reaction EX_acmp[e] deleted.
# Reaction EX_MGlcn142(e) deleted.
# Reaction EX_sphmyln18120_hs(e) deleted.
# Reaction EX_C05301(e) deleted.
# Reaction EX_3hpppnohgluc[e] deleted.
# Reaction EX_c5dc[e] deleted.
# Reaction EX_thrglntyr[e] deleted.
# Reaction EX_MGlcn51_rl(e) deleted.
# Reaction EX_arg_L(e) deleted.
# Reaction EX_starch1200(e) deleted.
# Reaction EX_debrisoquine[e] deleted.
# Reaction EX_achom_L[e] deleted.
# Reaction EX_ser_D(e) deleted.
# Reaction EX_coa[e] deleted.
# Reaction EX_hisprolys[e] deleted.
# Reaction EX_3hexdcrn(e) deleted.
# Reaction EX_5mta(e) deleted.
# Reaction EX_hmcarn(e) deleted.
# Reaction EX_C05300[e] deleted.
# Reaction EX_hislysile[e] deleted.
# Reaction EX_MGlcn134_rl(e) deleted.
# Reaction EX_gal1b3acgal(e) deleted.
# Reaction DM_mqn7[c] deleted.
# Reaction EX_dxtrn[e] deleted.
# Reaction EX_urea(e) deleted.
# Reaction EX_pydam(e) deleted.
# Reaction EX_pcholn183_hs[e] deleted.
# Reaction EX_ileprolys[e] deleted.
# Reaction EX_HC00002[e] deleted.
# Reaction DM_15HPET[x] deleted.
# Reaction EX_5aop(e) deleted.
# Reaction EX_ttdcea(e) deleted.
# Reaction sink_HC02197(c) deleted.
# Reaction sink_glygn2[c] deleted.
# Reaction EX_aact[e] deleted.
# Reaction sink_11_cis_retfa(c) deleted.
# Reaction EX_M01807[e] deleted.
# Reaction EX_pendecaeth[e] deleted.
# Reaction EX_hcys_L[e] deleted.
# Reaction EX_tymsf(e) deleted.
# Reaction EX_3ttetddcoacrn[e] deleted.
# Reaction EX_1331tacr[e] deleted.
# Reaction DM_clpn140(c) deleted.
# Reaction EX_camp(e) deleted.
# Reaction EX_am1accs[e] deleted.
# Reaction DM_3dhcdchol[c] deleted.
# Reaction EX_dopasf[e] deleted.
# Reaction EX_arg_D[e] deleted.
# Reaction EX_HC00319(e) deleted.
# Reaction EX_4tmeabutn[e] deleted.
# Reaction EX_11docrtsl[e] deleted.
# Reaction EX_dchac(e) deleted.
# Reaction EX_cholp[e] deleted.
# Reaction sink_HC02197[c] deleted.
# Reaction EX_sphings[e] deleted.
# Reaction EX_2425dhvitd3[e] deleted.
# Reaction EX_34hpp(e) deleted.
# Reaction EX_dhglz[e] deleted.
# Reaction EX_HC01441[e] deleted.
# Reaction EX_MGlcn94_rl(e) deleted.
# Reaction EX_whhdca[e] deleted.
# Reaction EX_CE5026(e) deleted.
# Reaction EX_7dhchsterol(e) deleted.
# Reaction sink_CE1273[c] deleted.
# Reaction EX_pe_hs(e) deleted.
# Reaction EX_MGlcn186_rl(e) deleted.
# Reaction EX_udpg[e] deleted.
# Reaction EX_tudca3s[e] deleted.
# Reaction EX_MGlcn33_rl(e) deleted.
# Reaction EX_MGlcn58_rl(e) deleted.
# Reaction EX_ser_L[e] deleted.
# Reaction EX_and19one[e] deleted.
# Reaction EX_CE4970(e) deleted.
# Reaction EX_C09642[e] deleted.
# Reaction sink_nad(c) deleted.
# Reaction EX_5a2opntn(e) deleted.
# Reaction EX_docosac(e) deleted.
# Reaction EX_MGlcn15_rl(e) deleted.
# Reaction EX_CE5868(e) deleted.
# Reaction EX_tmd[e] deleted.
# Reaction EX_thexdd(e) deleted.
# Reaction EX_n2o(e) deleted.
# Reaction EX_cysleuthr[e] deleted.
# Reaction EX_CE5786(e) deleted.
# Reaction EX_acngalacglcgal14acglcgalgluside_hs[e] deleted.
# Reaction EX_stcrn[e] deleted.
# Reaction EX_gp1c_hs(e) deleted.
# Reaction EX_4hbz[e] deleted.
# Reaction EX_rsvlac[e] deleted.
# Reaction EX_M02613[e] deleted.
# Reaction EX_mdz[e] deleted.
# Reaction EX_3hanthrn(e) deleted.
# Reaction EX_idl_hs(e) deleted.
# Reaction EX_homoval[e] deleted.
# Reaction EX_trideceth(e) deleted.
# Reaction EX_gcald(e) deleted.
# Reaction EX_citr_L(e) deleted.
# Reaction EX_h2co3[e] deleted.
# Reaction EX_M01571[e] deleted.
# Reaction EX_cspg_a[e] deleted.
# Reaction EX_hexdtr(e) deleted.
# Reaction EX_HC00250[e] deleted.
# Reaction EX_CE1447[e] deleted.
# Reaction EX_CE2049[e] deleted.
# Reaction DM_dca24g[c] deleted.
# Reaction EX_3aib(e) deleted.
# Reaction EX_pmtcrn(e) deleted.
# Reaction EX_nadp(e) deleted.
# Reaction EX_indole(e) deleted.
# Reaction EX_dag_hs[e] deleted.
# Reaction EX_hislysglu[e] deleted.
# Reaction EX_gncore1[e] deleted.
# Reaction EX_cu2[e] deleted.
# Reaction EX_adocbl(e) deleted.
# Reaction sink_pydam(c) deleted.
# Reaction EX_gd1a_hs[e] deleted.
# Reaction EX_MGlcn115_rl(e) deleted.
# Reaction EX_o2s(e) deleted.
# Reaction EX_decdicrn(e) deleted.
# Reaction EX_glyb[e] deleted.
# Reaction EX_mannan(e) deleted.
# Reaction EX_MGlcn172(e) deleted.
# Reaction EX_prostge2[e] deleted.
# Reaction EX_ind3ppa(e) deleted.
# Reaction DM_mqn8[c] deleted.
# Reaction EX_acald[e] deleted.
# Reaction EX_sql[e] deleted.
# Reaction EX_argcysser[e] deleted.
# Reaction EX_gluasnleu[e] deleted.
# Reaction EX_HC02207(e) deleted.
# Reaction EX_mhista(e) deleted.
# Reaction EX_sphmyln18122_hs[e] deleted.
# Reaction EX_2hb[e] deleted.
# Reaction EX_prostge1[e] deleted.
# Reaction EX_pheme[e] deleted.
# Reaction EX_MGlcn10_rl(e) deleted.
# Reaction EX_MGlcn21(e) deleted.
# Reaction EX_selni(e) deleted.
# Reaction EX_acnacngal14acglcgalgluside_hs[e] deleted.
# Reaction EX_isetac(e) deleted.
# Reaction EX_ala_B[e] deleted.
# Reaction EX_tyrtyr[e] deleted.
# Reaction EX_tetdec2crn(e) deleted.
# Reaction EX_MGlcn131_rl(e) deleted.
# Reaction DM_q8h2[c] deleted.
# Reaction EX_digalsgalside_hs(e) deleted.
# Reaction EX_pe224_hs[e] deleted.
# Reaction EX_egme[e] deleted.
# Reaction EX_MGlcn12(e) deleted.
# Reaction EX_c81crn(e) deleted.
# Reaction EX_onpthl(e) deleted.
# Reaction sink_gly[c] deleted.
# Reaction EX_tststerone(e) deleted.
# Reaction EX_pear_hs(e) deleted.
# Reaction EX_ins(e) deleted.
# Reaction EX_15HPET(e) deleted.
# Reaction EX_kestottr(e) deleted.
# Reaction EX_ndersv[e] deleted.
# Reaction EX_MGlcn106(e) deleted.
# Reaction DM_n5m2masn_g_ deleted.
# Reaction EX_sT_antigen_rl(e) deleted.
# Reaction DM_cdca3g[c] deleted.
# Reaction EX_MGlcn111(e) deleted.
# Reaction DM_ncam deleted.
# Reaction EX_leuasplys[e] deleted.
# Reaction EX_dgchol[e] deleted.
# Reaction EX_acthr_L(e) deleted.
# Reaction EX_xylt(e) deleted.
# Reaction EX_M03146[e] deleted.
# Reaction sink_retfa[c] deleted.
# Reaction EX_ch4s[e] deleted.
# Reaction EX_cysglnmet[e] deleted.
# Reaction DM_6hddopaqn(c) deleted.
# Reaction EX_valval[e] deleted.
# Reaction EX_nifedipine[e] deleted.
# Reaction DM_sprm_c_ deleted.
# Reaction EX_MGlcn112_rl(e) deleted.
# Reaction EX_C06314(e) deleted.
# Reaction EX_CE2934(e) deleted.
# Reaction sink_HC02191(c) deleted.
# Reaction EX_dad_5[e] deleted.
# Reaction EX_alagly(e) deleted.
# Reaction EX_lvst[e] deleted.
# Reaction DM_dttp_m_ deleted.
# Reaction EX_gq1b_hs(e) deleted.
# Reaction EX_2hiv[e] deleted.
# Reaction EX_CE0074[e] deleted.
# Reaction EX_MGlcn170(e) deleted.
# Reaction EX_pcholn15_hs(e) deleted.
# Reaction EX_cyscys[e] deleted.
# Reaction EX_c101crn(e) deleted.
# Reaction DM_mqn7(c) deleted.
# Reaction EX_M00242[e] deleted.
# Reaction EX_pcholn225_hs[e] deleted.
# Reaction EX_leuktrE4(e) deleted.
# Reaction EX_peplys[e] deleted.
# Reaction EX_glnhishis[e] deleted.
# Reaction EX_tyrala[e] deleted.
# Reaction EX_itacon[e] deleted.
# Reaction DM_fol deleted.
# Reaction DM_gncore2_g_ deleted.
# Reaction DM_dna5mtc[c] deleted.
# Reaction EX_3uib[e] deleted.
# Reaction EX_MGlcn141(e) deleted.
# Reaction EX_HC00250(e) deleted.
# Reaction EX_CE0737(e) deleted.
# Reaction EX_3h3mglt[e] deleted.
# Reaction sink_cholp(c) deleted.
# Reaction EX_biliverd[e] deleted.
# Reaction EX_cyst_L(e) deleted.
# Reaction EX_xol7aone(e) deleted.
# Reaction EX_nrvnc(e) deleted.
# Reaction EX_Lpipecol[e] deleted.
# Reaction EX_C05767(e) deleted.
# Reaction EX_34dhoxmand(e) deleted.
# Reaction EX_sphs1p(e) deleted.
# Reaction EX_2oxoadp(e) deleted.
# Reaction EX_ebastineoh[e] deleted.
# Reaction sink_tchola(c) deleted.
# Reaction EX_fucacgalfucgalacglcgalgluside_hs[e] deleted.
# Reaction EX_retn[e] deleted.
# Reaction EX_7bhglz[e] deleted.
# Reaction DM_hdca6g[c] deleted.
# Reaction EX_MGlcn134(e) deleted.
# Reaction EX_3mlda(e) deleted.
# Reaction EX_MGlcn73_rl(e) deleted.
# Reaction EX_tmdm1[e] deleted.
# Reaction EX_MGlcn123_rl(e) deleted.
# Reaction EX_13_cis_retn(e) deleted.
# Reaction EX_urcan(e) deleted.
# Reaction EX_MGlcn179(e) deleted.
# Reaction EX_HC01939(e) deleted.
# Reaction EX_1a25dhvitd2[e] deleted.
# Reaction EX_CE2028(e) deleted.
# Reaction EX_magpalm_hs(e) deleted.
# Reaction EX_CE1401(e) deleted.
# Reaction sink_decdicoa(c) deleted.
# Reaction EX_fad[e] deleted.
# Reaction EX_pe13_hs(e) deleted.
# Reaction EX_akg[e] deleted.
# Reaction EX_thbpt(e) deleted.
# Reaction EX_2hxic_L[e] deleted.
# Reaction EX_pcs[e] deleted.
# Reaction EX_MGlcn156(e) deleted.
# Reaction EX_nacvanala(e) deleted.
# Reaction EX_2m3hbu[e] deleted.
# Reaction EX_ha_pre1[e] deleted.
# Reaction EX_gt1a_hs[e] deleted.
# Reaction EX_MGlcn31_rl(e) deleted.
# Reaction EX_sheme(e) deleted.
# Reaction EX_glcr(e) deleted.
# Reaction EX_glyglu(e) deleted.
# Reaction EX_CE2026(e) deleted.
# Reaction EX_estrones[e] deleted.
# Reaction EX_ga1_hs[e] deleted.
# Reaction EX_C01601[e] deleted.
# Reaction EX_3moxtyr(e) deleted.
# Reaction EX_txb2[e] deleted.
# Reaction sink_xoldiolone(c) deleted.
# Reaction sink_C02528(c) deleted.
# Reaction EX_7ahglz[e] deleted.
# Reaction EX_mthgxl[e] deleted.
# Reaction EX_HC02196[e] deleted.
# Reaction EX_MGlcn62(e) deleted.
# Reaction EX_C04849(e) deleted.
# Reaction EX_ebastine(e) deleted.
# Reaction EX_tetdec2crn[e] deleted.
# Reaction EX_andrstndn[e] deleted.
# Reaction EX_gp1calpha_hs[e] deleted.
# Reaction EX_eicostet(e) deleted.
# Reaction EX_iletrptyr[e] deleted.
# Reaction EX_nfdnpy[e] deleted.
# Reaction EX_cystyrasn[e] deleted.
# Reaction EX_ksi[e] deleted.
# Reaction EX_CE5869(e) deleted.
# Reaction EX_galct_D(e) deleted.
# Reaction EX_CE4968(e) deleted.
# Reaction sink_chols deleted.
# Reaction EX_M03045[e] deleted.
# Reaction EX_perillyl(e) deleted.
# Reaction EX_hexdeceeth(e) deleted.
# Reaction EX_abt_D[e] deleted.
# Reaction EX_coke(e) deleted.
# Reaction EX_MGlcn111_rl(e) deleted.
# Reaction EX_phppa(e) deleted.
# Reaction EX_4mtolbutamide[e] deleted.
# Reaction EX_lgnc(e) deleted.
# Reaction EX_MGlcn50(e) deleted.
# Reaction EX_adrn(e) deleted.
# Reaction EX_N1aspmd(e) deleted.
# Reaction EX_3octdeccrn(e) deleted.
# Reaction EX_dextran40(e) deleted.
# Reaction EX_prist[e] deleted.
# Reaction EX_and19one(e) deleted.
# Reaction EX_phe_L(e) deleted.
# Reaction DM_4HBA deleted.
# Reaction EX_ppi(e) deleted.
# Reaction EX_HC00004[e] deleted.
# Reaction EX_ca2[e] deleted.
# Reaction EX_zn2(e) deleted.
# Reaction sink_c101coa[c] deleted.
# Reaction EX_egme(e) deleted.
# Reaction EX_ileglnglu[e] deleted.
# Reaction EX_MGlcn149(e) deleted.
# Reaction EX_arg_L[e] deleted.
# Reaction EX_6ohfvs[e] deleted.
# Reaction EX_pe203_hs(e) deleted.
# Reaction EX_sphmyln18118_hs(e) deleted.
# Reaction EX_HC00003[e] deleted.
# Reaction EX_15dmt[e] deleted.
# Reaction EX_CE5798[e] deleted.
# Reaction EX_dad_2[e] deleted.
# Reaction EX_limnen(e) deleted.
# Reaction EX_dca(e) deleted.
# Reaction EX_xolest181_hs(e) deleted.
# Reaction EX_lyscyshis[e] deleted.
# Reaction EX_udca3s[e] deleted.
# Reaction EX_MGlcn150_rl(e) deleted.
# Reaction DM_mqn8(c) deleted.
# Reaction EX_rhamnogalurI(e) deleted.
# Reaction EX_MGlcn107_rl(e) deleted.
# Reaction EX_tet(e) deleted.
# Reaction EX_3ump[e] deleted.
# Reaction EX_inds[e] deleted.
# Reaction EX_hspg_degr_8(e) deleted.
# Reaction EX_aspmetasp[e] deleted.
# Reaction EX_5HPET(e) deleted.
# Reaction EX_1a25dhvitd3[e] deleted.
# Reaction EX_3ohglutac[e] deleted.
# Reaction EX_na1[e] deleted.
# Reaction EX_zn2[e] deleted.
# Reaction EX_4hatvacid[e] deleted.
# Reaction EX_ppp9[e] deleted.
# Reaction EX_MGlcn136(e) deleted.
# Reaction EX_pppn(e) deleted.
# Reaction EX_kynate(e) deleted.
# Reaction EX_phethrlys[e] deleted.
# Reaction EX_f1a_rl(e) deleted.
# Reaction EX_pep(e) deleted.
# Reaction EX_4tmeabutn(e) deleted.
# Reaction EX_pe13_hs[e] deleted.
# Reaction EX_lstn[e] deleted.
# Reaction EX_2ddglcn(e) deleted.
# Reaction EX_mhglz[e] deleted.
# Reaction EX_taur[e] deleted.
# Reaction EX_gumdchac[e] deleted.
# Reaction EX_pcreat[e] deleted.
# Reaction EX_1glyc_hs[e] deleted.
# Reaction EX_sphmyln18118_hs[e] deleted.
# Reaction EX_tsul(e) deleted.
# Reaction sink_doco13ecoa(c) deleted.
# Reaction EX_dhdascb[e] deleted.
# Reaction EX_indole[e] deleted.
# Reaction EX_HC02191(e) deleted.
# Reaction EX_MGlcn176_rl(e) deleted.
# Reaction EX_MGlcn195_rl(e) deleted.
# Reaction EX_HC01942(e) deleted.
# Reaction EX_HC01852(e) deleted.
# Reaction EX_alaala[e] deleted.
# Reaction EX_gd2_hs[e] deleted.
# Reaction EX_25hvitd2(e) deleted.
# Reaction EX_ump[e] deleted.
# Reaction EX_so3[e] deleted.
# Reaction EX_lneldccrn[e] deleted.
# Reaction EX_gumtchol[e] deleted.
# Reaction DM_hdca24g[c] deleted.
# Reaction EX_ptdca(e) deleted.
# Reaction EX_nh4(e) deleted.
# Reaction EX_lysvalphe[e] deleted.
# Reaction EX_MGlcn171_rl(e) deleted.
# Reaction EX_asphiscys[e] deleted.
# Reaction EX_estrone[e] deleted.
# Reaction DM_Ser_Thr_ly_ deleted.
# Reaction EX_MGlcn180(e) deleted.
# Reaction EX_MGlcn86_rl(e) deleted.
# Reaction EX_apnnox(e) deleted.
# Reaction EX_coprost[e] deleted.
# Reaction EX_pcholeic_hs(e) deleted.
# Reaction EX_CE2838(e) deleted.
# Reaction EX_idour(e) deleted.
# Reaction EX_C14769(e) deleted.
# Reaction EX_26dap_M(e) deleted.
# Reaction EX_bilirub[e] deleted.
# Reaction EX_leutrparg[e] deleted.
# Reaction EX_oagt3_hs[e] deleted.
# Reaction DM_for(c) deleted.
# Reaction EX_CE6205(e) deleted.
# Reaction EX_lanost(e) deleted.
# Reaction EX_MGlcn143(e) deleted.
# Reaction EX_C14826[e] deleted.
# Reaction EX_phetyrlys[e] deleted.
# Reaction EX_hyptaur(e) deleted.
# Reaction EX_leu_L[e] deleted.
# Reaction EX_c3dc[e] deleted.
# Reaction EX_3hdececrn[e] deleted.
# Reaction EX_tyrvalmet[e] deleted.
# Reaction EX_HC00006(e) deleted.
# Reaction EX_HC02020[e] deleted.
# Reaction EX_xyl_D[e] deleted.
# Reaction EX_thrserarg[e] deleted.
# Reaction EX_sphmyln18114_hs[e] deleted.
# Reaction EX_MGlcn138(e) deleted.
# Reaction EX_gm1b_hs(e) deleted.
# Reaction EX_ptth[e] deleted.
# Reaction DM_K_c_ deleted.
# Reaction EX_trpphe[e] deleted.
# Reaction EX_CE1273[e] deleted.
# Reaction EX_HC00008[e] deleted.
# Reaction EX_sl_L[e] deleted.
# Reaction EX_5mta[e] deleted.
# Reaction DM_clpn160(c) deleted.
# Reaction EX_CE1939[e] deleted.
# Reaction EX_dopa4glcur(e) deleted.
# Reaction DM_no2(c) deleted.
# Reaction EX_atvacid[e] deleted.
# Reaction EX_6htststerone(e) deleted.
# Reaction EX_CE5304[e] deleted.
# Reaction EX_3hibupglu_S[e] deleted.
# Reaction EX_sphmyln180241_hs[e] deleted.
# Reaction EX_appnn(e) deleted.
# Reaction EX_psyltdechol[e] deleted.
# Reaction EX_MGlcn38_rl(e) deleted.
# Reaction EX_2425dhvitd3(e) deleted.
# Reaction EX_gbside_hs[e] deleted.
# Reaction EX_leu_L(e) deleted.
# Reaction EX_fuc_L[e] deleted.
# Reaction EX_bz(e) deleted.
# Reaction EX_MGlcn152_rl(e) deleted.
# Reaction EX_nfdoh[e] deleted.
# Reaction EX_3thexddcoacrn[e] deleted.
# Reaction EX_CE5787[e] deleted.
# Reaction EX_phephethr[e] deleted.
# Reaction EX_4hphac(e) deleted.
# Reaction EX_C05302(e) deleted.
# Reaction EX_acald(e) deleted.
# Reaction EX_nicrnt(e) deleted.
# Reaction EX_hepdeceth[e] deleted.
# Reaction EX_vldl_hs[e] deleted.
# Reaction DM_pail35p_hs[n] deleted.
# Reaction EX_thcholstoic[e] deleted.
# Reaction EX_malthp[e] deleted.
# Reaction EX_HC00005(e) deleted.
# Reaction EX_MGlcn196_rl(e) deleted.
# Reaction EX_retnglc[e] deleted.
# Reaction sink_gthrd(c) deleted.
# Reaction EX_acleu_L[e] deleted.
# Reaction EX_CE0955[e] deleted.
# Reaction sink_tmndnccoa[c] deleted.
# Reaction EX_31dmt[e] deleted.
# Reaction DM_5cysdopa[c] deleted.
# Reaction EX_6bhglz[e] deleted.
# Reaction EX_magole_hs[e] deleted.
# Reaction EX_fucgalgbside_hs[e] deleted.
# Reaction EX_fru(e) deleted.
# Reaction DM_thm(m) deleted.
# Reaction EX_5mthf(e) deleted.
# Reaction EX_trpaspasp[e] deleted.
# Reaction EX_tre(e) deleted.
# Reaction EX_C02356(e) deleted.
# Reaction EX_3tdcrn[e] deleted.
# Reaction EX_15kprostgf2[e] deleted.
# Reaction EX_MGlcn103_rl(e) deleted.
# Reaction EX_MGlcn32(e) deleted.
# Reaction EX_gp1c_hs[e] deleted.
# Reaction DM_clpnai15(c) deleted.
# Reaction sink_7klitchol(c) deleted.
# Reaction EX_gua(e) deleted.
# Reaction DM_Asn_X_Ser_Thr_ly_ deleted.
# Reaction EX_HC02195[e] deleted.
# Reaction EX_pelinl_hs(e) deleted.
# Reaction EX_adprbp[e] deleted.
# Reaction EX_MGlcn99_rl(e) deleted.
# Reaction EX_c10dc[e] deleted.
# Reaction EX_3ohsebac[e] deleted.
# Reaction EX_MGlcn66(e) deleted.
# Reaction EX_4nph(e) deleted.
# Reaction EX_whttdca(e) deleted.
# Reaction EX_2425dhvitd2[e] deleted.
# Reaction sink_xol7ah3[c] deleted.
# Reaction EX_acetone(e) deleted.
# Reaction EX_caro(e) deleted.
# Reaction EX_his_L(e) deleted.
# Reaction EX_3ityr_L[e] deleted.
# Reaction EX_pmeth[e] deleted.
# Reaction EX_dxtrn(e) deleted.
# Reaction EX_pcholdoc_hs(e) deleted.
# Reaction EX_hspg_degr_2(e) deleted.
# Reaction EX_asp_L[e] deleted.
# Reaction sink_tetdec2coa(c) deleted.
# Reaction EX_M00117[e] deleted.
# Reaction EX_sel[e] deleted.
# Reaction EX_thexdd[e] deleted.
# Reaction EX_rsv[e] deleted.
# Reaction EX_12dgr120[e] deleted.
# Reaction EX_prostgh2(e) deleted.
# Reaction EX_Lcyst(e) deleted.
# Reaction EX_fucacngalacglcgalgluside_hs[e] deleted.
# Reaction EX_trpglyleu[e] deleted.
# Reaction EX_dodecanac[e] deleted.
# Reaction EX_ibup_R[e] deleted.
# Reaction EX_hLkynr(e) deleted.
# Reaction EX_gltcho[e] deleted.
# Reaction EX_3dhlchol[e] deleted.
# Reaction EX_MGlcn140(e) deleted.
# Reaction EX_CE2209(e) deleted.
# Reaction EX_M02560[e] deleted.
# Reaction EX_vldl_hs(e) deleted.
# Reaction EX_caproic[e] deleted.
# Reaction EX_met_L[e] deleted.
# Reaction EX_thmtp(e) deleted.
# Reaction EX_xylu_L[e] deleted.
# Reaction EX_gd3_hs[e] deleted.
# Reaction EX_3mglutac[e] deleted.
# Reaction EX_4pyrdx[e] deleted.
# Reaction EX_hspg(e) deleted.
# Reaction EX_MGlcn21_rl(e) deleted.
# Reaction EX_MGlcn113_rl(e) deleted.
# Reaction EX_5HPET[e] deleted.
# Reaction EX_M00315[e] deleted.
# Reaction EX_MGlcn32_rl(e) deleted.
# Reaction EX_sucr(e) deleted.
# Reaction EX_MGlcn150(e) deleted.
# Reaction sink_HC02192(c) deleted.
# Reaction EX_orot[e] deleted.
# Reaction EX_CE4969[e] deleted.
# Reaction EX_MGlcn160_rl(e) deleted.
# Reaction EX_HC02197(e) deleted.
# Reaction EX_M02821[e] deleted.
# Reaction EX_xolest226_hs(e) deleted.
# Reaction EX_n2m2nmasn[e] deleted.
# Reaction sink_tdechola(c) deleted.
# Reaction EX_MGlcn181_rl(e) deleted.
# Reaction EX_pailpalm_hs[e] deleted.
# Reaction EX_5htrp[e] deleted.
# Reaction EX_CE2026[e] deleted.
# Reaction EX_cala(e) deleted.
# Reaction DM_GCALD deleted.
# Reaction EX_gt1b_hs(e) deleted.
# Reaction EX_1hmdgluc[e] deleted.
# Reaction EX_3mtp[e] deleted.
# Reaction EX_Rtotal(e) deleted.
# Reaction EX_HC00342(e) deleted.
# Reaction EX_elaidcrn(e) deleted.
# Reaction EX_fvstet[e] deleted.
# Reaction EX_dgtp[e] deleted.
# Reaction EX_bhb(e) deleted.
# Reaction sink_phe_L[c] deleted.
# Reaction EX_retinol_9_cis(e) deleted.
# Reaction EX_dchac[e] deleted.
# Reaction EX_MGlcn20(e) deleted.
# Reaction EX_protrplys[e] deleted.
# Reaction EX_mqn9(e) deleted.
# Reaction EX_nrpphr(e) deleted.
# Reaction EX_core4_rl(e) deleted.
# Reaction EX_MGlcn101_rl(e) deleted.
# Reaction EX_pchol_hs[e] deleted.
# Reaction EX_18harachd(e) deleted.
# Reaction EX_HC02207[e] deleted.
# Reaction EX_sel(e) deleted.
# Reaction EX_MGlcn28_rl(e) deleted.
# Reaction EX_dms(e) deleted.
# Reaction EX_cit[e] deleted.
# Reaction EX_M02035[e] deleted.
# ...
# Reaction EX_gncore1_rl(e) deleted.
# Reaction EX_acgalidour(e) deleted.
# Reaction EX_h2o(e) deleted.
# Reaction EX_xyluglc(e) deleted.
# Reaction EX_3hcinnm[e] deleted.
# Reaction DM_gda1_hs[n] deleted.
# Reaction EX_glcr[e] deleted.
# Reaction EX_srtn[e] deleted.
# Reaction EX_M02353[e] deleted.
# Reaction EX_MGlcn96(e) deleted.
# Reaction EX_arg_D(e) deleted.
# Reaction EX_gm2a_hs[e] deleted.
# Reaction EX_C05957(e) deleted.
# Reaction EX_crvsm1[e] deleted.
# Reaction EX_prolyspro[e] deleted.
# Reaction EX_HC02199[e] deleted.
# Reaction DM_isochol[c] deleted.
# Reaction EX_CE7085(e) deleted.
# Reaction EX_CE2705(e) deleted.
# Reaction EX_4aabutn[e] deleted.
# Reaction EX_CE2510(e) deleted.
# Reaction EX_MGlcn82(e) deleted.
# Reaction EX_magste_hs(e) deleted.
# Reaction EX_xolest183_hs[e] deleted.
# Reaction EX_fucfuc12gal14acglcgalgluside_hs(e) deleted.
# Reaction sink_tchola[c] deleted.
# Reaction EX_HC00007[e] deleted.
# Reaction EX_M02449[e] deleted.
# Reaction EX_hista(e) deleted.
# Reaction EX_3tetd7ecoacrn(e) deleted.
# Reaction EX_C02712(e) deleted.
# Reaction EX_prostgi2[e] deleted.
# Reaction DM_dca3g[c] deleted.
# Reaction EX_tetpent6[e] deleted.
# Reaction EX_MGlcn97(e) deleted.
# Reaction EX_aspalaarg[e] deleted.
# Reaction EX_ascb_L[e] deleted.
# Reaction EX_allop[e] deleted.
# Reaction EX_pglyc_hs[e] deleted.
# Reaction EX_MGlcn90_rl(e) deleted.
# Reaction EX_adrn[e] deleted.
# Reaction sink_HC02198(c) deleted.
# Reaction EX_3hlvstacid[e] deleted.
# Reaction EX_MGlcn127(e) deleted.
# Reaction EX_methsucc(e) deleted.
# Reaction DM_15HPET[n] deleted.
# Reaction EX_25hvitd3(e) deleted.
# Reaction EX_MGlcn5_rl(e) deleted.
# Reaction EX_ppbng[e] deleted.
# Reaction EX_h2o[e] deleted.
# Reaction DM_12dhchol[c] deleted.
# Reaction EX_CE5643[e] deleted.
# Reaction DM_4abut[c] deleted.
# Reaction EX_CE4968[e] deleted.
# Reaction EX_procys[e] deleted.
# Reaction EX_sphmyln181221_hs(e) deleted.
# Reaction EX_phyQ[e] deleted.
# Reaction EX_MGlcn35(e) deleted.
# Reaction EX_maltttr(e) deleted.
# Reaction sink_thmpp[c] deleted.
# Reaction DM_Lkynr[c] deleted.
# Reaction EX_asn_L[e] deleted.
# Reaction EX_MGlcn58(e) deleted.
# Reaction EX_MGlcn16_rl(e) deleted.
# Reaction EX_o2(e) deleted.
# Reaction EX_7thf[e] deleted.
# Reaction EX_lstnm1[e] deleted.
# Reaction EX_aspglu[e] deleted.
# Reaction EX_pydxn(e) deleted.
# Reaction sink_c81coa(c) deleted.
# Reaction EX_tym[e] deleted.
# Reaction EX_M03117[e] deleted.
# Reaction EX_gly[e] deleted.
# Reaction sink_pmtcoa(c) deleted.
# Reaction EX_gam[e] deleted.
# Reaction EX_cro4(e) deleted.
# Reaction EX_5ohhexa(e) deleted.
# Reaction EX_MGlcn33(e) deleted.
# Reaction EX_pnto_R(e) deleted.
# Reaction EX_gncore2[e] deleted.
# Reaction EX_adpac[e] deleted.
# Reaction EX_gluthr[e] deleted.
# Reaction EX_icdchol[e] deleted.
# Reaction EX_akg(e) deleted.
# Reaction sink_lnlc(c) deleted.
# Reaction EX_nrpphrsf[e] deleted.
# Reaction EX_tettet6(e) deleted.
# Reaction EX_acleu_L(e) deleted.
# Reaction EX_21hprgnlone[e] deleted.
# Reaction EX_2hyoxplac(e) deleted.
# Reaction EX_ncam[e] deleted.
# Reaction EX_ksii_core2[e] deleted.
# Reaction DM_PROTEIN deleted.
# Reaction sink_HC02220(c) deleted.
# Reaction EX_MGlcn19(e) deleted.
# Reaction EX_no2(e) deleted.
# Reaction EX_CE2916[e] deleted.
# Reaction EX_cu2(e) deleted.
# Reaction EX_pcholar_hs[e] deleted.
# Reaction EX_xolest181_hs[e] deleted.
# Reaction EX_glyasp(e) deleted.
# Reaction EX_leuval[e] deleted.
# Reaction EX_56eppvs[e] deleted.
# Reaction EX_cbasp(e) deleted.
# Reaction EX_dca3s[e] deleted.
# Reaction EX_prostgd2(e) deleted.
# Reaction EX_lthstrl[e] deleted.
# Reaction EX_ileserarg[e] deleted.
# Reaction DM_pchol_hs(c) deleted.
# Reaction EX_lstn1gluc[e] deleted.
# Reaction EX_pime(e) deleted.
# Reaction EX_udp[e] deleted.
# Reaction EX_andrstrnglc[e] deleted.
# Reaction EX_carveol[e] deleted.
# Reaction EX_trpprogly[e] deleted.
# Reaction EX_r34hpp(e) deleted.
# Reaction EX_leuleu(e) deleted.
# Reaction EX_diholineth[e] deleted.
# Reaction EX_4mtolbutamide(e) deleted.
# Reaction EX_pcholn2254_hs(e) deleted.
# Reaction EX_gca3s[e] deleted.
# Reaction EX_caribup_s[e] deleted.
# Reaction EX_ethmalac[e] deleted.
# Reaction EX_psyltchol[e] deleted.
# Reaction DM_na1[x] deleted.
# Reaction EX_4ohmdz[e] deleted.
# Reaction EX_thym[e] deleted.
# Reaction EX_tststerones[e] deleted.
# Reaction EX_nfd[e] deleted.
# Reaction EX_tethex3[e] deleted.
# Reaction EX_MGlcn36(e) deleted.
# Reaction EX_12HPET[e] deleted.
# Reaction EX_M00932[e] deleted.
# Reaction EX_MGlcn167_rl(e) deleted.
# Reaction EX_homogal(e) deleted.
# Reaction EX_3octdeccrn[e] deleted.
# Reaction EX_hexgly[e] deleted.
# Reaction EX_cysaspphe[e] deleted.
# Reaction EX_oh1[e] deleted.
# Reaction EX_mqn9[e] deleted.
# Reaction EX_MGlcn74(e) deleted.
# Reaction DM_taur[c] deleted.
# Reaction EX_am4ncs[e] deleted.
# Reaction EX_caro[e] deleted.
# Reaction EX_3tdcrn(e) deleted.
# Reaction EX_trpglyasp[e] deleted.
# Reaction EX_MGlcn25_rl(e) deleted.
# Reaction EX_subgly[e] deleted.
# Reaction EX_MGlcn74_rl(e) deleted.
# Reaction EX_MGlcn60(e) deleted.
# Reaction EX_abt(e) deleted.
# Reaction sink_c226coa[c] deleted.
# Reaction DM_udca3s[c] deleted.
# Reaction DM_Ser_Gly_Ala_X_Gly_ly_ deleted.
# Reaction sink_HC02194(c) deleted.
# Reaction EX_ca24g[e] deleted.
# Reaction DM_3dhchol[c] deleted.
# Reaction EX_trpsertyr[e] deleted.
# Reaction EX_alaglylys[e] deleted.
# Reaction EX_oxyp[e] deleted.
# Reaction EX_gm1_hs(e) deleted.
# Reaction EX_udpglcur[e] deleted.
# Reaction EX_fe2[e] deleted.
# Reaction EX_MGlcn102(e) deleted.
# Reaction sink_thmtp(c) deleted.
# Reaction DM_core5_g_ deleted.
# Reaction EX_oagd3_hs[e] deleted.
# Reaction EX_hspg[e] deleted.
# Reaction EX_malt(e) deleted.
# Reaction EX_xylan(e) deleted.
# Reaction DM_na1[c] deleted.
# Reaction EX_CE1935[e] deleted.
# Reaction EX_M02108[e] deleted.
# Reaction DM_mi134p[c] deleted.
# Reaction EX_meoh(e) deleted.
# Reaction EX_gbside_hs(e) deleted.
# Reaction EX_acglu(e) deleted.
# Reaction EX_ala_L(e) deleted.
# Reaction EX_3deccrn[e] deleted.
# Reaction DM_pe_hs[r] deleted.
# Reaction EX_34dhphe(e) deleted.
# Reaction EX_MGlcn53_rl(e) deleted.
# Reaction EX_fuc14galacglcgalgluside_hs(e) deleted.
# Reaction EX_orn(e) deleted.
# Reaction EX_metasntyr[e] deleted.
# Reaction EX_CE0074(e) deleted.
# Reaction EX_tyrcysgly[e] deleted.
# Reaction EX_cysacmp[e] deleted.
# Reaction EX_M01872[e] deleted.
# Reaction EX_acgal[e] deleted.
# Reaction EX_lystyrile[e] deleted.
# Reaction EX_leuktrD4(e) deleted.
# Reaction EX_ametam(e) deleted.
# Reaction EX_whttdca[e] deleted.
# Reaction EX_CE5854[e] deleted.
# Reaction DM_thm[m] deleted.
# Reaction EX_HC02202[e] deleted.
# Reaction EX_man[e] deleted.
# Reaction sink_HC02220[c] deleted.
# Reaction EX_HC01446[e] deleted.
# Reaction EX_MGlcn149_rl(e) deleted.
# Reaction EX_ak2lgchol_hs[e] deleted.
# Reaction EX_crtn[e] deleted.
# Reaction EX_malcoa[e] deleted.
# Reaction EX_pcholet_hs(e) deleted.
# Reaction EX_ddecrn[e] deleted.
# Reaction EX_tym(e) deleted.
# Reaction EX_cgly[e] deleted.
# Reaction EX_11_cis_retfa[e] deleted.
# Reaction EX_i[e] deleted.
# Reaction EX_MGlcn65_rl(e) deleted.
# Reaction EX_MGlcn2_rl(e) deleted.
# Reaction EX_glcur[e] deleted.
# Reaction EX_docohxeth[e] deleted.
# Reaction EX_CE5789[e] deleted.
# Reaction EX_pe14_hs[e] deleted.
# Reaction EX_pcholole_hs(e) deleted.
# Reaction EX_MGlcn30_rl(e) deleted.
# Reaction EX_3aib_D(e) deleted.
# Reaction EX_C11695[e] deleted.
# Reaction EX_proglulys[e] deleted.
# Reaction EX_udp(e) deleted.
# Reaction EX_dha[e] deleted.
# Reaction EX_4nphsf(e) deleted.
# Reaction EX_sphmyln181201_hs[e] deleted.
# Reaction EX_MGlcn121(e) deleted.
# Reaction EX_glctnb(e) deleted.
# Reaction EX_6hmsmvacid[e] deleted.
# Reaction EX_core5(e) deleted.
# Reaction EX_core2(e) deleted.
# Reaction EX_M00003[e] deleted.
# Reaction EX_cysgluhis[e] deleted.
# Reaction EX_estradiolglc[e] deleted.
# Reaction EX_arabttr(e) deleted.
# Reaction EX_MGlcn93_rl(e) deleted.
# Reaction EX_inost(e) deleted.
# Reaction EX_nac(e) deleted.
# Reaction EX_dopa[e] deleted.
# Reaction EX_C10164[e] deleted.
# Reaction EX_mma[e] deleted.
# Reaction EX_h2o2(e) deleted.
# Reaction EX_asnmetpro[e] deleted.
# Reaction EX_sphmyln18116_hs(e) deleted.
# Reaction EX_cdp(e) deleted.
# Reaction EX_actyr(e) deleted.
# Reaction EX_xol24oh(e) deleted.
# Reaction EX_hisglnala[e] deleted.
# Reaction EX_galgluside_hs[e] deleted.
# Reaction EX_cit(e) deleted.
# Reaction EX_ileasp[e] deleted.
# Reaction EX_hspg_degr_7(e) deleted.
# Reaction EX_trphismet[e] deleted.
# Reaction EX_glyleu(e) deleted.
# Reaction sink_doco13ecoa[c] deleted.
# Reaction EX_xoldiolone[e] deleted.
# Reaction EX_MGlcn114(e) deleted.
# Reaction EX_CE1401[e] deleted.
# Reaction EX_sph1p[e] deleted.
# Reaction EX_11docrtstrn(e) deleted.
# Reaction EX_3hpppn(e) deleted.
# Reaction EX_CN0020[e] deleted.
# Reaction DM_hcys_L[c] deleted.
# Reaction EX_7dhcdchol[e] deleted.
# Reaction EX_trpvalasp[e] deleted.
# Reaction EX_limnen[e] deleted.
# Reaction EX_MGlcn161_rl(e) deleted.
# Reaction EX_glyhislys[e] deleted.
# Reaction EX_lstnm2[e] deleted.
# Reaction EX_CE0737[e] deleted.
# Reaction EX_ahcys(e) deleted.
# Reaction EX_adn[e] deleted.
# Reaction EX_txb2(e) deleted.
# Reaction sink_HC02195[c] deleted.
# Reaction EX_C11695(e) deleted.
# Reaction EX_ppp9(e) deleted.
# Reaction EX_hexdeceeth[e] deleted.
# Reaction EX_tcynt(e) deleted.
# Reaction EX_CE4969(e) deleted.
# Reaction EX_C05299[e] deleted.
# Reaction EX_2h3mv(e) deleted.
# Reaction EX_CE4890(e) deleted.
# Reaction EX_pcholn15_hs[e] deleted.
# Reaction EX_hyochol[e] deleted.
# Reaction EX_pheacgln[e] deleted.
# Reaction EX_5eipenc(e) deleted.
# Reaction sink_5hpet[c] deleted.
# Reaction EX_c5dc(e) deleted.
# Reaction EX_malthx[e] deleted.
# Reaction EX_alaasp(e) deleted.
# Reaction DM_gda1_hs(n) deleted.
# Reaction EX_hisglylys[e] deleted.
# Reaction EX_alltn[e] deleted.
# Reaction EX_15HPET[e] deleted.
# Reaction EX_MGlcn23_rl(e) deleted.
# Reaction EX_dgmp[e] deleted.
# Reaction EX_2hiv(e) deleted.
# Reaction EX_MGlcn89(e) deleted.
# Reaction EX_retinal[e] deleted.
# Reaction EX_ade(e) deleted.
# Reaction EX_maltttr[e] deleted.
# Reaction EX_phenol(e) deleted.
# Reaction EX_MGlcn27_rl(e) deleted.
# Reaction DM_clpni14(c) deleted.
# Reaction EX_duri[e] deleted.
# Reaction sink_q8(c) deleted.
# Reaction DM_dad_5 deleted.
# Reaction EX_sphmyln180241_hs(e) deleted.
# Reaction EX_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs(e) deleted.
# Reaction EX_HC01939[e] deleted.
# Reaction EX_CE2915[e] deleted.
# Reaction EX_MGlcn126(e) deleted.
# Reaction EX_13_cis_retn[e] deleted.
# Reaction EX_trp_L[e] deleted.
# Reaction EX_isoval(e) deleted.
# Reaction EX_MGlcn160(e) deleted.
# Reaction EX_glyc2p(e) deleted.
# Reaction EX_glyb(e) deleted.
# Reaction EX_kdn[e] deleted.
# Reaction EX_vanillac(e) deleted.
# Reaction EX_4mptnl(e) deleted.
# Reaction EX_pcholn203_hs[e] deleted.
# Reaction EX_kynate[e] deleted.
# Reaction EX_ribflv[e] deleted.
# Reaction EX_C14771(e) deleted.
# Reaction EX_MGlcn192_rl(e) deleted.
# Reaction EX_tma(e) deleted.
# Reaction sink_tyr_L[c] deleted.
# Reaction EX_thmtp[e] deleted.
# Reaction EX_tyrargglu[e] deleted.
# Reaction EX_MGlcn107(e) deleted.
# Reaction EX_o2s[e] deleted.
# Reaction EX_ncam(e) deleted.
# Reaction EX_subeac(e) deleted.
# Reaction sink_hdca(c) deleted.
# Reaction EX_mercplaccys(e) deleted.
# Reaction EX_whtststerone[e] deleted.
# Reaction EX_3dhchol(e) deleted.
# Reaction EX_gtp(e) deleted.
# Reaction EX_7ohocata[e] deleted.
# Reaction EX_cellul(e) deleted.
# Reaction EX_hexc[e] deleted.
# Reaction EX_gal[e] deleted.
# Reaction EX_acgalidour2s(e) deleted.
# Reaction EX_utp[e] deleted.
# Reaction sink_Ser_Gly_Ala_X_Gly[r] deleted.
# Reaction DM_for[c] deleted.
# Reaction EX_Lcystin(e) deleted.
# Reaction EX_CE1617(e) deleted.
# Reaction EX_56dura[e] deleted.
# Reaction EX_asncyscys[e] deleted.
# Reaction EX_HC00002(e) deleted.
# Reaction EX_asn_L(e) deleted.
# Reaction EX_dgtp(e) deleted.
# Reaction EX_CE2011[e] deleted.
# Reaction EX_gluside_hs(e) deleted.
# Reaction EX_i(e) deleted.
# Reaction EX_asp_D(e) deleted.
# Reaction EX_c81crn[e] deleted.
# Reaction EX_n2m2nmasn(e) deleted.
# Reaction EX_alaasnleu[e] deleted.
# Reaction sink_lnlccoa(c) deleted.
# Reaction EX_MGlcn177_rl(e) deleted.
# Reaction EX_MGlcn171(e) deleted.
# Reaction DM_dhptd(c) deleted.
# Reaction EX_cspg_a(e) deleted.
# Reaction EX_dmgly(e) deleted.
# Reaction EX_HC02203[e] deleted.
# Reaction EX_C05770[e] deleted.
# Reaction DM_k[g] deleted.
# Reaction EX_dmso(e) deleted.
# Reaction EX_pre_prot[e] deleted.
# Reaction EX_CE6247(e) deleted.
# Reaction EX_xolest205_hs(e) deleted.
# Reaction EX_hdca24g[e] deleted.
# Reaction EX_6bhglzglc[e] deleted.
# Reaction EX_thbpt[e] deleted.
# Reaction DM_adocbl(c) deleted.
# Reaction EX_asntyrgly[e] deleted.
# Reaction EX_aclys[e] deleted.
# Reaction EX_propropro[e] deleted.
# Reaction DM_dgpi_prot_hs_r_ deleted.
# Reaction EX_alahisala[e] deleted.
# Reaction sink_octdececoa[c] deleted.
# Reaction EX_C13856[e] deleted.
# Reaction EX_fe2(e) deleted.
# Reaction sink_nadp(c) deleted.
# Reaction EX_glnhislys[e] deleted.
# Reaction EX_adpoh(e) deleted.
# Reaction EX_CE2047[e] deleted.
# Reaction EX_MGlcn22(e) deleted.
# Reaction EX_10fthf7glu[e] deleted.
# Reaction DM_4abut[n] deleted.
# Reaction EX_estriol(e) deleted.
# Reaction EX_CE5786[e] deleted.
# Reaction EX_3hphac(e) deleted.
# Reaction EX_3mox4hoxm(e) deleted.
# Reaction sink_glu_L[c] deleted.
# Reaction EX_leugly[e] deleted.
# Reaction EX_peole_hs[e] deleted.
# Reaction EX_CE2510[e] deleted.
# Reaction EX_MGlcn128_rl(e) deleted.
# Reaction EX_mettrpphe[e] deleted.
# Reaction EX_3mhis[e] deleted.
# Reaction EX_MGlcn38(e) deleted.
# Reaction EX_dsT_antigen[e] deleted.
# Reaction EX_crm_hs(e) deleted.
# Reaction EX_nrvnc[e] deleted.
# Reaction EX_triodthysuf[e] deleted.
# Reaction EX_MGlcn123(e) deleted.
# Reaction xenobiotics deleted.
# Reaction EX_xylu_D(e) deleted.
# Reaction EX_cholate(e) deleted.
# Reaction EX_adpcbl(e) deleted.
# Reaction EX_glcmannan(e) deleted.
# Reaction DM_pmtcoa[r] deleted.
# Reaction EX_sphmyln181221_hs[e] deleted.
# Reaction EX_ins[e] deleted.
# Reaction EX_CE1447(e) deleted.
# Reaction EX_CE2839(e) deleted.
# Reaction EX_HC02210[e] deleted.
# Reaction EX_CE7172(e) deleted.
# Reaction EX_pchol2ste_hs[e] deleted.
# Reaction EX_hspg_degr_14(e) deleted.
# Reaction EX_MGlcn135(e) deleted.
# Reaction EX_5fthf[e] deleted.
# Reaction EX_1mncam(e) deleted.
# Reaction DM_adprbp[c] deleted.
# Reaction EX_dhap[e] deleted.
# Reaction EX_1hibup_S[e] deleted.
# Reaction EX_CE5304(e) deleted.
# Reaction EX_aqcobal[e] deleted.
# Reaction EX_ind3ac(e) deleted.
# Reaction EX_7hpvs[e] deleted.
# Reaction EX_pvs[e] deleted.
# Reaction EX_c4dc(e) deleted.
# Reaction EX_sphs1p[e] deleted.
# Reaction DM_oretn_n_ deleted.
# Reaction EX_HC02220[e] deleted.
# Reaction EX_HC01944[e] deleted.
# Reaction DM_tdca3s[c] deleted.
# Reaction EX_bilglcur[e] deleted.
# Reaction EX_whtststerone(e) deleted.
# Reaction EX_MGlcn188_rl(e) deleted.
# Reaction EX_s2l2n2m2m[e] deleted.
# Reaction EX_C05767[e] deleted.
# Reaction EX_HC02205[e] deleted.
# Reaction EX_ddece1crn(e) deleted.
# Reaction EX_aicar[e] deleted.
# Reaction EX_hdcecrn[e] deleted.
# Reaction EX_gd1b_hs[e] deleted.
# Reaction EX_prgnlone(e) deleted.
# Reaction EX_sph1p(e) deleted.
# Reaction EX_MGlcn148(e) deleted.
# Reaction EX_pedh203_hs(e) deleted.
# Reaction DM_chylo_hs(e) deleted.
# Reaction EX_octa[e] deleted.
# Reaction EX_HC02204[e] deleted.
# Reaction EX_hexdiac(e) deleted.
# Reaction EX_nicrnt[e] deleted.
# Reaction EX_lanost[e] deleted.
# Reaction EX_perillyl[e] deleted.
# Reaction EX_val_L(e) deleted.
# Reaction EX_tolbutamide[e] deleted.
# Reaction EX_melib(e) deleted.
# Reaction EX_cdp[e] deleted.
# Reaction EX_hmcr[e] deleted.
# Reaction EX_dsmsterol[e] deleted.
# Reaction EX_5ohfvs[e] deleted.
# Reaction EX_M00265[e] deleted.
# Reaction EX_etoh[e] deleted.
# Reaction EX_pchol2linl_hs(e) deleted.
# Reaction EX_gdp[e] deleted.
# Reaction sink_cholate[c] deleted.
# Reaction EX_tdchola[e] deleted.
# Reaction EX_crtstrn(e) deleted.
# Reaction EX_hisglu[e] deleted.
# Reaction DM_3dhlchol[c] deleted.
# Reaction EX_MGlcn119(e) deleted.
# Reaction EX_hexgly(e) deleted.
# Reaction EX_rib_D(e) deleted.
# Reaction EX_pro_L(e) deleted.
# Reaction EX_im4ac[e] deleted.
# Reaction EX_galgalgalthcrm_hs(e) deleted.
# Reaction EX_dhap(e) deleted.
# Reaction EX_c51crn[e] deleted.
# Reaction EX_MGlcn97_rl(e) deleted.
# Reaction EX_datp(e) deleted.
# Reaction EX_npthl[e] deleted.
# Reaction EX_thrilearg[e] deleted.
# Reaction EX_hspg_degr_9(e) deleted.
# Reaction EX_MGlcn139(e) deleted.
# Reaction EX_MGlcn105(e) deleted.
# Reaction EX_steeth(e) deleted.
# Reaction EX_chols(e) deleted.
# Reaction sink_val_L[c] deleted.
# Reaction EX_HC01609(e) deleted.
# Reaction EX_trpgluleu[e] deleted.
# Reaction EX_gt1a_hs(e) deleted.

# %%
vmh_products['menuguide_reaction_id'] = vmh_products.reaction_abbreviation.apply(lambda x: reactions_vmh[x])
kegg_products['menuguide_reaction_id'] = kegg_products.reaction_id.apply(lambda x: reactions_kegg[x])

# %%
def add_product_to_reaction_dict(row):
    reaction_id = row['menuguide_reaction_id']
    product_id = row['menuguide_id']
    if reaction_id in reactions_dict:
        entry = reactions_dict[reaction_id]
        if 'products' in entry:
            entry['products'].add(product_id)
        else:
            entry['products'] = {product_id}

# %%
kegg_products.apply(add_product_to_reaction_dict, axis=1)
vmh_products.apply(add_product_to_reaction_dict, axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 53179    None
# 53180    None
# 53181    None
# 53182    None
# 53183    None
# Length: 49569, dtype: object

# %%
reactions_dict
# Out:
# {'reaction_0': {'kegg_id': 'R00001',
#   'description': 'polyphosphate polyphosphohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_5449'},
#   'products': {'compound_4433', 'compound_7069'}},
#  'reaction_1': {'kegg_id': 'R00002',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_2019',
#    'compound_2300',
#    'compound_2460',
#    'compound_3505',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_2018',
#    'compound_3473',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744',
#    'compound_9361'}},
#  'reaction_2': {'kegg_id': 'R00005',
#   'description': 'urea-1-carboxylate amidohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_6210',
#    'compound_6211',
#    'compound_808'},
#   'products': {'compound_1654', 'compound_4158'}},
#  'reaction_3': {'kegg_id': 'R00006',
#   'description': 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)',
#   'substrates': {'compound_1654', 'compound_6130'},
#   'products': {'compound_4529', 'compound_5012'}},
#  'reaction_4': {'kegg_id': 'R00008',
#   'description': '4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)',
#   'substrates': {'compound_9790', 'compound_9791'},
#   'products': {'compound_4529', 'compound_5012'}},
#  'reaction_5': {'kegg_id': 'R00010',
#   'description': 'alpha,alpha-trehalose glucohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4833',
#    'compound_4834',
#    'compound_5003'},
#   'products': {'compound_2166', 'compound_5019'}},
#  'reaction_6': {'kegg_id': 'R00011',
#   'description': 'Mn(II):hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_21891',
#    'compound_400782',
#    'compound_403943',
#    'compound_404077'},
#   'products': {'compound_21892', 'compound_2300', 'compound_5003'}},
#  'reaction_7': {'kegg_id': 'R00012',
#   'description': 'GTP:GTP guanylyltransferase',
#   'substrates': {'compound_2285', 'compound_2286'},
#   'products': {'compound_403470', 'compound_4425', 'compound_4426'}},
#  'reaction_8': {'kegg_id': 'R00013',
#   'description': 'glyoxylate carboxy-lyase (dimerizing; tartronate-semialdehyde-forming)',
#   'substrates': {'compound_400367', 'compound_5030'},
#   'products': {'compound_1654',
#    'compound_201',
#    'compound_3124',
#    'compound_6313'}},
#  'reaction_9': {'kegg_id': 'R00014',
#   'vmh_id': 'HMR_8746',
#   'description': 'pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)',
#   'substrates': {'compound_404077',
#    'compound_4529',
#    'compound_4784',
#    'compound_5012'},
#   'products': {'compound_1654', 'compound_3106', 'compound_3107'}},
#  'reaction_10': {'kegg_id': 'R00015',
#   'description': "sucrose:sucrose 1'-beta-D-fructosyltransferase",
#   'substrates': {'compound_4705'},
#   'products': {'compound_2166',
#    'compound_400958',
#    'compound_5019',
#    'compound_8203'}},
#  'reaction_11': {'kegg_id': 'R00017',
#   'description': 'ferrocytochrome-c:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_2028', 'compound_403943'},
#   'products': {'compound_2023', 'compound_2300', 'compound_5003'}},
#  'reaction_12': {'kegg_id': 'R00018',
#   'description': 'putrescine:putrescine 4-aminobutyltransferase (ammonia-forming)',
#   'substrates': {'compound_4511'},
#   'products': {'compound_10096', 'compound_4158'}},
#  'reaction_13': {'kegg_id': 'R00019',
#   'description': 'hydrogen:ferredoxin oxidoreductase',
#   'substrates': {'compound_2019',
#    'compound_3505',
#    'compound_400782',
#    'compound_404077'},
#   'products': {'compound_2018', 'compound_2298', 'compound_3473'}},
#  'reaction_14': {'kegg_id': 'R00021',
#   'description': 'L-glutamate:ferredoxin oxidoreductase (transaminating)',
#   'substrates': {'compound_2018', 'compound_2196', 'compound_3473'},
#   'products': {'compound_2019',
#    'compound_2180',
#    'compound_2181',
#    'compound_3505',
#    'compound_400782',
#    'compound_403968',
#    'compound_404077',
#    'compound_5014'}},
#  'reaction_15': {'kegg_id': 'R00022',
#   'description': 'chitobiose N-acetylglucosaminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2330',
#    'compound_5003',
#    'compound_6663'},
#   'products': {'compound_687', 'compound_688'}},
#  'reaction_16': {'kegg_id': 'R00023',
#   'description': 'hydroxylamine:NAD+ oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5260'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6776',
#    'compound_6777',
#    'compound_6778'}},
#  'reaction_17': {'kegg_id': 'R00024',
#   'description': '3-phospho-D-glycerate carboxy-lyase (dimerizing; D-ribulose-1,5-bisphosphate-forming)',
#   'substrates': {'compound_1654',
#    'compound_2300',
#    'compound_404370',
#    'compound_5003',
#    'compound_6333'},
#   'products': {'compound_403270'}},
#  'reaction_18': {'kegg_id': 'R00025',
#   'description': 'ethylnitronate:oxygen 2-oxidoreductase (nitrite-forming)',
#   'substrates': {'compound_20443',
#    'compound_400589',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2024',
#    'compound_2025',
#    'compound_2300',
#    'compound_4169',
#    'compound_5003',
#    'compound_5050',
#    'compound_667'}},
#  'reaction_19': {'kegg_id': 'R00026',
#   'description': 'cellobiose glucohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_5256'},
#   'products': {'compound_2167', 'compound_3269'}},
#  'reaction_20': {'kegg_id': 'R00027',
#   'description': '2-hydroxy-1,2-diphenylethanone benzaldehyde-lyase (benzaldehyde-forming)',
#   'substrates': {'compound_400935'},
#   'products': {'compound_5306'}},
#  'reaction_21': {'kegg_id': 'R00029',
#   'description': 'thiosulfate:ferricytochrome-c oxidoreductase',
#   'substrates': {'compound_2023',
#    'compound_4871',
#    'compound_5341',
#    'compound_5342'},
#   'products': {'compound_2028', 'compound_6994', 'compound_6995'}},
#  'reaction_22': {'kegg_id': 'R00031',
#   'description': '1,2-benzenediol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_4881', 'compound_5005'},
#   'products': {'compound_272'}},
#  'reaction_23': {'kegg_id': 'R00032',
#   'vmh_id': 'BCDO',
#   'description': "beta-carotene:oxygen 15,15'-oxidoreductase (bond-cleaving)",
#   'substrates': {'compound_1068', 'compound_4182', 'compound_5005'},
#   'products': {'compound_4556', 'compound_4559'}},
#  'reaction_24': {'kegg_id': 'R00033',
#   'description': 'thiamine:oxygen 5-oxidoreductase',
#   'substrates': {'compound_4182', 'compound_4781', 'compound_5005'},
#   'products': {'compound_403943', 'compound_9691'}},
#  'reaction_25': {'kegg_id': 'R00034',
#   'description': 'Cyclobutadipyrimidine (in DNA) pyrimidine-lyase',
#   'substrates': {'compound_7811'},
#   'products': {'compound_11614'}},
#  'reaction_26': {'kegg_id': 'R00036',
#   'vmh_id': 'PPBNGS',
#   'description': '5-aminolevulinate hydro-lyase (adding 5-aminolevulinate and cyclizing; porphobilinogen-forming)',
#   'substrates': {'compound_539', 'compound_5584'},
#   'products': {'compound_2300',
#    'compound_404077',
#    'compound_4420',
#    'compound_5003'}},
#  'reaction_27': {'kegg_id': 'R00038',
#   'description': '4-hydroxy-3-hexanone propanal-lyase (propanal-forming)',
#   'substrates': {'compound_4419'},
#   'products': {'compound_7682'}},
#  'reaction_28': {'kegg_id': 'R00039',
#   'description': 'raffinose:raffinose 1F-alpha-D-galactosyltransferase',
#   'substrates': {'compound_4549', 'compound_5622'},
#   'products': {'compound_11604', 'compound_4705'}},
#  'reaction_29': {'kegg_id': 'R00041',
#   'description': 'long-chain-alcohol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5358'},
#   'products': {'compound_2300', 'compound_5003', 'compound_5719'}},
#  'reaction_30': {'kegg_id': 'R00042',
#   'description': '4-hydroxyphenylpyruvate:oxygen oxidoreductase (decarboxylating)',
#   'substrates': {'compound_276',
#    'compound_4182',
#    'compound_5005',
#    'compound_6332'},
#   'products': {'compound_1654', 'compound_401672', 'compound_5924'}},
#  'reaction_31': {'kegg_id': 'R00043',
#   'description': '1,2-bis(4-hydroxy-3-methoxyphenyl)ethylene:oxygen oxidoreductase (alpha-beta-bond-cleaving)',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_8868',
#    'compound_8869',
#    'compound_8870'},
#   'products': {'compound_6001'}},
#  'reaction_32': {'kegg_id': 'R00044',
#   'description': 'columbamine:oxygen oxidoreductase (cyclizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6762'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6004'}},
#  'reaction_33': {'kegg_id': 'R00045',
#   'vmh_id': 'TYRDOPO3',
#   'description': '3,4-dihydroxy-L-phenylalanine:oxygen oxidoreductase',
#   'substrates': {'compound_272', 'compound_4182', 'compound_5005'},
#   'products': {'compound_1929',
#    'compound_1930',
#    'compound_2300',
#    'compound_5003'}},
#  'reaction_34': {'kegg_id': 'R00047',
#   'description': '6-hydroxynicotinate,hydrogen-donor:oxygen oxidoreductase (3-hydroxylating, decarboxylating)',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_5018',
#    'compound_6222'},
#   'products': {'compound_1654',
#    'compound_2300',
#    'compound_5003',
#    'compound_5015',
#    'compound_6247'}},
#  'reaction_35': {'kegg_id': 'R00048',
#   'description': '(R)-3-((R)-3-Hydroxybutanoyloxy)-butanoate hydroxybutanoylhydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_8866',
#    'compound_8867'},
#   'products': {'compound_1349',
#    'compound_6270',
#    'compound_941',
#    'compound_942'}},
#  'reaction_36': {'kegg_id': 'R00049',
#   'description': '1-O-galloyl-beta-D-glucose:1-O-galloyl-beta-D-glucose O-galloyltransferase',
#   'substrates': {'compound_6323'},
#   'products': {'compound_2166', 'compound_5019', 'compound_8523'}},
#  'reaction_37': {'kegg_id': 'R00052',
#   'description': 'chloride:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_400850',
#    'compound_403943',
#    'compound_6434',
#    'compound_6454'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6437'}},
#  'reaction_38': {'kegg_id': 'R00053',
#   'description': 'digallate acylhydrolase',
#   'substrates': {'compound_2300',
#    'compound_403736',
#    'compound_5003',
#    'compound_6600'},
#   'products': {'compound_6483', 'compound_6484'}},
#  'reaction_39': {'kegg_id': 'R00054',
#   'description': 'orsellinate-depside hydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_7624'},
#   'products': {'compound_6792', 'compound_6793', 'compound_6794'}},
#  'reaction_40': {'kegg_id': 'R00055',
#   'description': "inosine:oxygen 5'-oxidoreductase",
#   'substrates': {'compound_2713', 'compound_4182', 'compound_5005'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6919'}},
#  'reaction_41': {'kegg_id': 'R00056',
#   'description': 'dinucleotide nucleotidohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_6853'},
#   'products': {'compound_7066'}},
#  'reaction_42': {'kegg_id': 'R00057',
#   'description': 'thiol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6565'},
#   'products': {'compound_403943', 'compound_7190'}},
#  'reaction_43': {'kegg_id': 'R00058',
#   'description': 'catechol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5051'},
#   'products': {'compound_2300', 'compound_400816', 'compound_5003'}},
#  'reaction_44': {'kegg_id': 'R00059',
#   'description': 'N-(6-aminohexanoyl)-6-aminohexanoate amidohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_6383',
#    'compound_6384'},
#   'products': {'compound_7247', 'compound_7248'}},
#  'reaction_45': {'kegg_id': 'R00060',
#   'description': 'Sulochrin:oxygen oxidoreductase (cyclizing, (+)-specific)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5625'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7759'}},
#  'reaction_46': {'kegg_id': 'R00061',
#   'description': 'sulochrin:oxygen oxidoreductase (cyclizing, (-)-specific)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5625'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7763'}},
#  'reaction_47': {'kegg_id': 'R00062',
#   'vmh_id': 'HMR_4767',
#   'description': 'bilirubin-glucuronoside:bilirubin-glucuronoside D-glucuronosyltransferase',
#   'substrates': {'compound_943',
#    'compound_944',
#    'compound_945',
#    'compound_946'},
#   'products': {'compound_943',
#    'compound_944',
#    'compound_945',
#    'compound_946'}},
#  'reaction_48': {'kegg_id': 'R00063',
#   'description': '1-O-sinapoyl-beta-D-glucose:1-O-sinapoyl-beta-D-glucose 1-O-sinapoyltransferase',
#   'substrates': {'compound_6331'},
#   'products': {'compound_2166', 'compound_5019', 'compound_8673'}},
#  'reaction_49': {'kegg_id': 'R00066',
#   'description': '6,7-Dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase',
#   'substrates': {'compound_1901'},
#   'products': {'compound_401782', 'compound_9021', 'compound_9022'}},
#  'reaction_50': {'kegg_id': 'R00067',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_400782', 'compound_404077', 'compound_9361'},
#   'products': {'compound_2298'}},
#  'reaction_51': {'kegg_id': 'R00068',
#   'description': 'L-ascorbate:oxygen oxidoreductase',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_5041',
#    'compound_5042',
#    'compound_900'},
#   'products': {'compound_1860',
#    'compound_2300',
#    'compound_5003',
#    'compound_9400'}},
#  'reaction_52': {'kegg_id': 'R00069',
#   'description': '4-imidazolone-5-propanoate:oxygen oxidoreductase',
#   'substrates': {'compound_403943', 'compound_9476', 'compound_9477'},
#   'products': {'compound_2300',
#    'compound_4182',
#    'compound_500',
#    'compound_5003',
#    'compound_5005'}},
#  'reaction_53': {'kegg_id': 'R00070',
#   'description': 'D-urobilinogen:oxygen oxidoreductase',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_9629',
#    'compound_9630'},
#   'products': {'compound_2300', 'compound_5003', 'compound_9635'}},
#  'reaction_54': {'kegg_id': 'R00072',
#   'description': 'thiamine-aldehyde:oxygen 5-oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4182',
#    'compound_5003',
#    'compound_5005',
#    'compound_9691'},
#   'products': {'compound_403943', 'compound_7639'}},
#  'reaction_55': {'kegg_id': 'R00073',
#   'description': 'reduced acceptor:prostaglandin G2 oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4480',
#    'compound_5003',
#    'compound_5015'},
#   'products': {'compound_2495', 'compound_5018'}},
#  'reaction_56': {'kegg_id': 'R00074',
#   'description': '2-aminophenol:oxygen oxidoreductase (dimerizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6913'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7057'}},
#  'reaction_57': {'kegg_id': 'R00075',
#   'description': 'S-adenosyl-L-methionine:S-adenosyl-L-methionine 3-amino-3-carboxypropyltransferase',
#   'substrates': {'compound_5009', 'compound_828', 'compound_829'},
#   'products': {'compound_401540',
#    'compound_402461',
#    'compound_9336',
#    'compound_9337'}},
#  'reaction_58': {'kegg_id': 'R00076',
#   'vmh_id': 'HMR_9488',
#   'description': 'ATP:phosphorylase-b phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_3015',
#    'compound_7188',
#    'compound_925'},
#   'products': {'compound_3014', 'compound_7187', 'compound_744'}},
#  'reaction_59': {'kegg_id': 'R00077',
#   'vmh_id': 'HMR_9489',
#   'description': '[Phosphorylase a] phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_3014',
#    'compound_5003',
#    'compound_7187'},
#   'products': {'compound_3015',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_7188'}},
#  'reaction_60': {'kegg_id': 'R00078',
#   'vmh_id': 'r0016',
#   'description': 'Fe(II):oxygen oxidoreductase',
#   'substrates': {'compound_2020',
#    'compound_400782',
#    'compound_404077',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2021',
#    'compound_2022',
#    'compound_2300',
#    'compound_5003'}},
#  'reaction_61': {'kegg_id': 'R00080',
#   'description': 'Catechol:oxygen oxidoreductase (dimerizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5051'},
#   'products': {'compound_2300', 'compound_5003', 'compound_8346'}},
#  'reaction_62': {'kegg_id': 'R00081',
#   'description': 'ferrocytochrome-c:oxygen oxidoreductase',
#   'substrates': {'compound_2028',
#    'compound_400782',
#    'compound_404077',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2023', 'compound_2300', 'compound_5003'}},
#  'reaction_63': {'kegg_id': 'R00082',
#   'description': 'ferrocytochrome c2:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6199'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6197'}},
#  'reaction_64': {'kegg_id': 'R00083',
#   'description': 'Benzenediol:oxygen oxidoreductase',
#   'substrates': {'compound_1070',
#    'compound_4182',
#    'compound_5005',
#    'compound_6755'},
#   'products': {'compound_2300', 'compound_5003', 'compound_9324'}},
#  'reaction_65': {'kegg_id': 'R00084',
#   'vmh_id': 'HMBS',
#   'description': 'porphobilinogen:(4-[2-carboxyethyl]-3-[carboxymethyl]pyrrol-2-yl)methyltransferase (hydrolysing)',
#   'substrates': {'compound_2300', 'compound_4420', 'compound_5003'},
#   'products': {'compound_2571', 'compound_4158'}},
#  'reaction_66': {'kegg_id': 'R00085',
#   'vmh_id': 'ATPH1e',
#   'description': 'ATP diphosphohydrolase (phosphate-forming)',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'}},
#  'reaction_67': {'kegg_id': 'R00086',
#   'description': 'ATP phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'}},
#  'reaction_68': {'kegg_id': 'R00087',
#   'description': 'ATP diphosphohydrolase (diphosphate-forming)',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_4425',
#    'compound_4426',
#    'compound_5010',
#    'compound_832',
#    'compound_833'}},
#  'reaction_69': {'kegg_id': 'R00088',
#   'description': 'ATP aminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_2724', 'compound_4158'}},
#  'reaction_70': {'kegg_id': 'R00089',
#   'vmh_id': 'ADNCYC',
#   'description': "ATP diphosphate-lyase (cyclizing; 3',5'-cyclic-AMP-forming)",
#   'substrates': {'compound_2460', 'compound_925'},
#   'products': {'compound_401336', 'compound_4425', 'compound_4426'}},
#  'reaction_71': {'kegg_id': 'R00090',
#   'description': 'NADH:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_403943',
#    'compound_404077'},
#   'products': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'}},
#  'reaction_72': {'kegg_id': 'R00091',
#   'description': 'CoA:NAD+ oxidoreductase',
#   'substrates': {'compound_1656',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6940'}},
#  'reaction_73': {'kegg_id': 'R00092',
#   'description': 'Fe2+:NAD+ oxidoreductase',
#   'substrates': {'compound_2020',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2021',
#    'compound_2022',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077'}},
#  'reaction_74': {'kegg_id': 'R00093',
#   'description': 'L-glutamate:NAD+ oxidoreductase (transaminating)',
#   'substrates': {'compound_2196',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2180',
#    'compound_2181',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_403968',
#    'compound_404077',
#    'compound_5014'}},
#  'reaction_75': {'kegg_id': 'R00094',
#   'description': 'glutathione:NAD+ oxidoreductase',
#   'substrates': {'compound_2284',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2282',
#    'compound_2283',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077'}},
#  'reaction_76': {'kegg_id': 'R00095',
#   'description': 'NADH:monodehydroascorbate oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5041',
#    'compound_5042',
#    'compound_900'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6234',
#    'compound_901',
#    'compound_966'}},
#  'reaction_77': {'kegg_id': 'R00100',
#   'description': 'NADH:ferricytochrome-b5 oxidoreductase',
#   'substrates': {'compound_2323', 'compound_2461', 'compound_402126'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_404619',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'}},
#  'reaction_78': {'kegg_id': 'R00101',
#   'description': 'NADH:ferrileghemoglobin oxidoreductase',
#   'substrates': {'compound_2461', 'compound_402126', 'compound_7467'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_7469'}},
#  'reaction_79': {'kegg_id': 'R00103',
#   'description': 'NAD+ phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_4165',
#    'compound_4166',
#    'compound_5010',
#    'compound_832',
#    'compound_833'}},
#  'reaction_80': {'kegg_id': 'R00104',
#   'vmh_id': 'NADK',
#   'description': "ATP:NAD+ 2'-phosphotransferase",
#   'substrates': {'compound_2460',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_925'},
#   'products': {'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_744'}},
#  'reaction_81': {'kegg_id': 'R00105',
#   'description': "ATP:NADH 2'-phosphotransferase",
#   'substrates': {'compound_2460',
#    'compound_2461',
#    'compound_402126',
#    'compound_925'},
#   'products': {'compound_4144', 'compound_744'}},
#  'reaction_82': {'kegg_id': 'R00106',
#   'vmh_id': 'HMR_9501',
#   'description': 'NADPH:ferricytochrome oxidoreductase',
#   'substrates': {'compound_2028',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144',
#    'compound_6149'},
#   'products': {'compound_2023',
#    'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144',
#    'compound_6150'}},
#  'reaction_83': {'kegg_id': 'R00108',
#   'description': 'NADPH:ferricytochrome-c2 oxidoreductase',
#   'substrates': {'compound_4144', 'compound_6197'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_6199'}},
#  'reaction_84': {'kegg_id': 'R00109',
#   'description': 'NADPH:ferrileghemoglobin oxidoreductase',
#   'substrates': {'compound_4144', 'compound_7467'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_7469'}},
#  'reaction_85': {'kegg_id': 'R00111',
#   'description': 'N-(omega)-Hydroxyarginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_4179',
#    'compound_4180',
#    'compound_4181',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_1624',
#    'compound_2300',
#    'compound_3017',
#    'compound_4142',
#    'compound_4143',
#    'compound_4168',
#    'compound_5003'}},
#  'reaction_86': {'kegg_id': 'R00112',
#   'description': 'NADPH:NAD+ oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_4144',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_402126',
#    'compound_4142',
#    'compound_4143'}},
#  'reaction_87': {'kegg_id': 'R00113',
#   'description': 'NADPH:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_400782',
#    'compound_403943',
#    'compound_404077',
#    'compound_4144'},
#   'products': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003'}},
#  'reaction_88': {'kegg_id': 'R00114',
#   'description': 'L-glutamate:NADP+ oxidoreductase (transaminating)',
#   'substrates': {'compound_2196', 'compound_4142', 'compound_4143'},
#   'products': {'compound_2180',
#    'compound_2181',
#    'compound_400782',
#    'compound_403968',
#    'compound_404077',
#    'compound_4144',
#    'compound_5014'}},
#  'reaction_89': {'kegg_id': 'R00115',
#   'vmh_id': 'GTHOm',
#   'description': 'glutathione:NADP+ oxidoreductase',
#   'substrates': {'compound_2282',
#    'compound_2283',
#    'compound_2284',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144'},
#   'products': {'compound_2282',
#    'compound_2283',
#    'compound_2284',
#    'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144'}},
#  'reaction_90': {'kegg_id': 'R00118',
#   'vmh_id': 'HMR_4270',
#   'description': "NADP+ 2'-phosphohydrolase",
#   'substrates': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003'},
#   'products': {'compound_4140',
#    'compound_4141',
#    'compound_4400',
#    'compound_4401',
#    'compound_5004',
#    'compound_5006'}},
#  'reaction_91': {'kegg_id': 'R00119',
#   'description': 'NADP+:nicotinate ADP-ribosyltransferase',
#   'substrates': {'compound_4138',
#    'compound_4142',
#    'compound_4143',
#    'compound_5301'},
#   'products': {'compound_16161', 'compound_402462'}},
#  'reaction_92': {'kegg_id': 'R00120',
#   'description': 'glutathione:oxygen oxidoreductase',
#   'substrates': {'compound_2284', 'compound_4182', 'compound_5005'},
#   'products': {'compound_2282', 'compound_2283', 'compound_403943'}},
#  'reaction_93': {'kegg_id': 'R00122',
#   'vmh_id': 'ATPH2e',
#   'description': 'ADP phosphohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_744'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'}},
#  'reaction_94': {'kegg_id': 'R00123',
#   'description': 'ADP aminohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_744'},
#   'products': {'compound_403996', 'compound_4158'}},
#  'reaction_95': {'kegg_id': 'R00125',
#   'description': "P1,P4-bis(5'-adenosyl)-tetraphosphate nucleotidebisphosphohydrolase",
#   'substrates': {'compound_2300', 'compound_5003', 'compound_845'},
#   'products': {'compound_744'}},
#  'reaction_96': {'kegg_id': 'R00126',
#   'description': 'ADP:ATP adenylyltransferase',
#   'substrates': {'compound_2460', 'compound_744', 'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_845'}},
#  'reaction_97': {'kegg_id': 'R00128',
#   'description': 'Adenosine-tetraphosphate phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_8082',
#    'compound_8083'},
#   'products': {'compound_2460',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_925'}},
#  'reaction_98': {'kegg_id': 'R00129',
#   'description': '(6S)-6beta-hydroxy-1,4,5,6-tetrahydronicotinamide-adenine dinucleotide hydro-lyase (ATP-hydrolysing, NADH-forming)',
#   'substrates': {'compound_2460',
#    'compound_402134',
#    'compound_9114',
#    'compound_925'},
#   'products': {'compound_2461',
#    'compound_402126',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'}},
#  'reaction_99': {'kegg_id': 'R00130',
#   'vmh_id': 'DPCOAK',
#   'description': "ATP:dephospho-CoA 3'-phosphotransferase",
#   'substrates': {'compound_1933', 'compound_2460', 'compound_925'},
#   'products': {'compound_1656', 'compound_404077', 'compound_744'}},
#  'reaction_100': {'kegg_id': 'R00131',
#   'description': 'Urea amidohydrolase',
#   'substrates': {'compound_2300', 'compound_4924', 'compound_5003'},
#   'products': {'compound_1654', 'compound_4158'}},
#  'reaction_101': {'kegg_id': 'R00132',
#   'description': 'carbonate hydro-lyase (carbon-dioxide-forming)',
#   'substrates': {'compound_2299', 'compound_2512'},
#   'products': {'compound_1654', 'compound_2300', 'compound_5003'}},
#  'reaction_102': {'kegg_id': 'R00134',
#   'description': 'formate:NADP+ oxidoreductase',
#   'substrates': {'compound_2030',
#    'compound_4142',
#    'compound_4143',
#    'compound_5035'},
#   'products': {'compound_1654',
#    'compound_400782',
#    'compound_404077',
#    'compound_4144'}},
#  'reaction_103': {'kegg_id': 'R00138',
#   'vmh_id': 'PPA2',
#   'description': 'Triphosphate phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4432',
#    'compound_4433',
#    'compound_5003',
#    'compound_5652'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5006'}},
#  'reaction_104': {'kegg_id': 'R00139',
#   'description': "ATP:2'-deoxy-5-hydroxymethylcytidine-5'-diphosphate phosphotransferase",
#   'substrates': {'compound_14561', 'compound_2460', 'compound_925'},
#   'products': {'compound_14562', 'compound_744'}},
#  'reaction_105': {'kegg_id': 'R00140',
#   'description': 'ATP:5-hydroxymethyldeoxycytidylate phosphotransferase',
#   'substrates': {'compound_14561', 'compound_744'},
#   'products': {'compound_2460', 'compound_8450', 'compound_925'}},
#  'reaction_106': {'kegg_id': 'R00141',
#   'description': 'ATP:ammonia phosphotransferase',
#   'substrates': {'compound_2460', 'compound_4158', 'compound_925'},
#   'products': {'compound_7185', 'compound_7186', 'compound_744'}},
#  'reaction_107': {'kegg_id': 'R00143',
#   'description': 'ammonia:NAD+ oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_4158',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_5260'}},
#  'reaction_108': {'kegg_id': 'R00145',
#   'description': 'alpha-amino acid:NAD+ oxidoreductase (deaminating)',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004',
#    'compound_9254'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_4158',
#    'compound_5222'}},
#  'reaction_109': {'kegg_id': 'R00146',
#   'description': 'alpha-amino acid:NADP+ oxidoreductase (deaminating)',
#   'substrates': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003',
#    'compound_9254'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_4158',
#    'compound_5222'}},
#  'reaction_110': {'kegg_id': 'R00148',
#   'description': 'ammonia,ubiquinol:oxygen oxidoreductase',
#   'substrates': {'compound_4158',
#    'compound_4182',
#    'compound_4531',
#    'compound_5005',
#    'compound_5437'},
#   'products': {'compound_2300',
#    'compound_400174',
#    'compound_404214',
#    'compound_4530',
#    'compound_5003',
#    'compound_5260'}},
#  'reaction_111': {'kegg_id': 'R00149',
#   'description': 'Carbon-dioxide:ammonia ligase (ADP-forming,carbamate-phosphorylating)',
#   'substrates': {'compound_1654',
#    'compound_2300',
#    'compound_2460',
#    'compound_4158',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_403038',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'}},
#  'reaction_112': {'kegg_id': 'R00150',
#   'description': 'ATP:carbamate phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_2511',
#    'compound_4158',
#    'compound_925'},
#   'products': {'compound_2300',
#    'compound_403038',
#    'compound_5003',
#    'compound_744'}},
#  'reaction_113': {'kegg_id': 'R00152',
#   'description': 'hydrogen cyanide aminohydrolase',
#   'substrates': {'compound_1772', 'compound_2300', 'compound_5003'},
#   'products': {'compound_2030', 'compound_4158', 'compound_5035'}},
#  'reaction_114': {'kegg_id': 'R00153',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_9361',
#    'compound_9364'},
#   'products': {'compound_4158'}},
#  'reaction_115': {'kegg_id': 'R00157',
#   'vmh_id': 'UTPATPT',
#   'description': 'Uridine triphosphate:AMP phosphotransferase',
#   'substrates': {'compound_4927',
#    'compound_4928',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_403617', 'compound_744'}},
#  'reaction_116': {'kegg_id': 'R00159',
#   'vmh_id': 'NDP8ex',
#   'description': 'UTP phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4927',
#    'compound_4928',
#    'compound_5003'},
#   'products': {'compound_403617',
#    'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006'}},
#  'reaction_117': {'kegg_id': 'R00161',
#   'vmh_id': 'FMNAT',
#   'description': 'ATP:FMN adenylyltransferase',
#   'substrates': {'compound_2024',
#    'compound_2025',
#    'compound_2460',
#    'compound_404077',
#    'compound_925'},
#   'products': {'compound_2011', 'compound_4425', 'compound_4426'}},
#  'reaction_118': {'kegg_id': 'R00162',
#   'vmh_id': 'HMR_9577',
#   'description': 'ATP:protein phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_3016',
#    'compound_5008',
#    'compound_925'},
#   'products': {'compound_404593', 'compound_744'}},
#  'reaction_119': {'kegg_id': 'R00164',
#   'vmh_id': 'HMR_9578',
#   'description': 'Phosphoprotein phosphohydrolase',
#   'substrates': {'compound_2300', 'compound_404593', 'compound_5003'},
#   'products': {'compound_3016',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5008'}},
#  'reaction_120': {'kegg_id': 'R00173',
#   'vmh_id': 'PYDXPP',
#   'description': "pyridoxal-5'-phosphate phosphohydrolase",
#   'substrates': {'compound_2300', 'compound_4525', 'compound_5003'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_4524',
#    'compound_5006'}},
#  'reaction_121': {'kegg_id': 'R00174',
#   'vmh_id': 'PYDXK',
#   'description': "ATP:pyridoxal 5'-phosphotransferase",
#   'substrates': {'compound_2460', 'compound_4524', 'compound_925'},
#   'products': {'compound_404077', 'compound_4525', 'compound_744'}},
#  'reaction_122': {'kegg_id': 'R00177',
#   'vmh_id': 'METAT',
#   'description': 'ATP:L-methionine S-adenosyltransferase',
#   'substrates': {'compound_2300',
#    'compound_3690',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5006',
#    'compound_5009',
#    'compound_828',
#    'compound_829',
#    'compound_925'},
#   'products': {'compound_2300',
#    'compound_2460',
#    'compound_3690',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5003',
#    'compound_828',
#    'compound_829',
#    'compound_925'}},
#  'reaction_123': {'kegg_id': 'R00178',
#   'vmh_id': 'ADMDC',
#   'description': 'S-adenosyl-L-methionine carboxy-lyase [S-adenosyl 3-(methylsulfanyl)propylamine-forming]',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_5009',
#    'compound_828',
#    'compound_829'},
#   'products': {'compound_1654', 'compound_2465', 'compound_830'}},
#  'reaction_124': {'kegg_id': 'R00179',
#   'description': 'S-adenosyl-L-methionine methylthioadenosine-lyase (1-aminocyclopropane-1-carboxylate-forming)',
#   'substrates': {'compound_5009', 'compound_828', 'compound_829'},
#   'products': {'compound_401540',
#    'compound_402461',
#    'compound_6370',
#    'compound_6371',
#    'compound_6372'}},
#  'reaction_125': {'kegg_id': 'R00181',
#   'vmh_id': 'AMPDA',
#   'description': 'AMP aminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_404077',
#    'compound_5003',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_2702', 'compound_4158'}},
#  'reaction_126': {'kegg_id': 'R00182',
#   'vmh_id': 'AMPN',
#   'description': 'AMP phosphoribohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_4546',
#    'compound_4547',
#    'compound_5064',
#    'compound_737'}},
#  'reaction_127': {'kegg_id': 'R00184',
#   'description': "P1,P4-bis(5'-adenosyl)-tetraphosphate adenylohydrolase",
#   'substrates': {'compound_2300', 'compound_5003', 'compound_845'},
#   'products': {'compound_2460',
#    'compound_5010',
#    'compound_832',
#    'compound_833',
#    'compound_925'}},
#  'reaction_128': {'kegg_id': 'R00187',
#   'vmh_id': 'HMR_9497',
#   'description': "P1,P3-bis(5'-adenosyl)-triphosphate adenylohydrolase",
#   'substrates': {'compound_2300', 'compound_3265', 'compound_5003'},
#   'products': {'compound_404077',
#    'compound_5010',
#    'compound_744',
#    'compound_832',
#    'compound_833'}},
#  'reaction_129': {'kegg_id': 'R00188',
#   'vmh_id': 'BPNT',
#   'description': "adenosine-3',5'-bisphosphate 3'-phosphohydrolase",
#   'substrates': {'compound_2300',
#    'compound_4253',
#    'compound_5003',
#    'compound_5033'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'}},
#  'reaction_130': {'kegg_id': 'R00192',
#   'description': 'S-Adenosyl-L-homocysteine hydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_5011',
#    'compound_767',
#    'compound_768'},
#   'products': {'compound_2514', 'compound_2515', 'compound_740'}},
#  'reaction_131': {'kegg_id': 'R00193',
#   'description': 'S-Adenosyl-L-homocysteine aminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_5011',
#    'compound_767',
#    'compound_768'},
#   'products': {'compound_4158', 'compound_8054'}},
#  'reaction_132': {'kegg_id': 'R00195',
#   'description': '2,3-diaminopropanoate ammonia-lyase (adding water; pyruvate-forming)',
#   'substrates': {'compound_10128', 'compound_2300', 'compound_5003'},
#   'products': {'compound_4158', 'compound_4529', 'compound_5012'}},
#  'reaction_133': {'kegg_id': 'R00196',
#   'description': '(S)-Lactate:ferricytochrome-c 2-oxidoreductase',
#   'substrates': {'compound_2023', 'compound_2864', 'compound_5257'},
#   'products': {'compound_2028',
#    'compound_400782',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_134': {'kegg_id': 'R00197',
#   'vmh_id': 'HMR_3859',
#   'description': '(R)-Lactate:ferricytochrome-c 2-oxidoreductase',
#   'substrates': {'compound_2023', 'compound_2863', 'compound_5303'},
#   'products': {'compound_2028',
#    'compound_400782',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_135': {'kegg_id': 'R00198',
#   'description': '(R)-Lactate:ferricytochrome-c-553 2-oxidoreductase',
#   'substrates': {'compound_2863', 'compound_5303', 'compound_6258'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012',
#    'compound_6259'}},
#  'reaction_136': {'kegg_id': 'R00199',
#   'description': 'ATP:pyruvate,water phosphotransferase',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_4529',
#    'compound_5003',
#    'compound_5012',
#    'compound_925'},
#   'products': {'compound_4328',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_5043',
#    'compound_832',
#    'compound_833'}},
#  'reaction_137': {'kegg_id': 'R00200',
#   'vmh_id': 'PYK',
#   'description': 'ATP:pyruvate 2-O-phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_404077',
#    'compound_4328',
#    'compound_4529',
#    'compound_5012',
#    'compound_744',
#    'compound_925'},
#   'products': {'compound_4328',
#    'compound_4529',
#    'compound_5043',
#    'compound_744',
#    'compound_925'}},
#  'reaction_138': {'kegg_id': 'R00203',
#   'description': 'pyruvaldehyde:NAD+ oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_401513',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_139': {'kegg_id': 'R00205',
#   'description': '2-Oxopropanal:NADP+ oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_401513',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_140': {'kegg_id': 'R00206',
#   'description': 'ATP:pyruvate,phosphate phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_4400',
#    'compound_4401',
#    'compound_4529',
#    'compound_5006',
#    'compound_5012',
#    'compound_925'},
#   'products': {'compound_4328',
#    'compound_4425',
#    'compound_4426',
#    'compound_5010',
#    'compound_5043',
#    'compound_832',
#    'compound_833'}},
#  'reaction_141': {'kegg_id': 'R00207',
#   'description': 'Pyruvate:oxygen 2-oxidoreductase (phosphorylating)',
#   'substrates': {'compound_4182',
#    'compound_4400',
#    'compound_4401',
#    'compound_4529',
#    'compound_5005',
#    'compound_5006',
#    'compound_5012'},
#   'products': {'compound_1654', 'compound_403943', 'compound_733'}},
#  'reaction_142': {'kegg_id': 'R00208',
#   'description': 'Phosphoenolpyruvate phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4328',
#    'compound_5003',
#    'compound_5043'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_4529',
#    'compound_5006',
#    'compound_5012'}},
#  'reaction_143': {'kegg_id': 'R00209',
#   'vmh_id': 'PDHm',
#   'description': 'pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating)',
#   'substrates': {'compound_1656',
#    'compound_4140',
#    'compound_4141',
#    'compound_4529',
#    'compound_5004',
#    'compound_5012'},
#   'products': {'compound_1654',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_670'}},
#  'reaction_144': {'kegg_id': 'R00210',
#   'description': 'pyruvate:NADP+ 2-oxidoreductase (CoA-acetylating)',
#   'substrates': {'compound_1656',
#    'compound_4142',
#    'compound_4143',
#    'compound_4529',
#    'compound_5012'},
#   'products': {'compound_1654',
#    'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_670'}},
#  'reaction_145': {'kegg_id': 'R00211',
#   'description': 'pyruvate:oxygen 2-oxidoreductase (CoA-acetylating)',
#   'substrates': {'compound_1656',
#    'compound_4182',
#    'compound_4529',
#    'compound_5005',
#    'compound_5012'},
#   'products': {'compound_1654', 'compound_403943', 'compound_670'}},
#  'reaction_146': {'kegg_id': 'R00212',
#   'vmh_id': 'PFL',
#   'description': 'Acetyl-CoA:formate C-acetyltransferase',
#   'substrates': {'compound_1656',
#    'compound_2030',
#    'compound_4529',
#    'compound_5035',
#    'compound_670'},
#   'products': {'compound_1656',
#    'compound_2030',
#    'compound_4529',
#    'compound_5012',
#    'compound_670'}},
#  'reaction_147': {'kegg_id': 'R00213',
#   'description': 'O-carbamoyl-L-serine ammonia-lyase (decarboxylating; pyruvate-forming)',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_7730'},
#   'products': {'compound_1654',
#    'compound_4158',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_148': {'kegg_id': 'R00214',
#   'vmh_id': 'ME1m',
#   'description': '(S)-malate:NAD+ oxidoreductase (decarboxylating)',
#   'substrates': {'compound_3647',
#    'compound_3648',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5076'},
#   'products': {'compound_1654',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_149': {'kegg_id': 'R00215',
#   'description': '(R)-Malate:NAD+ oxidoreductase (decarboxylating)',
#   'substrates': {'compound_3646',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5626'},
#   'products': {'compound_1654',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_4529',
#    'compound_5012'}},
#  'reaction_150': {'kegg_id': 'R00217',
#   'description': 'oxaloacetate carboxy-lyase (pyruvate-forming)',
#   'substrates': {'compound_4184', 'compound_5023', 'compound_5024'},
#   'products': {'compound_1654', 'compound_4529', 'compound_5012'}},
#  'reaction_151': {'kegg_id': 'R00218',
#   'description': 'acetylenedicarboxylate carboxy-lyase (pyruvate-forming)',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_7935',
#    'compound_7936'},
#   'products': {'compound_1654', 'compound_4529', 'compound_5012'}},
#  'reaction_152': {'kegg_id': 'R00219',
#   'vmh_id': 'OAADC',
#   'description': '2-Hydroxyethylenedicarboxylate carboxy-lyase (pyruvate-forming)',
#   'substrates': {'compound_1654',
#    'compound_404077',
#    'compound_4184',
#    'compound_4529',
#    'compound_5012'},
#   'products': {'compound_1654', 'compound_4529', 'compound_8435'}},
#  'reaction_153': {'kegg_id': 'R00220',
#   'description': 'L-serine ammonia-lyase',
#   'substrates': {'compound_4626'},
#   'products': {'compound_4158', 'compound_4529', 'compound_5012'}},
#  'reaction_154': {'kegg_id': 'R00221',
#   'description': 'D-serine ammonia-lyase',
#   'substrates': {'compound_4624'},
#   'products': {'compound_4158', 'compound_4529', 'compound_5012'}},
#  'reaction_155': {'kegg_id': 'R00223',
#   'description': 'serine ammonia-lyase (pyruvate-forming)',
#   'substrates': {'compound_5973'},
#   'products': {'compound_4158', 'compound_4529', 'compound_5012'}},
#  'reaction_156': {'kegg_id': 'R00224',
#   'description': 'pyruvate carboxy-lyase (acetaldehyde-forming)',
#   'substrates': {'compound_4529', 'compound_5012'},
#   'products': {'compound_1654', 'compound_667'}},
#  'reaction_157': {'kegg_id': 'R00226',
#   'description': 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)',
#   'substrates': {'compound_1654', 'compound_796'},
#   'products': {'compound_4529', 'compound_5012'}},
#  'reaction_158': {'kegg_id': 'R00227',
#   'description': 'Acetyl-CoA hydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_670'},
#   'products': {'compound_1656', 'compound_404257', 'compound_5021'}},
#  'reaction_159': {'kegg_id': 'R00228',
#   'description': 'acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)',
#   'substrates': {'compound_1656',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_667'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_670'}},
#  'reaction_160': {'kegg_id': 'R00229',
#   'description': 'acetate:CoA ligase (ADP-forming)',
#   'substrates': {'compound_1656',
#    'compound_2460',
#    'compound_404257',
#    'compound_5021',
#    'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_670',
#    'compound_744'}},
#  'reaction_161': {'kegg_id': 'R00230',
#   'vmh_id': 'PTAr',
#   'description': 'acetyl-CoA:phosphate acetyltransferase',
#   'substrates': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_670'},
#   'products': {'compound_1656', 'compound_733'}},
#  'reaction_162': {'kegg_id': 'R00236',
#   'vmh_id': 'r0068',
#   'description': 'acetyl adenylate:CoA acetyltransferase',
#   'substrates': {'compound_1656', 'compound_2391'},
#   'products': {'compound_404077',
#    'compound_5010',
#    'compound_670',
#    'compound_832',
#    'compound_833'}},
#  'reaction_163': {'kegg_id': 'R00237',
#   'description': '(3S)-citramalyl-CoA pyruvate-lyase (acetyl-CoA-forming)',
#   'substrates': {'compound_1623', 'compound_6212'},
#   'products': {'compound_4529', 'compound_5012', 'compound_670'}},
#  'reaction_164': {'kegg_id': 'R00239',
#   'vmh_id': 'GLU5Km',
#   'description': 'ATP:L-glutamate 5-phosphotransferase',
#   'substrates': {'compound_2196', 'compound_2460', 'compound_925'},
#   'products': {'compound_2193', 'compound_744'}},
#  'reaction_165': {'kegg_id': 'R00243',
#   'description': 'L-glutamate:NAD+ oxidoreductase (deaminating)',
#   'substrates': {'compound_2196',
#    'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_403968',
#    'compound_404077',
#    'compound_4158',
#    'compound_5014'}},
#  'reaction_166': {'kegg_id': 'R00245',
#   'vmh_id': 'r0074',
#   'description': 'L-glutamate gamma-semialdehyde:NAD+ oxidoreductase',
#   'substrates': {'compound_2194',
#    'compound_2300',
#    'compound_4140',
# ...
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'},
#   'products': {'compound_401064',
#    'compound_401262',
#    'compound_401619',
#    'compound_401775',
#    'compound_402464',
#    'compound_402833',
#    'compound_404250',
#    'compound_4263',
#    'compound_4264',
#    'compound_4271',
#    'compound_4272',
#    'compound_4281',
#    'compound_5283',
#    'compound_8624',
#    'compound_8625',
#    'compound_8626',
#    'compound_8627',
#    'compound_8628',
#    'compound_8629',
#    'compound_8630',
#    'compound_8631',
#    'compound_8632',
#    'compound_8633',
#    'compound_8634',
#    'compound_8635',
#    'compound_8636',
#    'compound_8637',
#    'compound_8638',
#    'compound_8639',
#    'compound_8640',
#    'compound_871'}},
#  'reaction_993': {'kegg_id': 'R01318',
#   'vmh_id': 'HMR_0632',
#   'description': 'Acyl-CoA:1-acyl-sn-glycero-3-phosphocholine O-acyltransferase',
#   'substrates': {'compound_2419',
#    'compound_2933',
#    'compound_401064',
#    'compound_401262',
#    'compound_401619',
#    'compound_401775',
#    'compound_402464',
#    'compound_402833',
#    'compound_404250',
#    'compound_4263',
#    'compound_4264',
#    'compound_4271',
#    'compound_4272',
#    'compound_4281',
#    'compound_5027',
#    'compound_8624',
#    'compound_8625',
#    'compound_8626',
#    'compound_8627',
#    'compound_8628',
#    'compound_8629',
#    'compound_8630',
#    'compound_8631',
#    'compound_8632',
#    'compound_8633',
#    'compound_8634',
#    'compound_8635',
#    'compound_8636',
#    'compound_8637',
#    'compound_8638',
#    'compound_8639',
#    'compound_8640'},
#   'products': {'compound_1656',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'}},
#  'reaction_994': {'kegg_id': 'R01319',
#   'description': 'Acyl-CoA:2-acyl-sn-glycero-3-phosphocholine O-acyltransferase',
#   'substrates': {'compound_404721', 'compound_5027', 'compound_8642'},
#   'products': {'compound_1656',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'}},
#  'reaction_995': {'kegg_id': 'R01320',
#   'vmh_id': 'HMR_0657',
#   'description': 'S-adenosyl-L-methionine:phosphatidyl-N-dimethylethanolamine N-methyltransferase',
#   'substrates': {'compound_3496',
#    'compound_5009',
#    'compound_828',
#    'compound_829',
#    'compound_8700',
#    'compound_997'},
#   'products': {'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5011',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219',
#    'compound_767',
#    'compound_768'}},
#  'reaction_996': {'kegg_id': 'R01321',
#   'description': 'CDP-choline:1,2-diacyl-sn-glycerol cholinephosphotransferase',
#   'substrates': {'compound_1085',
#    'compound_1086',
#    'compound_2429',
#    'compound_2430',
#    'compound_2431',
#    'compound_2432',
#    'compound_3035',
#    'compound_3036',
#    'compound_404609',
#    'compound_404702'},
#   'products': {'compound_1636',
#    'compound_1637',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5034',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'}},
#  'reaction_997': {'kegg_id': 'R01322',
#   'description': 'Citrate:CoA ligase (ADP-forming)',
#   'substrates': {'compound_1656',
#    'compound_2460',
#    'compound_401317',
#    'compound_5220',
#    'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5691',
#    'compound_744'}},
#  'reaction_998': {'kegg_id': 'R01323',
#   'description': 'Acetyl-CoA:citrate CoA-transferase',
#   'substrates': {'compound_401317', 'compound_5220', 'compound_670'},
#   'products': {'compound_404257', 'compound_5021', 'compound_5691'}},
#  'reaction_999': {'kegg_id': 'R01325',
#   'description': 'citrate hydro-lyase (cis-aconitate-forming)',
#   'substrates': {'compound_401317', 'compound_5220'},
#   'products': {'compound_2300',
#    'compound_2317',
#    'compound_2318',
#    'compound_404601',
#    'compound_5003',
#    'compound_5463'}},
#  ...}

# %% [markdown]
# ### Add Genes & Proteins

# %%
genes = pd.read_csv(os.path.join(processed_data_folder, "genes_kegg_vmh.csv"), dtype={'gene_number': 'string'})
vmh_genes = pd.read_csv(os.path.join(vmh_folder, 'vmh_gene_reactions.csv'))
kegg_genes = pd.read_csv(os.path.join(processed_data_folder, "kegg_enzyme_gene_symbols.csv"))
kegg_enzymes = pd.read_csv(os.path.join(kegg_folder, "kegg_reaction_enzymes.csv"))

# %%
genes
# Out:
#       symbol gene_number chromosome  \
# 0      36951     55016.1          4
# 1      37316     51257.1         19
# 2      37681    115123.1          5
# 3      38047     57574.1          2
# 4      38412     54708.1         10
# ...      ...         ...        ...
# 5107   ZNRF3        <NA>        NaN
# 5108   ZNRF4        <NA>        NaN
# 5109  ZRANB1        <NA>        NaN
# 5110  ZSWIM2    151112.1          2
# 5111    ZUP1        <NA>        NaN
#
#                                             description     ensembl_gene  \
# 0     membrane associated ring-CH-type finger 1 [Sou...  ENSG00000145416
# 1     membrane associated ring-CH-type finger 2 [Sou...  ENSG00000099785
# 2     membrane associated ring-CH-type finger 3 [Sou...  ENSG00000173926
# 3     membrane associated ring-CH-type finger 4 [Sou...  ENSG00000144583
# 4     membrane associated ring-CH-type finger 5 [Sou...  ENSG00000198060
# ...                                                 ...              ...
# 5107                                                NaN              NaN
# 5108                                                NaN              NaN
# 5109                                                NaN              NaN
# 5110  zinc finger, SWIM-type containing 2 [Source:HG...  ENSG00000163012
# 5111                                                NaN              NaN
#
#      chebl_id uniprot_gname kegg_gene_id
# 0         NaN        Q8TCQ1          NaN
# 1         NaN        Q9P0N8          NaN
# 2         NaN        Q86UD3          NaN
# 3         NaN        Q9P2E8          NaN
# 4         NaN        Q9NX47          NaN
# ...       ...           ...          ...
# 5107      NaN           NaN    hsa:84133
# 5108      NaN           NaN   hsa:148066
# 5109      NaN           NaN    hsa:54764
# 5110      NaN        Q8NEG5   hsa:151112
# 5111      NaN           NaN   hsa:221302
#
# [5112 rows x 8 columns]

# %%
kegg_enzymes.loc[:, 'enzyme_id'] = kegg_enzymes.enzyme_id.apply(lambda x: f'EC {x}')

# %%
kegg_genes_to_reactions = kegg_genes.merge(kegg_enzymes, left_on='kegg_enzyme_id', right_on='enzyme_id', how='inner')

# %%
kegg_genes_to_reactions.loc[:, 'menuguide_id'] = kegg_genes_to_reactions.reaction_id.apply(lambda x: reactions_kegg[x])
kegg_genes_to_reactions
# Out:
#         symbol kegg_enzyme_id    enzyme_id reaction_id   menuguide_id
# 0         AOC3    EC 1.4.3.21  EC 1.4.3.21      R01853  reaction_1391
# 1         AOC3    EC 1.4.3.21  EC 1.4.3.21      R02382  reaction_1785
# 2         AOC3    EC 1.4.3.21  EC 1.4.3.21      R02529  reaction_1901
# 3         AOC3    EC 1.4.3.21  EC 1.4.3.21      R02613  reaction_1974
# 4         AOC3    EC 1.4.3.21  EC 1.4.3.21      R03139  reaction_2386
# ...        ...            ...          ...         ...            ...
# 8826      COX1     EC 7.1.1.9   EC 7.1.1.9      R00081    reaction_62
# 8827      COX1     EC 7.1.1.9   EC 7.1.1.9      R00082    reaction_63
# 8828  CYB561D2     EC 7.2.1.3   EC 7.2.1.3      R09739  reaction_6487
# 8829    CYB561     EC 7.2.1.3   EC 7.2.1.3      R09739  reaction_6487
# 8830  CYB561A3     EC 7.2.1.3   EC 7.2.1.3      R09739  reaction_6487
#
# [8831 rows x 5 columns]

# %%
vmh_genes_symbols = genes[genes.gene_number.notna()]

# %%
vmh_genes = vmh_genes.merge(vmh_genes_symbols, on='gene_number', how='inner')[['reaction_abbreviation', 'symbol']]

# %%
vmh_genes.loc[:, 'menuguide_id'] = vmh_genes.reaction_abbreviation.apply(lambda x: reactions_vmh[x])
vmh_genes
# Out:
#       reaction_abbreviation  symbol    menuguide_id
# 0                 13DAMPPOX    AOC3   reaction_2386
# 1                 42A12BOOX    AOC3   reaction_3270
# 2                  NMPTRCOX    AOC3  reaction_11118
# 3                 13DAMPPOX    AOC1   reaction_2386
# 4                 42A12BOOX    AOC1   reaction_3270
# ...                     ...     ...             ...
# 21916                MTHFD2  MTHFD2  reaction_18381
# 21917                MTHFD2  MTHFD2  reaction_18381
# 21918                   AHC    AHCY  reaction_18383
# 21919                   AHC  AHCYL1  reaction_18383
# 21920                   AHC  AHCYL1  reaction_18383
#
# [21921 rows x 3 columns]

# %%
enzymes_to_add = kegg_genes_to_reactions[['enzyme_id', 'menuguide_id']]

# %%
genes_to_add = pd.concat([kegg_genes_to_reactions[['menuguide_id', 'symbol']], vmh_genes[['menuguide_id', 'symbol']]])

# %%
genes_to_add = genes_to_add.drop_duplicates()

# %%
enzymes_to_add = enzymes_to_add.drop_duplicates()

# %%
enzymes_to_add
# Out:
#         enzyme_id   menuguide_id
# 0     EC 1.4.3.21  reaction_1391
# 1     EC 1.4.3.21  reaction_1785
# 2     EC 1.4.3.21  reaction_1901
# 3     EC 1.4.3.21  reaction_1974
# 4     EC 1.4.3.21  reaction_2386
# ...           ...            ...
# 8814   EC 6.5.1.7   reaction_266
# 8815   EC 6.5.1.7  reaction_7390
# 8816   EC 6.5.1.7  reaction_7391
# 8826   EC 7.1.1.9    reaction_62
# 8827   EC 7.1.1.9    reaction_63
#
# [2821 rows x 2 columns]

# %%
vmh_reaction_enzymes = vmh_reaction_enzymes[vmh_reaction_enzymes.ecnumber.notna()]
vmh_reaction_enzymes
# Out:
#          menuguide_id                 ecnumber
# 2          reaction_2                  3.6.1.1
# 3          reaction_3                  3.6.1.1
# 4          reaction_4                  3.6.1.1
# 5          reaction_5                  3.6.1.1
# 6          reaction_6                  3.6.1.1
# ...               ...                      ...
# 22134  reaction_22135               EC:3.4.-.-
# 22135  reaction_22136              EC:6.3.4.14
# 22136  reaction_22137              EC:2.6.1.82
# 22137  reaction_22138               EC:5.1.3.2
# 22139  reaction_22140  EC:1.1.1.79;EC:1.1.1.81
#
# [6465 rows x 2 columns]

# %%
vmh_reaction_enzymes[vmh_reaction_enzymes.ecnumber.str.contains('EC')]
# Out:
#          menuguide_id                 ecnumber
# 18        reaction_18               EC:1.2.4.1
# 59        reaction_59              EC:2.4.1.95
# 70        reaction_70             EC:2.7.11.19
# 71        reaction_71              EC:3.1.3.17
# 96        reaction_96               EC:1.6.2.4
# ...               ...                      ...
# 22134  reaction_22135               EC:3.4.-.-
# 22135  reaction_22136              EC:6.3.4.14
# 22136  reaction_22137              EC:2.6.1.82
# 22137  reaction_22138               EC:5.1.3.2
# 22139  reaction_22140  EC:1.1.1.79;EC:1.1.1.81
#
# [2135 rows x 2 columns]

# %%
vmh_enzymes_to_add = []

def extract_vmh_enzymes(row):
    reaction_id = row['menuguide_id']
    ecnumber = row['ecnumber']
    ecnumber = ecnumber.strip()
    
    if ',' in ecnumber:
        ecnumber_list = ecnumber.split(',')
        for number in ecnumber_list:
            if number:
                if 'EC:' in number:
                    vmh_enzymes_to_add.append([reaction_id, number])
                else:
                    number_temp = f"EC:{number.strip()}"
                    vmh_enzymes_to_add.append([reaction_id, number_temp])
                
    elif ';' in ecnumber:
        ecnumber_list = ecnumber.split(';')
        for number in ecnumber_list:
            if number:
                if 'EC:' in number:
                    vmh_enzymes_to_add.append([reaction_id, number])
                else:
                    number_temp = f"EC:{number.strip()}"
                    vmh_enzymes_to_add.append([reaction_id, number_temp])
                    
    elif ' ' in ecnumber:
        ecnumber_list = ecnumber.split(' ')
        for number in ecnumber_list:
            if number:
                if 'EC:' in number:
                    vmh_enzymes_to_add.append([reaction_id, number])
                else:
                    number_temp = f"EC:{number.strip()}"
                    vmh_enzymes_to_add.append([reaction_id, number_temp])
    
    elif 'EC:' in ecnumber:
        vmh_enzymes_to_add.append([reaction_id, ecnumber])
    else:
        number_temp = f"EC:{ecnumber.strip()}"
        vmh_enzymes_to_add.append([reaction_id, number_temp])

vmh_reaction_enzymes.apply(extract_vmh_enzymes, axis=1)
# Out:
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
#          ...
# 22134    None
# 22135    None
# 22136    None
# 22137    None
# 22139    None
# Length: 6465, dtype: object

# %%
pattern = re.compile(r"EC:[1-9]{1}.[1-9]{1}[0-9]{0,1}.[-1-9]{1}[0-9]{0,1}.[-1-9]{1}")

# %%
cleaned_vmh_enzymes = []

for idx, enzyme in enumerate(vmh_enzymes_to_add):
    match = pattern.match(enzyme[1])
    
    if match:
        cleaned_vmh_enzymes.append(enzyme)

# %%
enzymes_to_add = pd.concat([enzymes_to_add, pd.DataFrame(cleaned_vmh_enzymes, columns=['menuguide_id', 'enzyme_id'])], axis=0)

# %%
enzymes_to_add = enzymes_to_add.drop_duplicates()

# %%
enzymes_to_add
# Out:
#         enzyme_id    menuguide_id
# 0     EC 1.4.3.21   reaction_1391
# 1     EC 1.4.3.21   reaction_1785
# 2     EC 1.4.3.21   reaction_1901
# 3     EC 1.4.3.21   reaction_1974
# 4     EC 1.4.3.21   reaction_2386
# ...           ...             ...
# 7183  EC:6.3.4.14  reaction_22136
# 7184  EC:2.6.1.82  reaction_22137
# 7185   EC:5.1.3.2  reaction_22138
# 7186  EC:1.1.1.79  reaction_22140
# 7187  EC:1.1.1.81  reaction_22140
#
# [10009 rows x 2 columns]

# %%
def add_gene_to_dict(row):
    reaction_id = row['menuguide_id']
    gene_symbol = row['symbol']
    if reaction_id in reactions_dict:
        entry = reactions_dict[reaction_id]
        if 'genes' in entry:
            entry['genes'].add(gene_symbol)
        else:
            entry['genes'] = {gene_symbol}
            
def add_enzyme_to_dict(row):
    reaction_id = row['menuguide_id']
    enzyme = row['enzyme_id']
    enzyme = enzyme.replace('EC ', 'EC:')
    if reaction_id in reactions_dict:
        entry = reactions_dict[reaction_id]
        if 'enzymes' in entry:
            entry['enzymes'].add(enzyme)
        else:
            entry['enzymes'] = {enzyme}

# %%
genes_to_add = genes_to_add[~genes_to_add.symbol.str.isnumeric()]

# %%
enzymes_to_add
# Out:
#         enzyme_id    menuguide_id
# 0     EC 1.4.3.21   reaction_1391
# 1     EC 1.4.3.21   reaction_1785
# 2     EC 1.4.3.21   reaction_1901
# 3     EC 1.4.3.21   reaction_1974
# 4     EC 1.4.3.21   reaction_2386
# ...           ...             ...
# 7183  EC:6.3.4.14  reaction_22136
# 7184  EC:2.6.1.82  reaction_22137
# 7185   EC:5.1.3.2  reaction_22138
# 7186  EC:1.1.1.79  reaction_22140
# 7187  EC:1.1.1.81  reaction_22140
#
# [10009 rows x 2 columns]

# %%
genes_to_add.apply(add_gene_to_dict, axis=1)
enzymes_to_add.apply(add_enzyme_to_dict, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 7183    None
# 7184    None
# 7185    None
# 7186    None
# 7187    None
# Length: 10009, dtype: object

# %%
reactions_dict
# Out:
# {'reaction_0': {'kegg_id': 'R00001',
#   'description': 'polyphosphate polyphosphohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_5449'},
#   'products': {'compound_4433', 'compound_7069'}},
#  'reaction_1': {'kegg_id': 'R00002',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_2019',
#    'compound_2300',
#    'compound_2460',
#    'compound_3505',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_2018',
#    'compound_3473',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744',
#    'compound_9361'}},
#  'reaction_2': {'kegg_id': 'R00005',
#   'description': 'urea-1-carboxylate amidohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_6210',
#    'compound_6211',
#    'compound_808'},
#   'products': {'compound_1654', 'compound_4158'},
#   'enzymes': {'EC:3.6.1.1'}},
#  'reaction_3': {'kegg_id': 'R00006',
#   'description': 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)',
#   'substrates': {'compound_1654', 'compound_6130'},
#   'products': {'compound_4529', 'compound_5012'},
#   'enzymes': {'EC:3.6.1.1'}},
#  'reaction_4': {'kegg_id': 'R00008',
#   'description': '4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)',
#   'substrates': {'compound_9790', 'compound_9791'},
#   'products': {'compound_4529', 'compound_5012'},
#   'enzymes': {'EC:3.6.1.1'}},
#  'reaction_5': {'kegg_id': 'R00010',
#   'description': 'alpha,alpha-trehalose glucohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4833',
#    'compound_4834',
#    'compound_5003'},
#   'products': {'compound_2166', 'compound_5019'},
#   'genes': {'TREH'},
#   'enzymes': {'EC:3.2.1.28', 'EC:3.6.1.1'}},
#  'reaction_6': {'kegg_id': 'R00011',
#   'description': 'Mn(II):hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_21891',
#    'compound_400782',
#    'compound_403943',
#    'compound_404077'},
#   'products': {'compound_21892', 'compound_2300', 'compound_5003'},
#   'enzymes': {'EC:3.6.1.1'}},
#  'reaction_7': {'kegg_id': 'R00012',
#   'description': 'GTP:GTP guanylyltransferase',
#   'substrates': {'compound_2285', 'compound_2286'},
#   'products': {'compound_403470', 'compound_4425', 'compound_4426'}},
#  'reaction_8': {'kegg_id': 'R00013',
#   'description': 'glyoxylate carboxy-lyase (dimerizing; tartronate-semialdehyde-forming)',
#   'substrates': {'compound_400367', 'compound_5030'},
#   'products': {'compound_1654',
#    'compound_201',
#    'compound_3124',
#    'compound_6313'}},
#  'reaction_9': {'kegg_id': 'R00014',
#   'vmh_id': 'HMR_8746',
#   'description': 'pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)',
#   'substrates': {'compound_404077',
#    'compound_4529',
#    'compound_4784',
#    'compound_5012'},
#   'products': {'compound_1654', 'compound_3106', 'compound_3107'},
#   'genes': {'PDHA1', 'PDHA2', 'PDHB'},
#   'enzymes': {'EC:1.2.4.1'}},
#  'reaction_10': {'kegg_id': 'R00015',
#   'description': "sucrose:sucrose 1'-beta-D-fructosyltransferase",
#   'substrates': {'compound_4705'},
#   'products': {'compound_2166',
#    'compound_400958',
#    'compound_5019',
#    'compound_8203'},
#   'enzymes': {'EC:1.11.1.21', 'EC:1.11.1.6'}},
#  'reaction_11': {'kegg_id': 'R00017',
#   'description': 'ferrocytochrome-c:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_2028', 'compound_403943'},
#   'products': {'compound_2023', 'compound_2300', 'compound_5003'},
#   'enzymes': {'EC:1.11.1.21', 'EC:1.11.1.6'}},
#  'reaction_12': {'kegg_id': 'R00018',
#   'description': 'putrescine:putrescine 4-aminobutyltransferase (ammonia-forming)',
#   'substrates': {'compound_4511'},
#   'products': {'compound_10096', 'compound_4158'},
#   'enzymes': {'EC:1.11.1.6'}},
#  'reaction_13': {'kegg_id': 'R00019',
#   'description': 'hydrogen:ferredoxin oxidoreductase',
#   'substrates': {'compound_2019',
#    'compound_3505',
#    'compound_400782',
#    'compound_404077'},
#   'products': {'compound_2018', 'compound_2298', 'compound_3473'}},
#  'reaction_14': {'kegg_id': 'R00021',
#   'description': 'L-glutamate:ferredoxin oxidoreductase (transaminating)',
#   'substrates': {'compound_2018', 'compound_2196', 'compound_3473'},
#   'products': {'compound_2019',
#    'compound_2180',
#    'compound_2181',
#    'compound_3505',
#    'compound_400782',
#    'compound_403968',
#    'compound_404077',
#    'compound_5014'}},
#  'reaction_15': {'kegg_id': 'R00022',
#   'description': 'chitobiose N-acetylglucosaminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2330',
#    'compound_5003',
#    'compound_6663'},
#   'products': {'compound_687', 'compound_688'},
#   'genes': {'HEXA', 'HEXB', 'HEXD'},
#   'enzymes': {'EC:3.2.1.52'}},
#  'reaction_16': {'kegg_id': 'R00023',
#   'description': 'hydroxylamine:NAD+ oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5260'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6776',
#    'compound_6777',
#    'compound_6778'}},
#  'reaction_17': {'kegg_id': 'R00024',
#   'description': '3-phospho-D-glycerate carboxy-lyase (dimerizing; D-ribulose-1,5-bisphosphate-forming)',
#   'substrates': {'compound_1654',
#    'compound_2300',
#    'compound_404370',
#    'compound_5003',
#    'compound_6333'},
#   'products': {'compound_403270'}},
#  'reaction_18': {'kegg_id': 'R00025',
#   'description': 'ethylnitronate:oxygen 2-oxidoreductase (nitrite-forming)',
#   'substrates': {'compound_20443',
#    'compound_400589',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2024',
#    'compound_2025',
#    'compound_2300',
#    'compound_4169',
#    'compound_5003',
#    'compound_5050',
#    'compound_667'},
#   'enzymes': {'EC:1.2.4.1'}},
#  'reaction_19': {'kegg_id': 'R00026',
#   'description': 'cellobiose glucohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_5256'},
#   'products': {'compound_2167', 'compound_3269'},
#   'genes': {'GBA3'},
#   'enzymes': {'EC:3.2.1.21'}},
#  'reaction_20': {'kegg_id': 'R00027',
#   'description': '2-hydroxy-1,2-diphenylethanone benzaldehyde-lyase (benzaldehyde-forming)',
#   'substrates': {'compound_400935'},
#   'products': {'compound_5306'}},
#  'reaction_21': {'kegg_id': 'R00029',
#   'description': 'thiosulfate:ferricytochrome-c oxidoreductase',
#   'substrates': {'compound_2023',
#    'compound_4871',
#    'compound_5341',
#    'compound_5342'},
#   'products': {'compound_2028', 'compound_6994', 'compound_6995'}},
#  'reaction_22': {'kegg_id': 'R00031',
#   'description': '1,2-benzenediol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_4881', 'compound_5005'},
#   'products': {'compound_272'},
#   'genes': {'TYR'},
#   'enzymes': {'EC:1.14.18.1'}},
#  'reaction_23': {'kegg_id': 'R00032',
#   'vmh_id': 'BCDO',
#   'description': "beta-carotene:oxygen 15,15'-oxidoreductase (bond-cleaving)",
#   'substrates': {'compound_1068', 'compound_4182', 'compound_5005'},
#   'products': {'compound_4556', 'compound_4559'},
#   'genes': {'BCO1'},
#   'enzymes': {'EC:1.13.11.63'}},
#  'reaction_24': {'kegg_id': 'R00033',
#   'description': 'thiamine:oxygen 5-oxidoreductase',
#   'substrates': {'compound_4182', 'compound_4781', 'compound_5005'},
#   'products': {'compound_403943', 'compound_9691'}},
#  'reaction_25': {'kegg_id': 'R00034',
#   'description': 'Cyclobutadipyrimidine (in DNA) pyrimidine-lyase',
#   'substrates': {'compound_7811'},
#   'products': {'compound_11614'}},
#  'reaction_26': {'kegg_id': 'R00036',
#   'vmh_id': 'PPBNGS',
#   'description': '5-aminolevulinate hydro-lyase (adding 5-aminolevulinate and cyclizing; porphobilinogen-forming)',
#   'substrates': {'compound_539', 'compound_5584'},
#   'products': {'compound_2300',
#    'compound_404077',
#    'compound_4420',
#    'compound_5003'},
#   'genes': {'ALAD'},
#   'enzymes': {'EC:4.2.1.24'}},
#  'reaction_27': {'kegg_id': 'R00038',
#   'description': '4-hydroxy-3-hexanone propanal-lyase (propanal-forming)',
#   'substrates': {'compound_4419'},
#   'products': {'compound_7682'}},
#  'reaction_28': {'kegg_id': 'R00039',
#   'description': 'raffinose:raffinose 1F-alpha-D-galactosyltransferase',
#   'substrates': {'compound_4549', 'compound_5622'},
#   'products': {'compound_11604', 'compound_4705'}},
#  'reaction_29': {'kegg_id': 'R00041',
#   'description': 'long-chain-alcohol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5358'},
#   'products': {'compound_2300', 'compound_5003', 'compound_5719'}},
#  'reaction_30': {'kegg_id': 'R00042',
#   'description': '4-hydroxyphenylpyruvate:oxygen oxidoreductase (decarboxylating)',
#   'substrates': {'compound_276',
#    'compound_4182',
#    'compound_5005',
#    'compound_6332'},
#   'products': {'compound_1654', 'compound_401672', 'compound_5924'},
#   'enzymes': {'EC:3.2.1.20'}},
#  'reaction_31': {'kegg_id': 'R00043',
#   'description': '1,2-bis(4-hydroxy-3-methoxyphenyl)ethylene:oxygen oxidoreductase (alpha-beta-bond-cleaving)',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_8868',
#    'compound_8869',
#    'compound_8870'},
#   'products': {'compound_6001'},
#   'enzymes': {'EC:3.2.1.20'}},
#  'reaction_32': {'kegg_id': 'R00044',
#   'description': 'columbamine:oxygen oxidoreductase (cyclizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6762'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6004'},
#   'enzymes': {'EC:3.2.1.20'}},
#  'reaction_33': {'kegg_id': 'R00045',
#   'vmh_id': 'TYRDOPO3',
#   'description': '3,4-dihydroxy-L-phenylalanine:oxygen oxidoreductase',
#   'substrates': {'compound_272', 'compound_4182', 'compound_5005'},
#   'products': {'compound_1929',
#    'compound_1930',
#    'compound_2300',
#    'compound_5003'},
#   'genes': {'TYR'},
#   'enzymes': {'EC:1.14.18.1'}},
#  'reaction_34': {'kegg_id': 'R00047',
#   'description': '6-hydroxynicotinate,hydrogen-donor:oxygen oxidoreductase (3-hydroxylating, decarboxylating)',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_5018',
#    'compound_6222'},
#   'products': {'compound_1654',
#    'compound_2300',
#    'compound_5003',
#    'compound_5015',
#    'compound_6247'}},
#  'reaction_35': {'kegg_id': 'R00048',
#   'description': '(R)-3-((R)-3-Hydroxybutanoyloxy)-butanoate hydroxybutanoylhydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_8866',
#    'compound_8867'},
#   'products': {'compound_1349',
#    'compound_6270',
#    'compound_941',
#    'compound_942'},
#   'enzymes': {'EC:1.13.11.63', 'EC:1.14.99.36'}},
#  'reaction_36': {'kegg_id': 'R00049',
#   'description': '1-O-galloyl-beta-D-glucose:1-O-galloyl-beta-D-glucose O-galloyltransferase',
#   'substrates': {'compound_6323'},
#   'products': {'compound_2166', 'compound_5019', 'compound_8523'}},
#  'reaction_37': {'kegg_id': 'R00052',
#   'description': 'chloride:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_400850',
#    'compound_403943',
#    'compound_6434',
#    'compound_6454'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6437'}},
#  'reaction_38': {'kegg_id': 'R00053',
#   'description': 'digallate acylhydrolase',
#   'substrates': {'compound_2300',
#    'compound_403736',
#    'compound_5003',
#    'compound_6600'},
#   'products': {'compound_6483', 'compound_6484'},
#   'enzymes': {'EC:4.2.1.24'}},
#  'reaction_39': {'kegg_id': 'R00054',
#   'description': 'orsellinate-depside hydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_7624'},
#   'products': {'compound_6792', 'compound_6793', 'compound_6794'}},
#  'reaction_40': {'kegg_id': 'R00055',
#   'description': "inosine:oxygen 5'-oxidoreductase",
#   'substrates': {'compound_2713', 'compound_4182', 'compound_5005'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6919'}},
#  'reaction_41': {'kegg_id': 'R00056',
#   'description': 'dinucleotide nucleotidohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_6853'},
#   'products': {'compound_7066'}},
#  'reaction_42': {'kegg_id': 'R00057',
#   'description': 'thiol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6565'},
#   'products': {'compound_403943', 'compound_7190'},
#   'genes': {'GFER', 'QSOX1', 'QSOX2'},
#   'enzymes': {'EC:1.8.3.2'}},
#  'reaction_43': {'kegg_id': 'R00058',
#   'description': 'catechol:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5051'},
#   'products': {'compound_2300', 'compound_400816', 'compound_5003'},
#   'genes': {'TYR'},
#   'enzymes': {'EC:1.14.18.1'}},
#  'reaction_44': {'kegg_id': 'R00059',
#   'description': 'N-(6-aminohexanoyl)-6-aminohexanoate amidohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_6383',
#    'compound_6384'},
#   'products': {'compound_7247', 'compound_7248'}},
#  'reaction_45': {'kegg_id': 'R00060',
#   'description': 'Sulochrin:oxygen oxidoreductase (cyclizing, (+)-specific)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5625'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7759'},
#   'enzymes': {'EC:1.14.18.1'}},
#  'reaction_46': {'kegg_id': 'R00061',
#   'description': 'sulochrin:oxygen oxidoreductase (cyclizing, (-)-specific)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5625'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7763'}},
#  'reaction_47': {'kegg_id': 'R00062',
#   'vmh_id': 'HMR_4767',
#   'description': 'bilirubin-glucuronoside:bilirubin-glucuronoside D-glucuronosyltransferase',
#   'substrates': {'compound_943',
#    'compound_944',
#    'compound_945',
#    'compound_946'},
#   'products': {'compound_943',
#    'compound_944',
#    'compound_945',
#    'compound_946'}},
#  'reaction_48': {'kegg_id': 'R00063',
#   'description': '1-O-sinapoyl-beta-D-glucose:1-O-sinapoyl-beta-D-glucose 1-O-sinapoyltransferase',
#   'substrates': {'compound_6331'},
#   'products': {'compound_2166', 'compound_5019', 'compound_8673'}},
#  'reaction_49': {'kegg_id': 'R00066',
#   'description': '6,7-Dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase',
#   'substrates': {'compound_1901'},
#   'products': {'compound_401782', 'compound_9021', 'compound_9022'}},
#  'reaction_50': {'kegg_id': 'R00067',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_400782', 'compound_404077', 'compound_9361'},
#   'products': {'compound_2298'}},
#  'reaction_51': {'kegg_id': 'R00068',
#   'description': 'L-ascorbate:oxygen oxidoreductase',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_5041',
#    'compound_5042',
#    'compound_900'},
#   'products': {'compound_1860',
#    'compound_2300',
#    'compound_5003',
#    'compound_9400'}},
#  'reaction_52': {'kegg_id': 'R00069',
#   'description': '4-imidazolone-5-propanoate:oxygen oxidoreductase',
#   'substrates': {'compound_403943', 'compound_9476', 'compound_9477'},
#   'products': {'compound_2300',
#    'compound_4182',
#    'compound_500',
#    'compound_5003',
#    'compound_5005'},
#   'genes': {'XDH'},
#   'enzymes': {'EC:1.17.3.2'}},
#  'reaction_53': {'kegg_id': 'R00070',
#   'description': 'D-urobilinogen:oxygen oxidoreductase',
#   'substrates': {'compound_4182',
#    'compound_5005',
#    'compound_9629',
#    'compound_9630'},
#   'products': {'compound_2300', 'compound_5003', 'compound_9635'}},
#  'reaction_54': {'kegg_id': 'R00072',
#   'description': 'thiamine-aldehyde:oxygen 5-oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4182',
#    'compound_5003',
#    'compound_5005',
#    'compound_9691'},
#   'products': {'compound_403943', 'compound_7639'}},
#  'reaction_55': {'kegg_id': 'R00073',
#   'description': 'reduced acceptor:prostaglandin G2 oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4480',
#    'compound_5003',
#    'compound_5015'},
#   'products': {'compound_2495', 'compound_5018'},
#   'genes': {'PTGS1', 'PTGS2'},
#   'enzymes': {'EC:1.14.99.1'}},
#  'reaction_56': {'kegg_id': 'R00074',
#   'description': '2-aminophenol:oxygen oxidoreductase (dimerizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6913'},
#   'products': {'compound_2300', 'compound_5003', 'compound_7057'}},
#  'reaction_57': {'kegg_id': 'R00075',
#   'description': 'S-adenosyl-L-methionine:S-adenosyl-L-methionine 3-amino-3-carboxypropyltransferase',
#   'substrates': {'compound_5009', 'compound_828', 'compound_829'},
#   'products': {'compound_401540',
#    'compound_402461',
#    'compound_9336',
#    'compound_9337'}},
#  'reaction_58': {'kegg_id': 'R00076',
#   'vmh_id': 'HMR_9488',
#   'description': 'ATP:phosphorylase-b phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_3015',
#    'compound_7188',
#    'compound_925'},
#   'products': {'compound_3014', 'compound_7187', 'compound_744'},
#   'genes': {'CALM1', 'PHKA1', 'PHKA2', 'PHKB', 'PHKG1', 'PHKG2'},
#   'enzymes': {'EC:2.7.11.19'}},
#  'reaction_59': {'kegg_id': 'R00077',
#   'vmh_id': 'HMR_9489',
#   'description': '[Phosphorylase a] phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_3014',
#    'compound_5003',
#    'compound_7187'},
#   'products': {'compound_3015',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_7188'},
#   'enzymes': {'EC:2.4.1.95'}},
#  'reaction_60': {'kegg_id': 'R00078',
#   'vmh_id': 'r0016',
#   'description': 'Fe(II):oxygen oxidoreductase',
#   'substrates': {'compound_2020',
#    'compound_400782',
#    'compound_404077',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2021',
#    'compound_2022',
#    'compound_2300',
#    'compound_5003'},
#   'genes': {'CP', 'FTH1', 'FTL', 'FTMT', 'FXN', 'HEPH', 'HEPHL1'},
#   'enzymes': {'EC:1.16.3.1'}},
#  'reaction_61': {'kegg_id': 'R00080',
#   'description': 'Catechol:oxygen oxidoreductase (dimerizing)',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_5051'},
#   'products': {'compound_2300', 'compound_5003', 'compound_8346'}},
#  'reaction_62': {'kegg_id': 'R00081',
#   'description': 'ferrocytochrome-c:oxygen oxidoreductase',
#   'substrates': {'compound_2028',
#    'compound_400782',
#    'compound_404077',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_2023', 'compound_2300', 'compound_5003'},
#   'genes': {'COX1'},
#   'enzymes': {'EC:7.1.1.9'}},
#  'reaction_63': {'kegg_id': 'R00082',
#   'description': 'ferrocytochrome c2:oxygen oxidoreductase',
#   'substrates': {'compound_4182', 'compound_5005', 'compound_6199'},
#   'products': {'compound_2300', 'compound_5003', 'compound_6197'},
#   'genes': {'COX1'},
#   'enzymes': {'EC:7.1.1.9'}},
#  'reaction_64': {'kegg_id': 'R00083',
#   'description': 'Benzenediol:oxygen oxidoreductase',
#   'substrates': {'compound_1070',
#    'compound_4182',
#    'compound_5005',
#    'compound_6755'},
#   'products': {'compound_2300', 'compound_5003', 'compound_9324'}},
#  'reaction_65': {'kegg_id': 'R00084',
#   'vmh_id': 'HMBS',
#   'description': 'porphobilinogen:(4-[2-carboxyethyl]-3-[carboxymethyl]pyrrol-2-yl)methyltransferase (hydrolysing)',
#   'substrates': {'compound_2300', 'compound_4420', 'compound_5003'},
#   'products': {'compound_2571', 'compound_4158'},
#   'genes': {'HMBS'},
#   'enzymes': {'EC:2.5.1.61'}},
#  'reaction_66': {'kegg_id': 'R00085',
#   'vmh_id': 'ATPH1e',
#   'description': 'ATP diphosphohydrolase (phosphate-forming)',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'genes': {'ENTPD1', 'ENTPD2', 'ENTPD3', 'ENTPD5', 'ENTPD6', 'ENTPD8'},
#   'enzymes': {'EC:3.6.1.5'}},
#  'reaction_67': {'kegg_id': 'R00086',
#   'description': 'ATP phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'},
#   'genes': {'ENTPD1', 'ENTPD3', 'ENTPD8', 'NTPCR'},
#   'enzymes': {'EC:3.6.1.15', 'EC:3.6.1.5'}},
#  'reaction_68': {'kegg_id': 'R00087',
#   'description': 'ATP diphosphohydrolase (diphosphate-forming)',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_4425',
#    'compound_4426',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'genes': {'ENPP1', 'ENPP3'},
#   'enzymes': {'EC:3.6.1.9'}},
#  'reaction_69': {'kegg_id': 'R00088',
#   'description': 'ATP aminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_2460',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_2724', 'compound_4158'}},
#  'reaction_70': {'kegg_id': 'R00089',
#   'vmh_id': 'ADNCYC',
#   'description': "ATP diphosphate-lyase (cyclizing; 3',5'-cyclic-AMP-forming)",
#   'substrates': {'compound_2460', 'compound_925'},
#   'products': {'compound_401336', 'compound_4425', 'compound_4426'},
#   'genes': {'ADCY1',
#    'ADCY10',
#    'ADCY2',
#    'ADCY3',
#    'ADCY4',
#    'ADCY5',
#    'ADCY6',
#    'ADCY7',
#    'ADCY8',
#    'ADCY9'},
#   'enzymes': {'EC:2.7.11.19', 'EC:4.6.1.1'}},
#  'reaction_71': {'kegg_id': 'R00090',
#   'description': 'NADH:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_403943',
#    'compound_404077'},
#   'products': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'},
#   'enzymes': {'EC:3.1.3.17'}},
#  'reaction_72': {'kegg_id': 'R00091',
#   'description': 'CoA:NAD+ oxidoreductase',
#   'substrates': {'compound_1656',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6940'},
#   'enzymes': {'EC:1.16.3.1'}},
#  'reaction_73': {'kegg_id': 'R00092',
#   'description': 'Fe2+:NAD+ oxidoreductase',
#   'substrates': {'compound_2020',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2021',
#    'compound_2022',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077'}},
#  'reaction_74': {'kegg_id': 'R00093',
#   'description': 'L-glutamate:NAD+ oxidoreductase (transaminating)',
#   'substrates': {'compound_2196',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2180',
#    'compound_2181',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_403968',
#    'compound_404077',
#    'compound_5014'}},
#  'reaction_75': {'kegg_id': 'R00094',
#   'description': 'glutathione:NAD+ oxidoreductase',
#   'substrates': {'compound_2284',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'products': {'compound_2282',
#    'compound_2283',
#    'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077'},
#   'genes': {'GSR'},
#   'enzymes': {'EC:1.8.1.7'}},
#  'reaction_76': {'kegg_id': 'R00095',
#   'description': 'NADH:monodehydroascorbate oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_5041',
#    'compound_5042',
#    'compound_900'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_6234',
#    'compound_901',
#    'compound_966'}},
#  'reaction_77': {'kegg_id': 'R00100',
#   'description': 'NADH:ferricytochrome-b5 oxidoreductase',
#   'substrates': {'compound_2323', 'compound_2461', 'compound_402126'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_404619',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004'},
#   'genes': {'CYB5R1', 'CYB5R2', 'CYB5R3', 'CYB5R4', 'CYB5RL'},
#   'enzymes': {'EC:1.6.2.2', 'EC:2.5.1.61', 'EC:4.3.1.8'}},
#  'reaction_78': {'kegg_id': 'R00101',
#   'description': 'NADH:ferrileghemoglobin oxidoreductase',
#   'substrates': {'compound_2461', 'compound_402126', 'compound_7467'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_7469'},
#   'enzymes': {'EC:3.6.1.5'}},
#  'reaction_79': {'kegg_id': 'R00103',
#   'description': 'NAD+ phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_4165',
#    'compound_4166',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'genes': {'ENPP1', 'ENPP3', 'NUDT12'},
#   'enzymes': {'EC:3.6.1.22', 'EC:3.6.1.9'}},
#  'reaction_80': {'kegg_id': 'R00104',
#   'vmh_id': 'NADK',
#   'description': "ATP:NAD+ 2'-phosphotransferase",
#   'substrates': {'compound_2460',
#    'compound_4140',
#    'compound_4141',
#    'compound_5004',
#    'compound_925'},
#   'products': {'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_744'},
#   'genes': {'NADK', 'NADK2'},
#   'enzymes': {'EC:2.7.1.23'}},
#  'reaction_81': {'kegg_id': 'R00105',
#   'description': "ATP:NADH 2'-phosphotransferase",
#   'substrates': {'compound_2460',
#    'compound_2461',
#    'compound_402126',
#    'compound_925'},
#   'products': {'compound_4144', 'compound_744'}},
#  'reaction_82': {'kegg_id': 'R00106',
#   'vmh_id': 'HMR_9501',
#   'description': 'NADPH:ferricytochrome oxidoreductase',
#   'substrates': {'compound_2028',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144',
#    'compound_6149'},
#   'products': {'compound_2023',
#    'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144',
#    'compound_6150'},
#   'genes': {'POR'},
#   'enzymes': {'EC:1.6.2.4', 'EC:4.6.1.1'}},
#  'reaction_83': {'kegg_id': 'R00108',
#   'description': 'NADPH:ferricytochrome-c2 oxidoreductase',
#   'substrates': {'compound_4144', 'compound_6197'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_6199'}},
#  'reaction_84': {'kegg_id': 'R00109',
#   'description': 'NADPH:ferrileghemoglobin oxidoreductase',
#   'substrates': {'compound_4144', 'compound_7467'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_7469'}},
#  'reaction_85': {'kegg_id': 'R00111',
#   'description': 'N-(omega)-Hydroxyarginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_4179',
#    'compound_4180',
#    'compound_4181',
#    'compound_4182',
#    'compound_5005'},
#   'products': {'compound_1624',
#    'compound_2300',
#    'compound_3017',
#    'compound_4142',
#    'compound_4143',
#    'compound_4168',
#    'compound_5003'},
#   'genes': {'NOS1', 'NOS2', 'NOS3'},
#   'enzymes': {'EC:1.14.13.39'}},
#  'reaction_86': {'kegg_id': 'R00112',
#   'description': 'NADPH:NAD+ oxidoreductase',
#   'substrates': {'compound_4140',
#    'compound_4141',
#    'compound_4144',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_402126',
#    'compound_4142',
#    'compound_4143'},
#   'genes': {'NNT'},
#   'enzymes': {'EC:1.6.1.2'}},
#  'reaction_87': {'kegg_id': 'R00113',
#   'description': 'NADPH:hydrogen-peroxide oxidoreductase',
#   'substrates': {'compound_400782',
#    'compound_403943',
#    'compound_404077',
#    'compound_4144'},
#   'products': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003'}},
#  'reaction_88': {'kegg_id': 'R00114',
#   'description': 'L-glutamate:NADP+ oxidoreductase (transaminating)',
#   'substrates': {'compound_2196', 'compound_4142', 'compound_4143'},
#   'products': {'compound_2180',
#    'compound_2181',
#    'compound_400782',
#    'compound_403968',
#    'compound_404077',
#    'compound_4144',
#    'compound_5014'}},
#  'reaction_89': {'kegg_id': 'R00115',
#   'vmh_id': 'GTHOm',
#   'description': 'glutathione:NADP+ oxidoreductase',
#   'substrates': {'compound_2282',
#    'compound_2283',
#    'compound_2284',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144'},
#   'products': {'compound_2282',
#    'compound_2283',
#    'compound_2284',
#    'compound_400782',
#    'compound_404077',
#    'compound_4142',
#    'compound_4143',
#    'compound_4144'},
#   'genes': {'GSR'},
#   'enzymes': {'EC:1.8.1.7'}},
#  'reaction_90': {'kegg_id': 'R00118',
#   'vmh_id': 'HMR_4270',
#   'description': "NADP+ 2'-phosphohydrolase",
#   'substrates': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003'},
#   'products': {'compound_4140',
#    'compound_4141',
#    'compound_4400',
#    'compound_4401',
#    'compound_5004',
#    'compound_5006'},
#   'genes': {'ACP1', 'ACP5', 'ACP6', 'ACP7', 'ACPP', 'ACPT', 'NOCT', 'PXYLP1'},
#   'enzymes': {'EC:3.1.3.108'}},
#  'reaction_91': {'kegg_id': 'R00119',
#   'description': 'NADP+:nicotinate ADP-ribosyltransferase',
#   'substrates': {'compound_4138',
#    'compound_4142',
#    'compound_4143',
#    'compound_5301'},
#   'products': {'compound_16161', 'compound_402462'},
#   'genes': {'BST1', 'CD38'},
#   'enzymes': {'EC:2.4.99.20', 'EC:3.2.2.5', 'EC:3.2.2.6', 'EC:3.5.1.-'}},
#  'reaction_92': {'kegg_id': 'R00120',
#   'description': 'glutathione:oxygen oxidoreductase',
#   'substrates': {'compound_2284', 'compound_4182', 'compound_5005'},
#   'products': {'compound_2282', 'compound_2283', 'compound_403943'},
#   'enzymes': {'EC:3.2.2.5', 'EC:3.2.2.6', 'EC:3.5.1.-'}},
#  'reaction_93': {'kegg_id': 'R00122',
#   'vmh_id': 'ATPH2e',
#   'description': 'ADP phosphohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_744'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'genes': {'ENTPD1', 'ENTPD2', 'ENTPD3', 'ENTPD5', 'ENTPD6', 'ENTPD8'},
#   'enzymes': {'EC:3.6.1.5'}},
#  'reaction_94': {'kegg_id': 'R00123',
#   'description': 'ADP aminohydrolase',
#   'substrates': {'compound_2300', 'compound_5003', 'compound_744'},
#   'products': {'compound_403996', 'compound_4158'},
#   'enzymes': {'EC:2.7.1.23'}},
#  'reaction_95': {'kegg_id': 'R00125',
#   'description': "P1,P4-bis(5'-adenosyl)-tetraphosphate nucleotidebisphosphohydrolase",
#   'substrates': {'compound_2300', 'compound_5003', 'compound_845'},
#   'products': {'compound_744'}},
#  'reaction_96': {'kegg_id': 'R00126',
#   'description': 'ADP:ATP adenylyltransferase',
#   'substrates': {'compound_2460', 'compound_744', 'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_845'},
#   'enzymes': {'EC:1.6.2.4'}},
#  'reaction_97': {'kegg_id': 'R00128',
#   'description': 'Adenosine-tetraphosphate phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_8082',
#    'compound_8083'},
#   'products': {'compound_2460',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_925'}},
#  'reaction_98': {'kegg_id': 'R00129',
#   'description': '(6S)-6beta-hydroxy-1,4,5,6-tetrahydronicotinamide-adenine dinucleotide hydro-lyase (ATP-hydrolysing, NADH-forming)',
#   'substrates': {'compound_2460',
#    'compound_402134',
#    'compound_9114',
#    'compound_925'},
#   'products': {'compound_2461',
#    'compound_402126',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'},
#   'genes': {'NAXD'},
#   'enzymes': {'EC:4.2.1.93'}},
#  'reaction_99': {'kegg_id': 'R00130',
#   'vmh_id': 'DPCOAK',
#   'description': "ATP:dephospho-CoA 3'-phosphotransferase",
#   'substrates': {'compound_1933', 'compound_2460', 'compound_925'},
#   'products': {'compound_1656', 'compound_404077', 'compound_744'},
#   'genes': {'COASY'},
#   'enzymes': {'EC:2.7.1.24'}},
#  'reaction_100': {'kegg_id': 'R00131',
#   'description': 'Urea amidohydrolase',
#   'substrates': {'compound_2300', 'compound_4924', 'compound_5003'},
#   'products': {'compound_1654', 'compound_4158'}},
#  'reaction_101': {'kegg_id': 'R00132',
#   'description': 'carbonate hydro-lyase (carbon-dioxide-forming)',
#   'substrates': {'compound_2299', 'compound_2512'},
#   'products': {'compound_1654', 'compound_2300', 'compound_5003'},
#   'genes': {'CA1',
#    'CA12',
#    'CA13',
#    'CA14',
#    'CA2',
#    'CA3',
#    'CA4',
#    'CA5A',
#    'CA5B',
#    'CA6',
#    'CA7',
#    'CA8',
#    'CA9'},
#   'enzymes': {'EC:4.2.1.1'}},
#  'reaction_102': {'kegg_id': 'R00134',
#   'description': 'formate:NADP+ oxidoreductase',
#   'substrates': {'compound_2030',
#    'compound_4142',
#    'compound_4143',
#    'compound_5035'},
#   'products': {'compound_1654',
#    'compound_400782',
#    'compound_404077',
#    'compound_4144'}},
#  'reaction_103': {'kegg_id': 'R00138',
#   'vmh_id': 'PPA2',
#   'description': 'Triphosphate phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4432',
#    'compound_4433',
#    'compound_5003',
#    'compound_5652'},
#   'products': {'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5006'},
#   'enzymes': {'EC:1.8.1.7'}},
#  'reaction_104': {'kegg_id': 'R00139',
#   'description': "ATP:2'-deoxy-5-hydroxymethylcytidine-5'-diphosphate phosphotransferase",
#   'substrates': {'compound_14561', 'compound_2460', 'compound_925'},
#   'products': {'compound_14562', 'compound_744'},
#   'genes': {'AK9',
#    'NME1',
#    'NME1-NME2',
#    'NME2',
#    'NME3',
#    'NME4',
#    'NME6',
#    'NME7'},
#   'enzymes': {'EC:2.7.4.6', 'EC:3.1.3.2'}},
#  'reaction_105': {'kegg_id': 'R00140',
#   'description': 'ATP:5-hydroxymethyldeoxycytidylate phosphotransferase',
#   'substrates': {'compound_14561', 'compound_744'},
#   'products': {'compound_2460', 'compound_8450', 'compound_925'}},
#  'reaction_106': {'kegg_id': 'R00141',
#   'description': 'ATP:ammonia phosphotransferase',
#   'substrates': {'compound_2460', 'compound_4158', 'compound_925'},
#   'products': {'compound_7185', 'compound_7186', 'compound_744'}},
#  'reaction_107': {'kegg_id': 'R00143',
#   'description': 'ammonia:NAD+ oxidoreductase',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_4158',
#    'compound_5003',
#    'compound_5004'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_5260'},
#   'enzymes': {'EC:3.6.1.5'}},
#  'reaction_108': {'kegg_id': 'R00145',
#   'description': 'alpha-amino acid:NAD+ oxidoreductase (deaminating)',
#   'substrates': {'compound_2300',
#    'compound_4140',
#    'compound_4141',
#    'compound_5003',
#    'compound_5004',
#    'compound_9254'},
#   'products': {'compound_2461',
#    'compound_400782',
#    'compound_402126',
#    'compound_404077',
#    'compound_4158',
#    'compound_5222'},
#   'genes': {'GLUD1', 'GLUD2'},
#   'enzymes': {'EC:1.4.1.3'}},
#  'reaction_109': {'kegg_id': 'R00146',
#   'description': 'alpha-amino acid:NADP+ oxidoreductase (deaminating)',
#   'substrates': {'compound_2300',
#    'compound_4142',
#    'compound_4143',
#    'compound_5003',
#    'compound_9254'},
#   'products': {'compound_400782',
#    'compound_404077',
#    'compound_4144',
#    'compound_4158',
#    'compound_5222'},
#   'genes': {'GLUD1', 'GLUD2'},
#   'enzymes': {'EC:1.4.1.3', 'EC:2.7.4.6'}},
#  'reaction_110': {'kegg_id': 'R00148',
#   'description': 'ammonia,ubiquinol:oxygen oxidoreductase',
#   'substrates': {'compound_4158',
#    'compound_4182',
#    'compound_4531',
#    'compound_5005',
#    'compound_5437'},
#   'products': {'compound_2300',
#    'compound_400174',
#    'compound_404214',
#    'compound_4530',
#    'compound_5003',
#    'compound_5260'},
#   'enzymes': {'EC:2.7.4.6'}},
#  'reaction_111': {'kegg_id': 'R00149',
#   'description': 'Carbon-dioxide:ammonia ligase (ADP-forming,carbamate-phosphorylating)',
#   'substrates': {'compound_1654',
#    'compound_2300',
#    'compound_2460',
#    'compound_4158',
#    'compound_5003',
#    'compound_925'},
#   'products': {'compound_403038',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_744'},
#   'genes': {'CPS1'},
#   'enzymes': {'EC:2.7.4.6', 'EC:6.3.4.16'}},
#  'reaction_112': {'kegg_id': 'R00150',
#   'description': 'ATP:carbamate phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_2511',
#    'compound_4158',
#    'compound_925'},
#   'products': {'compound_2300',
#    'compound_403038',
#    'compound_5003',
#    'compound_744'}},
#  'reaction_113': {'kegg_id': 'R00152',
#   'description': 'hydrogen cyanide aminohydrolase',
#   'substrates': {'compound_1772', 'compound_2300', 'compound_5003'},
#   'products': {'compound_2030', 'compound_4158', 'compound_5035'}},
#  'reaction_114': {'kegg_id': 'R00153',
#   'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_9361',
#    'compound_9364'},
#   'products': {'compound_4158'},
#   'enzymes': {'EC:2.7.4.3'}},
#  'reaction_115': {'kegg_id': 'R00157',
#   'vmh_id': 'UTPATPT',
#   'description': 'Uridine triphosphate:AMP phosphotransferase',
#   'substrates': {'compound_4927',
#    'compound_4928',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_403617', 'compound_744'},
#   'genes': {'AK3'},
#   'enzymes': {'EC:2.7.4.10', 'EC:2.7.4.3'}},
#  'reaction_116': {'kegg_id': 'R00159',
#   'vmh_id': 'NDP8ex',
#   'description': 'UTP phosphohydrolase',
#   'substrates': {'compound_2300',
#    'compound_4927',
#    'compound_4928',
#    'compound_5003'},
#   'products': {'compound_403617',
#    'compound_404077',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006'},
#   'genes': {'CANT1', 'ENTPD1', 'ENTPD3', 'ENTPD8'},
#   'enzymes': {'EC:3.6.1.5'}},
#  'reaction_117': {'kegg_id': 'R00161',
#   'vmh_id': 'FMNAT',
#   'description': 'ATP:FMN adenylyltransferase',
#   'substrates': {'compound_2024',
#    'compound_2025',
#    'compound_2460',
#    'compound_404077',
#    'compound_925'},
#   'products': {'compound_2011', 'compound_4425', 'compound_4426'},
#   'genes': {'FLAD1'},
#   'enzymes': {'EC:2.7.7.2'}},
#  'reaction_118': {'kegg_id': 'R00162',
#   'vmh_id': 'HMR_9577',
#   'description': 'ATP:protein phosphotransferase',
#   'substrates': {'compound_2460',
#    'compound_3016',
#    'compound_5008',
#    'compound_925'},
#   'products': {'compound_404593', 'compound_744'},
#   'genes': {'AAK1',
#    'AATK',
#    'ACVR1',
#    'ACVR1B',
#    'ACVR1C',
#    'ACVR2A',
#    'ACVR2B',
#    'ACVRL1',
#    'AKT1',
#    'AKT2',
#    'AKT3',
#    'AMHR2',
#    'ANKK1',
#    'ARAF',
#    'ATM',
#    'ATR',
#    'AURKA',
#    'AURKB',
#    'AURKC',
#    'BCR',
#    'BMP2K',
#    'BMPR1A',
#    'BMPR1B',
#    'BMPR2',
#    'BRAF',
#    'BRSK1',
#    'BRSK2',
#    'BUB1',
#    'BUB1B',
#    'BUB1B-PAK6',
#    'C8orf44-SGK3',
#    'CAMK1',
#    'CAMK1D',
#    'CAMK1G',
#    'CAMK2A',
#    'CAMK2B',
#    'CAMK2D',
#    'CAMK2G',
#    'CAMK4',
#    'CAMKK1',
#    'CAMKK2',
#    'CASK',
#    'CDC42BPA',
#    'CDC42BPB',
#    'CDC42BPG',
#    'CDC7',
#    'CDK1',
#    'CDK10',
#    'CDK11A',
#    'CDK11B',
#    'CDK12',
#    'CDK13',
#    'CDK14',
#    'CDK15',
#    'CDK16',
#    'CDK17',
#    'CDK18',
#    'CDK19',
#    'CDK2',
#    'CDK20',
#    'CDK3',
#    'CDK4',
#    'CDK5',
#    'CDK6',
#    'CDK7',
#    'CDK8',
#    'CDK9',
#    'CDKL1',
#    'CDKL2',
#    'CDKL3',
#    'CDKL4',
#    'CDKL5',
#    'CHEK1',
#    'CHEK2',
#    'CHUK',
#    'CIITA',
#    'CILK1',
#    'CIT',
#    'CLK1',
#    'CLK2',
#    'CLK3',
#    'CLK4',
#    'COL4A3BP',
#    'CSNK1A1',
#    'CSNK1A1L',
#    'CSNK1D',
#    'CSNK1E',
#    'CSNK1G1',
#    'CSNK1G2',
#    'CSNK1G3',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2A3',
#    'CSNK2B',
#    'DAPK1',
#    'DAPK2',
#    'DAPK3',
#    'DCAF1',
#    'DCLK1',
#    'DCLK2',
#    'DCLK3',
#    'DMPK',
#    'DSTYK',
#    'DYRK1A',
#    'DYRK1B',
#    'DYRK2',
#    'DYRK3',
#    'DYRK4',
#    'EIF2AK1',
#    'EIF2AK2',
#    'EIF2AK3',
#    'EIF2AK4',
#    'ERN1',
#    'ERN2',
#    'FAM20C',
#    'FASTK',
#    'FPGT-TNNI3K',
#    'GAK',
#    'GTF2F1',
#    'HASPIN',
#    'HIPK1',
#    'HIPK2',
#    'HIPK3',
#    'HIPK4',
#    'HUNK',
#    'ICK',
#    'IKBKB',
#    'IKBKE',
#    'ILK',
#    'IRAK1',
#    'IRAK2',
#    'IRAK3',
#    'IRAK4',
#    'KALRN',
#    'KSR2',
#    'LATS1',
#    'LATS2',
#    'LIMK1',
#    'LIMK2',
#    'LRRK1',
#    'LRRK2',
#    'MAK',
#    'MAP2K1',
#    'MAP2K2',
#    'MAP2K3',
#    'MAP2K4',
#    'MAP2K5',
#    'MAP2K6',
#    'MAP2K7',
#    'MAP3K1',
#    'MAP3K10',
#    'MAP3K11',
#    'MAP3K12',
#    'MAP3K13',
#    'MAP3K14',
#    'MAP3K15',
#    'MAP3K19',
#    'MAP3K2',
#    'MAP3K20',
#    'MAP3K21',
#    'MAP3K3',
#    'MAP3K4',
#    'MAP3K5',
#    'MAP3K6',
#    'MAP3K7',
#    'MAP3K8',
#    'MAP3K9',
#    'MAP4K1',
#    'MAP4K2',
#    'MAP4K3',
#    'MAP4K4',
#    'MAP4K5',
#    'MAPK1',
#    'MAPK10',
#    'MAPK11',
#    'MAPK12',
#    'MAPK13',
#    'MAPK14',
#    'MAPK15',
#    'MAPK3',
#    'MAPK4',
#    'MAPK6',
#    'MAPK7',
#    'MAPK8',
#    'MAPK9',
#    'MAPKAPK2',
#    'MAPKAPK3',
#    'MAPKAPK5',
#    'MARK1',
#    'MARK2',
#    'MARK3',
#    'MARK4',
#    'MAST1',
#    'MAST2',
#    'MAST3',
#    'MAST4',
#    'MASTL',
#    'MELK',
#    'MINK1',
#    'MKNK1',
#    'MKNK2',
#    'MLKL',
#    'MOK',
#    'MOS',
#    'MTOR',
#    'MYLK4',
#    'MYO3A',
#    'MYO3B',
#    'NEK1',
#    'NEK10',
#    'NEK11',
#    'NEK2',
#    'NEK3',
#    'NEK4',
#    'NEK5',
#    'NEK6',
#    'NEK7',
#    'NEK8',
#    'NEK9',
#    'NIM1K',
#    'NLK',
#    'NRK',
#    'NUAK1',
#    'NUAK2',
#    'OBSCN',
#    'OXSR1',
#    'PAK1',
#    'PAK2',
#    'PAK3',
#    'PAK4',
#    'PAK5',
#    'PAK6',
#    'PAK7',
#    'PASK',
#    'PBK',
#    'PDIK1L',
#    'PDPK1',
#    'PIK3R4',
#    'PIM1',
#    'PIM2',
#    'PIM3',
#    'PINK1',
#    'PKMYT1',
#    'PKN1',
#    'PKN2',
#    'PKN3',
#    'PLK1',
#    'PLK2',
#    'PLK3',
#    'PLK4',
#    'PNCK',
#    'PRKAA1',
#    'PRKAA2',
#    'PRKAB2',
#    'PRKACA',
#    'PRKACB',
#    'PRKACG',
#    'PRKAG2',
#    'PRKAR1A',
#    'PRKAR1B',
#    'PRKAR2A',
#    'PRKAR2B',
#    'PRKCA',
#    'PRKCB',
#    'PRKCD',
#    'PRKCE',
#    'PRKCG',
#    'PRKCH',
#    'PRKCI',
#    'PRKCQ',
#    'PRKCSH',
#    'PRKCZ',
#    'PRKD1',
#    'PRKD2',
#    'PRKD3',
#    'PRKDC',
#    'PRKG1',
#    'PRKG2',
#    'PRKX',
#    'PRPF4',
#    'PRPF4B',
#    'PSKH1',
#    'PSKH2',
#    'RAF1',
#    'RIOK1',
#    'RIOK2',
#    'RIOK3',
#    'RIPK1',
#    'RIPK2',
#    'RIPK3',
#    'RIPK4',
#    'ROCK1',
#    'ROCK2',
#    'RPS6KA1',
#    'RPS6KA2',
#    'RPS6KA3',
#    'RPS6KA4',
#    'RPS6KA5',
#    'RPS6KA6',
#    'RPS6KB1',
#    'RPS6KB2',
#    'RPS6KC1',
#    'RSKR',
#    'SBK1',
#    'SBK2',
#    'SBK3',
#    'SGK1',
#    'SGK2',
#    'SGK3',
#    'SIK',
#    'SIK1',
#    'SIK2',
#    'SIK3',
#    'SLK',
#    'SMG1',
#    'SNRK',
#    'SPEG',
#    'SRPK1',
#    'SRPK2',
#    'SRPK3',
#    'STK10',
#    'STK11',
#    'STK16',
#    'STK17A',
#    'STK17B',
#    'STK19',
#    'STK24',
#    'STK25',
#    'STK26',
#    'STK3',
#    'STK31',
#    'STK32A',
#    'STK32B',
#    'STK32C',
#    'STK33',
#    'STK35',
#    'STK36',
#    'STK38',
#    'STK38L',
#    'STK39',
#    'STK4',
#    'STK40',
#    'TAF1',
#    'TAF1L',
#    'TAOK1',
#    'TAOK2',
#    'TAOK3',
#    'TBK1',
#    'TEN1-CDK3',
#    'TESK1',
#    'TESK2',
#    'TGFBR1',
#    'TGFBR2',
#    'TLK1',
#    'TLK2',
#    'TNIK',
#    'TNK2',
#    'TNNI3K',
#    'TP53RK',
#    'TPTEP2-CSNK1E',
#    'TRIO',
#    'TRPM6',
#    'TRPM7',
#    'TSSK1B',
#    'TSSK2',
#    'TSSK3',
#    'TSSK4',
#    'TSSK6',
#    'TTK',
#    'TTN',
#    'UHMK1',
#    'ULK1',
#    'ULK2',
#    'ULK3',
#    'ULK4',
#    'VRK1',
#    'VRK2',
#    'VRK3',
#    'WEE1',
#    'WEE2',
#    'WNK1',
#    'WNK2',
#    'WNK3',
#    'WNK4'},
#   'enzymes': {'EC:2.7.1.24',
#    'EC:2.7.11.1',
#    'EC:2.7.11.10',
#    'EC:2.7.11.11',
#    'EC:2.7.11.12',
#    'EC:2.7.11.13',
#    'EC:2.7.11.17',
#    'EC:2.7.11.21',
#    'EC:2.7.11.22',
#    'EC:2.7.11.24',
#    'EC:2.7.11.25',
#    'EC:2.7.11.30',
#    'EC:2.7.11.8',
#    'EC:2.7.12.1',
#    'EC:2.7.12.2'}},
#  'reaction_119': {'kegg_id': 'R00164',
#   'vmh_id': 'HMR_9578',
#   'description': 'Phosphoprotein phosphohydrolase',
#   'substrates': {'compound_2300', 'compound_404593', 'compound_5003'},
#   'products': {'compound_3016',
#    'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5008'},
#   'genes': {'CDC14A',
#    'CDC14B',
#    'CDKN3',
#    'CPPED1',
#    'CTDNEP1',
#    'CTDP1',
#    'CTDSP1',
#    'CTDSP2',
#    'CTDSPL',
#    'DUPD1',
#    'DUSP1',
#    'DUSP10',
#    'DUSP11',
#    'DUSP12',
#    'DUSP13',
#    'DUSP14',
#    'DUSP15',
#    'DUSP16',
#    'DUSP18',
#    'DUSP19',
#    'DUSP2',
#    'DUSP21',
#    'DUSP22',
#    'DUSP23',
#    'DUSP26',
#    'DUSP27',
#    'DUSP28',
#    'DUSP29',
#    'DUSP3',
#    'DUSP4',
#    'DUSP5',
#    'DUSP6',
#    'DUSP7',
#    'DUSP8',
#    'DUSP9',
#    'EPM2A',
#    'ILKAP',
#    'PGAM5',
#    'PHLPP1',
#    'PHLPP2',
#    'PPEF1',
#    'PPEF2',
#    'PPM1A',
#    'PPM1B',
#    'PPM1D',
#    'PPM1E',
#    'PPM1F',
#    'PPM1G',
#    'PPM1H',
#    'PPM1J',
#    'PPM1K',
#    'PPM1L',
#    'PPM1M',
#    'PPM1N',
#    'PPP1CA',
#    'PPP1CB',
#    'PPP1CC',
#    'PPP1R1A',
#    'PPP1R1B',
#    'PPP1R2',
#    'PPP1R3A',
#    'PPP1R3C',
#    'PPP2CA',
#    'PPP2CB',
#    'PPP2R1A',
#    'PPP2R1B',
#    'PPP2R2A',
#    'PPP2R2B',
#    'PPP2R2C',
#    'PPP2R3A',
#    'PPP2R3B',
#    'PPP3CA',
#    'PPP3CB',
#    'PPP3CC',
#    'PPP3R1',
#    'PPP3R2',
#    'PPP4C',
#    'PPP5C',
#    'PPP6C',
#    'PPTC7',
#    'PTEN',
#    'PTPMT1',
#    'RPAP2',
#    'SSH1',
#    'SSH2',
#    'SSH3',
#    'SSU72',
#    'STYXL1',
#    'STYXL2',
#    'UBLCP1'},
#   'enzymes': {'EC:3.1.3.16'}},
#  'reaction_120': {'kegg_id': 'R00173',
#   'vmh_id': 'PYDXPP',
#   'description': "pyridoxal-5'-phosphate phosphohydrolase",
#   'substrates': {'compound_2300', 'compound_4525', 'compound_5003'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_4524',
#    'compound_5006'},
#   'genes': {'PDXP', 'PHOSPHO2'},
#   'enzymes': {'EC:3.1.3.74'}},
#  'reaction_121': {'kegg_id': 'R00174',
#   'vmh_id': 'PYDXK',
#   'description': "ATP:pyridoxal 5'-phosphotransferase",
#   'substrates': {'compound_2460', 'compound_4524', 'compound_925'},
#   'products': {'compound_404077', 'compound_4525', 'compound_744'},
#   'genes': {'PDXK'},
#   'enzymes': {'EC:2.7.1.35'}},
#  'reaction_122': {'kegg_id': 'R00177',
#   'vmh_id': 'METAT',
#   'description': 'ATP:L-methionine S-adenosyltransferase',
#   'substrates': {'compound_2300',
#    'compound_3690',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5006',
#    'compound_5009',
#    'compound_828',
#    'compound_829',
#    'compound_925'},
#   'products': {'compound_2300',
#    'compound_2460',
#    'compound_3690',
#    'compound_4400',
#    'compound_4401',
#    'compound_4425',
#    'compound_4426',
#    'compound_5003',
#    'compound_828',
#    'compound_829',
#    'compound_925'},
#   'genes': {'MAT1A', 'MAT2A', 'MAT2B'},
#   'enzymes': {'EC:2.5.1.6', 'EC:2.7.7.1', 'EC:2.7.7.18'}},
#  'reaction_123': {'kegg_id': 'R00178',
#   'vmh_id': 'ADMDC',
#   'description': 'S-adenosyl-L-methionine carboxy-lyase [S-adenosyl 3-(methylsulfanyl)propylamine-forming]',
#   'substrates': {'compound_400782',
#    'compound_404077',
#    'compound_5009',
#    'compound_828',
#    'compound_829'},
#   'products': {'compound_1654', 'compound_2465', 'compound_830'},
#   'genes': {'AMD1'},
#   'enzymes': {'EC:2.7.7.1', 'EC:2.7.7.18', 'EC:4.1.1.50'}},
#  'reaction_124': {'kegg_id': 'R00179',
#   'description': 'S-adenosyl-L-methionine methylthioadenosine-lyase (1-aminocyclopropane-1-carboxylate-forming)',
#   'substrates': {'compound_5009', 'compound_828', 'compound_829'},
#   'products': {'compound_401540',
#    'compound_402461',
#    'compound_6370',
#    'compound_6371',
#    'compound_6372'},
#   'enzymes': {'EC:2.7.7.1', 'EC:2.7.7.18'}},
#  'reaction_125': {'kegg_id': 'R00181',
#   'vmh_id': 'AMPDA',
#   'description': 'AMP aminohydrolase',
#   'substrates': {'compound_2300',
#    'compound_404077',
#    'compound_5003',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_2702', 'compound_4158'},
#   'genes': {'AMPD1', 'AMPD2', 'AMPD3'},
#   'enzymes': {'EC:3.5.4.6', 'EC:3.6.1.25'}},
#  'reaction_126': {'kegg_id': 'R00182',
#   'vmh_id': 'AMPN',
#   'description': 'AMP phosphoribohydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'products': {'compound_4546',
#    'compound_4547',
#    'compound_5064',
#    'compound_737'}},
#  'reaction_127': {'kegg_id': 'R00184',
#   'description': "P1,P4-bis(5'-adenosyl)-tetraphosphate adenylohydrolase",
#   'substrates': {'compound_2300', 'compound_5003', 'compound_845'},
#   'products': {'compound_2460',
#    'compound_5010',
#    'compound_832',
#    'compound_833',
#    'compound_925'},
#   'genes': {'NUDT2'},
#   'enzymes': {'EC:3.6.1.17'}},
#  'reaction_128': {'kegg_id': 'R00187',
#   'vmh_id': 'HMR_9497',
#   'description': "P1,P3-bis(5'-adenosyl)-triphosphate adenylohydrolase",
#   'substrates': {'compound_2300', 'compound_3265', 'compound_5003'},
#   'products': {'compound_404077',
#    'compound_5010',
#    'compound_744',
#    'compound_832',
#    'compound_833'},
#   'genes': {'ENPP4', 'FHIT'},
#   'enzymes': {'EC:3.6.1.29'}},
#  'reaction_129': {'kegg_id': 'R00188',
#   'vmh_id': 'BPNT',
#   'description': "adenosine-3',5'-bisphosphate 3'-phosphohydrolase",
#   'substrates': {'compound_2300',
#    'compound_4253',
#    'compound_5003',
#    'compound_5033'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5010',
#    'compound_832',
#    'compound_833'},
#   'genes': {'BPNT1', 'BPNT2'},
#   'enzymes': {'EC:3.1.3.7'}},
#  'reaction_130': {'kegg_id': 'R00192',
#   'description': 'S-Adenosyl-L-homocysteine hydrolase',
#   'substrates': {'compound_2300',
#    'compound_5003',
#    'compound_5011',
#    'compound_767',
#    'compound_768'},
#   'products': {'compound_2514', 'compound_2515', 'compound_740'},
#   'genes': {'AHCY', 'AHCYL1', 'AHCYL2'},
#   'enzymes': {'EC:3.13.2.1'}},
# ...
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'},
#   'products': {'compound_401064',
#    'compound_401262',
#    'compound_401619',
#    'compound_401775',
#    'compound_402464',
#    'compound_402833',
#    'compound_404250',
#    'compound_4263',
#    'compound_4264',
#    'compound_4271',
#    'compound_4272',
#    'compound_4281',
#    'compound_5283',
#    'compound_8624',
#    'compound_8625',
#    'compound_8626',
#    'compound_8627',
#    'compound_8628',
#    'compound_8629',
#    'compound_8630',
#    'compound_8631',
#    'compound_8632',
#    'compound_8633',
#    'compound_8634',
#    'compound_8635',
#    'compound_8636',
#    'compound_8637',
#    'compound_8638',
#    'compound_8639',
#    'compound_8640',
#    'compound_871'},
#   'genes': {'CEL',
#    'JMJD7-PLA2G4B',
#    'LIPA',
#    'PLA2G10',
#    'PLA2G12A',
#    'PLA2G12B',
#    'PLA2G1B',
#    'PLA2G2A',
#    'PLA2G2C',
#    'PLA2G2D',
#    'PLA2G2E',
#    'PLA2G2F',
#    'PLA2G3',
#    'PLA2G4A',
#    'PLA2G4B',
#    'PLA2G4C',
#    'PLA2G4D',
#    'PLA2G4E',
#    'PLA2G4F',
#    'PLA2G5',
#    'PLA2G6',
#    'PLAAT2',
#    'PLAAT3',
#    'PLB1'},
#   'enzymes': {'EC:2.6.1.42',
#    'EC:2.6.1.6',
#    'EC:2.6.1.67',
#    'EC:3.1.1.13',
#    'EC:3.1.1.4'}},
#  'reaction_993': {'kegg_id': 'R01318',
#   'vmh_id': 'HMR_0632',
#   'description': 'Acyl-CoA:1-acyl-sn-glycero-3-phosphocholine O-acyltransferase',
#   'substrates': {'compound_2419',
#    'compound_2933',
#    'compound_401064',
#    'compound_401262',
#    'compound_401619',
#    'compound_401775',
#    'compound_402464',
#    'compound_402833',
#    'compound_404250',
#    'compound_4263',
#    'compound_4264',
#    'compound_4271',
#    'compound_4272',
#    'compound_4281',
#    'compound_5027',
#    'compound_8624',
#    'compound_8625',
#    'compound_8626',
#    'compound_8627',
#    'compound_8628',
#    'compound_8629',
#    'compound_8630',
#    'compound_8631',
#    'compound_8632',
#    'compound_8633',
#    'compound_8634',
#    'compound_8635',
#    'compound_8636',
#    'compound_8637',
#    'compound_8638',
#    'compound_8639',
#    'compound_8640'},
#   'products': {'compound_1656',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'},
#   'genes': {'LPCAT1', 'LPCAT2', 'LPCAT3', 'LPCAT4'},
#   'enzymes': {'EC:2.3.1.23', 'EC:2.6.1.42', 'EC:2.6.1.6', 'EC:2.6.1.67'}},
#  'reaction_994': {'kegg_id': 'R01319',
#   'description': 'Acyl-CoA:2-acyl-sn-glycero-3-phosphocholine O-acyltransferase',
#   'substrates': {'compound_404721', 'compound_5027', 'compound_8642'},
#   'products': {'compound_1656',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'}},
#  'reaction_995': {'kegg_id': 'R01320',
#   'vmh_id': 'HMR_0657',
#   'description': 'S-adenosyl-L-methionine:phosphatidyl-N-dimethylethanolamine N-methyltransferase',
#   'substrates': {'compound_3496',
#    'compound_5009',
#    'compound_828',
#    'compound_829',
#    'compound_8700',
#    'compound_997'},
#   'products': {'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5011',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219',
#    'compound_767',
#    'compound_768'},
#   'genes': {'PEMT'},
#   'enzymes': {'EC:2.1.1.71'}},
#  'reaction_996': {'kegg_id': 'R01321',
#   'description': 'CDP-choline:1,2-diacyl-sn-glycerol cholinephosphotransferase',
#   'substrates': {'compound_1085',
#    'compound_1086',
#    'compound_2429',
#    'compound_2430',
#    'compound_2431',
#    'compound_2432',
#    'compound_3035',
#    'compound_3036',
#    'compound_404609',
#    'compound_404702'},
#   'products': {'compound_1636',
#    'compound_1637',
#    'compound_402778',
#    'compound_403142',
#    'compound_404470',
#    'compound_5034',
#    'compound_5080',
#    'compound_5081',
#    'compound_5082',
#    'compound_5083',
#    'compound_5084',
#    'compound_5085',
#    'compound_5086',
#    'compound_5087',
#    'compound_5088',
#    'compound_5089',
#    'compound_5090',
#    'compound_5091',
#    'compound_5092',
#    'compound_5093',
#    'compound_5094',
#    'compound_5095',
#    'compound_5096',
#    'compound_5097',
#    'compound_5098',
#    'compound_5099',
#    'compound_5100',
#    'compound_5101',
#    'compound_5102',
#    'compound_5103',
#    'compound_5104',
#    'compound_5105',
#    'compound_5106',
#    'compound_5107',
#    'compound_5108',
#    'compound_5109',
#    'compound_5110',
#    'compound_5111',
#    'compound_5112',
#    'compound_5113',
#    'compound_5114',
#    'compound_5115',
#    'compound_5116',
#    'compound_5117',
#    'compound_5118',
#    'compound_5119',
#    'compound_5120',
#    'compound_5121',
#    'compound_5122',
#    'compound_5123',
#    'compound_5124',
#    'compound_5125',
#    'compound_5126',
#    'compound_5127',
#    'compound_5128',
#    'compound_5129',
#    'compound_5130',
#    'compound_5131',
#    'compound_5132',
#    'compound_5133',
#    'compound_5134',
#    'compound_5135',
#    'compound_5136',
#    'compound_5137',
#    'compound_5138',
#    'compound_5139',
#    'compound_5140',
#    'compound_5141',
#    'compound_5142',
#    'compound_5143',
#    'compound_5144',
#    'compound_5145',
#    'compound_5146',
#    'compound_5147',
#    'compound_5148',
#    'compound_5149',
#    'compound_5150',
#    'compound_5151',
#    'compound_5152',
#    'compound_5153',
#    'compound_5154',
#    'compound_5155',
#    'compound_5156',
#    'compound_5157',
#    'compound_5158',
#    'compound_5159',
#    'compound_5160',
#    'compound_5161',
#    'compound_5162',
#    'compound_5163',
#    'compound_5164',
#    'compound_5165',
#    'compound_5166',
#    'compound_5167',
#    'compound_5168',
#    'compound_5169',
#    'compound_5170',
#    'compound_5171',
#    'compound_5172',
#    'compound_5173',
#    'compound_5174',
#    'compound_5175',
#    'compound_5176',
#    'compound_5177',
#    'compound_5178',
#    'compound_5179',
#    'compound_5180',
#    'compound_5181',
#    'compound_5182',
#    'compound_5183',
#    'compound_5184',
#    'compound_5185',
#    'compound_5186',
#    'compound_5187',
#    'compound_5188',
#    'compound_5189',
#    'compound_5190',
#    'compound_5191',
#    'compound_5192',
#    'compound_5193',
#    'compound_5194',
#    'compound_5195',
#    'compound_5196',
#    'compound_5197',
#    'compound_5198',
#    'compound_5199',
#    'compound_5200',
#    'compound_5201',
#    'compound_5202',
#    'compound_5203',
#    'compound_5204',
#    'compound_5205',
#    'compound_5206',
#    'compound_5207',
#    'compound_5208',
#    'compound_5209',
#    'compound_5210',
#    'compound_5211',
#    'compound_5212',
#    'compound_5213',
#    'compound_5214',
#    'compound_5215',
#    'compound_5216',
#    'compound_5217',
#    'compound_5218',
#    'compound_5219'},
#   'genes': {'CEPT1', 'CHPT1'},
#   'enzymes': {'EC:2.7.8.2'}},
#  'reaction_997': {'kegg_id': 'R01322',
#   'description': 'Citrate:CoA ligase (ADP-forming)',
#   'substrates': {'compound_1656',
#    'compound_2460',
#    'compound_401317',
#    'compound_5220',
#    'compound_925'},
#   'products': {'compound_4400',
#    'compound_4401',
#    'compound_5006',
#    'compound_5691',
#    'compound_744'}},
#  'reaction_998': {'kegg_id': 'R01323',
#   'description': 'Acetyl-CoA:citrate CoA-transferase',
#   'substrates': {'compound_401317', 'compound_5220', 'compound_670'},
#   'products': {'compound_404257', 'compound_5021', 'compound_5691'},
#   'enzymes': {'EC:1.1.1.21'}},
#  'reaction_999': {'kegg_id': 'R01325',
#   'description': 'citrate hydro-lyase (cis-aconitate-forming)',
#   'substrates': {'compound_401317', 'compound_5220'},
#   'products': {'compound_2300',
#    'compound_2317',
#    'compound_2318',
#    'compound_404601',
#    'compound_5003',
#    'compound_5463'},
#   'genes': {'ACO1', 'ACO2'},
#   'enzymes': {'EC:4.2.1.3'}},
#  ...}

# %% [markdown]
# ## Add reactions to graph

# %%
def find_enzyme(ec_number):
    query = prepareQuery(
        f"""SELECT ?iri
            WHERE {{
              # ?iri <http://www.geneontology.org/formats/oboInOwl#hasDbXref> '{ec_number}' .
              FILTER(isIRI(?iri))
            }}
        """,
    )
    
    result = onto_graph.query(query)
    return list(result)

# %%
ec_test = list(reactions_dict['reaction_23']['enzymes'])[0]

# %%
results = find_enzyme(ec_test)

# %%
for term in results:
    print(term[0])
# Out:
# http://purl.obolibrary.org/obo/GO_0003834

# %%
mapped = set()
not_mapped = set()

for reaction_name, reaction in reactions_dict.items():
    if 'enzymes' in reaction:
        enzymes = reaction['enzymes']
        for enzyme in enzymes:
            results = find_enzyme(enzyme)
            if results:
                mapped.add(enzyme)
            else:
                not_mapped.add(enzyme)

# %%
len(mapped)
# Out:
# 1735

# %%
len(not_mapped)
# Out:
# 245

# %%
def add_triple_property(subject, predicate, object, prefix=''):
    if pd.notna(object):
        if prefix:
            object = prefix + object
        onto_graph.add((subject, predicate, Literal(object)))
        
def class_exists(iri):
    # SPARQL query to check if the IRI exists in the graph
    query = prepareQuery(
        """ASK
           WHERE {
              VALUES ?iri_to_check { <""" + str(iri) + """> }
              # ?iri_to_check ?p ?o .
           }""",
    )
    
    exists = onto_graph.query(query)
    return exists
        
def add_reactant(subject, predicate, object_uri):
    if pd.notna(object_uri):
        iri_to_check = URIRef(object_uri)
        
        if class_exists(iri_to_check):
            onto_graph.add((subject, predicate, iri_to_check))

# %%
def add_reaction_content_to_graph(reaction_name, reaction_entry):
    reaction = URIRef(MeNuGUIDE[reaction_name])
    
    onto_graph.add((reaction, RDF.type, MeNuGUIDE.Reaction))
    
    # TODO: make it reaction abbreviation?
    onto_graph.add((reaction, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(reaction_name)))
    
    # Description - http://purl.obolibrary.org/obo/IAO_0000115 (used in ChEBI ontology)
    if 'description' in reaction_entry:
        add_triple_property(reaction, OBO.IAO_0000115, reaction_entry['description'])
    
    # KEGG - http://www.geneontology.org/formats/oboInOwl#hasDbXref 
    if 'kegg_id' in reaction_entry:
        add_triple_property(reaction, GO.hasDbXref, reaction_entry['kegg_id'], 'KEGG:')
        
    # VMH - http://www.geneontology.org/formats/oboInOwl#hasDbXref 
    if 'vmh_id' in reaction_entry:
        if type(reaction_entry['vmh_id']) == list:
            for vmh_identifier in reaction_entry['vmh_id']:
                 add_triple_property(reaction, GO.hasDbXref, vmh_identifier, 'VMH:')
        else:
            add_triple_property(reaction, GO.hasDbXref, reaction_entry['vmh_id'], 'VMH:')
    
    # input of - http://purl.obolibrary.org/obo/RO_0002352
    # has input - http://purl.obolibrary.org/obo/RO_0002233
    if 'substrates' in reaction_entry: 
        for substrate in reaction_entry['substrates']:
            add_reactant(MeNuGUIDE[substrate], OBO.RO_0002352, reaction)
            add_reactant(reaction, OBO.RO_0002233, MeNuGUIDE[substrate])
    
    # output of - http://purl.obolibrary.org/obo/RO_0002353
    # has output - http://purl.obolibrary.org/obo/RO_0002234
    if 'products' in reaction_entry:
        for product in reaction_entry['products']:
            add_reactant(MeNuGUIDE[product], OBO.RO_0002353, reaction)
            add_reactant(reaction, OBO.RO_0002234, MeNuGUIDE[product])
    
    # has function - http://purl.obolibrary.org/obo/RO_0000085
    # participates in - http://purl.obolibrary.org/obo/RO_0000056
    # has participant - http://purl.obolibrary.org/obo/RO_0000057
    if 'enzymes' in reaction_entry:
        for enzyme in reaction_entry['enzymes']:
            enzyme_uri = URIRef(MeNuGUIDE[enzyme])
            onto_graph.add((enzyme_uri, RDF.type, MeNuGUIDE.Enzyme))
            onto_graph.add((enzyme_uri, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(enzyme)))
            
            onto_graph.add((reaction, OBO.RO_0000057, enzyme_uri))
            onto_graph.add((enzyme_uri, OBO.RO_0000056, reaction))
            
            go_terms_found = find_enzyme(ec_test)
            if go_terms_found:
                for term in go_terms_found:
                    onto_graph.add((enzyme_uri, OBO.RO_0000085, term[0]))
    
    # involved in - http://purl.obolibrary.org/obo/RO_0002331
    if 'genes' in reaction_entry:
        for gene in reaction_entry['genes']:
            gene_uri = URIRef(MeNuGUIDE[gene])
            onto_graph.add((gene_uri, RDF.type, MeNuGUIDE.Gene))
            onto_graph.add((gene_uri, URIRef("http://www.w3.org/2000/01/rdf-schema#label"), Literal(gene)))
            
            onto_graph.add((gene_uri, OBO.RO_0002331, reaction))

# %%
for reaction_id, reaction_entry in reactions_dict.items():
    print(reaction_id)
    print(reaction_entry)
    if reaction_id == "reaction_15":
        break
# Out:
# reaction_0
# {'kegg_id': 'R00001', 'description': 'polyphosphate polyphosphohydrolase', 'substrates': {'compound_5449', 'compound_2300', 'compound_5003'}, 'products': {'compound_7069', 'compound_4433'}}
# reaction_1
# {'kegg_id': 'R00002', 'description': 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)', 'substrates': {'compound_2300', 'compound_925', 'compound_2019', 'compound_3505', 'compound_2460', 'compound_5003'}, 'products': {'compound_744', 'compound_4401', 'compound_9361', 'compound_3473', 'compound_4400', 'compound_5006', 'compound_2018'}}
# reaction_2
# {'kegg_id': 'R00005', 'description': 'urea-1-carboxylate amidohydrolase', 'substrates': {'compound_2300', 'compound_6210', 'compound_808', 'compound_6211', 'compound_5003'}, 'products': {'compound_4158', 'compound_1654'}, 'enzymes': {'EC:3.6.1.1'}}
# reaction_3
# {'kegg_id': 'R00006', 'description': 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)', 'substrates': {'compound_1654', 'compound_6130'}, 'products': {'compound_5012', 'compound_4529'}, 'enzymes': {'EC:3.6.1.1'}}
# reaction_4
# {'kegg_id': 'R00008', 'description': '4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)', 'substrates': {'compound_9790', 'compound_9791'}, 'products': {'compound_5012', 'compound_4529'}, 'enzymes': {'EC:3.6.1.1'}}
# reaction_5
# {'kegg_id': 'R00010', 'description': 'alpha,alpha-trehalose glucohydrolase', 'substrates': {'compound_4834', 'compound_2300', 'compound_5003', 'compound_4833'}, 'products': {'compound_2166', 'compound_5019'}, 'genes': {'TREH'}, 'enzymes': {'EC:3.6.1.1', 'EC:3.2.1.28'}}
# reaction_6
# {'kegg_id': 'R00011', 'description': 'Mn(II):hydrogen-peroxide oxidoreductase', 'substrates': {'compound_403943', 'compound_21891', 'compound_404077', 'compound_400782'}, 'products': {'compound_21892', 'compound_2300', 'compound_5003'}, 'enzymes': {'EC:3.6.1.1'}}
# reaction_7
# {'kegg_id': 'R00012', 'description': 'GTP:GTP guanylyltransferase', 'substrates': {'compound_2285', 'compound_2286'}, 'products': {'compound_4426', 'compound_403470', 'compound_4425'}}
# reaction_8
# {'kegg_id': 'R00013', 'description': 'glyoxylate carboxy-lyase (dimerizing; tartronate-semialdehyde-forming)', 'substrates': {'compound_5030', 'compound_400367'}, 'products': {'compound_1654', 'compound_3124', 'compound_201', 'compound_6313'}}
# reaction_9
# {'kegg_id': 'R00014', 'vmh_id': 'HMR_8746', 'description': 'pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)', 'substrates': {'compound_5012', 'compound_404077', 'compound_4529', 'compound_4784'}, 'products': {'compound_3106', 'compound_1654', 'compound_3107'}, 'genes': {'PDHA1', 'PDHA2', 'PDHB'}, 'enzymes': {'EC:1.2.4.1'}}
# reaction_10
# {'kegg_id': 'R00015', 'description': "sucrose:sucrose 1'-beta-D-fructosyltransferase", 'substrates': {'compound_4705'}, 'products': {'compound_400958', 'compound_2166', 'compound_8203', 'compound_5019'}, 'enzymes': {'EC:1.11.1.21', 'EC:1.11.1.6'}}
# reaction_11
# {'kegg_id': 'R00017', 'description': 'ferrocytochrome-c:hydrogen-peroxide oxidoreductase', 'substrates': {'compound_2028', 'compound_403943'}, 'products': {'compound_2023', 'compound_2300', 'compound_5003'}, 'enzymes': {'EC:1.11.1.21', 'EC:1.11.1.6'}}
# reaction_12
# {'kegg_id': 'R00018', 'description': 'putrescine:putrescine 4-aminobutyltransferase (ammonia-forming)', 'substrates': {'compound_4511'}, 'products': {'compound_10096', 'compound_4158'}, 'enzymes': {'EC:1.11.1.6'}}
# reaction_13
# {'kegg_id': 'R00019', 'description': 'hydrogen:ferredoxin oxidoreductase', 'substrates': {'compound_2019', 'compound_3505', 'compound_404077', 'compound_400782'}, 'products': {'compound_3473', 'compound_2298', 'compound_2018'}}
# reaction_14
# {'kegg_id': 'R00021', 'description': 'L-glutamate:ferredoxin oxidoreductase (transaminating)', 'substrates': {'compound_3473', 'compound_2018', 'compound_2196'}, 'products': {'compound_2180', 'compound_5014', 'compound_400782', 'compound_404077', 'compound_2019', 'compound_2181', 'compound_3505', 'compound_403968'}}
# reaction_15
# {'kegg_id': 'R00022', 'description': 'chitobiose N-acetylglucosaminohydrolase', 'substrates': {'compound_2330', 'compound_2300', 'compound_5003', 'compound_6663'}, 'products': {'compound_687', 'compound_688'}, 'genes': {'HEXB', 'HEXA', 'HEXD'}, 'enzymes': {'EC:3.2.1.52'}}

# %%
for reaction_id, reaction_entry in reactions_dict.items():
    print(reaction_id)
    add_reaction_content_to_graph(reaction_id, reaction_entry)
# Out:
# reaction_0
# reaction_1
# reaction_2
# reaction_3
# reaction_4
# reaction_5
# reaction_6
# reaction_7
# reaction_8
# reaction_9
# reaction_10
# reaction_11
# reaction_12
# reaction_13
# reaction_14
# reaction_15
# reaction_16
# reaction_17
# reaction_18
# reaction_19
# reaction_20
# reaction_21
# reaction_22
# reaction_23
# reaction_24
# reaction_25
# reaction_26
# reaction_27
# reaction_28
# reaction_29
# reaction_30
# reaction_31
# reaction_32
# reaction_33
# reaction_34
# reaction_35
# reaction_36
# reaction_37
# reaction_38
# reaction_39
# reaction_40
# reaction_41
# reaction_42
# reaction_43
# reaction_44
# reaction_45
# reaction_46
# reaction_47
# reaction_48
# reaction_49
# reaction_50
# reaction_51
# reaction_52
# reaction_53
# reaction_54
# reaction_55
# reaction_56
# reaction_57
# reaction_58
# reaction_59
# reaction_60
# reaction_61
# reaction_62
# reaction_63
# reaction_64
# reaction_65
# reaction_66
# reaction_67
# reaction_68
# reaction_69
# reaction_70
# reaction_71
# reaction_72
# reaction_73
# reaction_74
# reaction_75
# reaction_76
# reaction_77
# reaction_78
# reaction_79
# reaction_80
# reaction_81
# reaction_82
# reaction_83
# reaction_84
# reaction_85
# reaction_86
# reaction_87
# reaction_88
# reaction_89
# reaction_90
# reaction_91
# reaction_92
# reaction_93
# reaction_94
# reaction_95
# reaction_96
# reaction_97
# reaction_98
# reaction_99
# reaction_100
# reaction_101
# reaction_102
# reaction_103
# reaction_104
# reaction_105
# reaction_106
# reaction_107
# reaction_108
# reaction_109
# reaction_110
# reaction_111
# reaction_112
# reaction_113
# reaction_114
# reaction_115
# reaction_116
# reaction_117
# reaction_118
# reaction_119
# reaction_120
# reaction_121
# reaction_122
# reaction_123
# reaction_124
# reaction_125
# reaction_126
# reaction_127
# reaction_128
# reaction_129
# reaction_130
# reaction_131
# reaction_132
# reaction_133
# reaction_134
# reaction_135
# reaction_136
# reaction_137
# reaction_138
# reaction_139
# reaction_140
# reaction_141
# reaction_142
# reaction_143
# reaction_144
# reaction_145
# reaction_146
# reaction_147
# reaction_148
# reaction_149
# reaction_150
# reaction_151
# reaction_152
# reaction_153
# reaction_154
# reaction_155
# reaction_156
# reaction_157
# reaction_158
# reaction_159
# reaction_160
# reaction_161
# reaction_162
# reaction_163
# reaction_164
# reaction_165
# reaction_166
# reaction_167
# reaction_168
# reaction_169
# reaction_170
# reaction_171
# reaction_172
# reaction_173
# reaction_174
# reaction_175
# reaction_176
# reaction_177
# reaction_178
# reaction_179
# reaction_180
# reaction_181
# reaction_182
# reaction_183
# reaction_184
# reaction_185
# reaction_186
# reaction_187
# reaction_188
# reaction_189
# reaction_190
# reaction_191
# reaction_192
# reaction_193
# reaction_194
# reaction_195
# reaction_196
# reaction_197
# reaction_198
# reaction_199
# reaction_200
# reaction_201
# reaction_202
# reaction_203
# reaction_204
# reaction_205
# reaction_206
# reaction_207
# reaction_208
# reaction_209
# reaction_210
# reaction_211
# reaction_212
# reaction_213
# reaction_214
# reaction_215
# reaction_216
# reaction_217
# reaction_218
# reaction_219
# reaction_220
# reaction_221
# reaction_222
# reaction_223
# reaction_224
# reaction_225
# reaction_226
# reaction_227
# reaction_228
# reaction_229
# reaction_230
# reaction_231
# reaction_232
# reaction_233
# reaction_234
# reaction_235
# reaction_236
# reaction_237
# reaction_238
# reaction_239
# reaction_240
# reaction_241
# reaction_242
# reaction_243
# reaction_244
# reaction_245
# reaction_246
# reaction_247
# reaction_248
# reaction_249
# reaction_250
# reaction_251
# reaction_252
# reaction_253
# reaction_254
# reaction_255
# reaction_256
# reaction_257
# reaction_258
# reaction_259
# reaction_260
# reaction_261
# reaction_262
# reaction_263
# reaction_264
# reaction_265
# reaction_266
# reaction_267
# reaction_268
# reaction_269
# reaction_270
# reaction_271
# reaction_272
# reaction_273
# reaction_274
# reaction_275
# reaction_276
# reaction_277
# reaction_278
# reaction_279
# reaction_280
# reaction_281
# reaction_282
# reaction_283
# reaction_284
# reaction_285
# reaction_286
# reaction_287
# reaction_288
# reaction_289
# reaction_290
# reaction_291
# reaction_292
# reaction_293
# reaction_294
# reaction_295
# reaction_296
# reaction_297
# reaction_298
# reaction_299
# reaction_300
# reaction_301
# reaction_302
# reaction_303
# reaction_304
# reaction_305
# reaction_306
# reaction_307
# reaction_308
# reaction_309
# reaction_310
# reaction_311
# reaction_312
# reaction_313
# reaction_314
# reaction_315
# reaction_316
# reaction_317
# reaction_318
# reaction_319
# reaction_320
# reaction_321
# reaction_322
# reaction_323
# reaction_324
# reaction_325
# reaction_326
# reaction_327
# reaction_328
# reaction_329
# reaction_330
# reaction_331
# reaction_332
# reaction_333
# reaction_334
# reaction_335
# reaction_336
# reaction_337
# reaction_338
# reaction_339
# reaction_340
# reaction_341
# reaction_342
# reaction_343
# reaction_344
# reaction_345
# reaction_346
# reaction_347
# reaction_348
# reaction_349
# reaction_350
# reaction_351
# reaction_352
# reaction_353
# reaction_354
# reaction_355
# reaction_356
# reaction_357
# reaction_358
# reaction_359
# reaction_360
# reaction_361
# reaction_362
# reaction_363
# reaction_364
# reaction_365
# reaction_366
# reaction_367
# reaction_368
# reaction_369
# reaction_370
# reaction_371
# reaction_372
# reaction_373
# reaction_374
# reaction_375
# reaction_376
# reaction_377
# reaction_378
# reaction_379
# reaction_380
# reaction_381
# reaction_382
# reaction_383
# reaction_384
# reaction_385
# reaction_386
# reaction_387
# reaction_388
# reaction_389
# reaction_390
# reaction_391
# reaction_392
# reaction_393
# reaction_394
# reaction_395
# reaction_396
# reaction_397
# reaction_398
# reaction_399
# reaction_400
# reaction_401
# reaction_402
# reaction_403
# reaction_404
# reaction_405
# reaction_406
# reaction_407
# reaction_408
# reaction_409
# reaction_410
# reaction_411
# reaction_412
# reaction_413
# reaction_414
# reaction_415
# reaction_416
# reaction_417
# reaction_418
# reaction_419
# reaction_420
# reaction_421
# reaction_422
# reaction_423
# reaction_424
# reaction_425
# reaction_426
# reaction_427
# reaction_428
# reaction_429
# reaction_430
# reaction_431
# reaction_432
# reaction_433
# reaction_434
# reaction_435
# reaction_436
# reaction_437
# reaction_438
# reaction_439
# reaction_440
# reaction_441
# reaction_442
# reaction_443
# reaction_444
# reaction_445
# reaction_446
# reaction_447
# reaction_448
# reaction_449
# reaction_450
# reaction_451
# reaction_452
# reaction_453
# reaction_454
# reaction_455
# reaction_456
# reaction_457
# reaction_458
# reaction_459
# reaction_460
# reaction_461
# reaction_462
# reaction_463
# reaction_464
# reaction_465
# reaction_466
# reaction_467
# reaction_468
# reaction_469
# reaction_470
# reaction_471
# reaction_472
# reaction_473
# reaction_474
# reaction_475
# reaction_476
# reaction_477
# reaction_478
# reaction_479
# reaction_480
# reaction_481
# reaction_482
# reaction_483
# reaction_484
# reaction_485
# reaction_486
# reaction_487
# reaction_488
# reaction_489
# reaction_490
# reaction_491
# reaction_492
# reaction_493
# reaction_494
# reaction_495
# reaction_496
# reaction_497
# reaction_498
# reaction_499
# reaction_500
# reaction_501
# reaction_502
# reaction_503
# reaction_504
# reaction_505
# reaction_506
# reaction_507
# reaction_508
# reaction_509
# reaction_510
# reaction_511
# reaction_512
# reaction_513
# reaction_514
# reaction_515
# reaction_516
# reaction_517
# reaction_518
# reaction_519
# reaction_520
# reaction_521
# reaction_522
# reaction_523
# reaction_524
# reaction_525
# reaction_526
# reaction_527
# reaction_528
# reaction_529
# reaction_530
# reaction_531
# reaction_532
# reaction_533
# reaction_534
# reaction_535
# reaction_536
# reaction_537
# reaction_538
# reaction_539
# reaction_540
# reaction_541
# reaction_542
# reaction_543
# reaction_544
# reaction_545
# reaction_546
# reaction_547
# reaction_548
# reaction_549
# reaction_550
# reaction_551
# reaction_552
# reaction_553
# reaction_554
# reaction_555
# reaction_556
# reaction_557
# reaction_558
# reaction_559
# reaction_560
# reaction_561
# reaction_562
# reaction_563
# reaction_564
# reaction_565
# reaction_566
# reaction_567
# reaction_568
# reaction_569
# reaction_570
# reaction_571
# reaction_572
# reaction_573
# reaction_574
# reaction_575
# reaction_576
# reaction_577
# reaction_578
# reaction_579
# reaction_580
# reaction_581
# reaction_582
# reaction_583
# reaction_584
# reaction_585
# reaction_586
# reaction_587
# reaction_588
# reaction_589
# reaction_590
# reaction_591
# reaction_592
# reaction_593
# reaction_594
# reaction_595
# reaction_596
# reaction_597
# reaction_598
# reaction_599
# reaction_600
# reaction_601
# reaction_602
# reaction_603
# reaction_604
# reaction_605
# reaction_606
# reaction_607
# reaction_608
# reaction_609
# reaction_610
# reaction_611
# reaction_612
# reaction_613
# reaction_614
# reaction_615
# reaction_616
# reaction_617
# reaction_618
# reaction_619
# reaction_620
# reaction_621
# reaction_622
# reaction_623
# reaction_624
# reaction_625
# reaction_626
# reaction_627
# reaction_628
# reaction_629
# reaction_630
# reaction_631
# reaction_632
# reaction_633
# reaction_634
# reaction_635
# reaction_636
# reaction_637
# reaction_638
# reaction_639
# reaction_640
# reaction_641
# reaction_642
# reaction_643
# reaction_644
# reaction_645
# reaction_646
# reaction_647
# reaction_648
# reaction_649
# reaction_650
# reaction_651
# reaction_652
# reaction_653
# reaction_654
# reaction_655
# reaction_656
# reaction_657
# reaction_658
# reaction_659
# reaction_660
# reaction_661
# reaction_662
# reaction_663
# reaction_664
# reaction_665
# reaction_666
# reaction_667
# reaction_668
# reaction_669
# reaction_670
# reaction_671
# reaction_672
# reaction_673
# reaction_674
# reaction_675
# reaction_676
# reaction_677
# reaction_678
# reaction_679
# reaction_680
# reaction_681
# reaction_682
# reaction_683
# reaction_684
# reaction_685
# reaction_686
# reaction_687
# reaction_688
# reaction_689
# reaction_690
# reaction_691
# reaction_692
# reaction_693
# reaction_694
# reaction_695
# reaction_696
# reaction_697
# reaction_698
# reaction_699
# reaction_700
# reaction_701
# reaction_702
# reaction_703
# reaction_704
# reaction_705
# reaction_706
# reaction_707
# reaction_708
# reaction_709
# reaction_710
# reaction_711
# reaction_712
# reaction_713
# reaction_714
# reaction_715
# reaction_716
# reaction_717
# reaction_718
# reaction_719
# reaction_720
# reaction_721
# reaction_722
# reaction_723
# reaction_724
# reaction_725
# reaction_726
# reaction_727
# reaction_728
# reaction_729
# reaction_730
# reaction_731
# reaction_732
# reaction_733
# reaction_734
# reaction_735
# reaction_736
# reaction_737
# reaction_738
# reaction_739
# reaction_740
# reaction_741
# reaction_742
# reaction_743
# reaction_744
# reaction_745
# reaction_746
# reaction_747
# reaction_748
# reaction_749
# reaction_750
# reaction_751
# reaction_752
# reaction_753
# reaction_754
# reaction_755
# reaction_756
# reaction_757
# reaction_758
# reaction_759
# reaction_760
# reaction_761
# reaction_762
# reaction_763
# reaction_764
# reaction_765
# reaction_766
# reaction_767
# reaction_768
# reaction_769
# reaction_770
# reaction_771
# reaction_772
# reaction_773
# reaction_774
# reaction_775
# reaction_776
# reaction_777
# reaction_778
# reaction_779
# reaction_780
# reaction_781
# reaction_782
# reaction_783
# reaction_784
# reaction_785
# reaction_786
# reaction_787
# reaction_788
# reaction_789
# reaction_790
# reaction_791
# reaction_792
# reaction_793
# reaction_794
# reaction_795
# reaction_796
# reaction_797
# reaction_798
# reaction_799
# reaction_800
# reaction_801
# reaction_802
# reaction_803
# reaction_804
# reaction_805
# reaction_806
# reaction_807
# reaction_808
# reaction_809
# reaction_810
# reaction_811
# reaction_812
# reaction_813
# reaction_814
# reaction_815
# reaction_816
# reaction_817
# reaction_818
# reaction_819
# reaction_820
# reaction_821
# reaction_822
# reaction_823
# reaction_824
# reaction_825
# reaction_826
# reaction_827
# reaction_828
# reaction_829
# reaction_830
# reaction_831
# reaction_832
# reaction_833
# reaction_834
# reaction_835
# reaction_836
# reaction_837
# reaction_838
# reaction_839
# reaction_840
# reaction_841
# reaction_842
# reaction_843
# reaction_844
# reaction_845
# reaction_846
# reaction_847
# reaction_848
# reaction_849
# reaction_850
# reaction_851
# reaction_852
# reaction_853
# reaction_854
# reaction_855
# reaction_856
# reaction_857
# reaction_858
# reaction_859
# reaction_860
# reaction_861
# reaction_862
# reaction_863
# reaction_864
# reaction_865
# reaction_866
# reaction_867
# reaction_868
# reaction_869
# reaction_870
# reaction_871
# reaction_872
# reaction_873
# reaction_874
# reaction_875
# reaction_876
# reaction_877
# reaction_878
# reaction_879
# reaction_880
# reaction_881
# reaction_882
# reaction_883
# reaction_884
# reaction_885
# reaction_886
# reaction_887
# reaction_888
# reaction_889
# reaction_890
# reaction_891
# reaction_892
# reaction_893
# reaction_894
# reaction_895
# reaction_896
# reaction_897
# reaction_898
# reaction_899
# reaction_900
# reaction_901
# reaction_902
# reaction_903
# reaction_904
# reaction_905
# reaction_906
# reaction_907
# reaction_908
# reaction_909
# reaction_910
# reaction_911
# reaction_912
# reaction_913
# reaction_914
# reaction_915
# reaction_916
# reaction_917
# reaction_918
# reaction_919
# reaction_920
# reaction_921
# reaction_922
# reaction_923
# reaction_924
# reaction_925
# reaction_926
# reaction_927
# reaction_928
# reaction_929
# reaction_930
# reaction_931
# reaction_932
# reaction_933
# reaction_934
# reaction_935
# reaction_936
# reaction_937
# reaction_938
# reaction_939
# reaction_940
# reaction_941
# reaction_942
# reaction_943
# reaction_944
# reaction_945
# reaction_946
# reaction_947
# reaction_948
# reaction_949
# reaction_950
# reaction_951
# reaction_952
# reaction_953
# reaction_954
# reaction_955
# reaction_956
# reaction_957
# reaction_958
# reaction_959
# reaction_960
# reaction_961
# reaction_962
# reaction_963
# reaction_964
# reaction_965
# reaction_966
# reaction_967
# reaction_968
# reaction_969
# reaction_970
# reaction_971
# reaction_972
# reaction_973
# reaction_974
# reaction_975
# reaction_976
# reaction_977
# reaction_978
# reaction_979
# reaction_980
# reaction_981
# reaction_982
# reaction_983
# reaction_984
# reaction_985
# reaction_986
# reaction_987
# reaction_988
# reaction_989
# reaction_990
# reaction_991
# reaction_992
# reaction_993
# reaction_994
# reaction_995
# reaction_996
# reaction_997
# reaction_998
# reaction_999
# reaction_1000
# reaction_1001
# reaction_1002
# reaction_1003
# reaction_1004
# reaction_1005
# reaction_1006
# reaction_1007
# reaction_1008
# reaction_1009
# reaction_1010
# reaction_1011
# reaction_1012
# reaction_1013
# reaction_1014
# reaction_1015
# reaction_1016
# reaction_1017
# reaction_1018
# reaction_1019
# reaction_1020
# reaction_1021
# reaction_1022
# reaction_1023
# reaction_1024
# reaction_1025
# reaction_1026
# reaction_1027
# reaction_1028
# reaction_1029
# reaction_1030
# reaction_1031
# reaction_1032
# reaction_1033
# reaction_1034
# reaction_1035
# reaction_1036
# reaction_1037
# reaction_1038
# reaction_1039
# reaction_1040
# reaction_1041
# reaction_1042
# reaction_1043
# reaction_1044
# reaction_1045
# reaction_1046
# reaction_1047
# reaction_1048
# reaction_1049
# reaction_1050
# reaction_1051
# reaction_1052
# reaction_1053
# reaction_1054
# reaction_1055
# reaction_1056
# reaction_1057
# reaction_1058
# reaction_1059
# reaction_1060
# reaction_1061
# reaction_1062
# reaction_1063
# reaction_1064
# reaction_1065
# reaction_1066
# reaction_1067
# reaction_1068
# reaction_1069
# reaction_1070
# reaction_1071
# reaction_1072
# reaction_1073
# reaction_1074
# reaction_1075
# reaction_1076
# reaction_1077
# reaction_1078
# reaction_1079
# reaction_1080
# reaction_1081
# reaction_1082
# reaction_1083
# reaction_1084
# reaction_1085
# reaction_1086
# reaction_1087
# reaction_1088
# reaction_1089
# reaction_1090
# reaction_1091
# reaction_1092
# reaction_1093
# reaction_1094
# reaction_1095
# reaction_1096
# reaction_1097
# reaction_1098
# reaction_1099
# reaction_1100
# reaction_1101
# reaction_1102
# reaction_1103
# reaction_1104
# reaction_1105
# reaction_1106
# reaction_1107
# reaction_1108
# reaction_1109
# reaction_1110
# reaction_1111
# reaction_1112
# reaction_1113
# reaction_1114
# reaction_1115
# reaction_1116
# reaction_1117
# reaction_1118
# reaction_1119
# reaction_1120
# reaction_1121
# reaction_1122
# reaction_1123
# reaction_1124
# reaction_1125
# reaction_1126
# reaction_1127
# reaction_1128
# reaction_1129
# reaction_1130
# reaction_1131
# reaction_1132
# reaction_1133
# reaction_1134
# reaction_1135
# reaction_1136
# reaction_1137
# reaction_1138
# reaction_1139
# reaction_1140
# reaction_1141
# reaction_1142
# reaction_1143
# reaction_1144
# reaction_1145
# reaction_1146
# reaction_1147
# reaction_1148
# reaction_1149
# reaction_1150
# reaction_1151
# reaction_1152
# reaction_1153
# reaction_1154
# reaction_1155
# reaction_1156
# reaction_1157
# reaction_1158
# reaction_1159
# reaction_1160
# reaction_1161
# reaction_1162
# reaction_1163
# reaction_1164
# reaction_1165
# reaction_1166
# reaction_1167
# reaction_1168
# reaction_1169
# reaction_1170
# reaction_1171
# reaction_1172
# reaction_1173
# reaction_1174
# reaction_1175
# reaction_1176
# reaction_1177
# reaction_1178
# reaction_1179
# reaction_1180
# reaction_1181
# reaction_1182
# reaction_1183
# reaction_1184
# reaction_1185
# reaction_1186
# reaction_1187
# reaction_1188
# reaction_1189
# reaction_1190
# reaction_1191
# reaction_1192
# reaction_1193
# reaction_1194
# reaction_1195
# reaction_1196
# reaction_1197
# reaction_1198
# reaction_1199
# reaction_1200
# reaction_1201
# reaction_1202
# reaction_1203
# reaction_1204
# reaction_1205
# reaction_1206
# reaction_1207
# reaction_1208
# reaction_1209
# reaction_1210
# reaction_1211
# reaction_1212
# reaction_1213
# reaction_1214
# reaction_1215
# reaction_1216
# reaction_1217
# reaction_1218
# reaction_1219
# reaction_1220
# reaction_1221
# reaction_1222
# reaction_1223
# reaction_1224
# reaction_1225
# reaction_1226
# reaction_1227
# reaction_1228
# reaction_1229
# reaction_1230
# reaction_1231
# reaction_1232
# reaction_1233
# reaction_1234
# reaction_1235
# reaction_1236
# reaction_1237
# reaction_1238
# reaction_1239
# reaction_1240
# reaction_1241
# reaction_1242
# reaction_1243
# reaction_1244
# reaction_1245
# reaction_1246
# reaction_1247
# reaction_1248
# reaction_1249
# reaction_1250
# reaction_1251
# reaction_1252
# reaction_1253
# reaction_1254
# reaction_1255
# reaction_1256
# reaction_1257
# reaction_1258
# reaction_1259
# reaction_1260
# reaction_1261
# reaction_1262
# reaction_1263
# reaction_1264
# reaction_1265
# reaction_1266
# reaction_1267
# reaction_1268
# reaction_1269
# reaction_1270
# reaction_1271
# reaction_1272
# reaction_1273
# reaction_1274
# reaction_1275
# reaction_1276
# reaction_1277
# reaction_1278
# reaction_1279
# reaction_1280
# reaction_1281
# reaction_1282
# reaction_1283
# reaction_1284
# reaction_1285
# reaction_1286
# reaction_1287
# reaction_1288
# reaction_1289
# reaction_1290
# reaction_1291
# reaction_1292
# reaction_1293
# reaction_1294
# reaction_1295
# reaction_1296
# reaction_1297
# reaction_1298
# reaction_1299
# reaction_1300
# reaction_1301
# reaction_1302
# reaction_1303
# reaction_1304
# reaction_1305
# reaction_1306
# reaction_1307
# reaction_1308
# reaction_1309
# reaction_1310
# reaction_1311
# reaction_1312
# reaction_1313
# reaction_1314
# reaction_1315
# reaction_1316
# reaction_1317
# reaction_1318
# reaction_1319
# reaction_1320
# reaction_1321
# reaction_1322
# reaction_1323
# reaction_1324
# reaction_1325
# reaction_1326
# reaction_1327
# reaction_1328
# reaction_1329
# reaction_1330
# reaction_1331
# reaction_1332
# reaction_1333
# reaction_1334
# reaction_1335
# reaction_1336
# reaction_1337
# reaction_1338
# reaction_1339
# reaction_1340
# reaction_1341
# reaction_1342
# reaction_1343
# reaction_1344
# reaction_1345
# reaction_1346
# reaction_1347
# reaction_1348
# reaction_1349
# reaction_1350
# reaction_1351
# reaction_1352
# reaction_1353
# reaction_1354
# reaction_1355
# reaction_1356
# reaction_1357
# reaction_1358
# reaction_1359
# reaction_1360
# reaction_1361
# reaction_1362
# reaction_1363
# reaction_1364
# reaction_1365
# reaction_1366
# reaction_1367
# reaction_1368
# reaction_1369
# reaction_1370
# reaction_1371
# reaction_1372
# reaction_1373
# reaction_1374
# reaction_1375
# reaction_1376
# reaction_1377
# reaction_1378
# reaction_1379
# reaction_1380
# reaction_1381
# reaction_1382
# reaction_1383
# reaction_1384
# reaction_1385
# reaction_1386
# reaction_1387
# reaction_1388
# reaction_1389
# reaction_1390
# reaction_1391
# reaction_1392
# reaction_1393
# reaction_1394
# reaction_1395
# reaction_1396
# reaction_1397
# reaction_1398
# reaction_1399
# reaction_1400
# reaction_1401
# reaction_1402
# reaction_1403
# reaction_1404
# reaction_1405
# reaction_1406
# reaction_1407
# reaction_1408
# reaction_1409
# reaction_1410
# reaction_1411
# reaction_1412
# reaction_1413
# reaction_1414
# reaction_1415
# reaction_1416
# reaction_1417
# reaction_1418
# reaction_1419
# reaction_1420
# reaction_1421
# reaction_1422
# reaction_1423
# reaction_1424
# reaction_1425
# reaction_1426
# reaction_1427
# reaction_1428
# reaction_1429
# reaction_1430
# reaction_1431
# reaction_1432
# reaction_1433
# reaction_1434
# reaction_1435
# reaction_1436
# reaction_1437
# reaction_1438
# reaction_1439
# reaction_1440
# reaction_1441
# reaction_1442
# reaction_1443
# reaction_1444
# reaction_1445
# reaction_1446
# reaction_1447
# reaction_1448
# reaction_1449
# reaction_1450
# reaction_1451
# reaction_1452
# reaction_1453
# reaction_1454
# reaction_1455
# reaction_1456
# reaction_1457
# reaction_1458
# reaction_1459
# reaction_1460
# reaction_1461
# reaction_1462
# reaction_1463
# reaction_1464
# reaction_1465
# reaction_1466
# reaction_1467
# reaction_1468
# reaction_1469
# reaction_1470
# reaction_1471
# reaction_1472
# reaction_1473
# reaction_1474
# reaction_1475
# reaction_1476
# reaction_1477
# reaction_1478
# reaction_1479
# reaction_1480
# reaction_1481
# reaction_1482
# reaction_1483
# reaction_1484
# reaction_1485
# reaction_1486
# reaction_1487
# reaction_1488
# reaction_1489
# reaction_1490
# reaction_1491
# reaction_1492
# reaction_1493
# reaction_1494
# reaction_1495
# reaction_1496
# reaction_1497
# reaction_1498
# reaction_1499
# reaction_1500
# reaction_1501
# reaction_1502
# reaction_1503
# reaction_1504
# reaction_1505
# reaction_1506
# reaction_1507
# reaction_1508
# reaction_1509
# reaction_1510
# reaction_1511
# reaction_1512
# reaction_1513
# reaction_1514
# reaction_1515
# reaction_1516
# reaction_1517
# reaction_1518
# reaction_1519
# reaction_1520
# reaction_1521
# reaction_1522
# reaction_1523
# reaction_1524
# reaction_1525
# reaction_1526
# reaction_1527
# reaction_1528
# reaction_1529
# reaction_1530
# reaction_1531
# reaction_1532
# reaction_1533
# reaction_1534
# reaction_1535
# reaction_1536
# reaction_1537
# reaction_1538
# reaction_1539
# reaction_1540
# reaction_1541
# reaction_1542
# reaction_1543
# reaction_1544
# reaction_1545
# reaction_1546
# reaction_1547
# reaction_1548
# reaction_1549
# reaction_1550
# reaction_1551
# reaction_1552
# reaction_1553
# reaction_1554
# reaction_1555
# reaction_1556
# reaction_1557
# reaction_1558
# reaction_1559
# reaction_1560
# reaction_1561
# reaction_1562
# reaction_1563
# reaction_1564
# reaction_1565
# reaction_1566
# reaction_1567
# reaction_1568
# reaction_1569
# reaction_1570
# reaction_1571
# reaction_1572
# reaction_1573
# reaction_1574
# reaction_1575
# reaction_1576
# reaction_1577
# reaction_1578
# reaction_1579
# reaction_1580
# reaction_1581
# reaction_1582
# reaction_1583
# reaction_1584
# reaction_1585
# reaction_1586
# reaction_1587
# reaction_1588
# reaction_1589
# reaction_1590
# reaction_1591
# reaction_1592
# reaction_1593
# reaction_1594
# reaction_1595
# reaction_1596
# reaction_1597
# reaction_1598
# reaction_1599
# reaction_1600
# reaction_1601
# reaction_1602
# reaction_1603
# reaction_1604
# reaction_1605
# reaction_1606
# reaction_1607
# reaction_1608
# reaction_1609
# reaction_1610
# reaction_1611
# reaction_1612
# reaction_1613
# reaction_1614
# reaction_1615
# reaction_1616
# reaction_1617
# reaction_1618
# reaction_1619
# reaction_1620
# reaction_1621
# reaction_1622
# reaction_1623
# reaction_1624
# reaction_1625
# reaction_1626
# reaction_1627
# reaction_1628
# reaction_1629
# reaction_1630
# reaction_1631
# reaction_1632
# reaction_1633
# reaction_1634
# reaction_1635
# reaction_1636
# reaction_1637
# reaction_1638
# reaction_1639
# reaction_1640
# reaction_1641
# reaction_1642
# reaction_1643
# reaction_1644
# reaction_1645
# reaction_1646
# reaction_1647
# reaction_1648
# reaction_1649
# reaction_1650
# reaction_1651
# reaction_1652
# reaction_1653
# reaction_1654
# reaction_1655
# reaction_1656
# reaction_1657
# reaction_1658
# reaction_1659
# reaction_1660
# reaction_1661
# reaction_1662
# reaction_1663
# reaction_1664
# reaction_1665
# reaction_1666
# reaction_1667
# reaction_1668
# reaction_1669
# reaction_1670
# reaction_1671
# reaction_1672
# reaction_1673
# reaction_1674
# reaction_1675
# reaction_1676
# reaction_1677
# reaction_1678
# reaction_1679
# reaction_1680
# reaction_1681
# reaction_1682
# reaction_1683
# reaction_1684
# reaction_1685
# reaction_1686
# reaction_1687
# reaction_1688
# reaction_1689
# reaction_1690
# reaction_1691
# reaction_1692
# reaction_1693
# reaction_1694
# reaction_1695
# reaction_1696
# reaction_1697
# reaction_1698
# reaction_1699
# reaction_1700
# reaction_1701
# reaction_1702
# reaction_1703
# reaction_1704
# reaction_1705
# reaction_1706
# reaction_1707
# reaction_1708
# reaction_1709
# reaction_1710
# reaction_1711
# reaction_1712
# reaction_1713
# reaction_1714
# reaction_1715
# reaction_1716
# reaction_1717
# reaction_1718
# reaction_1719
# reaction_1720
# reaction_1721
# reaction_1722
# reaction_1723
# reaction_1724
# reaction_1725
# reaction_1726
# reaction_1727
# reaction_1728
# reaction_1729
# reaction_1730
# reaction_1731
# reaction_1732
# reaction_1733
# reaction_1734
# reaction_1735
# reaction_1736
# reaction_1737
# reaction_1738
# reaction_1739
# reaction_1740
# reaction_1741
# reaction_1742
# reaction_1743
# reaction_1744
# reaction_1745
# reaction_1746
# reaction_1747
# reaction_1748
# reaction_1749
# reaction_1750
# reaction_1751
# reaction_1752
# reaction_1753
# reaction_1754
# reaction_1755
# reaction_1756
# reaction_1757
# reaction_1758
# reaction_1759
# reaction_1760
# reaction_1761
# reaction_1762
# reaction_1763
# reaction_1764
# reaction_1765
# reaction_1766
# reaction_1767
# reaction_1768
# reaction_1769
# reaction_1770
# reaction_1771
# reaction_1772
# reaction_1773
# reaction_1774
# reaction_1775
# reaction_1776
# reaction_1777
# reaction_1778
# reaction_1779
# reaction_1780
# reaction_1781
# reaction_1782
# reaction_1783
# reaction_1784
# reaction_1785
# reaction_1786
# reaction_1787
# reaction_1788
# reaction_1789
# reaction_1790
# reaction_1791
# reaction_1792
# reaction_1793
# reaction_1794
# reaction_1795
# reaction_1796
# reaction_1797
# reaction_1798
# reaction_1799
# reaction_1800
# reaction_1801
# reaction_1802
# reaction_1803
# reaction_1804
# reaction_1805
# reaction_1806
# reaction_1807
# reaction_1808
# reaction_1809
# reaction_1810
# reaction_1811
# reaction_1812
# reaction_1813
# reaction_1814
# reaction_1815
# reaction_1816
# reaction_1817
# reaction_1818
# reaction_1819
# reaction_1820
# reaction_1821
# reaction_1822
# reaction_1823
# reaction_1824
# reaction_1825
# reaction_1826
# reaction_1827
# reaction_1828
# reaction_1829
# reaction_1830
# reaction_1831
# reaction_1832
# reaction_1833
# reaction_1834
# reaction_1835
# reaction_1836
# reaction_1837
# reaction_1838
# reaction_1839
# reaction_1840
# reaction_1841
# reaction_1842
# reaction_1843
# reaction_1844
# reaction_1845
# reaction_1846
# reaction_1847
# reaction_1848
# reaction_1849
# reaction_1850
# reaction_1851
# reaction_1852
# reaction_1853
# reaction_1854
# reaction_1855
# reaction_1856
# reaction_1857
# reaction_1858
# reaction_1859
# reaction_1860
# reaction_1861
# reaction_1862
# reaction_1863
# reaction_1864
# reaction_1865
# reaction_1866
# reaction_1867
# reaction_1868
# reaction_1869
# reaction_1870
# reaction_1871
# reaction_1872
# reaction_1873
# reaction_1874
# reaction_1875
# reaction_1876
# reaction_1877
# reaction_1878
# reaction_1879
# reaction_1880
# reaction_1881
# reaction_1882
# reaction_1883
# reaction_1884
# reaction_1885
# reaction_1886
# reaction_1887
# reaction_1888
# reaction_1889
# reaction_1890
# reaction_1891
# reaction_1892
# reaction_1893
# reaction_1894
# reaction_1895
# reaction_1896
# reaction_1897
# reaction_1898
# reaction_1899
# reaction_1900
# reaction_1901
# reaction_1902
# reaction_1903
# reaction_1904
# reaction_1905
# reaction_1906
# reaction_1907
# reaction_1908
# reaction_1909
# reaction_1910
# reaction_1911
# reaction_1912
# reaction_1913
# reaction_1914
# reaction_1915
# reaction_1916
# reaction_1917
# reaction_1918
# reaction_1919
# reaction_1920
# reaction_1921
# reaction_1922
# reaction_1923
# reaction_1924
# reaction_1925
# reaction_1926
# reaction_1927
# reaction_1928
# reaction_1929
# reaction_1930
# reaction_1931
# reaction_1932
# reaction_1933
# reaction_1934
# reaction_1935
# reaction_1936
# reaction_1937
# reaction_1938
# reaction_1939
# reaction_1940
# reaction_1941
# reaction_1942
# reaction_1943
# reaction_1944
# reaction_1945
# reaction_1946
# reaction_1947
# reaction_1948
# reaction_1949
# reaction_1950
# reaction_1951
# reaction_1952
# reaction_1953
# reaction_1954
# reaction_1955
# reaction_1956
# reaction_1957
# reaction_1958
# reaction_1959
# reaction_1960
# reaction_1961
# reaction_1962
# reaction_1963
# reaction_1964
# reaction_1965
# reaction_1966
# reaction_1967
# reaction_1968
# reaction_1969
# reaction_1970
# reaction_1971
# reaction_1972
# reaction_1973
# reaction_1974
# reaction_1975
# reaction_1976
# reaction_1977
# reaction_1978
# reaction_1979
# reaction_1980
# reaction_1981
# reaction_1982
# reaction_1983
# reaction_1984
# reaction_1985
# reaction_1986
# reaction_1987
# reaction_1988
# reaction_1989
# reaction_1990
# reaction_1991
# reaction_1992
# reaction_1993
# reaction_1994
# reaction_1995
# reaction_1996
# reaction_1997
# reaction_1998
# reaction_1999
# reaction_2000
# reaction_2001
# reaction_2002
# reaction_2003
# reaction_2004
# reaction_2005
# reaction_2006
# reaction_2007
# reaction_2008
# reaction_2009
# reaction_2010
# reaction_2011
# reaction_2012
# reaction_2013
# reaction_2014
# reaction_2015
# reaction_2016
# reaction_2017
# reaction_2018
# reaction_2019
# reaction_2020
# reaction_2021
# reaction_2022
# reaction_2023
# reaction_2024
# reaction_2025
# reaction_2026
# reaction_2027
# reaction_2028
# reaction_2029
# reaction_2030
# reaction_2031
# reaction_2032
# reaction_2033
# reaction_2034
# reaction_2035
# reaction_2036
# reaction_2037
# reaction_2038
# reaction_2039
# reaction_2040
# reaction_2041
# reaction_2042
# reaction_2043
# reaction_2044
# reaction_2045
# reaction_2046
# reaction_2047
# reaction_2048
# reaction_2049
# reaction_2050
# reaction_2051
# reaction_2052
# reaction_2053
# reaction_2054
# reaction_2055
# reaction_2056
# reaction_2057
# reaction_2058
# reaction_2059
# reaction_2060
# reaction_2061
# reaction_2062
# reaction_2063
# reaction_2064
# reaction_2065
# reaction_2066
# reaction_2067
# reaction_2068
# reaction_2069
# reaction_2070
# reaction_2071
# reaction_2072
# reaction_2073
# reaction_2074
# reaction_2075
# reaction_2076
# reaction_2077
# reaction_2078
# reaction_2079
# reaction_2080
# reaction_2081
# reaction_2082
# reaction_2083
# reaction_2084
# reaction_2085
# reaction_2086
# reaction_2087
# reaction_2088
# reaction_2089
# reaction_2090
# reaction_2091
# reaction_2092
# reaction_2093
# reaction_2094
# reaction_2095
# reaction_2096
# reaction_2097
# reaction_2098
# reaction_2099
# reaction_2100
# reaction_2101
# reaction_2102
# reaction_2103
# reaction_2104
# reaction_2105
# reaction_2106
# reaction_2107
# reaction_2108
# reaction_2109
# reaction_2110
# reaction_2111
# reaction_2112
# reaction_2113
# reaction_2114
# reaction_2115
# reaction_2116
# reaction_2117
# reaction_2118
# reaction_2119
# reaction_2120
# reaction_2121
# reaction_2122
# reaction_2123
# reaction_2124
# reaction_2125
# reaction_2126
# reaction_2127
# reaction_2128
# reaction_2129
# reaction_2130
# reaction_2131
# reaction_2132
# reaction_2133
# reaction_2134
# reaction_2135
# reaction_2136
# reaction_2137
# reaction_2138
# reaction_2139
# reaction_2140
# reaction_2141
# reaction_2142
# reaction_2143
# reaction_2144
# reaction_2145
# reaction_2146
# reaction_2147
# reaction_2148
# reaction_2149
# reaction_2150
# reaction_2151
# reaction_2152
# reaction_2153
# reaction_2154
# reaction_2155
# reaction_2156
# reaction_2157
# reaction_2158
# reaction_2159
# reaction_2160
# reaction_2161
# reaction_2162
# reaction_2163
# reaction_2164
# reaction_2165
# reaction_2166
# reaction_2167
# reaction_2168
# reaction_2169
# reaction_2170
# reaction_2171
# reaction_2172
# reaction_2173
# reaction_2174
# reaction_2175
# reaction_2176
# reaction_2177
# reaction_2178
# reaction_2179
# reaction_2180
# reaction_2181
# reaction_2182
# reaction_2183
# reaction_2184
# reaction_2185
# reaction_2186
# reaction_2187
# reaction_2188
# reaction_2189
# reaction_2190
# reaction_2191
# reaction_2192
# reaction_2193
# reaction_2194
# reaction_2195
# reaction_2196
# reaction_2197
# reaction_2198
# reaction_2199
# reaction_2200
# reaction_2201
# reaction_2202
# reaction_2203
# reaction_2204
# reaction_2205
# reaction_2206
# reaction_2207
# reaction_2208
# reaction_2209
# reaction_2210
# reaction_2211
# reaction_2212
# reaction_2213
# reaction_2214
# reaction_2215
# reaction_2216
# reaction_2217
# reaction_2218
# reaction_2219
# reaction_2220
# reaction_2221
# reaction_2222
# reaction_2223
# reaction_2224
# reaction_2225
# reaction_2226
# reaction_2227
# reaction_2228
# reaction_2229
# reaction_2230
# reaction_2231
# reaction_2232
# reaction_2233
# reaction_2234
# reaction_2235
# reaction_2236
# reaction_2237
# reaction_2238
# reaction_2239
# reaction_2240
# reaction_2241
# reaction_2242
# reaction_2243
# reaction_2244
# reaction_2245
# reaction_2246
# reaction_2247
# reaction_2248
# reaction_2249
# reaction_2250
# reaction_2251
# reaction_2252
# reaction_2253
# reaction_2254
# reaction_2255
# reaction_2256
# reaction_2257
# reaction_2258
# reaction_2259
# reaction_2260
# reaction_2261
# reaction_2262
# reaction_2263
# reaction_2264
# reaction_2265
# reaction_2266
# reaction_2267
# reaction_2268
# reaction_2269
# reaction_2270
# reaction_2271
# reaction_2272
# reaction_2273
# reaction_2274
# reaction_2275
# reaction_2276
# reaction_2277
# reaction_2278
# reaction_2279
# reaction_2280
# reaction_2281
# reaction_2282
# reaction_2283
# reaction_2284
# reaction_2285
# reaction_2286
# reaction_2287
# reaction_2288
# reaction_2289
# reaction_2290
# reaction_2291
# reaction_2292
# reaction_2293
# reaction_2294
# reaction_2295
# reaction_2296
# reaction_2297
# reaction_2298
# reaction_2299
# reaction_2300
# reaction_2301
# reaction_2302
# reaction_2303
# reaction_2304
# reaction_2305
# reaction_2306
# reaction_2307
# reaction_2308
# reaction_2309
# reaction_2310
# reaction_2311
# reaction_2312
# reaction_2313
# reaction_2314
# reaction_2315
# reaction_2316
# reaction_2317
# reaction_2318
# reaction_2319
# reaction_2320
# reaction_2321
# reaction_2322
# reaction_2323
# reaction_2324
# reaction_2325
# reaction_2326
# reaction_2327
# reaction_2328
# reaction_2329
# reaction_2330
# reaction_2331
# reaction_2332
# reaction_2333
# reaction_2334
# reaction_2335
# reaction_2336
# reaction_2337
# reaction_2338
# reaction_2339
# reaction_2340
# reaction_2341
# reaction_2342
# reaction_2343
# reaction_2344
# reaction_2345
# reaction_2346
# reaction_2347
# reaction_2348
# reaction_2349
# reaction_2350
# reaction_2351
# reaction_2352
# reaction_2353
# reaction_2354
# reaction_2355
# reaction_2356
# reaction_2357
# reaction_2358
# reaction_2359
# reaction_2360
# reaction_2361
# reaction_2362
# reaction_2363
# reaction_2364
# reaction_2365
# reaction_2366
# reaction_2367
# reaction_2368
# reaction_2369
# reaction_2370
# reaction_2371
# reaction_2372
# reaction_2373
# reaction_2374
# reaction_2375
# reaction_2376
# reaction_2377
# reaction_2378
# reaction_2379
# reaction_2380
# reaction_2381
# reaction_2382
# reaction_2383
# reaction_2384
# reaction_2385
# reaction_2386
# reaction_2387
# reaction_2388
# reaction_2389
# reaction_2390
# reaction_2391
# reaction_2392
# reaction_2393
# reaction_2394
# reaction_2395
# reaction_2396
# reaction_2397
# reaction_2398
# reaction_2399
# reaction_2400
# reaction_2401
# reaction_2402
# reaction_2403
# reaction_2404
# reaction_2405
# reaction_2406
# reaction_2407
# reaction_2408
# reaction_2409
# reaction_2410
# reaction_2411
# reaction_2412
# reaction_2413
# reaction_2414
# reaction_2415
# reaction_2416
# reaction_2417
# reaction_2418
# reaction_2419
# reaction_2420
# reaction_2421
# reaction_2422
# reaction_2423
# reaction_2424
# reaction_2425
# reaction_2426
# reaction_2427
# reaction_2428
# reaction_2429
# reaction_2430
# reaction_2431
# reaction_2432
# reaction_2433
# reaction_2434
# reaction_2435
# reaction_2436
# reaction_2437
# reaction_2438
# reaction_2439
# reaction_2440
# reaction_2441
# reaction_2442
# reaction_2443
# reaction_2444
# reaction_2445
# reaction_2446
# reaction_2447
# reaction_2448
# reaction_2449
# reaction_2450
# reaction_2451
# reaction_2452
# reaction_2453
# reaction_2454
# reaction_2455
# reaction_2456
# reaction_2457
# reaction_2458
# reaction_2459
# reaction_2460
# reaction_2461
# reaction_2462
# reaction_2463
# reaction_2464
# reaction_2465
# reaction_2466
# reaction_2467
# reaction_2468
# reaction_2469
# reaction_2470
# reaction_2471
# reaction_2472
# reaction_2473
# reaction_2474
# reaction_2475
# reaction_2476
# reaction_2477
# reaction_2478
# reaction_2479
# reaction_2480
# reaction_2481
# reaction_2482
# reaction_2483
# reaction_2484
# reaction_2485
# reaction_2486
# reaction_2487
# reaction_2488
# reaction_2489
# reaction_2490
# reaction_2491
# reaction_2492
# reaction_2493
# reaction_2494
# reaction_2495
# reaction_2496
# reaction_2497
# reaction_2498
# reaction_2499
# reaction_2500
# reaction_2501
# reaction_2502
# reaction_2503
# reaction_2504
# reaction_2505
# reaction_2506
# reaction_2507
# reaction_2508
# reaction_2509
# reaction_2510
# reaction_2511
# reaction_2512
# reaction_2513
# reaction_2514
# reaction_2515
# reaction_2516
# reaction_2517
# reaction_2518
# reaction_2519
# reaction_2520
# reaction_2521
# reaction_2522
# reaction_2523
# reaction_2524
# reaction_2525
# reaction_2526
# reaction_2527
# reaction_2528
# reaction_2529
# reaction_2530
# reaction_2531
# reaction_2532
# reaction_2533
# reaction_2534
# reaction_2535
# reaction_2536
# reaction_2537
# reaction_2538
# reaction_2539
# reaction_2540
# reaction_2541
# reaction_2542
# reaction_2543
# reaction_2544
# reaction_2545
# reaction_2546
# reaction_2547
# reaction_2548
# reaction_2549
# reaction_2550
# reaction_2551
# reaction_2552
# reaction_2553
# reaction_2554
# reaction_2555
# reaction_2556
# reaction_2557
# reaction_2558
# reaction_2559
# reaction_2560
# reaction_2561
# reaction_2562
# reaction_2563
# reaction_2564
# reaction_2565
# reaction_2566
# reaction_2567
# reaction_2568
# reaction_2569
# reaction_2570
# reaction_2571
# reaction_2572
# reaction_2573
# reaction_2574
# reaction_2575
# reaction_2576
# reaction_2577
# reaction_2578
# reaction_2579
# reaction_2580
# reaction_2581
# reaction_2582
# reaction_2583
# reaction_2584
# reaction_2585
# reaction_2586
# reaction_2587
# reaction_2588
# reaction_2589
# reaction_2590
# reaction_2591
# reaction_2592
# reaction_2593
# reaction_2594
# reaction_2595
# reaction_2596
# reaction_2597
# reaction_2598
# reaction_2599
# reaction_2600
# reaction_2601
# reaction_2602
# reaction_2603
# reaction_2604
# reaction_2605
# reaction_2606
# reaction_2607
# reaction_2608
# reaction_2609
# reaction_2610
# reaction_2611
# reaction_2612
# reaction_2613
# reaction_2614
# reaction_2615
# reaction_2616
# reaction_2617
# reaction_2618
# reaction_2619
# reaction_2620
# reaction_2621
# reaction_2622
# reaction_2623
# reaction_2624
# reaction_2625
# reaction_2626
# reaction_2627
# reaction_2628
# reaction_2629
# reaction_2630
# reaction_2631
# reaction_2632
# reaction_2633
# reaction_2634
# reaction_2635
# reaction_2636
# reaction_2637
# reaction_2638
# reaction_2639
# reaction_2640
# reaction_2641
# reaction_2642
# reaction_2643
# reaction_2644
# reaction_2645
# reaction_2646
# reaction_2647
# reaction_2648
# reaction_2649
# reaction_2650
# reaction_2651
# reaction_2652
# reaction_2653
# reaction_2654
# reaction_2655
# reaction_2656
# reaction_2657
# reaction_2658
# reaction_2659
# reaction_2660
# reaction_2661
# reaction_2662
# reaction_2663
# reaction_2664
# reaction_2665
# reaction_2666
# reaction_2667
# reaction_2668
# reaction_2669
# reaction_2670
# reaction_2671
# reaction_2672
# reaction_2673
# reaction_2674
# reaction_2675
# reaction_2676
# reaction_2677
# reaction_2678
# reaction_2679
# reaction_2680
# reaction_2681
# reaction_2682
# reaction_2683
# reaction_2684
# reaction_2685
# reaction_2686
# reaction_2687
# reaction_2688
# reaction_2689
# reaction_2690
# reaction_2691
# reaction_2692
# reaction_2693
# reaction_2694
# reaction_2695
# reaction_2696
# reaction_2697
# reaction_2698
# reaction_2699
# reaction_2700
# reaction_2701
# reaction_2702
# reaction_2703
# reaction_2704
# reaction_2705
# reaction_2706
# reaction_2707
# reaction_2708
# reaction_2709
# reaction_2710
# reaction_2711
# reaction_2712
# reaction_2713
# reaction_2714
# reaction_2715
# reaction_2716
# reaction_2717
# reaction_2718
# reaction_2719
# reaction_2720
# reaction_2721
# reaction_2722
# reaction_2723
# reaction_2724
# reaction_2725
# reaction_2726
# reaction_2727
# reaction_2728
# reaction_2729
# reaction_2730
# reaction_2731
# reaction_2732
# reaction_2733
# reaction_2734
# reaction_2735
# reaction_2736
# reaction_2737
# reaction_2738
# reaction_2739
# reaction_2740
# reaction_2741
# reaction_2742
# reaction_2743
# reaction_2744
# reaction_2745
# reaction_2746
# reaction_2747
# reaction_2748
# reaction_2749
# reaction_2750
# reaction_2751
# reaction_2752
# reaction_2753
# reaction_2754
# reaction_2755
# reaction_2756
# reaction_2757
# reaction_2758
# reaction_2759
# reaction_2760
# reaction_2761
# reaction_2762
# reaction_2763
# reaction_2764
# reaction_2765
# reaction_2766
# reaction_2767
# reaction_2768
# reaction_2769
# reaction_2770
# reaction_2771
# reaction_2772
# reaction_2773
# reaction_2774
# reaction_2775
# reaction_2776
# reaction_2777
# reaction_2778
# reaction_2779
# reaction_2780
# reaction_2781
# reaction_2782
# reaction_2783
# reaction_2784
# reaction_2785
# reaction_2786
# reaction_2787
# reaction_2788
# reaction_2789
# reaction_2790
# reaction_2791
# reaction_2792
# reaction_2793
# reaction_2794
# reaction_2795
# reaction_2796
# reaction_2797
# reaction_2798
# reaction_2799
# reaction_2800
# reaction_2801
# reaction_2802
# reaction_2803
# reaction_2804
# reaction_2805
# reaction_2806
# reaction_2807
# reaction_2808
# reaction_2809
# reaction_2810
# reaction_2811
# reaction_2812
# reaction_2813
# reaction_2814
# reaction_2815
# reaction_2816
# reaction_2817
# reaction_2818
# reaction_2819
# reaction_2820
# reaction_2821
# reaction_2822
# reaction_2823
# reaction_2824
# reaction_2825
# reaction_2826
# reaction_2827
# reaction_2828
# reaction_2829
# reaction_2830
# reaction_2831
# reaction_2832
# reaction_2833
# reaction_2834
# reaction_2835
# reaction_2836
# reaction_2837
# reaction_2838
# reaction_2839
# reaction_2840
# reaction_2841
# reaction_2842
# reaction_2843
# reaction_2844
# reaction_2845
# reaction_2846
# reaction_2847
# reaction_2848
# reaction_2849
# reaction_2850
# reaction_2851
# reaction_2852
# reaction_2853
# reaction_2854
# reaction_2855
# reaction_2856
# reaction_2857
# reaction_2858
# reaction_2859
# reaction_2860
# reaction_2861
# reaction_2862
# reaction_2863
# reaction_2864
# reaction_2865
# reaction_2866
# reaction_2867
# reaction_2868
# reaction_2869
# reaction_2870
# reaction_2871
# reaction_2872
# reaction_2873
# reaction_2874
# reaction_2875
# reaction_2876
# reaction_2877
# reaction_2878
# reaction_2879
# reaction_2880
# reaction_2881
# reaction_2882
# reaction_2883
# reaction_2884
# reaction_2885
# reaction_2886
# reaction_2887
# reaction_2888
# reaction_2889
# reaction_2890
# reaction_2891
# reaction_2892
# reaction_2893
# reaction_2894
# reaction_2895
# reaction_2896
# reaction_2897
# reaction_2898
# reaction_2899
# reaction_2900
# reaction_2901
# reaction_2902
# reaction_2903
# reaction_2904
# reaction_2905
# reaction_2906
# reaction_2907
# reaction_2908
# reaction_2909
# reaction_2910
# reaction_2911
# reaction_2912
# reaction_2913
# reaction_2914
# reaction_2915
# reaction_2916
# reaction_2917
# reaction_2918
# reaction_2919
# reaction_2920
# reaction_2921
# reaction_2922
# reaction_2923
# reaction_2924
# reaction_2925
# reaction_2926
# reaction_2927
# reaction_2928
# reaction_2929
# reaction_2930
# reaction_2931
# reaction_2932
# reaction_2933
# reaction_2934
# reaction_2935
# reaction_2936
# reaction_2937
# reaction_2938
# reaction_2939
# reaction_2940
# reaction_2941
# reaction_2942
# reaction_2943
# reaction_2944
# reaction_2945
# reaction_2946
# reaction_2947
# reaction_2948
# reaction_2949
# reaction_2950
# reaction_2951
# reaction_2952
# reaction_2953
# reaction_2954
# reaction_2955
# reaction_2956
# reaction_2957
# reaction_2958
# reaction_2959
# reaction_2960
# reaction_2961
# reaction_2962
# reaction_2963
# reaction_2964
# reaction_2965
# reaction_2966
# reaction_2967
# reaction_2968
# reaction_2969
# reaction_2970
# reaction_2971
# reaction_2972
# reaction_2973
# reaction_2974
# reaction_2975
# reaction_2976
# reaction_2977
# reaction_2978
# reaction_2979
# reaction_2980
# reaction_2981
# reaction_2982
# reaction_2983
# reaction_2984
# reaction_2985
# reaction_2986
# reaction_2987
# reaction_2988
# reaction_2989
# reaction_2990
# reaction_2991
# reaction_2992
# reaction_2993
# reaction_2994
# reaction_2995
# reaction_2996
# reaction_2997
# reaction_2998
# reaction_2999
# reaction_3000
# reaction_3001
# reaction_3002
# reaction_3003
# reaction_3004
# reaction_3005
# reaction_3006
# reaction_3007
# reaction_3008
# reaction_3009
# reaction_3010
# reaction_3011
# reaction_3012
# reaction_3013
# reaction_3014
# reaction_3015
# reaction_3016
# reaction_3017
# reaction_3018
# reaction_3019
# reaction_3020
# reaction_3021
# reaction_3022
# reaction_3023
# reaction_3024
# reaction_3025
# reaction_3026
# reaction_3027
# reaction_3028
# reaction_3029
# reaction_3030
# reaction_3031
# reaction_3032
# reaction_3033
# reaction_3034
# reaction_3035
# reaction_3036
# reaction_3037
# reaction_3038
# reaction_3039
# reaction_3040
# reaction_3041
# reaction_3042
# reaction_3043
# reaction_3044
# reaction_3045
# reaction_3046
# reaction_3047
# reaction_3048
# reaction_3049
# reaction_3050
# reaction_3051
# reaction_3052
# reaction_3053
# reaction_3054
# reaction_3055
# reaction_3056
# reaction_3057
# reaction_3058
# reaction_3059
# reaction_3060
# reaction_3061
# reaction_3062
# reaction_3063
# reaction_3064
# reaction_3065
# reaction_3066
# reaction_3067
# reaction_3068
# reaction_3069
# reaction_3070
# reaction_3071
# reaction_3072
# reaction_3073
# reaction_3074
# reaction_3075
# reaction_3076
# reaction_3077
# reaction_3078
# reaction_3079
# reaction_3080
# reaction_3081
# reaction_3082
# reaction_3083
# reaction_3084
# reaction_3085
# reaction_3086
# reaction_3087
# reaction_3088
# reaction_3089
# reaction_3090
# reaction_3091
# reaction_3092
# reaction_3093
# reaction_3094
# reaction_3095
# reaction_3096
# reaction_3097
# reaction_3098
# reaction_3099
# reaction_3100
# reaction_3101
# reaction_3102
# reaction_3103
# reaction_3104
# reaction_3105
# reaction_3106
# reaction_3107
# reaction_3108
# reaction_3109
# reaction_3110
# reaction_3111
# reaction_3112
# reaction_3113
# reaction_3114
# reaction_3115
# reaction_3116
# reaction_3117
# reaction_3118
# reaction_3119
# reaction_3120
# reaction_3121
# reaction_3122
# reaction_3123
# reaction_3124
# reaction_3125
# reaction_3126
# reaction_3127
# reaction_3128
# reaction_3129
# reaction_3130
# reaction_3131
# reaction_3132
# reaction_3133
# reaction_3134
# reaction_3135
# reaction_3136
# reaction_3137
# reaction_3138
# reaction_3139
# reaction_3140
# reaction_3141
# reaction_3142
# reaction_3143
# reaction_3144
# reaction_3145
# reaction_3146
# reaction_3147
# reaction_3148
# reaction_3149
# reaction_3150
# reaction_3151
# reaction_3152
# reaction_3153
# reaction_3154
# reaction_3155
# reaction_3156
# reaction_3157
# reaction_3158
# reaction_3159
# reaction_3160
# reaction_3161
# reaction_3162
# reaction_3163
# reaction_3164
# reaction_3165
# reaction_3166
# reaction_3167
# reaction_3168
# reaction_3169
# reaction_3170
# reaction_3171
# reaction_3172
# reaction_3173
# reaction_3174
# reaction_3175
# reaction_3176
# reaction_3177
# reaction_3178
# reaction_3179
# reaction_3180
# reaction_3181
# reaction_3182
# reaction_3183
# reaction_3184
# reaction_3185
# reaction_3186
# reaction_3187
# reaction_3188
# reaction_3189
# reaction_3190
# reaction_3191
# reaction_3192
# reaction_3193
# reaction_3194
# reaction_3195
# reaction_3196
# reaction_3197
# reaction_3198
# reaction_3199
# reaction_3200
# reaction_3201
# reaction_3202
# reaction_3203
# reaction_3204
# reaction_3205
# reaction_3206
# reaction_3207
# reaction_3208
# reaction_3209
# reaction_3210
# reaction_3211
# reaction_3212
# reaction_3213
# reaction_3214
# reaction_3215
# reaction_3216
# reaction_3217
# reaction_3218
# reaction_3219
# reaction_3220
# reaction_3221
# reaction_3222
# reaction_3223
# reaction_3224
# reaction_3225
# reaction_3226
# reaction_3227
# reaction_3228
# reaction_3229
# reaction_3230
# reaction_3231
# reaction_3232
# reaction_3233
# reaction_3234
# reaction_3235
# reaction_3236
# reaction_3237
# reaction_3238
# reaction_3239
# reaction_3240
# reaction_3241
# reaction_3242
# reaction_3243
# reaction_3244
# reaction_3245
# reaction_3246
# reaction_3247
# reaction_3248
# reaction_3249
# reaction_3250
# reaction_3251
# reaction_3252
# reaction_3253
# reaction_3254
# reaction_3255
# reaction_3256
# reaction_3257
# reaction_3258
# reaction_3259
# reaction_3260
# reaction_3261
# reaction_3262
# reaction_3263
# reaction_3264
# reaction_3265
# reaction_3266
# reaction_3267
# reaction_3268
# reaction_3269
# reaction_3270
# reaction_3271
# reaction_3272
# reaction_3273
# reaction_3274
# reaction_3275
# reaction_3276
# reaction_3277
# reaction_3278
# reaction_3279
# reaction_3280
# reaction_3281
# reaction_3282
# reaction_3283
# reaction_3284
# reaction_3285
# reaction_3286
# reaction_3287
# reaction_3288
# reaction_3289
# reaction_3290
# reaction_3291
# reaction_3292
# reaction_3293
# reaction_3294
# reaction_3295
# reaction_3296
# reaction_3297
# reaction_3298
# reaction_3299
# reaction_3300
# reaction_3301
# reaction_3302
# reaction_3303
# reaction_3304
# reaction_3305
# reaction_3306
# reaction_3307
# reaction_3308
# reaction_3309
# reaction_3310
# reaction_3311
# reaction_3312
# reaction_3313
# reaction_3314
# reaction_3315
# reaction_3316
# reaction_3317
# reaction_3318
# reaction_3319
# reaction_3320
# reaction_3321
# reaction_3322
# reaction_3323
# reaction_3324
# reaction_3325
# reaction_3326
# reaction_3327
# reaction_3328
# reaction_3329
# reaction_3330
# reaction_3331
# reaction_3332
# reaction_3333
# reaction_3334
# reaction_3335
# reaction_3336
# reaction_3337
# reaction_3338
# reaction_3339
# reaction_3340
# reaction_3341
# reaction_3342
# reaction_3343
# reaction_3344
# reaction_3345
# reaction_3346
# reaction_3347
# reaction_3348
# reaction_3349
# reaction_3350
# reaction_3351
# reaction_3352
# reaction_3353
# reaction_3354
# reaction_3355
# reaction_3356
# reaction_3357
# reaction_3358
# reaction_3359
# reaction_3360
# reaction_3361
# reaction_3362
# reaction_3363
# reaction_3364
# reaction_3365
# reaction_3366
# reaction_3367
# reaction_3368
# reaction_3369
# reaction_3370
# reaction_3371
# reaction_3372
# reaction_3373
# reaction_3374
# reaction_3375
# reaction_3376
# reaction_3377
# reaction_3378
# reaction_3379
# reaction_3380
# reaction_3381
# reaction_3382
# reaction_3383
# reaction_3384
# reaction_3385
# reaction_3386
# reaction_3387
# reaction_3388
# reaction_3389
# reaction_3390
# reaction_3391
# reaction_3392
# reaction_3393
# reaction_3394
# reaction_3395
# reaction_3396
# reaction_3397
# reaction_3398
# reaction_3399
# reaction_3400
# reaction_3401
# reaction_3402
# reaction_3403
# reaction_3404
# reaction_3405
# reaction_3406
# reaction_3407
# reaction_3408
# reaction_3409
# reaction_3410
# reaction_3411
# reaction_3412
# reaction_3413
# reaction_3414
# reaction_3415
# reaction_3416
# reaction_3417
# reaction_3418
# reaction_3419
# reaction_3420
# reaction_3421
# reaction_3422
# reaction_3423
# reaction_3424
# reaction_3425
# reaction_3426
# reaction_3427
# reaction_3428
# reaction_3429
# reaction_3430
# reaction_3431
# reaction_3432
# reaction_3433
# reaction_3434
# reaction_3435
# reaction_3436
# reaction_3437
# reaction_3438
# reaction_3439
# reaction_3440
# reaction_3441
# reaction_3442
# reaction_3443
# reaction_3444
# reaction_3445
# reaction_3446
# reaction_3447
# reaction_3448
# reaction_3449
# reaction_3450
# reaction_3451
# reaction_3452
# reaction_3453
# reaction_3454
# reaction_3455
# reaction_3456
# reaction_3457
# reaction_3458
# reaction_3459
# reaction_3460
# reaction_3461
# reaction_3462
# reaction_3463
# reaction_3464
# reaction_3465
# reaction_3466
# reaction_3467
# reaction_3468
# reaction_3469
# reaction_3470
# reaction_3471
# reaction_3472
# reaction_3473
# reaction_3474
# reaction_3475
# reaction_3476
# reaction_3477
# reaction_3478
# reaction_3479
# reaction_3480
# reaction_3481
# reaction_3482
# reaction_3483
# reaction_3484
# reaction_3485
# reaction_3486
# reaction_3487
# reaction_3488
# reaction_3489
# reaction_3490
# reaction_3491
# reaction_3492
# reaction_3493
# reaction_3494
# reaction_3495
# reaction_3496
# reaction_3497
# reaction_3498
# reaction_3499
# reaction_3500
# reaction_3501
# reaction_3502
# reaction_3503
# reaction_3504
# reaction_3505
# reaction_3506
# ...
# reaction_25319
# reaction_25320
# reaction_25321
# reaction_25322
# reaction_25323
# reaction_25324
# reaction_25325
# reaction_25326
# reaction_25327
# reaction_25328
# reaction_25329
# reaction_25330
# reaction_25331
# reaction_25718
# reaction_25719
# reaction_25720
# reaction_25721
# reaction_25722
# reaction_25723
# reaction_25724
# reaction_25725
# reaction_25726
# reaction_25727
# reaction_25728
# reaction_25729
# reaction_25730
# reaction_25731
# reaction_25732
# reaction_25733
# reaction_25734
# reaction_25735
# reaction_25736
# reaction_25737
# reaction_25738
# reaction_25739
# reaction_25740
# reaction_25741
# reaction_25742
# reaction_25743
# reaction_25744
# reaction_25745
# reaction_25746
# reaction_25747
# reaction_25748
# reaction_25749
# reaction_25750
# reaction_25751
# reaction_25752
# reaction_25753
# reaction_25754
# reaction_25755
# reaction_25756
# reaction_25757
# reaction_25758
# reaction_25759
# reaction_25760
# reaction_25761
# reaction_25762
# reaction_25763
# reaction_25764
# reaction_25765
# reaction_25766
# reaction_25767
# reaction_25768
# reaction_25769
# reaction_25770
# reaction_25771
# reaction_25772
# reaction_25773
# reaction_25774
# reaction_25775
# reaction_25776
# reaction_25777
# reaction_25778
# reaction_25779
# reaction_25780
# reaction_25781
# reaction_25782
# reaction_25783
# reaction_25784
# reaction_25785
# reaction_25786
# reaction_25787
# reaction_25788
# reaction_25789
# reaction_25790
# reaction_25791
# reaction_25792
# reaction_25793
# reaction_25794
# reaction_25795
# reaction_25796
# reaction_25797
# reaction_25798
# reaction_25799
# reaction_25800
# reaction_25801
# reaction_25802
# reaction_25803
# reaction_25804
# reaction_25805
# reaction_25806
# reaction_25807
# reaction_25808
# reaction_25809
# reaction_25810
# reaction_25811
# reaction_25812
# reaction_25813
# reaction_25814
# reaction_25815
# reaction_25816
# reaction_25817
# reaction_25818
# reaction_25819
# reaction_25820
# reaction_25821
# reaction_25822
# reaction_25823
# reaction_25824
# reaction_25825
# reaction_25826
# reaction_25827
# reaction_25828
# reaction_25829
# reaction_25830
# reaction_25831
# reaction_25832
# reaction_25833
# reaction_25834
# reaction_25835
# reaction_25836
# reaction_25837
# reaction_25838
# reaction_25839
# reaction_25840
# reaction_25841
# reaction_25842
# reaction_25843
# reaction_25844
# reaction_25845
# reaction_25846
# reaction_25847
# reaction_25848
# reaction_25849
# reaction_25850
# reaction_25851
# reaction_25852
# reaction_25853
# reaction_25854
# reaction_25855
# reaction_25856
# reaction_25857
# reaction_25858
# reaction_25859
# reaction_25860
# reaction_25861
# reaction_25862
# reaction_25863
# reaction_25864
# reaction_25865
# reaction_25866
# reaction_25867
# reaction_25868
# reaction_25869
# reaction_25870
# reaction_25871
# reaction_25872
# reaction_25873
# reaction_25874
# reaction_25875
# reaction_25876
# reaction_25877
# reaction_25878
# reaction_25879
# reaction_25880
# reaction_25881
# reaction_25882
# reaction_25883
# reaction_25884
# reaction_25885
# reaction_25886
# reaction_25887
# reaction_25888
# reaction_25889
# reaction_25890
# reaction_25891
# reaction_25892
# reaction_25893
# reaction_25894
# reaction_25895
# reaction_25896
# reaction_25897
# reaction_25898
# reaction_25899
# reaction_25900
# reaction_25901
# reaction_25902
# reaction_25903
# reaction_25904
# reaction_25905
# reaction_25906
# reaction_25907
# reaction_25908
# reaction_25909
# reaction_25910
# reaction_25911
# reaction_25912
# reaction_25913
# reaction_25914
# reaction_25915
# reaction_25916
# reaction_25917
# reaction_25918
# reaction_25919
# reaction_25920
# reaction_25921
# reaction_25922
# reaction_25923
# reaction_25924
# reaction_25925
# reaction_25926
# reaction_25927
# reaction_25928
# reaction_25929
# reaction_25930
# reaction_25931
# reaction_25932
# reaction_25933
# reaction_25934
# reaction_25935
# reaction_25936
# reaction_25937
# reaction_25938
# reaction_25939
# reaction_25940
# reaction_25941
# reaction_25942
# reaction_25943
# reaction_25944
# reaction_25945
# reaction_25946
# reaction_25947
# reaction_25948
# reaction_25949
# reaction_25950
# reaction_25951
# reaction_25952
# reaction_25953
# reaction_25954
# reaction_25955
# reaction_25956
# reaction_25957
# reaction_25961
# reaction_25962
# reaction_25963
# reaction_25964
# reaction_25965
# reaction_25966
# reaction_25967
# reaction_25968
# reaction_25969
# reaction_25970
# reaction_25971
# reaction_25972
# reaction_25973
# reaction_25974
# reaction_25975
# reaction_25976
# reaction_25977
# reaction_25978
# reaction_25979
# reaction_25980
# reaction_25981
# reaction_25982
# reaction_25983
# reaction_25984
# reaction_25985
# reaction_25986
# reaction_25987
# reaction_25988
# reaction_25989
# reaction_25990
# reaction_25991
# reaction_25992
# reaction_25993
# reaction_25994
# reaction_25995
# reaction_25996
# reaction_25997
# reaction_25998
# reaction_25999
# reaction_26000
# reaction_26001
# reaction_26002
# reaction_26003
# reaction_26004
# reaction_26005
# reaction_26006
# reaction_26007
# reaction_26008
# reaction_26009
# reaction_26010
# reaction_26011
# reaction_26012
# reaction_26013
# reaction_26014
# reaction_26015
# reaction_26016
# reaction_26017
# reaction_26018
# reaction_26019
# reaction_26020
# reaction_26021
# reaction_26022
# reaction_26023
# reaction_26024
# reaction_26025
# reaction_26026
# reaction_26027
# reaction_26028
# reaction_26029
# reaction_26030
# reaction_26031
# reaction_26032
# reaction_26033
# reaction_26034
# reaction_26035
# reaction_26036
# reaction_26037
# reaction_26038
# reaction_26039
# reaction_26040
# reaction_26041
# reaction_26042
# reaction_26043
# reaction_26044
# reaction_26045
# reaction_26046
# reaction_26047
# reaction_26048
# reaction_26049
# reaction_26050
# reaction_26051
# reaction_26052
# reaction_26053
# reaction_26054
# reaction_26055
# reaction_26056
# reaction_26057
# reaction_26058
# reaction_26059
# reaction_26060
# reaction_26061
# reaction_26062
# reaction_26063
# reaction_26064
# reaction_26065
# reaction_26066
# reaction_26067
# reaction_26068
# reaction_26069
# reaction_26070
# reaction_26071
# reaction_26072
# reaction_26073
# reaction_26074
# reaction_26075
# reaction_26076
# reaction_26077
# reaction_26078
# reaction_26079
# reaction_26080
# reaction_26081
# reaction_26082
# reaction_26083
# reaction_26084
# reaction_26085
# reaction_26086
# reaction_26087
# reaction_26088
# reaction_26089
# reaction_26090
# reaction_26091
# reaction_26092
# reaction_26093
# reaction_26094
# reaction_26095
# reaction_26096
# reaction_26097
# reaction_26098
# reaction_26099
# reaction_26100
# reaction_26101
# reaction_26102
# reaction_26103
# reaction_26104
# reaction_26105
# reaction_26106
# reaction_26107
# reaction_26108
# reaction_26109
# reaction_26110
# reaction_26111
# reaction_26112
# reaction_26113
# reaction_26114
# reaction_26115
# reaction_26116
# reaction_26117
# reaction_26118
# reaction_26119
# reaction_26120
# reaction_26121
# reaction_26122
# reaction_26123
# reaction_26124
# reaction_26125
# reaction_26126
# reaction_26127
# reaction_26128
# reaction_26129
# reaction_26130
# reaction_26131
# reaction_26132
# reaction_26133
# reaction_26134
# reaction_26135
# reaction_26136
# reaction_26137
# reaction_26138
# reaction_26139
# reaction_26140
# reaction_26141
# reaction_26142
# reaction_26143
# reaction_26144
# reaction_26145
# reaction_26146
# reaction_26147
# reaction_26148
# reaction_26149
# reaction_26150
# reaction_26151
# reaction_26152
# reaction_26153
# reaction_26154
# reaction_26155
# reaction_26156
# reaction_26157
# reaction_26158
# reaction_26159
# reaction_26160
# reaction_26161
# reaction_26162
# reaction_26163
# reaction_26164
# reaction_26165
# reaction_26166
# reaction_26167
# reaction_26168
# reaction_26169
# reaction_26170
# reaction_26171
# reaction_26172
# reaction_26173
# reaction_26174
# reaction_26175
# reaction_26176
# reaction_26177
# reaction_26178
# reaction_26179
# reaction_26180
# reaction_26181
# reaction_26182
# reaction_26183
# reaction_26184
# reaction_26185
# reaction_26186
# reaction_26187
# reaction_26188
# reaction_26189
# reaction_26190
# reaction_26191
# reaction_26192
# reaction_26193
# reaction_26194
# reaction_26195
# reaction_26196
# reaction_26197
# reaction_26198
# reaction_26199
# reaction_26200
# reaction_26201
# reaction_26202
# reaction_26203
# reaction_26204
# reaction_26205
# reaction_26206
# reaction_26207
# reaction_26208
# reaction_26209
# reaction_26210
# reaction_26211
# reaction_26212
# reaction_26213
# reaction_26214
# reaction_26215
# reaction_26216
# reaction_26217
# reaction_26218
# reaction_26219
# reaction_26220
# reaction_26221
# reaction_26222
# reaction_26223
# reaction_26224
# reaction_26225
# reaction_26226
# reaction_26227
# reaction_26228
# reaction_26229
# reaction_26230
# reaction_26231
# reaction_26232
# reaction_26233
# reaction_26234
# reaction_26235
# reaction_26236
# reaction_26237
# reaction_26238
# reaction_26239
# reaction_26240
# reaction_26241
# reaction_26242
# reaction_26243
# reaction_26244
# reaction_26245
# reaction_26246
# reaction_26247
# reaction_26248
# reaction_26249
# reaction_26250
# reaction_26251
# reaction_26252
# reaction_26253
# reaction_26254
# reaction_26255
# reaction_26256
# reaction_26257
# reaction_26258
# reaction_26259
# reaction_26260
# reaction_26261
# reaction_26262
# reaction_26263
# reaction_26264
# reaction_26265
# reaction_26266
# reaction_26267
# reaction_26268
# reaction_26269
# reaction_26270
# reaction_26271
# reaction_26272
# reaction_26273
# reaction_26274
# reaction_26275
# reaction_26276
# reaction_26277
# reaction_26278
# reaction_26279
# reaction_26280
# reaction_26281
# reaction_26282
# reaction_26283
# reaction_26284
# reaction_26285
# reaction_26286
# reaction_26287
# reaction_26288
# reaction_26289
# reaction_26290
# reaction_26291
# reaction_26292
# reaction_26293
# reaction_26294
# reaction_26295
# reaction_26296
# reaction_26297
# reaction_26298
# reaction_26299
# reaction_26300
# reaction_26301
# reaction_26302
# reaction_26303
# reaction_26304
# reaction_26305
# reaction_26306
# reaction_26307
# reaction_26308
# reaction_26309
# reaction_26310
# reaction_26311
# reaction_26312
# reaction_26313
# reaction_26314
# reaction_26315
# reaction_26316
# reaction_26317
# reaction_26318
# reaction_26319
# reaction_26320
# reaction_26321
# reaction_26322
# reaction_26323
# reaction_26324
# reaction_26325
# reaction_26326
# reaction_26327
# reaction_26328
# reaction_26329
# reaction_26330
# reaction_26331
# reaction_26332
# reaction_26333
# reaction_26334
# reaction_26335
# reaction_26336
# reaction_26337
# reaction_26338
# reaction_26339
# reaction_26340
# reaction_26341
# reaction_26342
# reaction_26343
# reaction_26344
# reaction_26345
# reaction_26346
# reaction_26347
# reaction_26348
# reaction_26349
# reaction_26352
# reaction_26353
# reaction_26354
# reaction_26355
# reaction_26357
# reaction_26358
# reaction_26359
# reaction_26360
# reaction_26361
# reaction_26362
# reaction_26363
# reaction_26364
# reaction_26366
# reaction_26367
# reaction_26368
# reaction_26369
# reaction_26370
# reaction_26371
# reaction_26372
# reaction_26373
# reaction_26374
# reaction_26375
# reaction_26376
# reaction_26377
# reaction_26378
# reaction_26379
# reaction_26380
# reaction_26381
# reaction_26382
# reaction_26385
# reaction_26386
# reaction_26387
# reaction_26388
# reaction_26389
# reaction_26390
# reaction_26391
# reaction_26392
# reaction_26393
# reaction_26394
# reaction_26395
# reaction_26396
# reaction_26397
# reaction_26398
# reaction_26399
# reaction_26400
# reaction_26401
# reaction_26402
# reaction_26403
# reaction_26404
# reaction_26405
# reaction_26406
# reaction_26407
# reaction_26408
# reaction_26409
# reaction_26410
# reaction_26411
# reaction_26412
# reaction_26413
# reaction_26414
# reaction_26415
# reaction_26416
# reaction_26417
# reaction_26418
# reaction_26419
# reaction_26420
# reaction_26421
# reaction_26422
# reaction_26423
# reaction_26424
# reaction_26425
# reaction_26426
# reaction_26427
# reaction_26428
# reaction_26429
# reaction_26430
# reaction_26431
# reaction_26432
# reaction_26433
# reaction_26434
# reaction_26435
# reaction_26436
# reaction_26437
# reaction_26438
# reaction_26439
# reaction_26440
# reaction_26441
# reaction_26442
# reaction_26443
# reaction_26444
# reaction_26445
# reaction_26446
# reaction_26447
# reaction_26448
# reaction_26449
# reaction_26450
# reaction_26451
# reaction_26452
# reaction_26453
# reaction_26454
# reaction_26455
# reaction_26456
# reaction_26457
# reaction_26458
# reaction_26459
# reaction_26460
# reaction_26461
# reaction_26462
# reaction_26463
# reaction_26464
# reaction_26465
# reaction_26466
# reaction_26467
# reaction_26468
# reaction_26469
# reaction_26470
# reaction_26471
# reaction_26472
# reaction_26473
# reaction_26474
# reaction_26475
# reaction_26476
# reaction_26477
# reaction_26478
# reaction_26479
# reaction_26480
# reaction_26481
# reaction_26482
# reaction_26483
# reaction_26484
# reaction_26485
# reaction_26486
# reaction_26487
# reaction_26488
# reaction_26489
# reaction_26490
# reaction_26491
# reaction_26492
# reaction_26493
# reaction_26494
# reaction_26495
# reaction_26496
# reaction_26497
# reaction_26498
# reaction_26499
# reaction_26500
# reaction_26501
# reaction_26502
# reaction_26503
# reaction_26504
# reaction_26505
# reaction_26506
# reaction_26507
# reaction_26508
# reaction_26509
# reaction_26510
# reaction_26511
# reaction_26512
# reaction_26513
# reaction_26514
# reaction_26515
# reaction_26516
# reaction_26517
# reaction_26518
# reaction_26519
# reaction_26520
# reaction_26521
# reaction_26522
# reaction_26523
# reaction_26524
# reaction_26525
# reaction_26526
# reaction_26527
# reaction_26528
# reaction_26529
# reaction_26530
# reaction_26531
# reaction_26532
# reaction_26533
# reaction_26534
# reaction_26537
# reaction_26538
# reaction_26540
# reaction_26541
# reaction_26542
# reaction_26543
# reaction_26544
# reaction_26545
# reaction_26546
# reaction_26547
# reaction_26548
# reaction_26550
# reaction_26551
# reaction_26552
# reaction_26556
# reaction_26557
# reaction_26558
# reaction_26559
# reaction_26562
# reaction_26563
# reaction_26564
# reaction_26565
# reaction_26566
# reaction_26567
# reaction_26568
# reaction_26569
# reaction_26570
# reaction_26571
# reaction_26572
# reaction_26573
# reaction_26574
# reaction_26575
# reaction_26576
# reaction_26577
# reaction_26578
# reaction_26579
# reaction_26580
# reaction_26581
# reaction_26582
# reaction_26583
# reaction_26584
# reaction_26585
# reaction_26586
# reaction_26587
# reaction_26588
# reaction_26589
# reaction_26590
# reaction_26591
# reaction_26592
# reaction_26593
# reaction_26594
# reaction_26595
# reaction_26596
# reaction_26597
# reaction_26598
# reaction_26599
# reaction_26600
# reaction_26601
# reaction_26602
# reaction_26603
# reaction_26604
# reaction_26605
# reaction_26606
# reaction_26607
# reaction_26608
# reaction_26609
# reaction_26610
# reaction_26611
# reaction_26612
# reaction_26613
# reaction_26614
# reaction_26615
# reaction_26616
# reaction_26617
# reaction_26618
# reaction_26619
# reaction_26620
# reaction_26621
# reaction_26622
# reaction_26623
# reaction_26624
# reaction_26625
# reaction_26626
# reaction_26627
# reaction_26628
# reaction_26629
# reaction_26630
# reaction_26631
# reaction_26632
# reaction_26633
# reaction_26634
# reaction_26635
# reaction_26636
# reaction_26637
# reaction_26638
# reaction_26639
# reaction_26640
# reaction_26641
# reaction_26642
# reaction_26643
# reaction_26644
# reaction_26645
# reaction_26646
# reaction_26647
# reaction_26648
# reaction_26649
# reaction_26650
# reaction_26651
# reaction_26652
# reaction_26653
# reaction_26654
# reaction_26655
# reaction_26656
# reaction_26657
# reaction_26658
# reaction_26659
# reaction_26660
# reaction_26661
# reaction_26662
# reaction_26663
# reaction_26664
# reaction_26665
# reaction_26666
# reaction_26667
# reaction_26668
# reaction_26669
# reaction_26670
# reaction_26671
# reaction_26672
# reaction_26673
# reaction_26674
# reaction_26675
# reaction_26676
# reaction_26677
# reaction_26678
# reaction_26679
# reaction_26680
# reaction_26681
# reaction_26682
# reaction_26683
# reaction_26684
# reaction_26685
# reaction_26686
# reaction_26687
# reaction_26688
# reaction_26689
# reaction_26690
# reaction_26691
# reaction_26692
# reaction_26693
# reaction_26694
# reaction_26695
# reaction_26696
# reaction_26697
# reaction_26698
# reaction_26699
# reaction_26700
# reaction_26701
# reaction_26702
# reaction_26703
# reaction_26704
# reaction_26705
# reaction_26706
# reaction_26707
# reaction_26708
# reaction_26709
# reaction_26710
# reaction_26711
# reaction_26712
# reaction_26713
# reaction_26714
# reaction_26715
# reaction_26716
# reaction_26717
# reaction_26718
# reaction_26719
# reaction_26720
# reaction_26721
# reaction_26722
# reaction_26723
# reaction_26724
# reaction_26725
# reaction_26726
# reaction_26727
# reaction_26728
# reaction_26729
# reaction_26730
# reaction_26731
# reaction_26732
# reaction_26733
# reaction_26734
# reaction_26735
# reaction_26736
# reaction_26737
# reaction_26738
# reaction_26739
# reaction_26740
# reaction_26741
# reaction_26742
# reaction_26743
# reaction_26744
# reaction_26745
# reaction_26746
# reaction_26747
# reaction_26748
# reaction_26749
# reaction_26750
# reaction_26751
# reaction_26752
# reaction_26753
# reaction_26754
# reaction_26755
# reaction_26756
# reaction_26757
# reaction_26758
# reaction_26759
# reaction_26760
# reaction_26761
# reaction_26762
# reaction_26763
# reaction_26764
# reaction_26765
# reaction_26766
# reaction_26767
# reaction_26768
# reaction_26769
# reaction_26770
# reaction_26771
# reaction_26772
# reaction_26773
# reaction_26774
# reaction_26775
# reaction_26776
# reaction_26777
# reaction_26778
# reaction_26779
# reaction_26780
# reaction_26781
# reaction_26782
# reaction_26783
# reaction_26784
# reaction_26785
# reaction_26786
# reaction_26787
# reaction_26788

# %%
len(onto_graph)
# Out:
# 25577969

# %%
def get_all_triples_for_iri(iri_to_check):
    sparql_query = f"""
    SELECT ?s ?p ?o
    WHERE {{
        {{ <{iri_to_check}> ?p ?o . }}
        UNION
        {{ ?s ?p <{iri_to_check}> . }}
    }}
    """
    
    # Execute the SPARQL query
    results = onto_graph.query(sparql_query)
    return list(results)

# %%
iri_test = URIRef(MeNuGUIDE.reaction_9)

triples = get_all_triples_for_iri(iri_test)

for triple in triples:
    print(triple)
# Out:
# (None, rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://MeNuGUIDE.local/Reaction'))
# (None, rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('reaction_9'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/IAO_0000115'), rdflib.term.Literal('pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('KEGG:R00014'))
# (None, rdflib.term.URIRef('http://www.geneontology.org/formats/oboInOwl#hasDbXref'), rdflib.term.Literal('VMH:HMR_8746'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002233'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_5012'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002233'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_404077'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002233'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_4529'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002233'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_4784'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002234'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_3106'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002234'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_1654'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002234'), rdflib.term.URIRef('http://MeNuGUIDE.local/compound_3107'))
# (None, rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0000057'), rdflib.term.URIRef('http://MeNuGUIDE.local/EC:1.2.4.1'))
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_5012'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002352'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_404077'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002352'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_4529'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002352'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_4784'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002352'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_3106'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002353'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_1654'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002353'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/compound_3107'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002353'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/EC:1.2.4.1'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0000056'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/PDHA1'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002331'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/PDHA2'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002331'), None)
# (rdflib.term.URIRef('http://MeNuGUIDE.local/PDHB'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/RO_0002331'), None)

# %%
reactions_dict['reaction_9']
# Out:
# {'kegg_id': 'R00014',
#  'vmh_id': 'HMR_8746',
#  'description': 'pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)',
#  'substrates': {'compound_404077',
#   'compound_4529',
#   'compound_4784',
#   'compound_5012'},
#  'products': {'compound_1654', 'compound_3106', 'compound_3107'},
#  'genes': {'PDHA1', 'PDHA2', 'PDHB'},
#  'enzymes': {'EC:1.2.4.1'}}

# %%
onto_graph.serialize(destination=os.path.join(ontology_folder, "merged_with_foods_compounds_reactions.ttl"),
    format="turtle")
# Out:
# <Graph identifier=N05dff0e96c2649b7a861678b835c583e (<class 'rdflib.graph.Graph'>)>
