# %% [markdown]
# *MeNu GUIDE*
#
# # Preprocessing HMDB Data

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
hmdb_folder = "/path/to/downloaded/HMDB/data/"
processed_data_folder = "/path/to/processed/data/folder/"

# %% [markdown]
# ## Load XML file
# This can take a while, as the file is around 6GB

# %%
tree = ET.parse(f'{hmdb_folder}hmdb_metabolites.xml')
root = tree.getroot()

# %% [markdown]
# ## Extract all metabolites and their properties

# %%
compounds = []

for child in root:
    child_dict = {}
    
    for elem in child:
        # Some texts are None, some just contain white space, both of which we want to sort out. 
        if elem.text:
            text = elem.text.strip()
            if text:
                tag = elem.tag.split('}')[1]
                child_dict[tag] = text
    
    compounds.append(child_dict)

# %%
compounds_df = pd.DataFrame(compounds)

# %%
compounds_df
# Out:
#        version            creation_date              update_date    accession  \
# 0          5.0  2005-11-16 15:48:42 UTC  2021-10-13 17:34:04 UTC  HMDB0000001
# 1          5.0  2005-11-16 15:48:42 UTC  2021-10-13 04:18:52 UTC  HMDB0000002
# 2          5.0  2005-11-16 15:48:42 UTC  2020-11-09 23:11:34 UTC  HMDB0000005
# 3          5.0  2005-11-16 15:48:42 UTC  2021-09-14 15:44:51 UTC  HMDB0000008
# 4          5.0  2005-11-16 15:48:42 UTC  2021-09-14 15:41:25 UTC  HMDB0000010
# ...        ...                      ...                      ...          ...
# 217915     5.0  2021-10-01 18:05:59 UTC  2021-10-01 18:05:59 UTC  HMDB0304947
# 217916     5.0  2021-10-01 18:07:16 UTC  2021-10-01 18:07:16 UTC  HMDB0304950
# 217917     5.0  2021-10-01 18:07:41 UTC  2021-10-01 18:07:41 UTC  HMDB0304951
# 217918     5.0  2021-10-08 16:13:31 UTC  2021-10-08 16:22:12 UTC  HMDB0304953
# 217919     5.0  2021-10-08 16:24:44 UTC  2021-10-08 16:24:45 UTC  HMDB0304954
#
#             status                        name  \
# 0       quantified           1-Methylhistidine
# 1       quantified          1,3-Diaminopropane
# 2       quantified          2-Ketobutyric acid
# 3       quantified       2-Hydroxybutyric acid
# 4       quantified            2-Methoxyestrone
# ...            ...                         ...
# 217915    expected         Nordeoxycholic acid
# 217916    expected  3-Oxo-5beta-cholanoic acid
# 217917    expected        Glycerol 1-myristate
# 217918    expected       O-Phenolsulfonic acid
# 217919    expected                   d-Fucitol
#
#                                               description chemical_formula  \
# 0       1-Methylhistidine, also known as 1-MHis or 1MH...        C7H11N3O2
# 1       1,3-Diaminopropane, also known as DAP or trime...          C3H10N2
# 2       2-Ketobutyric acid, also known as alpha-ketobu...           C4H6O3
# 3       2-Hydroxybutyric acid (CAS: 600-15-7), also kn...           C4H8O3
# 4       2-Methoxyestrone (or 2-ME1) belongs to the cla...         C19H24O3
# ...                                                   ...              ...
# 217915                                                NaN         C23H38O4
# 217916                                                NaN         C24H38O3
# 217917                                                NaN         C17H34O4
# 217918                                                NaN          C6H6O4S
# 217919                                                NaN          C6H14O5
#
#        average_molecular_weight monisotopic_molecular_weight  ... knapsack_id  \
# 0                      169.1811                169.085126611  ...   C00052105
# 1                       74.1249                  74.08439833  ...   C00007404
# 2                      102.0886                102.031694058  ...   C00019675
# 3                       104.105                104.047344118  ...         NaN
# 4                      300.3921                300.172544634  ...         NaN
# ...                         ...                          ...  ...         ...
# 217915                  378.553                378.277009704  ...         NaN
# 217916                  374.565                374.282095084  ...         NaN
# 217917                  302.455                302.245709575  ...         NaN
# 217918                   174.17                173.998679847  ...         NaN
# 217919                 166.1724                166.084123558  ...         NaN
#
#        kegg_id            wikipedia_id metlin_id  \
# 0       C01152         Methylhistidine      3741
# 1       C00986      1,3-Diaminopropane       NaN
# 2       C00109  Alpha-Ketobutyric_acid       NaN
# 3       C05984   2-Hydroxybutyric_acid       NaN
# 4       C05299        2-Methoxyestrone      2578
# ...        ...                     ...       ...
# 217915     NaN                     NaN       NaN
# 217916     NaN                     NaN       NaN
# 217917     NaN                     NaN       NaN
# 217918     NaN                     NaN       NaN
# 217919     NaN                 Fucitol       NaN
#
#                                       synthesis_reference       biocyc_id  \
# 0       Jain, Rahul; Cohen, Louis A. Regiospecific alk...             NaN
# 1       Takayanagi, Yasuyuki; Oohinata, Takahiro.  Pre...         CPD-313
# 2       Figge, Rainer; Lux, Fabien; Raynaud, Celine; S...  2-OXOBUTANOATE
# 3       Carlier, J. P.; Henry, C.; Lorin, V.; Rouffign...        CPD-3564
# 4       Stoelwinder, Johannes; Moers, Nicolaas Elisabe...             NaN
# ...                                                   ...             ...
# 217915                                                NaN             NaN
# 217916                                                NaN             NaN
# 217917                                                NaN             NaN
# 217918                                                NaN             NaN
# 217919                                                NaN             NaN
#
#        bigg_id  vmh_id phenol_explorer_compound_id pdb_id
# 0          NaN     NaN                         NaN    NaN
# 1          NaN     NaN                         NaN    NaN
# 2        33889   2OBUT                         NaN    NaN
# 3          NaN     NaN                         NaN    NaN
# 4          NaN  C05299                         NaN    NaN
# ...        ...     ...                         ...    ...
# 217915     NaN     NaN                         NaN    NaN
# 217916     NaN     NaN                         NaN    NaN
# 217917     NaN     NaN                         NaN    NaN
# 217918     NaN     NaN                         NaN    NaN
# 217919     NaN     NaN                         NaN    NaN
#
# [217920 rows x 32 columns]

# %%
compounds_df = compounds_df.drop(columns=['version', 'status', 'creation_date', 'update_date', 'average_molecular_weight', 'traditional_iupac', 'state', 'synthesis_reference'])

# %% [markdown]
# ## Check for duplicates with the same ChEBI ID
# HMDB has some incorrect, duplicate annotations for certain external identifiers, among them ChEBI. As we want to merge the compounds from HMDB with ChEBI, we need to take care of this issue. Unfortunately, this is something that needs to be done manually. It might also be, that there are even more falsely assigned external identifiers that do not appear multiple times, but there is no easy way to check for that, as we can't go manually through thousands of compounds, so that might be something we will have to check at a later timepoint.

# %%
duplicated_chebi_ids = list(compounds_df[(compounds_df.chebi_id.duplicated()) & (compounds_df.chebi_id.notna())].chebi_id)
len(duplicated_chebi_ids)
# Out:
# 139

# %%
compounds_for_manual_inspection = compounds_df[compounds_df.chebi_id.isin(duplicated_chebi_ids)].sort_values(by='chebi_id')[['name', 'accession', 'chebi_id']]
compounds_for_manual_inspection.to_csv(f"{hmdb_folder}compounds_for_manual_chebi_id_inspection.csv")

# %% [markdown]
# $\rightarrow$ Manual inspection step inbetween

# %%
compounds_for_manual_inspection = pd.read_csv(f"{hmdb_folder}compounds_for_manual_chebi_id_inspection.csv", sep=';')
compounds_for_manual_inspection
# Out:
#      Unnamed: 0                                          name_hmdb  \
# 0         10622  5-Hydroxy-7-(4-hydroxy-3-methoxyphenyl)-1-phen...
# 1         14437  1-Acetyl-3,14,20-trihydroxywitha-5,24-dienolid...
# 2        216973                 (S)-2,3,4,5-tetrahydrodipicolinate
# 3        216972                    (R+)-3-(4-hydroxyphenyl)lactate
# 4          6345                                   LysoPC(15:0/0:0)
# ..          ...                                                ...
# 294        8332                            SM(d18:0/24:1(15Z)(OH))
# 295       15238                   S-Propyl 1-propanesulfinothioate
# 296       15242                                Vinaginsenoside R17
# 297       11607                          Theaflavin 3,3'-digallate
# 298       16068                                 Ganolucidic acid D
#
#          hmdb_id  chebi_id_hmdb website check
# 0    HMDB0029524        1030794  CHEBI:121564
# 1    HMDB0033572        1030794  CHEBI:168690
# 2    HMDB0303994          10980   CHEBI:16845
# 3    HMDB0303993          10980   CHEBI:10980
# 4    HMDB0010381         131924  CHEBI:131924
# ..           ...            ...           ...
# 294  HMDB0013469          90006   CHEBI:90006
# 295  HMDB0034394          91021   CHEBI:91021
# 296  HMDB0034398          91021           NaN
# 297  HMDB0030551         975367  CHEBI:136608
# 298  HMDB0035299         975367  CHEBI:156195
#
# [299 rows x 5 columns]

# %% [markdown]
# ### Integrate the manually corrected ChEBI IDs

# %%
compounds_for_manual_inspection.loc[:, 'website check'] = compounds_for_manual_inspection['website check'].apply(lambda x: x.split('CHEBI:')[1] if pd.notna(x) else float('NaN'))

# %%
compounds_for_manual_inspection.index = compounds_for_manual_inspection.hmdb_id
compounds_for_manual_inspection = compounds_for_manual_inspection['website check']
compounds_correct_chebi_dict = compounds_for_manual_inspection.to_dict()

# %%
columns_to_modify = ['chemspider_id', 'drugbank_id', 'foodb_id', 'pubchem_compound_id', 'knapsack_id', 'kegg_id', 'wikipedia_id', 'metlin_id', 'biocyc_id', 'bigg_id', 'vmh_id', 'phenol_explorer_compound_id', 'pdb_id']

adjusted_df = compounds_df.copy(deep=True)
adjusted_df = adjusted_df.sort_values(by='chebi_id')

for column in columns_to_modify:
    adjusted_df[column] = adjusted_df.apply(lambda row: row[column] if (row.accession not in compounds_correct_chebi_dict.keys()) else (row[column] if row.chebi_id == compounds_correct_chebi_dict[row.accession] else float('NaN')), axis=1)

adjusted_df['chebi_id'] = adjusted_df.apply(lambda row: row.chebi_id if (row.accession not in compounds_correct_chebi_dict.keys()) else compounds_correct_chebi_dict[row.accession], axis=1)

# %%
adjusted_df[(adjusted_df.chebi_id.duplicated()) & (adjusted_df.chebi_id.notna())][['accession', 'name', 'chebi_id']]
# Out:
#          accession                                               name chebi_id
# 39781  HMDB0059641        4,4-Dimethyl-5-alpha-cholest-7-en-3-beta-ol    16455
# 41860  HMDB0062457  cholest-5-en-3beta-yl (7Z,10Z,13Z,16Z,19Z-doco...    73910
# 40159  HMDB0060089                             w Hydroxy testosterone      798
# 2873   HMDB0006759                      3a-Hydroxy-5b-pregnane-20-one     1712

# %%
adjusted_df = adjusted_df[adjusted_df.accession != 'HMDB0059641']
adjusted_df = adjusted_df[adjusted_df.accession != 'HMDB0006769']
adjusted_df = adjusted_df[adjusted_df.accession != 'HMDB0006759']
adjusted_df = adjusted_df[adjusted_df.accession != 'HMDB0010375']

# %%
adjusted_df.to_csv(f'{processed_data_folder}hmdb_metabolites.csv', index=False)
