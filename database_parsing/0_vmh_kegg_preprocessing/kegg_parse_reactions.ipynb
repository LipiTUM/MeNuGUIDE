# %% [markdown]
# **Metabolome-Microbiome-Network**
# ## Parsing KEGG Reactions

# %%
import os
import pandas as pd
import requests
import re

# %%
url_kegg_get_all_reactions = 'http://rest.kegg.jp/list/reaction'
response = requests.request("GET", url_kegg_get_all_reactions)
text = response.text
text = text.strip()

# %%
print(text)
# Out:
# R00001	polyphosphate polyphosphohydrolase
# R00002	Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)
# R00004	diphosphate phosphohydrolase
# R00005	urea-1-carboxylate amidohydrolase
# R00006	pyruvate:pyruvate acetaldehydetransferase (decarboxylating)
# R00008	4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)
# R00009	hydrogen-peroxide:hydrogen-peroxide oxidoreductase
# R00010	alpha,alpha-trehalose glucohydrolase
# R00011	Mn(II):hydrogen-peroxide oxidoreductase
# R00012	GTP:GTP guanylyltransferase
# R00013	glyoxylate carboxy-lyase (dimerizing
# R00014	pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)
# R00015	sucrose:sucrose 1'-beta-D-fructosyltransferase
# R00017	ferrocytochrome-c:hydrogen-peroxide oxidoreductase
# R00018	putrescine:putrescine 4-aminobutyltransferase (ammonia-forming)
# R00019	hydrogen:ferredoxin oxidoreductase
# R00021	L-glutamate:ferredoxin oxidoreductase (transaminating)
# R00022	chitobiose N-acetylglucosaminohydrolase
# R00023	hydroxylamine:NAD+ oxidoreductase
# R00024	3-phospho-D-glycerate carboxy-lyase (dimerizing
# R00025	ethylnitronate:oxygen 2-oxidoreductase (nitrite-forming)
# R00026	cellobiose glucohydrolase
# R00027	2-hydroxy-1,2-diphenylethanone benzaldehyde-lyase (benzaldehyde-forming)
# R00028	maltose glucohydrolase
# R00029	thiosulfate:ferricytochrome-c oxidoreductase
# R00031	1,2-benzenediol:oxygen oxidoreductase
# R00032	beta-carotene:oxygen 15,15'-oxidoreductase (bond-cleaving)
# R00033	thiamine:oxygen 5-oxidoreductase
# R00034	Cyclobutadipyrimidine (in DNA) pyrimidine-lyase
# R00036	5-aminolevulinate hydro-lyase (adding 5-aminolevulinate and cyclizing
# R00038	4-hydroxy-3-hexanone propanal-lyase (propanal-forming)
# R00039	raffinose:raffinose 1F-alpha-D-galactosyltransferase
# R00041	long-chain-alcohol:oxygen oxidoreductase
# R00042	4-hydroxyphenylpyruvate:oxygen oxidoreductase (decarboxylating)
# R00043	1,2-bis(4-hydroxy-3-methoxyphenyl)ethylene:oxygen oxidoreductase (alpha-beta-bond-cleaving)
# R00044	columbamine:oxygen oxidoreductase (cyclizing)
# R00045	3,4-dihydroxy-L-phenylalanine:oxygen oxidoreductase
# R00047	6-hydroxynicotinate,hydrogen-donor:oxygen oxidoreductase (3-hydroxylating, decarboxylating)
# R00048	(R)-3-((R)-3-Hydroxybutanoyloxy)-butanoate hydroxybutanoylhydrolase
# R00049	1-O-galloyl-beta-D-glucose:1-O-galloyl-beta-D-glucose O-galloyltransferase
# R00052	chloride:hydrogen-peroxide oxidoreductase
# R00053	digallate acylhydrolase
# R00054	orsellinate-depside hydrolase
# R00055	inosine:oxygen 5'-oxidoreductase
# R00056	dinucleotide nucleotidohydrolase
# R00057	thiol:oxygen oxidoreductase
# R00058	catechol:oxygen oxidoreductase
# R00059	N-(6-aminohexanoyl)-6-aminohexanoate amidohydrolase
# R00060	Sulochrin:oxygen oxidoreductase (cyclizing, (+)-specific)
# R00061	sulochrin:oxygen oxidoreductase (cyclizing, (-)-specific)
# R00062	bilirubin-glucuronoside:bilirubin-glucuronoside D-glucuronosyltransferase
# R00063	1-O-sinapoyl-beta-D-glucose:1-O-sinapoyl-beta-D-glucose 1-O-sinapoyltransferase
# R00066	6,7-Dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase
# R00067	Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)
# R00068	L-ascorbate:oxygen oxidoreductase
# R00069	4-imidazolone-5-propanoate:oxygen oxidoreductase
# R00070	D-urobilinogen:oxygen oxidoreductase
# R00072	thiamine-aldehyde:oxygen 5-oxidoreductase
# R00073	reduced acceptor:prostaglandin G2 oxidoreductase
# R00074	2-aminophenol:oxygen oxidoreductase (dimerizing)
# R00075	S-adenosyl-L-methionine:S-adenosyl-L-methionine 3-amino-3-carboxypropyltransferase
# R00076	ATP:phosphorylase-b phosphotransferase
# R00077	[Phosphorylase a] phosphohydrolase
# R00078	Fe(II):oxygen oxidoreductase
# R00080	Catechol:oxygen oxidoreductase (dimerizing)
# R00081	ferrocytochrome-c:oxygen oxidoreductase
# R00082	ferrocytochrome c2:oxygen oxidoreductase
# R00083	Benzenediol:oxygen oxidoreductase
# R00084	porphobilinogen:(4-[2-carboxyethyl]-3-[carboxymethyl]pyrrol-2-yl)methyltransferase (hydrolysing)
# R00085	ATP diphosphohydrolase (phosphate-forming)
# R00086	ATP phosphohydrolase
# R00087	ATP diphosphohydrolase (diphosphate-forming)
# R00088	ATP aminohydrolase
# R00089	ATP diphosphate-lyase (cyclizing
# R00090	NADH:hydrogen-peroxide oxidoreductase
# R00091	CoA:NAD+ oxidoreductase
# R00092	Fe2+:NAD+ oxidoreductase
# R00093	L-glutamate:NAD+ oxidoreductase (transaminating)
# R00094	glutathione:NAD+ oxidoreductase
# R00095	NADH:monodehydroascorbate oxidoreductase
# R00097	Cob(II)alamin <=> Aquacob(III)alamin
# R00099	Cob(I)alamin <=> Cob(II)alamin
# R00100	NADH:ferricytochrome-b5 oxidoreductase
# R00101	NADH:ferrileghemoglobin oxidoreductase
# R00102	NAD+ glycohydrolase
# R00103	NAD+ phosphohydrolase
# R00104	ATP:NAD+ 2'-phosphotransferase
# R00105	ATP:NADH 2'-phosphotransferase
# R00106	NADPH:ferricytochrome oxidoreductase
# R00108	NADPH:ferricytochrome-c2 oxidoreductase
# R00109	NADPH:ferrileghemoglobin oxidoreductase
# R00111	N-(omega)-Hydroxyarginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)
# R00112	NADPH:NAD+ oxidoreductase
# R00113	NADPH:hydrogen-peroxide oxidoreductase
# R00114	L-glutamate:NADP+ oxidoreductase (transaminating)
# R00115	glutathione:NADP+ oxidoreductase
# R00118	NADP+ 2'-phosphohydrolase
# R00119	NADP+:nicotinate ADP-ribosyltransferase
# R00120	glutathione:oxygen oxidoreductase
# R00122	ADP phosphohydrolase
# R00123	ADP aminohydrolase
# R00124	ATP:ADP phosphatransferase
# R00125	P1,P4-bis(5'-adenosyl)-tetraphosphate nucleotidebisphosphohydrolase
# R00126	ADP:ATP adenylyltransferase
# R00127	ATP:AMP phosphotransferase
# R00128	Adenosine-tetraphosphate phosphohydrolase
# R00129	(6S)-6beta-hydroxy-1,4,5,6-tetrahydronicotinamide-adenine dinucleotide hydro-lyase (ATP-hydrolysing, NADH-forming)
# R00130	ATP:dephospho-CoA 3'-phosphotransferase
# R00131	Urea amidohydrolase
# R00132	carbonate hydro-lyase (carbon-dioxide-forming)
# R00134	formate:NADP+ oxidoreductase
# R00135	Peptide + H2O <=> L-Proline + Peptide
# R00137	ATP:nicotinamide-nucleotide adenylyltransferase
# R00138	Triphosphate phosphohydrolase
# R00139	ATP:2'-deoxy-5-hydroxymethylcytidine-5'-diphosphate phosphotransferase
# R00140	ATP:5-hydroxymethyldeoxycytidylate phosphotransferase
# R00141	ATP:ammonia phosphotransferase
# R00143	ammonia:NAD+ oxidoreductase
# R00145	alpha-amino acid:NAD+ oxidoreductase (deaminating)
# R00146	alpha-amino acid:NADP+ oxidoreductase (deaminating)
# R00148	ammonia,ubiquinol:oxygen oxidoreductase
# R00149	Carbon-dioxide:ammonia ligase (ADP-forming,carbamate-phosphorylating)
# R00150	ATP:carbamate phosphotransferase
# R00152	hydrogen cyanide aminohydrolase
# R00153	Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)
# R00155	UDP phosphohydrolase
# R00156	ATP:UDP phosphotransferase
# R00157	Uridine triphosphate:AMP phosphotransferase
# R00158	ATP:UMP phosphotransferase
# R00159	UTP phosphohydrolase
# R00160	FAD nucleotidohydrolase
# R00161	ATP:FMN adenylyltransferase
# R00162	ATP:protein phosphotransferase
# R00164	Phosphoprotein phosphohydrolase
# R00165	Protein <=> L-Alanyl-tRNA
# R00166	Protein <=> L-Leucyl-tRNA
# R00167	L-Arginyl-tRNA(Arg) <=> Protein-L-arginine
# R00168	Protein <=> L-Valyl-tRNA(Val)
# R00169	Protein <=> L-Glutamyl-tRNA(Glu)
# R00170	Protein <=> L-Isoleucyl-tRNA(Ile)
# R00172	Protein <=> Selenomethionyl-tRNA(Met)
# R00173	pyridoxal-5'-phosphate phosphohydrolase
# R00174	ATP:pyridoxal 5'-phosphotransferase
# R00177	ATP:L-methionine S-adenosyltransferase
# R00178	S-adenosyl-L-methionine carboxy-lyase [S-adenosyl 3-(methylsulfanyl)propylamine-forming]
# R00179	S-adenosyl-L-methionine methylthioadenosine-lyase (1-aminocyclopropane-1-carboxylate-forming)
# R00181	AMP aminohydrolase
# R00182	AMP phosphoribohydrolase
# R00183	adenosine 5'-monophosphate phosphohydrolase
# R00184	P1,P4-bis(5'-adenosyl)-tetraphosphate adenylohydrolase
# R00185	ATP:adenosine 5'-phosphotransferase
# R00187	P1,P3-bis(5'-adenosyl)-triphosphate adenylohydrolase
# R00188	adenosine-3',5'-bisphosphate 3'-phosphohydrolase
# R00189	deamido-NAD+:ammonia ligase (AMP-forming)
# R00190	AMP:diphosphate phospho-D-ribosyltransferase
# R00191	adenosine 3',5'-phosphate 5'-nucleotidohydrolase
# R00192	S-Adenosyl-L-homocysteine hydrolase
# R00193	S-Adenosyl-L-homocysteine aminohydrolase
# R00194	S-Adenosyl-L-homocysteine homocysteinylribohydrolase
# R00195	2,3-diaminopropanoate ammonia-lyase (adding water
# R00196	(S)-Lactate:ferricytochrome-c 2-oxidoreductase
# R00197	(R)-Lactate:ferricytochrome-c 2-oxidoreductase
# R00198	(R)-Lactate:ferricytochrome-c-553 2-oxidoreductase
# R00199	ATP:pyruvate,water phosphotransferase
# R00200	ATP:pyruvate 2-O-phosphotransferase
# R00203	pyruvaldehyde:NAD+ oxidoreductase
# R00205	2-Oxopropanal:NADP+ oxidoreductase
# R00206	ATP:pyruvate,phosphate phosphotransferase
# R00207	Pyruvate:oxygen 2-oxidoreductase (phosphorylating)
# R00208	Phosphoenolpyruvate phosphohydrolase
# R00209	pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating)
# R00210	pyruvate:NADP+ 2-oxidoreductase (CoA-acetylating)
# R00211	pyruvate:oxygen 2-oxidoreductase (CoA-acetylating)
# R00212	Acetyl-CoA:formate C-acetyltransferase
# R00213	O-carbamoyl-L-serine ammonia-lyase (decarboxylating
# R00214	(S)-malate:NAD+ oxidoreductase (decarboxylating)
# R00215	(R)-Malate:NAD+ oxidoreductase (decarboxylating)
# R00216	(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)
# R00217	oxaloacetate carboxy-lyase (pyruvate-forming)
# R00218	acetylenedicarboxylate carboxy-lyase (pyruvate-forming)
# R00219	2-Hydroxyethylenedicarboxylate carboxy-lyase (pyruvate-forming)
# R00220	L-serine ammonia-lyase
# R00221	D-serine ammonia-lyase
# R00223	serine ammonia-lyase (pyruvate-forming)
# R00224	pyruvate carboxy-lyase (acetaldehyde-forming)
# R00226	pyruvate:pyruvate acetaldehydetransferase (decarboxylating)
# R00227	Acetyl-CoA hydrolase
# R00228	acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)
# R00229	acetate:CoA ligase (ADP-forming)
# R00230	acetyl-CoA:phosphate acetyltransferase
# R00233	malonyl-CoA carboxy-lyase (acetyl-CoA-forming)
# R00235	Acetate:CoA ligase (AMP-forming)
# R00236	acetyl adenylate:CoA acetyltransferase
# R00237	(3S)-citramalyl-CoA pyruvate-lyase (acetyl-CoA-forming)
# R00238	acetyl-CoA:acetyl-CoA C-acetyltransferase
# R00239	ATP:L-glutamate 5-phosphotransferase
# R00243	L-glutamate:NAD+ oxidoreductase (deaminating)
# R00245	L-glutamate gamma-semialdehyde:NAD+ oxidoreductase
# R00248	L-glutamate:NADP+ oxidoreductase (deaminating)
# R00250	L-Glutamate:oxygen oxidoreductase (deaminating)
# R00251	5-oxo-L-proline amidohydrolase (ATP-hydrolysing)
# R00253	L-Glutamate:ammonia ligase (ADP-forming)
# R00254	N-carbamyl-L-glutamate amidohydrolase
# R00256	L-glutamine amidohydrolase
# R00257	Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)
# R00258	L-Alanine:2-oxoglutarate aminotransferase
# R00259	acetyl-CoA:L-glutamate N-acetyltransferase
# R00260	glutamate racemase
# R00261	L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)
# R00262	L-threo-3-methylaspartate carboxy-aminomethylmutase
# R00263	L-Glutamate <=> Poly-gamma-D-glutamate
# R00264	2,5-dioxopentanoate:NADP+ 5-oxidoreductase
# R00265	2-oxoglutarate:NADP+ 2-oxidoreductase (CoA-succinylating)
# R00267	Isocitrate:NADP+ oxidoreductase (decarboxylating)
# R00268	oxalosuccinate carboxy-lyase (2-oxoglutarate-forming)
# R00269	2-oxoglutaramate amidohydrolase
# R00270	2-Oxoglutarate + Ammonia <=> 4-Oxoglutaramate + H2O
# R00271	acetyl-CoA:2-oxoglutarate C-acetyltransferase (thioester-hydrolysing, carboxymethyl forming)
# R00272	2-Oxoglutarate carboxy-lyase
# R00273	oxalate:oxygen oxidoreductase
# R00274	glutathione:hydrogen-peroxide oxidoreductase
# R00275	superoxide:superoxide oxidoreductase
# R00277	pyridoxamine-5'-phosphate:oxygen oxidoreductase (deaminating)
# R00278	pyridoxine 5'-phosphate:oxygen oxidoreductase
# R00279	D-Glutamate:oxygen oxidoreductase (deaminating)
# R00280	Nitric-oxide:acceptor oxidoreductase
# R00282	NADPH:acceptor oxidoreductase
# R00283	ammonium:acceptor oxidoreductase (ATP-forming)
# R00284	ammonia:acceptor oxidoreductase
# R00286	UDP-glucose:NAD+ 6-oxidoreductase
# R00287	UDP-glucose glucophosphohydrolase
# R00289	UTP:alpha-D-glucose-1-phosphate uridylyltransferase
# R00291	UDP-glucose 4-epimerase
# R00292	UDP-glucose:glycogen 4-alpha-D-glucosyltransferase
# R00293	UDP-glucose 4,6-hydro-lyase (UDP-4-dehydro-6-deoxy-D-glucose-forming)
# R00294	nitrous-oxide:ferricytochrome-c oxidoreductase
# R00295	trithionate: (acceptor) oxidoreductase
# R00297	(R)-2-hydroxy-acid:acceptor 2-oxidoreductase
# R00298	(S)-2-hydroxyglutarate:acceptor 2-oxidoreductase
# R00299	ATP:D-glucose 6-phosphotransferase
# R00300	D-Glucose:NAD+ 1-oxidoreductase
# R00301	D-Glucose:NADP+ 1-oxidoreductase
# R00302	D-glucose:oxygen 2-oxidoreductase
# R00303	D-Glucose-6-phosphate phosphohydrolase
# R00304	D-Glucose-1-phosphate phosphohydrolase
# R00305	D-glucose:quinone 1-oxidoreductase
# R00306	cellobiose glucohydrolase
# R00307	alpha-D-glucose aldose-ketose-isomerase
# R00308	1,3-beta-D-Glucan glucanohydrolase
# R00310	protoheme ferro-lyase (protoporphyrin-forming)
# R00311	protoheme,NADPH---hemoprotein reductase:oxygen oxidoreductase (alpha-methene-oxidizing, hydroxylating)
# R00312	Heme <=> Cytochrome a
# R00313	Heme <=> Catalase
# R00314	Heme <=> Peroxidase
# R00315	ATP:acetate phosphotransferase
# R00316	ATP:acetate adenylyltransferase
# R00317	Acetyl phosphate phosphohydrolase
# R00318	Phosphonoacetate phosphonohydrolase
# R00319	(S)-lactate:oxygen 2-oxidoreductase (decarboxylating)
# R00320	diphosphate:acetate phosphotransferase
# R00321	Acetamide amidohydrolase
# R00322	5'-acetylphosphoadenosine acetylhydrolase
# R00324	2,4-dioxopentanoate acetylhydrolase
# R00325	(2S)-2-hydroxy-2-methylbutanedioate pyruvate-lyase (acetate-forming)
# R00326	acetaldehyde:acceptor oxidoreductase
# R00327	6-Acetyl-D-glucose acetylhydrolase
# R00328	GDP phosphohydrolase
# R00329	Nucleoside-diphosphate phosphohydrolase
# R00330	ATP:GDP phosphotransferase
# R00331	ATP:nucleoside-diphosphate phosphotransferase
# R00332	ATP:GMP phosphotransferase
# R00333	nucleoside-triphosphate:AMP phosphotransferase
# R00334	ATP:nucleoside-phosphate phosphotransferase
# R00335	GTP phosphohydrolase
# R00336	guanosine-3',5'-bis(diphosphate) 3'-diphosphohydrolase
# R00337	GDP-glucose glucohydrolase
# R00338	Oxaloacetate acetylhydrolase
# R00339	(R,R)-tartrate hydro-lyase (oxaloacetate-forming)
# R00340	(S,S)-tartrate hydro-lyase (oxaloacetate-forming)
# R00341	ATP:oxaloacetate carboxy-lyase (transphosphorylating
# R00342	(S)-malate:NAD+ oxidoreductase
# R00343	(S)-malate:NADP+ oxidoreductase
# R00344	Pyruvate:carbon-dioxide ligase (ADP-forming)
# R00345	phosphate:oxaloacetate carboxy-lyase (adding phosphate
# R00346	diphosphate:oxaloacetate carboxy-lyase (transphosphorylating
# R00347	erythro-3-hydroxy-Ls-aspartate ammonia-lyase (oxaloacetate-forming)
# R00348	2-oxosuccinamate amidohydrolase
# R00350	4-carboxy-4-hydroxy-2-oxoadipate oxaloacetate-lyase (pyruvate-forming)
# R00351	acetyl-CoA:oxaloacetate C-acetyltransferase (thioester-hydrolysing)
# R00352	acetyl-CoA:oxaloacetate C-acetyltransferase [(pro-S)-carboxymethyl-forming, ADP-phosphorylating]
# R00353	malonyl-CoA:pyruvate carboxytransferase
# R00354	(3S)-citryl-CoA oxaloacetate-lyase (acetyl-CoA-forming)
# R00355	L-Aspartate:2-oxoglutarate aminotransferase
# R00357	L-Aspartic acid:oxygen oxidoreductase (deaminating)
# R00359	D-Aspartate:oxygen oxidoreductase (deaminating)
# R00360	(S)-Malate:oxygen oxidoreductase
# R00361	(S)-malate:quinone oxidoreductase
# R00362	citrate oxaloacetate-lyase (forming acetate from the pro-S carboxymethyl group of citrate)
# R00363	Oxaloacetate keto-enol-isomerase
# R00364	Glycine:ferricytochrome-c oxidoreductase (deaminating)
# R00365	glycine:NAD+ oxidoreductase (deaminating)
# R00366	glycine:oxygen oxidoreductase (deaminating)
# R00367	S-Adenosyl-L-methionine:glycine N-methyltransferase
# R00368	N-(carboxymethyl)-D-alanine:NAD+ oxidoreductase (glycine-forming)
# R00369	L-Alanine:glyoxylate aminotransferase
# R00371	Acetyl-CoA:glycine C-acetyltransferase
# R00372	Glycine:2-oxoglutarate aminotransferase
# R00373	Glycine:oxaloacetate aminotransferase
# R00374	glycine:acceptor oxidoreductase (cyanide-forming)
# R00375	Deoxyadenosine 5'-triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)
# R00376	Deoxyguanosine 5'-triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)
# R00377	Deoxycytidine triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)
# R00378	deoxythymidine triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)
# R00379	Deoxynucleoside triphosphate:DNA deoxynucleotidyltransferase
# R00380	S-Adenosyl-L-methionine:DNA (cytosine-5-)-methyltransferase
# R00381	(deoxyribonucleotide)n:5'-phospho-(deoxyribonucleotide)m ligase (AMP-forming)
# R00382	(deoxyribonucleotide)n:5'-phospho-(deoxyribonucleotide)m ligase (AMP-forming, NMN-forming)
# R00383	Acyl-CoA hydrolase
# R00384	acyl-CoA:NAD+ trans-2-oxidoreductase
# R00385	acyl-CoA:NADP+ 2-oxidoreductase
# R00387	acyl-CoA:NADP+ cis-2-oxidoreductase
# R00388	Acyl-CoA:oxygen 2-oxidoreductase
# R00389	medium-chain-fatty-acid:CoA ligase (AMP-forming)
# R00390	long-chain-fatty-acid:CoA ligase (AMP-forming)
# R00391	Acyl-CoA:acetyl-CoA C-acyltransferase
# R00392	acyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase
# R00393	Acyl-CoA:acetate CoA-transferase
# R00394	carboxylic acid:CoA ligase (GDP-forming)
# R00395	Acyl-CoA:glycine N-acyltransferase
# R00396	L-alanine:NAD+ oxidoreductase (deaminating)
# R00397	L-aspartate 4-carboxy-lyase (L-alanine-forming)
# R00398	2,2'-iminodipropanoate:NAD+ oxidoreductase (L-alanine-forming)
# R00399	2-amino-4-ketopentanoate thiolase
# R00400	L-alanine:oxaloacetate aminotransferase
# R00401	alanine racemase
# R00402	succinate:NAD+ oxidoreductase
# R00405	Succinate:CoA ligase (ADP-forming)
# R00406	succinyl-CoA:(S)-malate CoA-transferase
# R00407	Succinyl-CoA hydrolase
# R00408	succinate:FAD oxidoreductase
# R00409	(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylate pyruvate-lyase (succinate-forming)
# R00410	succinyl-CoA:acetoacetate CoA-transferase
# R00411	N-succinyl-L-glutamate amidohydrolase
# R00412	succinate:acceptor oxidoreductase
# R00414	UDP-N-acetyl-D-glucosamine 2-epimerase
# R00416	UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase
# R00417	UDP-N-acetyl-D-glucosamine:protein beta-N-acetyl-D-glucosaminyltransferase
# R00418	UDP-N-acetyl-D-glucosamine 4-epimerase
# R00420	UDP-N-acetyl-D-glucosamine 2-epimerase
# R00421	UDP-N-acetyl-D-glucosamine:NAD+ 6-oxidoreductase
# R00422	UDP-N-acetyl-alpha-D-glucosamine <=> Glycolipid
# R00423	UDP-N-acetyl-alpha-D-glucosamine <=> Mucopolysaccharide
# R00424	GTP 7,8-8,9-dihydrolase
# R00425	GTP 7,8-8,9-dihydrolase (diphosphate-forming)
# R00426	GTP diphosphohydrolase (diphosphate-forming)
# R00428	GTP 8,9-hydrolase
# R00429	ATP:GTP 3'-diphosphotransferase
# R00430	GTP:pyruvate 2-O-phosphotransferase
# R00431	GTP:oxaloacetate carboxy-lyase (adding GTP
# R00432	Succinate:CoA ligase (GDP-forming)
# R00434	GTP diphosphate-lyase (cyclizing
# R00435	ATP:polynucleotide adenylyltransferase
# R00436	polyribonucleotide ligase (cyclizing, AMP-forming)
# R00437	polyribonucleotide:phosphate adenylyltransferase
# R00438	polyribonucleotide:phosphate uridylyltransferase
# R00439	polyribonucleotide:phosphate guanylyltransferase
# R00440	polyribonucleotide:phosphate cytidylyltransferase
# R00441	GTP:RNA guanylyltransferase (DNA-directed)
# R00442	CTP:RNA cytidylyltransferase (DNA-directed)
# R00443	UTP:RNA uridylyltransferase
# R00444	nucleoside-triphosphate:RNA nucleotidyltransferase (DNA-directed)
# R00445	L-lysine:NAD+ oxidoreductase (deaminating, cyclizing)
# R00446	L-lysine:NAD+ 6-oxidoreductase (deaminating)
# R00447	L-lysine:oxygen 2-oxidoreductase (deaminating)
# R00448	L-lysine,NADPH:oxygen oxidoreductase (6-hydroxylating)
# R00449	L-lysine:oxygen 2-oxidoreductase (decarboxylating)
# R00451	meso-2,6-diaminoheptanedioate carboxy-lyase (L-lysine-forming)
# R00452	N2-(D-1-carboxylethyl)-L-lysine:NADP+ oxidoreductase (L-lysine-forming)
# R00453	L-Lysine:pyruvate aminotransferase
# R00454	acetyl-CoA:L-lysine N6-acetyltransferase
# R00457	L-Lysine:2-oxoglutarate 6-aminotransferase
# R00458	N6-acetyl-L-lysine amidohydrolase
# R00459	L-Lysine <=> L-Pipecolate
# R00460	lysine racemase
# R00461	L-Lysine 2,3-aminomutase
# R00462	L-lysine carboxy-lyase (cadaverine-forming)
# R00463	L-Lysine-1,6-lactam lactamhydrolase
# R00465	glycolate:NADP+ oxidoreductase
# R00466	Glyoxylate:oxygen oxidoreductase
# R00468	Glyoxylate:NADP+ oxidoreductase (CoA-oxalylating)
# R00469	(S)-ureidoglycolate amidohydrolase (decarboxylating)
# R00470	4-hydroxy-2-oxoglutarate glyoxylate-lyase (pyruvate-forming)
# R00471	4-hydroxy-2-oxoglutarate glyoxylate-lyase (pyruvate-forming)
# R00472	acetyl-CoA:glyoxylate C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)
# R00473	L-malyl-CoA glyoxylate-lyase (acetyl-CoA-forming)
# R00474	2-oxoglutarate:glyoxylate succinaldehydetransferase (decarboxylating)
# R00475	glycolate:oxygen 2-oxidoreductase
# R00476	glycolate:acceptor 2-oxidoreductase
# R00477	3-oxalomalate glyoxylate-lyase (oxaloacetate-forming)
# R00478	erythro-3-hydroxy-Ls-aspartate glyoxylate-lyase (glycine-forming)
# R00479	isocitrate glyoxylate-lyase (succinate-forming)
# R00480	ATP:L-aspartate 4-phosphotransferase
# R00481	L-aspartate:oxygen oxidoreductase
# R00482	L-Aspartate:ammonia ligase (ADP-forming)
# R00483	L-aspartate:ammonia ligase (AMP-forming)
# R00484	N-Carbamoyl-L-aspartate amidohydrolase
# R00485	L-asparagine amidohydrolase
# R00486	3-Cyano-L-alanine aminohydrolase
# R00487	acetyl-CoA:L-aspartate N-acetyltransferase
# R00488	N-Acetyl-L-aspartate amidohydrolase
# R00489	L-aspartate 1-carboxy-lyase (beta-alanine-forming)
# R00490	L-aspartate ammonia-lyase (fumarate-forming)
# R00491	aspartate racemase
# R00493	L-aspartate:2-oxo acid aminotransferase
# R00494	glutathione gamma-glutamylaminopeptidase
# R00497	gamma-L-glutamyl-L-cysteine:glycine ligase (ADP-forming)
# R00499	S-Succinylglutathione hydrolase
# R00501	UDP-alpha-D-galactose:NAD+ 6-oxidoreductase
# R00502	UTP:alpha-D-galactose-1-phosphate uridylyltransferase
# R00503	UDP-alpha-D-galactose:D-glucose 4-beta-D-galactosyltransferase
# R00504	UDP-alpha-D-galactose:UDP-N-acetyl-alpha-D-glucosamine galactose phosphotransferase
# R00505	UDP-alpha-D-galactopyranose furanomutase
# R00506	UDP-alpha-D-galactose:galactan beta-1,4-D-galactosyltransferase
# R00507	3'-phosphoadenylyl-sulfate sulfohydrolase
# R00508	3'-phospho-5'-adenylyl sulfate 3'-phosphohydrolase
# R00509	ATP:adenylylsulfate 3'-phosphotransferase
# R00510	cytidine-5'-monophosphate phosphoribohydrolase
# R00511	cytidine-5'-monophosphate phosphohydrolase
# R00512	ATP:CMP phosphotransferase
# R00513	ATP:cytidine 5'-phosphotransferase
# R00514	CDP phosphohydrolase
# R00515	CTP diphosphohydrolase (diphosphate-forming)
# R00517	GTP:cytidine 5'-phosphotransferase
# R00518	ATP:formate phosphotransferase
# R00519	formate:NAD+ oxidoreductase
# R00521	Formyl-CoA hydrolase
# R00522	Oxalate carboxy-lyase
# R00524	Formamide amidohydrolase
# R00525	N-Formyl-L-glutamate amidohydrolase
# R00526	N-Formyl-L-aspartate amidohydrolase
# R00527	S-Formylglutathione hydrolase
# R00528	sulfite:ferricytochrome-c oxidoreductase
# R00529	ATP:sulfate adenylyltransferase
# R00530	ADP:sulfate adenylyltransferase
# R00531	Adenylylsulfate sulfohydrolase
# R00532	L-Serine-O-sulfate ammonia-lyase (pyruvate-forming)
# R00533	Sulfite:oxygen oxidoreductase
# R00534	D-Glucose 6-sulfate sulfohydrolase
# R00535	3'-Phosphoadenylylsulfate:17beta-estradiol 3-sulfotransferase
# R00536	3'-Phosphoadenylylsulfate:phenolic-steroid sulfotransferase
# R00537	3'-Phosphoadenylylsulfate:phenolic-steroid sulfotransferase
# R00538	Aldehyde:NAD+ oxidoreductase
# R00539	Acyl phosphate phosphohydrolase
# R00540	Nitrile aminohydrolase
# R00542	5'-Acylphosphoadenosine acylhydrolase
# R00543	3-Acylpyruvate acylhydrolase
# R00544	aldehyde:acceptor oxidoreductase
# R00545	N6-Acyl-L-lysine amidohydrolase
# R00546	N-Acyl-L-aspartate amidohydrolase
# R00547	S-Acylglutathione hydrolase
# R00548	riboflavin-5-phosphate phosphohydrolase
# R00549	ATP:riboflavin 5'-phosphotransferase
# R00550	D-Glucose-1-phosphate:riboflavin 5'-phosphotransferase
# R00551	L-Arginine amidinohydrolase
# R00552	L-Arginine iminohydrolase
# R00554	ATP:L-arginine Nomega-phosphotransferase
# R00555	NAD+:protein-L-arginine ADP-D-ribosyltransferase
# R00557	L-arginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)
# R00558	L-arginine,NADPH:oxygen oxidoreductase (N-(omega)-hydroxyarginine-forming)
# R00559	L-Arginine:oxygen 2-oxidoreductase (decarboxylating)
# R00562	N2-(D-1-carboxyethyl)-L-arginine:NAD+ oxidoreductase (L-arginine-forming)
# R00563	N2-(D-1,3-dicarboxypropyl)-L-arginine:NADP+ oxidoreductase (L-arginine-forming)
# R00565	L-Arginine:glycine amidinotransferase
# R00566	L-arginine carboxy-lyase (agmatine-forming)
# R00567	arginine racemase
# R00569	CTP phosphohydrolase
# R00570	ATP:CDP phosphotransferase
# R00571	UTP:ammonia ligase (ADP-forming)
# R00572	CTP:pyruvate 2-O-phosphotransferase
# R00573	UTP:L-glutamine amido-ligase (ADP-forming)
# R00574	CTP diphosphate-lyase (cyclizing
# R00575	HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)
# R00576	L-Glutamine:pyruvate aminotransferase
# R00577	acyl-CoA:L-glutamine N-acyltransferase
# R00578	L-aspartate:L-glutamine amido-ligase (AMP-forming)
# R00579	glutamine racemase
# R00581	L-serine:NAD+ oxidoreductase (deaminating)
# R00582	O-phospho-L-serine phosphohydrolase
# R00584	diphosphate:L-serine O-phosphotransferase
# R00585	L-Serine:pyruvate aminotransferase
# R00586	acetyl-CoA:L-serine O-acetyltransferase
# R00588	L-Serine:glyoxylate aminotransferase
# R00589	serine racemase
# R00590	L-serine hydro-lyase
# R00594	S-Adenosyl-L-methionine:tRNA uracil 5-methyltransferase
# R00595	S-adenosyl-L-methionine:tRNA (cytosine-C5)-methyltransferase
# R00596	S-adenosyl-L-methionine:tRNA adenine N1-methyltransferase
# R00597	S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase
# R00598	S-Adenosyl-L-methionine:tRNA guanine N2-methyltransferase
# R00599	S-adenosyl-L-methionine:tRNA adenine N6-methyltransferase
# R00600	S-Adenosyl-L-methionine:tRNA guanine N7-methyltransferase
# R00601	S-adenosyl-L-methionine:tRNA 5-methylaminomethyl-2-thiouridine methyltransferase
# R00602	methanol:hydrogen-peroxide oxidoreductase
# R00603	dichloromethane chloride-lyase (adding H2O
# R00604	Formaldehyde:NAD+ oxidoreductase
# R00605	methanol:NAD+ oxidoreductase
# R00606	methylamine:amicyanin oxidoreductase (deaminating)
# R00608	Methanol:oxygen oxidereductase
# R00609	N-methyl-L-glutamate:acceptor oxidoreductase (demethylating)
# R00610	sarcosine:oxygen oxidoreductase (demethylating)
# R00611	sarcosine:electron-transfer flavoprotein oxidoreductase (demethylating)
# R00612	N6-Methyl-L-lysine:oxygen oxidoreductase (demethylating)
# R00614	formaldehyde:formaldehyde oxidoreductase
# R00615	Thiamin diphosphate phosphohydrolase
# R00616	ATP:thiamine-diphosphate phosphotransferase
# R00617	ATP:thiamin-phosphate phosphotransferase
# R00618	Thiamin-triphosphate phosphohydrolase
# R00619	ATP:thiamine diphosphotransferase
# R00621	2-Oxoglutarate + Thiamin diphosphate <=> 3-Carboxy-1-hydroxypropyl-ThPP + CO2
# R00623	primary_alcohol:NAD+ oxidoreductase
# R00624	Secondary_alcohol:NAD+ oxidoreductase
# R00625	primary_alcohol:NADP+ oxidoreductase
# R00626	phosphate-monoester phosphohydrolase
# R00627	Acetyl-CoA:alcohol O-acetyltransferase
# R00628	Acetic-ester acetylhydrolase
# R00629	3'-phosphoadenylyl-sulfate:alcohol sulfotransferase
# R00630	Carboxylic-ester hydrolase
# R00631	aldehyde:NAD+ oxidoreductase
# R00634	aldehyde:NADP+ oxidoreductase
# R00635	Aldehyde:oxygen oxidoreductase
# R00636	2-oxo-acid carboxy-lyase (aldehyde-forming)
# R00637	primary alcohol:oxygen oxidoreductase
# R00638	aldehyde:acceptor oxidoreductase
# R00639	primary alcohol:acceptor oxidoreductase
# R00640	L-Galactono-1,4-lactone:ferricytochrome-c oxidoreductase
# R00643	L-Galactono-1,4-lactone:oxygen 3-oxidoreductase
# R00644	L-ascorbate:hydrogen-peroxide oxidoreductase
# R00645	ascorbate:acceptor oxidoreductase
# R00646	Ascorbate + Oxygen + H2O <=> Threonate + Oxalate
# R00647	Ascorbate <=> L-xylo-Hexulonolactone
# R00648	L-Methionine:oxygen oxidoreductase (deaminating)
# R00649	S-Adenosyl-L-methionine:L-methionine S-methyltransferase
# R00650	S-Adenosyl-L-methionine:L-homocysteine S-methyltransferase
# R00651	O-acetyl-L-homoserine:methanethiol 3-amino-3-carboxypropyltransferase
# R00652	L-Methionine:glyoxylate aminotransferase
# R00653	N-formyl-L-methionine amidohydrolase
# R00654	L-methionine methanethiol-lyase (deaminating
# R00655	methionine racemase
# R00656	L-methionine carboxy-lyase (3-methylthiopropanamine-forming)
# R00657	Aminoacyl-L-methionine + H2O <=> L-Methionine
# R00658	2-phospho-D-glycerate hydro-lyase (phosphoenolpyruvate-forming)
# R00659	UTP:pyruvate 2-O-phosphotransferase
# R00660	Phosphoenolpyruvate:UDP-N-acetyl-D-glucosamine 1-carboxyvinyl-transferase
# R00661	phosphoenolpyruvate 2,3-phosphonomutase
# R00662	uridine triphosphate pyrophosphohydrolase
# R00664	Bezoyl-CoA:L-ornithine N-benzoyltransferase
# R00665	L-Citrulline N5-carbamoyldihydrolase
# R00666	N5-(L-1-carboxyethyl)-L-ornithine:NADP+ oxidoreductase (L-ornithine-forming)
# R00667	L-Ornithine:2-oxo-acid aminotransferase
# R00668	L-ornithine:2-oxoglutarate aminotransferase
# R00669	N2-Acetyl-L-ornithine amidohydrolase
# R00670	L-ornithine carboxy-lyase (putrescine-forming)
# R00671	L-ornithine ammonia-lyase (cyclizing
# R00672	ornithine racemase
# R00673	L-tryptophan indole-lyase (deaminating
# R00674	L-serine hydro-lyase (adding indole
# R00675	L-Tryptophan:NAD+ oxidoreductase (deaminating)
# R00676	L-Tryptophan:NADP+ oxidoreductase (deaminating)
# R00677	L-Tryptophan:oxygen oxidoreductase (deaminating)
# R00678	L-tryptophan:oxygen 2,3-oxidoreductase (decyclizing)
# R00679	L-tryptophan:oxygen 2-oxidoreductase (decarboxylating)
# R00681	L-Tryptophan:oxygen 2'-oxidoreductase (side-chain-cleaving)
# R00682	L-Tryptophanamide amidohydrolase
# R00683	S-Adenosyl-L-methionine:L-tryptophan N-methyltransferase
# R00684	L-Tryptophan:2-oxoglutarate aminotransferase
# R00685	L-tryptophan decarboxy-lyase
# R00686	L-Phenylalanine racemase (ATP-hydrolysing)
# R00688	L-phenylalanine:NAD+ oxidoreductase (deaminating)
# R00689	L-Phenylalanine:oxygen oxidoreductase (deaminating)
# R00690	L-phenylalanine:oxygen 2-oxidoreductase (decarboxylating)
# R00691	L-arogenate hydro-lyase (decarboxylating
# R00692	L-phenylalanine:pyruvate aminotransferase
# R00693	Acetyl-CoA:L-phenylalanine N-acetyltransferase
# R00694	L-Phenylalanine:2-oxoglutarate aminotransferase
# R00695	L-Aspartate:phenylpyruvate aminotransferase
# R00697	L-phenylalanine ammonia-lyase (trans-cinnamate-forming)
# R00698	L-phenylalanine:oxygen oxidoreductase (decarboxylating)
# R00699	L-phenylalanine carboxy-lyase (phenylethylamine-forming)
# R00700	hydrogen:NAD+ oxidoreductase
# R00702	farnesyl-diphosphate:farnesyl-diphosphate farnesyltransferase
# R00703	(S)-Lactate:NAD+ oxidoreductase
# R00704	(R)-Lactate:NAD+ oxidoreductase
# R00705	3-Oxopropanoate:NAD+ oxidoreductase (decarboxylating, CoA-acetylating)
# R00706	3-Oxopropanoate:NADP+ oxidoreductase (decarboxylating, CoA-acetylating)
# R00707	(S)-1-pyrroline-5-carboxylate:NAD+ oxidoreductase
# R00708	(S)-1-pyrroline-5-carboxylate:NADP+ oxidoreductase
# R00709	isocitrate:NAD+ oxidoreductase (decarboxylating)
# R00710	Acetaldehyde:NAD+ oxidoreductase
# R00711	Acetaldehyde:NADP+ oxidoreductase
# R00713	succinate-semialdehyde:NAD+ oxidoreductase
# R00714	succinate-semialdehyde:NADP+ oxidoreductase
# R00715	N6-(L-1,3-Dicarboxypropyl)-L-lysine:NAD+ oxidoreductase (L-lysine-forming)
# R00716	N6-(L-1,3-Dicarboxypropyl)-L-lysine:NADP+ oxidoreductase (L-lysine-forming)
# R00717	Glycolate:NAD+ oxidoreductase
# R00719	ITP phosphohydrolase
# R00720	Inosine 5'-triphosphate pyrophosphohydrolase
# R00722	ATP:IDP phosphotransferase
# R00723	Inosine 5'-tetraphosphate phosphohydrolase
# R00724	ITP:pyruvate 2-O-phosphotransferase
# R00725	ITP:D-glucose 6-phosphotransferase
# R00726	ITP:oxaloacetate carboxy-lyase (adding ITP
# R00727	Succinate:CoA ligase (IDP-forming)
# R00728	L-tyrosine phenol-lyase (deaminating
# R00729	L-Tyrosine:oxygen oxidoreductase (deaminating)
# R00730	L-tyrosine,[reduced NADPH-hemoprotein reductase]:oxygen oxidoreductase (N-hydroxylating)
# R00731	L-Tyrosine:oxygen oxidoreductase
# R00732	L-arogenate:NAD+ oxidoreductase
# R00733	L-arogenate:NADP+ oxidoreductase
# R00734	L-tyrosine:2-oxoglutarate aminotransferase
# R00735	L-Tyrosine:L-arginine ligase (AMP-forming)
# R00736	L-tyrosine carboxy-lyase (tyramine-forming)
# R00737	L-tyrosine ammonia-lyase (trans-p-hydroxycinnamate-forming)
# R00739	L-Tyrosine 2,3-aminomutase
# R00740	3-oxopropanoate:NADP+ oxidoreductase (CoA-malonylating)
# R00742	acetyl-CoA:carbon-dioxide ligase (ADP-forming)
# R00743	Acetyl-CoA:malonate CoA-transferase
# R00744	3-oxopropionyl-CoA:NAD+ oxidoreductase
# R00746	Ethanol:NADP+ oxidoreductase
# R00747	2-Phosphonoacetaldehyde phosphonohydrolase
# R00748	ethanolamine-phosphate phosphate-lyase (deaminating
# R00749	ethanolamine ammonia-lyase (acetaldehyde-forming)
# R00750	4-hydroxy-2-oxopentanoate pyruvate-lyase (acetaldehyde-forming)
# R00751	L-threonine acetaldehyde-lyase (glycine-forming)
# R00753	(S)-lactate acetaldehyde-lyase (formate-forming)
# R00754	ethanol:NAD+ oxidoreductase
# R00755	Acetaldehyde + Thiamin diphosphate <=> 2-(alpha-Hydroxyethyl)thiamine diphosphate
# R00756	ATP:D-fructose-6-phosphate 1-phosphotransferase
# R00758	D-Mannitol-1-phosphate:NAD+ 5-oxidoreductase
# R00760	ATP:D-fructose 6-phosphotransferase
# R00761	D-fructose-6-phosphate D-erythrose-4-phosphate-lyase (adding phosphate
# R00762	D-Fructose-1,6-bisphosphate 1-phosphohydrolase
# R00763	beta-D-fructose-2,6-bisphosphate 2-phosphohydrolase
# R00764	diphosphate:D-fructose-6-phosphate 1-phosphotransferase
# R00765	D-glucosamine-6-phosphate aminohydrolase (ketol isomerizing)
# R00766	UDP-glucose:D-fructose-6-phosphate 2-alpha-D-glucosyltransferase
# R00767	CTP:D-fructose-6-phosphate 1-phosphotransferase
# R00768	L-glutamine:D-fructose-6-phosphate isomerase (deaminating)
# R00769	UTP:D-fructose-6-phosphate 1-phosphotransferase
# R00770	ITP:D-fructose-6-phosphate 1-phosphotransferase
# R00771	D-glucose-6-phosphate aldose-ketose-isomerase
# R00772	D-mannose-6-phosphate aldose-ketose-isomerase
# R00774	Urea:carbon-dioxide ligase (ADP-forming)
# R00775	Guanidinoacetate amidohydrolase
# R00776	(S)-ureidoglycolate urea-lyase (glyoxylate-forming)
# R00777	N-Amidino-L-aspartate amidinohydrolase
# R00778	urea hydro-lyase (cyanamide-forming)
# R00782	L-cysteine hydrogen-sulfide-lyase (deaminating
# R00783	nitric-oxide:ferricytochrome-c oxidoreductase
# R00784	nitric-oxide:ferricytochrome-c2 oxidoreductase
# R00785	nitric-oxide:oxidized azurin oxidoreductase
# R00787	ammonia:NAD+ oxidoreductase
# R00789	ammonia:NADP+ oxidoreductase
# R00790	Ammonia:ferredoxin oxidoreductase
# R00791	nitrite:ferredoxin oxidoreductase
# R00792	ferrocytochrome-b:nitrate oxidoreductase
# R00793	Hydroxylamine:oxygen oxidoreductase
# R00794	nitrite:NAD+ oxidoreductase
# R00796	nitrite:NADP+ oxidoreductase
# R00798	nitrite:acceptor oxidoreductase
# R00799	Nitroethane:oxygen oxidoreductase
# R00800	nitrite oxidase
# R00801	sucrose glucohydrolase
# R00802	sucrose alpha-glucohydrolase
# R00803	sucrose:phosphate alpha-D-glucosyltransferase
# R00804	Sugar-phosphate phosphohydrolase
# R00805	sucrose-6F-phosphate phosphohydrolase
# R00806	UDP-glucose:D-fructose 2-alpha-D-glucosyltransferase
# R00807	Sucrose:(acceptor) 3-oxidoreductase
# R00808	Sucrose:(acceptor) 3-oxidoreductase
# R00809	UDP-alpha-D-galactose:sucrose 6F-alpha-D-galactosyltransferase
# R00810	Sucrose glucosylmutase
# R00811	protein-Npi-phospho-L-histidine:sugar phosphotransferase
# R00812	cis-1,2-dihydrobenzene-1,2-diol:NAD+ oxidoreductase
# R00813	(1R,6S)-1,6-dihydroxycyclohexa-2,4-diene-1-carboxylate:NAD+ oxidoreductase (decarboxylating)
# R00814	trans-1,2-dihydrobenzene-1,2-diol:NADP+ oxidoreductase
# R00815	phenol,NADPH:oxogen oxidoreductase (2-hydroxylating)
# R00816	catechol:oxygen 2,3-oxidoreductase (decyclizing)
# R00817	Catechol:oxygen 1,2-oxidoreductase(decyclizing)
# R00818	salicylate,NADH:oxygen oxidoreductase (1-hydroxylating, decarboxylating)
# R00821	2,3-dihydroxybenzoate carboxy-lyase
# R00822	3,4-dihydroxybenzoate carboxy-lyase (catechol-forming)
# R00823	Anthranilate,NADH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)
# R00825	anthranilate,NADPH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)
# R00827	S-Adenosyl-L-methionine:catechol O-methyltransferase
# R00828	2-nitrophenol,NADPH:oxygen 2-oxidoreductase (2-hydroxylating, nitrite-forming)
# R00829	succinyl-CoA:acetyl-CoA C-acyltransferase
# R00830	succinyl-CoA:glycine C-succinyltransferase (decarboxylating)
# R00832	succinyl-CoA:L-arginine N2-succinyltransferase
# R00833	(R)-Methylmalonyl-CoA CoA-carbonylmutase
# R00834	D-Sorbitol 6-phosphate:NADP+ 1-oxidoreductase
# R00835	D-glucose-6-phosphate:NADP+ 1-oxidoreductase
# R00836	UDP-glucose:D-glucose-6-phosphate 1-alpha-D-glucosyltransferase
# R00837	alpha,alpha-Trehalose-6-phosphate phosphoglucohydrolase
# R00838	Maltose-6'-phosphate 6-phosphoglucohydrolase
# R00839	6-phospho-beta-D-glucosyl-(1->4)-D-glucose 6-phosphoglucohydrolase
# R00841	sn-glycerol-3-phosphate phosphohydrolase
# R00842	sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase
# R00844	sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase
# R00845	sn-glycerol-3-phosphate:NADP+ 1-oxidoreductase
# R00846	sn-Glycerol-3-phosphate:oxygen 2-oxidoreductase
# R00847	ATP:glycerol 3-phosphotransferase
# R00848	sn-Glycerol-3-phosphate:(acceptor) 2-oxidoreductase
# R00849	sn-glycerol 3-phosphate:quinone oxidoreductase
# R00850	sn-Glycerol-3-phosphate:D-glucose 6-phosphotransferase
# R00851	acyl-CoA:sn-glycerol-3-phosphate 1-O-acyltransferase
# R00853	UDP-alpha-D-galactose:sn-glycerol-3-phosphate 2-alpha-D-galactosyltransferase
# R00854	UDP-alpha-D-galactose:sn-glycerol-3-phosphate 1-alpha-D-galactosyltransferase
# R00855	CDPglycerol phosphoglycerohydrolase
# R00856	CTP:sn-glycerol-3-phosphate cytidylyltransferase
# R00857	Glycerophosphodiester glycerophosphohydrolase
# R00858	hydrogen-sulfide:NADP+ oxidoreductase
# R00859	Hydrogen-sulfide:ferredoxin oxidoreductase
# R00860	AMP,sulfite:acceptor oxidoreductase (adenosine-5'-phosphosulfate-forming)
# R00861	hydrogen-sulfide:[DsrC sulfur-carrier protein],acceptor oxidoreductase
# R00863	3-Sulfino-L-alanine 4-carboxy-lyase
# R00864	Sulfite + Sulfur <=> Thiosulfate
# R00865	D-Mannitol:ferricytochrome-c 2-oxidoreductase
# R00866	ATP:D-fructose 1-phosphotransferase
# R00867	ATP:D-fructose 6-phosphotransferase
# R00868	D-Mannitol:NAD+ 2-oxidoreductase
# R00870	D-Mannitol:NADP+ 2-oxidoreductase
# R00871	D-Fructose:NADP+ 5-oxidoreductase
# R00872	D-fructose 2-phosphate phosphatase
# R00873	D-fructose:ubiquinone 5-oxidoreductase
# R00874	D-Glucose:D-fructose oxidoreductase
# R00875	D-Glucitol:NAD+ 2-oxidoreductase
# R00876	ITP:D-fructose 6-phosphotransferase
# R00877	D-mannose aldose-ketose-isomerase
# R00878	alpha-D-Glucose aldose-ketose-isomerase
# R00879	beta-D-Fructan fructohydrolase
# R00880	GDP-D-mannose:NAD+ 6-oxidoreductase
# R00881	GDP-mannose mannophosphohydrolase
# R00883	GDP:D-mannose-1-phosphate guanylyltransferase
# R00885	GTP:alpha-D-mannose-1-phosphate guanylyltransferase
# R00887	GDP-mannose + Mannan(n) <=> GDP + Mannan(n+1)
# R00888	GDP-alpha-D-mannose 4,6-hydro-lyase (GDP-4-dehydro-alpha-D-rhamnose-forming)
# R00889	GDP-mannose 3,5-epimerase
# R00890	GDPmannose:mannan 1,4-beta-D-mannosyltransferase
# R00891	L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)
# R00892	L-cysteine:NAD+ oxidoreductase
# R00893	L-Cysteine:oxygen oxidoreductase
# R00894	L-glutamate:L-cysteine gamma-ligase (ADP-forming)
# R00895	L-Cysteine:2-oxoglutarate aminotransferase
# R00896	L-cysteine:2-oxoglutarate aminotransferase
# R00897	O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase
# R00899	L-cysteinylglycine dipeptidase
# R00900	L-cysteine,glutathione:NADP+ oxidoreductase (disulfide-forming)
# R00901	L-cysteine hydrogen-sulfide-lyase (adding sulfite
# R00903	cysteine racemase
# R00904	3-aminopropanal:NAD+ oxidoreductase
# R00905	3-ureidopropanoate amidohydrolase
# R00906	N-(D-1-carboxyethyl)-beta-alanine:NAD+ oxidoreductase (beta-alanine-forming)
# R00907	L-Alanine:3-oxopropanoate aminotransferase
# R00908	beta-alanine:2-oxoglutarate aminotransferase
# R00909	N-Acetyl-beta-alanine amidohydrolase
# R00910	L-lysine:beta-alanine ligase (ADP-forming)
# R00911	beta-Alanyl-L-lysine hydrolase
# R00912	L-arginine:beta-alanine ligase (ADP-forming)
# R00913	3-Guanidinopropanoate amidinopropionase
# R00914	beta-alanine CoA-transferase
# R00915	beta-Alanine <=> Quinolinate
# R00916	beta-Alanine <=> beta-Nitropropanoate
# R00917	beta-aminopropionitrile aminohydrolase
# R00918	propanoyl-CoA:(2S)-methylmalonyl-CoA malonyltransferase (cyclizing)
# R00919	propanoyl-CoA:NADP+ 2-oxidoreductase
# R00920	propanoate:CoA ligase (ADP-forming)
# R00921	propanoyl-CoA:phosphate propanoyltransferase
# R00922	2-Methyl-3-oxopropanoate:NAD+ oxidoreductase (CoA-propanoylating)
# R00923	(S)-methylmalonyl-CoA carboxy-lyase (propanoyl-CoA-forming)
# R00925	Propanoate:CoA ligase (AMP-forming)
# R00926	Propionyladenylate:CoA propionyltransferase
# R00927	acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase
# R00928	Acetyl-CoA:propanoate CoA-transferase
# R00930	(S)-2-Methyl-3-oxopropanoyl-CoA:pyruvate carboxyltransferase
# R00931	propanoyl-CoA:oxaloacetate C-propanoyltransferase (thioester-hydrolysing, 1-carboxyethyl-forming)
# R00932	propanoyl-CoA:glyoxylate C-propanoyltransferase (thioester-hydrolysing, 2-carboxyethyl-forming)
# R00934	L-erythro-3-methylmalyl-CoA glyoxylate-lyase (propanoyl-CoA-forming)
# R00935	(S)-Methylmalonate semialdehyde:NAD+ oxidoreductase (CoA-propanoylating)
# R00936	5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase
# R00937	5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase
# R00939	5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase
# R00940	5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase
# R00941	10-formyltetrahydrofolate:NADP+ oxidoreductase
# R00942	Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)
# R00943	Formate:tetrahydrofolate ligase (ADP-forming)
# R00944	10-Formyltetrahydrofolate amidohydrolase
# R00945	5,10-Methylenetetrahydrofolate:glycine hydroxymethyltransferase
# R00946	5-methyltetrahydrofolate:L-homocysteine S-methyltransferase
# R00947	alpha-D-glucose-1-phosphate phosphohydrolase
# R00948	ATP:alpha-D-glucose-1-phosphate adenylyltransferase
# R00949	ATP:D-glucose-1-phosphate 6-phosphotransferase
# R00951	ADP-glucose glucose-1-phosphohydrolase
# R00952	cellobiose:phosphate alpha-D-glucosyltransferase
# R00953	3-beta-D-glucosyl-D-glucose:phosphate alpha-D-glucosyltransferase
# R00954	GTP:alpha-D-glucose-1-phosphate guanylyltransferase
# R00955	UDP-glucose:alpha-D-galactose-1-phosphate uridylyltransferase
# R00956	CTP:alpha-D-glucose-1-phosphate cytidylyltransferase
# R00957	alpha-D-Glucose-1-phosphate:alpha-D-glucose-1-phosphate 4-alpha-D-glucosyltransferase (dephosphorylating)
# R00959	alpha-D-Glucose 1-phosphate 1,6-phosphomutase
# R00960	D-Glucose-1-phosphate:D-glucose-1-phosphate 6-phosphotransferase
# R00961	IDP phosphohydrolase
# R00963	uridine 5'-monophosphate phosphohydrolase
# R00964	ATP:uridine 5'-phosphotransferase
# R00965	orotidine-5'-phosphate carboxy-lyase (UMP-forming)
# R00966	UMP:diphosphate phospho-alpha-D-ribosyltransferase
# R00968	GTP:uridine 5'-phosphotransferase
# R00969	P1,P4-bis(5'-uridyl)-tetraphosphate uridylohydrolase
# R00973	uracil-5-carboxylate carboxy-lyase (uracil-forming)
# R00974	Cytosine aminohydrolase
# R00975	5,6-Dihydrouracil:oxygen oxidoreductase
# R00976	uracil:acceptor oxidoreductase
# R00977	5,6-dihydrouracil:NAD+ oxidoreductase
# R00978	5,6-Dihydrouracil:NADP+ oxidoreductase
# R00980	Anthranilate,NADPH:oxygen oxidoreductase (3-hydroxylating, deaminating)
# R00982	Anthranilate:CoA ligase (AMP-forming)
# R00983	2,3-Dihydroxyindole:oxygen 2,3-oxidoreductase (decyclizing)
# R00984	S-Adenosyl-L-methionine:anthranilate N-methyltransferase
# R00985	chorismate pyruvate-lyase (amino-accepting
# R00986	Chorismate pyruvate-lyase (amino-accepting)
# R00987	L-Kynurenine hydrolase
# R00988	N-Formylanthranilate amidohydrolase
# R00989	Malonyl-CoA:anthranilate N-malonyltransferase
# R00990	2-Aminobenzoate carboxy-lyase
# R00991	Anthranilate <=> 2-Formaminobenzoylacetate
# R00993	2-oxobutanoate:oxygen 2-oxidoreductase (phosphorylating)
# R00994	(2R,3S)-3-methylmalate:NAD+ oxidoreductase
# R00995	methyloxaloacetate carboxy-lyase (2-oxobutanoate-forming)
# R00996	L-threonine ammonia-lyase (2-oxobutanoate-forming)
# R00997	1-aminocyclopropane-1-carboxylate aminohydrolase (isomerizing)
# R00998	acetyl-CoA:2-oxobutanoate C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)
# R00999	O-Succinyl-L-homoserine succinate-lyase (deaminating
# R01000	2-hydroxybutyrate:NAD+ oxidoreductase
# R01001	L-cystathionine cysteine-lyase (deaminating
# R01003	dolichyl-phosphate phosphohydrolase
# R01004	Dolichyl-diphosphate phosphohydrolase
# R01005	UDPglucose:dolichyl-phosphate beta-D-glucosyltransferase
# R01006	Dolichyl-beta-D-glucosyl-phosphate dolichylphosphohydrolase
# R01007	UDP-N-acetyl-D-glucosamine:dolichyl-phosphate N-acetyl-D-glucosamine phosphotransferase
# R01008	UDP-N-acetyl-D-glucosamine:dolichyl-phosphate alpha-N-acetyl-D-glucosaminyltransferase
# R01009	GDPmannose:dolichyl-phosphate O-beta-D-mannosyltransferase
# R01010	Glycerone phosphate phosphohydrolase
# R01011	ATP:glycerone phosphotransferase
# R01012	phosphoenolpyruvate:glycerone phosphotransferase
# R01013	Acyl-CoA:glycerone-phosphate O-acyltransferase
# R01014	erythrulose-1-phosphate formaldehyde-lyase (glycerone-phosphate-forming)
# R01015	D-glyceraldehyde-3-phosphate aldose-ketose-isomerase
# R01016	glycerone-phosphate phosphate-lyase (methylglyoxal-forming)
# R01018	CTP:dolichol O-phosphotransferase
# R01019	acetaldehyde:pyrroloquinoline-quinone oxidoreductase
# R01021	ATP:choline phosphotransferase
# R01022	choline:oxygen 1-oxidoreductase
# R01023	Acetyl-CoA:choline O-acetyltransferase
# R01025	choline:acceptor 1-oxidoreductase
# R01026	Acetylcholine aectylhydrolase
# R01027	3'-phosphoadenylyl-sulfate:choline sulfotransferase
# R01028	Choline sulfate sulfohydrolase
# R01029	Acylcholine acylhydrolase
# R01030	sn-Glycero-3-phosphocholine glycerophosphohydrolase
# R01031	3-chloro-D-alanine chloride-lyase (deaminating
# R01032	3-chloro-L-alanine chloride-lyase (deaminating
# R01033	2-chlorobenzoate,NADH:oxygen oxidoreductase (1,2-hydroxylating, dechlorinating, decarboxylating)
# R01034	glycerol:NAD+ 2-oxidoreductase
# R01036	Glycerol:NAD+ oxidoreductase
# R01039	glycerol:NADP+ 2-oxidoreductase (glycerone-forming)
# R01041	glycerol:NADP+ oxidoreductase
# R01043	Glycerol-2-phosphate phosphohydrolase
# R01044	diphosphate:glycerol 1-phosphotransferase
# R01045	Glycerol:(acceptor) 1-oxidoreductase
# R01047	glycerol hydro-lyase (3-hydroxypropanal-forming)
# R01049	ATP:D-ribose-5-phosphate diphosphotransferase
# R01050	ATP:D-ribose-5-phosphate 1-phosphotransferase
# R01051	ATP:D-ribose 5-phosphotransferase
# R01052	ADP:D-ribose-5-phosphate adenylyltransferase
# R01053	Ribose-5-phosphate:ammonia ligase (ADP-forming)
# R01054	ADP-ribose ribophosphohydrolase
# R01055	uracil hydro-lyase (adding D-ribose 5-phosphate
# R01056	D-ribose-5-phosphate aldose-ketose-isomerase
# R01057	D-Ribose 1,5-phosphomutase
# R01058	D-glyceraldehyde 3-phosphate:NADP+ oxidoreductase
# R01059	ATP:D-glyceraldehyde 3-phosphotransferase
# R01061	D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)
# R01063	D-glyceraldehyde-3-phosphate:NADP+ oxidoreductase (phosphorylating)
# R01064	2-dehydro-3-deoxy-6-phospho-D-galactonate D-glyceraldehyde-3-phospho-lyase (pyruvate-forming)
# R01066	2-deoxy-D-ribose-5-phosphate acetaldehyde-lyase (D-glyceraldehyde-3-phosphate-forming)
# R01067	D-Fructose 6-phosphate:D-glyceraldehyde-3-phosphate glycolaldehyde transferase
# R01068	D-fructose-1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)
# R01069	D-tagatose 1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)
# R01070	beta-D-fructose-1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)
# R01071	1-(5-phospho-D-ribosyl)-ATP:diphosphate phospho-alpha-D-ribosyl-transferase
# R01072	5-phosphoribosylamine:diphosphate phospho-alpha-D-ribosyltransferase (glutamate-amidating)
# R01073	N-(5-Phospho-D-ribosyl)anthranilate:pyrophosphate phosphoribosyl-transferase
# R01074	biotin:CoA ligase (AMP-forming)
# R01075	biotin:CoA ligase (AMP-forming)
# R01076	Biotin-amide amidohydrolase
# R01077	N6-D-Biotinyl-L-lysine amidohydrolase
# R01078	dethiobiotin:sulfur sulfurtransferase
# R01079	D-Ribose:NADP+ 1-oxidoreductase
# R01080	uridine ribohydrolase
# R01081	D-ribose aldose-ketose-isomerase
# R01082	(S)-malate hydro-lyase (fumarate-forming)
# R01083	N6-(1,2-dicarboxyethyl)AMP AMP-lyase (fumarate-forming)
# R01085	3-fumarylpyruvate fumarylhydrolase
# R01086	2-(Nomega-L-arginino)succinate arginine-lyase (fumarate-forming)
# R01087	Maleate cis-trans-isomerase
# R01088	L-leucine:NAD+ oxidoreductase (deaminating)
# R01089	Acetyl-CoA:L-leucine N-acetyltransferase
# R01090	L-Leucine:2-oxoglutarate aminotransferase
# R01091	(2S)-alpha-leucine 2,3-aminomutase
# ...
# R12935	8-amino-7-oxononanoate:[protein]-L-lysine aminotransferase (N-carboxylating)
# R12936	UDP-2-acetamido-3-amino-2,3-dideoxy-alpha-D-glucopyranose:2-oxoglutarate aminotransferase
# R12937	Chorismate + Ammonia <=> 2-Amino-2-deoxyisochorismate + H2O
# R12938	2-Amino-2-deoxyisochorismate + Ammonia <=> 4-Amino-4-deoxychorismate + Ammonia
# R12939	chorismate:L-glutamine aminotransferase (2-amino-4-deoxychorismate-forming)
# R12940	ATP:D-tagatopyranse-1-phosphate 6-phosphotransferase
# R12941	glutathione-S-conjugate glycine hydrolase
# R12942	N-methyl carbamate ester hydrolase
# R12943	3-amino-2-hydroxy-4-methoxybenzoate:nitrite ligase (AMP-forming)
# R12944	UDP-N-acetyl-alpha-D-glucosamine:N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminide 6-beta-N-acetylglucosaminyltransferase (configuration-inverting)
# R12945	ATP:cob(II)alamin Cobeta-adenosyltransferase (diphosphate-forming)
# R12946	S-methyl-1-thio-D-xylulose 5-phosphate:glutathione methylthiotransferase
# R12947	2-nitrobutanedioate lyase (fumarate-forming)
# R12948	(8S)-8-amino-7-oxononanoate:[protein]-L-lysine aminotransferase (N-carboxylating)
# R12949	(8S)-8-Amino-7-oxononanoate + Protein lysine + NADPH + H+ <=> [Protein]-N6-[(2S,3R)-2-amino-8-carboxyoctan-3-yl]-L-lysine + H2O + NADP+
# R12950	[Protein]-N6-[(2S,3R)-2-amino-8-carboxyoctan-3-yl]-L-lysine + CO2 + H2O + NADP+ <=> (7R,8S)-8-Amino-7-(carboxyamino)nonanoate + [Protein]-(S)-2-amino-6-oxohexanoate + NADPH + H+
# R12951	ATP:an alpha-Hep-(1->3)-alpha-Hep-(1->5)-[alpha-Kdo-(2->4)]-alpha-Kdo-(2->6)-[lipid A] heptoseI 4-O-phosphotransferase
# R12952	(8S)-8-Amino-7-oxononanoate + Protein lysine + NADH + H+ <=> [Protein]-N6-[(2S,3R)-2-amino-8-carboxyoctan-3-yl]-L-lysine + H2O + NAD+
# R12953	[Protein]-N6-[(2S,3R)-2-amino-8-carboxyoctan-3-yl]-L-lysine + CO2 + H2O + NAD+ <=> (7R,8S)-8-Amino-7-(carboxyamino)nonanoate + [Protein]-(S)-2-amino-6-oxohexanoate + NADH + H+
# R12954	Littorine <=> Hyoscyamine aldehyde
# R12955	uridine 5'-monophosphate phosphoribohydrolase
# R12956	thymidine 5'-monophosphate phosphodeoxyribohydrolase
# R12957	L-Tryptophan <=> 3-(Aminomethyl)indole
# R12958	dIMP phosphohydrolase
# R12959	Hypotaurine + NADPH + H+ + Oxygen <=> Taurine + NADP+ + H2O
# R12960	3'-phosphoadenylyl-sulfate:lactosylceramide 3'-sulfotransferase
# R12961	lactosylceramide-sulfate sulfohydrolase
# R12962	UDP-N-acetyl-D-galactosamine:lactosylceramide-sulfate N-acetyl-D-galactrosaminyltransferase
# R12963	gangliotriaosylceramide-II3-sulfate N-acetylgalactosaminohydrolase
# R12964	(2R)-2-hydroxy-4-(methylsulfanyl)butanoate:NAD+ 2-oxidoreductase
# R12965	6-deoxoteasterone,[reduced NADPH-hemoprotein reductase]:oxygen 3-oxidoreductase
# R12966	benzylmalonyl-CoA:oxygen oxidoreductase (decarboxylating)
# R12967	sarcosine, 5,6,7,8-tetrahydrofolate:O2 oxidoreductase (demethylating,5,10-methylenetetrahydrofolate-forming)
# R12968	(indol-3-yl)acetate:CoA ligase (AMP-forming)
# R12969	beta-D-glucosyl-N-acylsphingosine glycohydrolase (configuration-retaining)
# R12970	beta-D-galactosyl-N-acylsphingosine glycohydrolase (configuration-retaining)
# R12971	alpha-L-arabinopyranose:NAD+ 1-oxidoreductase
# R12972	alpha-L-arabinopyranose:NADP+ 1-oxidoreductase
# R12973	N-Acetyl-D-glucosamine + Oxygen <=> N-Acetyl-D-glucosamino-1,5-lactone + Hydrogen peroxide
# R12974	N-Acetyl-D-glucosamino-1,5-lactone + H2O <=> N-Acetyl-D-glucosaminate
# R12975	N-acetyl-D-galactosamine:oxygen 1-oxidoreductase
# R12976	N-Acetyl-D-galactosamine + Oxygen <=> N-Acetyl-D-galactosamino-1,5-lactone + Hydrogen peroxide
# R12977	N-Acetyl-D-galactosamino-1,5-lactone + H2O <=> N-acetyl-D-galactosaminate
# R12978	acetyl-CoA:N-terminal-Met-[tubulin] Met-Nalpha-acetyltransferase
# R12979	beta-D-glucosyl-(1->4)-D-galactose:phosphate alpha-D-glucosyltransferase (configuration-inverting)
# R12980	ATP:NAD+ 3'-phosphotransferase
# R12981	succinyl-CoA:2-phenylsuccinate CoA-transferase
# R12982	succinyl-CoA:3-phenylsuccinate CoA-transferase
# R12983	kojibiose glucohydrolase (configuration-inverting)
# R12984	alpha-isomaltosyl-(1->3)-1,4-alpha-D-glucan:1,4-alpha-D-glucan 3-alpha-isomaltosyltransferase
# R12985	alpha-isomaltosyl-(1->3)-1,4-alpha-D-glucan:1,4-alpha-D-glucan 3-alpha-isomaltosyltransferase
# R12986	alpha-D-xylopyranose aldose-ketose-isomerase
# R12987	adenine:NAD+ oxidoreductase
# R12988	8-hydroxyadenine:NAD+ oxidoreductase
# R12989	adenine:oxygen oxidoreductase
# R12990	8-hydroxyadenine:oxygen oxidoreductase
# R12991	beta-L-arabinopyranose aldose-ketose-isomerase
# R12992	8-[(1R,2R)-3-oxo-2-{(Z)-pent-2-enyl}cyclopentyl]octanoate:NADP+ 4-oxidoreductase
# R12993	2 p-Coumaroylagmatine <=> Hordatine A
# R12994	2 Feruloylagmatine <=> Hordatine B
# R12995	UDP-glucose + Protopanaxatriol <=> UDP + Ginsenoside F1
# R12996	6-deoxy-6-sulfo-D-glucopyranose isomerase (2-epimerizing)
# R12997	D-glucose:NADP+ 6-oxidoreductase
# R12998	UTP diphosphate-lyase (cyclizing
# R12999	[methylated methoxylated-aromatic-compound-specific corrinoid protein]:tetrahydromethanopterin methyltransferase
# R13000	6-deoxy-6-sulfo-D-fructose:D-glyceraldehyde-3-phosphate glycolaldehydetransferase
# R13001	4-deoxy-4-sulfo-D-erythrulose:D-glyceraldehyde-3-phosphate glycolaldehydetransferase
# R13002	solabiose:phosphate alpha-D-glucosyltransferase
# R13003	ADP-L-glycero-beta-D-manno-heptose:an alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-[lipid A] 5-alpha-heptosyltransferase
# R13004	ADP-L-glycero-beta-D-manno-heptose:an alpha-L-glycero-D-manno-heptosyl-(1->5)-[alpha-Kdo-(2->4)]-alpha -Kdo-(2->6)-[lipid A] 3-alpha-heptosyltransferase
# R13005	ADP-L-glycero-beta-D-manno-heptose:an alpha-Hep-(1->3)-4-O-phospho-alpha-Hep-(1->5)-[alpha-Kdo-(2->4)]-alpha-Kdo-(2->6)-[lipid A] heptoseI 7-alpha-heptosyltransferase
# R13006	all-trans pentaprenyl diphosphate:sn-glycerol-1-phosphate pentaprenyltransferase
# R13007	all-trans-pentaprenyl diphosphate:sn-3-O-(pentaprenyl)glycerol 1-phosphate pentaprenyltransferase
# R13008	4-deoxy-4-sulfo-D-erythrose ketose-aldose isomerase
# R13009	isethionate:NAD+ oxidoreductase
# R13010	a D-glucoside:ferric c-type cytochrome 3-oxidoreductase
# R13011	2-oxoadipate dioxygenase/carboxy lyase
# R13012	(3R)-3-[(Carboxylmethyl)amino]fatty acid + 2-Oxoglutarate + Oxygen <=> (3R)-3-{[Carboxy(hydroxy)methyl]amino}fatty acid + Succinate + CO2
# R13013	(3R)-3-{[Carboxy(hydroxy)methyl]amino}fatty acid + 2-Oxoglutarate + Oxygen <=> (3R)-3-Isocyanyl-fatty acid + Succinate + 2 CO2 + 2 H2O
# R13014	(3R)-3-[(carboxylmethyl)amino]fatty acid,2-oxoglutarate:oxygen oxidoreductase (isonitrile-forming)
# R13015	protein-L-histidine,2-oxoglutarate:oxygen oxidoreductase (3S-hydroxylating)
# R13016	glycine betaine,NADH:oxygen oxidoreductase (demethylating)
# R13017	6-sulfo-D-quinovose,FMNH2:oxygen oxidoreductase
# R13018	2alpha-hydroxytaxusin, [reduced NADPH---hemoprotein reductase]:oxygen 7-oxidoreductase
# R13019	taxusin, [reduced NADPH---hemoprotein reductase]:oxygen 2-oxidoreductase
# R13020	7beta-hydroxytaxusin, [reduced NADPH---hemoprotein reductase]:oxygen 2-oxidoreductase
# R13021	secondary-alkyl amine:NAD+ oxidoreductase (deaminating)
# R13022	secondary-alkyl amine:NADP+ oxidoreductase (deaminating)
# R13023	Iminoaspartate + H2O <=> Oxaloacetate + Ammonia
# R13024	N-(1-Deoxy-D-fructos-1-yl)amine + Oxygen <=> 2-[(3S,4R,5R)-3,4,5,6-Tetrahydroxy-2-oxohexylidene]amine + Hydrogen peroxide
# R13025	2-[(3S,4R,5R)-3,4,5,6-Tetrahydroxy-2-oxohexylidene]amine + H2O <=> D-Glucosone + Amine
# R13026	N-(1-deoxy-D-fructos-1-yl)amine:oxygen 2-oxidoreductase (glucosone-forming)
# R13027	N-(1-deoxy-D-fructos-1-yl)amine:oxygen oxidoreductase (fructosamine-forming)
# R13028	N,N-dimethylglycine:ferredoxin oxidoreductase (demethylating)
# R13029	sarcosine:ferredoxin oxidoreductase (demethylating)
# R13030	Sulfoacetate + CoA + ATP <=> Sulfoacetyl-CoA + AMP + Diphosphate
# R13031	L-Tyrosine + NADPH + Oxygen + H+ <=> 3,4-Dihydroxy-L-phenylalanine + NADP+ + H2O
# R13032	3,4-Dihydroxy-L-phenylalanine + NADPH + Oxygen + H+ <=> 2-Carboxy-2,3-dihydro-5,6-dihydroxyindole + NADP+ + 2 H2O
# R13033	carminate:oxygen 3'-oxidoreductase (H2O2-forming)
# R13034	D-Lysine <=> 6-Amino-2-oxohexanoate
# R13035	Glutarate + Succinyl-CoA <=> Glutaryl-CoA + Succinate
# R13036	(R)-2-Hydroxyglutarate <=> 2-Oxoglutarate
# R13037	L-2-Aminoadipate 6-semialdehyde <=> L-2-Aminoadipate
# R13038	(3R)-3-[(carboxylmethyl)amino]fatty acid glycine-lyase ((2E)-unsaturated fatty acyl-[acyl-carrier protein]-forming)
# R13039	Androstan-3alpha,17beta-diol + NAD+ <=> Androsterone + NADH + H+
# R13040	5(S)-HETE + NADP+ <=> 5-OxoETE + NADPH + H+
# R13041	11alpha-hydroxy-9,15-dioxoprostanoate:NAD+ Delta13-oxidoreductase
# R13042	11alpha-hydroxy-9,15-dioxoprostanoate:NADP+ Delta13-oxidoreductase
# R13043	glutathione:12(S)-HPETE oxidoreductase
# R13044	12(R)-HPETE hydro-lyase
# R13045	12(S)-HPETE hydro-lyase
# R13046	poly[(1->4)-beta-D-glucuronosyl-(1->4)-N-acetyl-alpha-D-glucosaminyl] amidohydrolase
# R13047	3'-phosphoadenylyl-sulfate:heparosan-D-glucuronate N-sulfonotransferase
# R13048	3'-phosphoadenylyl-sulfate:heparan-sulfate-containing-L-iduronate-2-sulfate 3-sulfotransferase
# R13049	(R)-lactate:NAD+,ferredoxin oxidoreductase
# R13050	(S)-lactate:NAD+,ferredoxin oxidoreductase
# R13051	daidzein 7-O-glucoside glucohydrolase
# R13052	genistein 7-O-beta-D-glucoside glucohydrolase
# R13053	Puerarin <=> Daidzein + 1,5-Anhydro-D-erythro-hex-1-en-3-ulose
# R13054	Daidzein + NADPH + H+ <=> (R)-Dihydrodaidzein + NADP+
# R13055	(R)-Dihydrodaidzein <=> (S)-Dihydrodaidzein
# R13056	(S)-Dihydrodaidzein + NADPH + H+ <=> (3S,4R)-Tetrahydrodaidzein + NADP+
# R13057	(3S,4R)-Tetrahydrodaidzein <=> Equol
# R13058	alpha-Linolenoyl-[glycerolipid],ferrocytochrome b5:oxygen oxidoreductase (6,7-cis-dehydrogenating)
# R13059	linoleoyl-[glycerolipid],ferrocytochrome b5:oxygen oxidoreductase (6,7-cis-dehydrogenating)
# R13060	(R)-Dihydrodaidzein <=> O-Desmethylangolensin
# R13061	Genistein <=> Dihydrogenistein
# R13062	Dihydrogenistein <=> 6'-Hydroxy-O-desmethylangolensin
# R13063	rutin rhamnohydrolase
# R13064	naringin rhamnohydrolase
# R13065	quercetin 3-O-glucoside glucohydrolase
# R13066	Apigenin <=> Naringenin
# R13067	Quercetin <=> Taxifolin
# R13068	Kaempferol <=> Dihydrokaempferol
# R13069	Luteolin <=> Eriodictyol
# R13070	Taxifolin + NADH + H+ <=> 2-Hydroxy-1-(2,4,6-trihydroxyphenyl)-3-(3,4-dihydroxyphenyl)propan-1-one + NAD+
# R13071	Dihydrokaempferol + NADH + H+ <=> 2-Hydroxy-1-(2,4,6-trihydroxyphenyl)-3-(4-hydroxyphenyl)propan-1-one + NAD+
# R13072	Eriodictyol + NADH + H+ <=> 3-Hydroxyphloretin + NAD+
# R13073	Naringenin + NADH + H+ <=> Phloretin + NAD+
# R13074	Naringenin <=> 5,7,8-Trihydroxy-2-(4-hydroxyphenyl)-2,3-dihydro-4H-chromen-4-one
# R13075	5,7,8-Trihydroxy-2-(4-hydroxyphenyl)-2,3-dihydro-4H-chromen-4-one <=> (2E,4E)-2,4-Dihydroxy-4-[6-(4-hydroxyphenyl)-2,4-dioxodihydro-2H-pyran-3(4H)-ylidene]but-2-enoate
# R13076	(2E,4E)-2,4-Dihydroxy-4-[6-(4-hydroxyphenyl)-2,4-dioxodihydro-2H-pyran-3(4H)-ylidene]but-2-enoate + H2O <=> 5-(4-Hydroxyphenyl)-3-oxovalero-delta-lactone + Oxaloacetate
# R13077	5-(4-Hydroxyphenyl)-3-oxovalero-delta-lactone + H2O <=> 5-Hydroxy-5-(4-hydroxyphenyl)-3-oxopentanoate
# R13078	5-Hydroxy-5-(4-hydroxyphenyl)-3-oxopentanoate <=> 4-Hydroxy-4-(4-hydroxyphenyl)-butan-2-one + CO2
# R13079	4-Hydroxy-4-(4-hydroxyphenyl)-butan-2-one <=> 4-Hydroxycinnamoylmethane + H2O
# R13080	double-stranded RNA adenine aminohydrolase
# R13081	naringenin 7-O-beta-D-glucoside glucohydrolase
# R13082	3-hydroxyphloretin acylhydrolase (phloroglucinol-forming)
# R13083	Taxifolin <=> Alphitonin
# R13084	Dihydrokaempferol <=> Maesopsin
# R13085	Alphitonin + 2 H2O <=> 3,4-Dihydroxyphenylacetate + Phloroglucinol + CO2 + 2 H+
# R13086	Maesopsin <=> 4-Hydroxyphenylacetate + Phloroglucinol
# R13087	UDP-2-acetamido-4-dehydro-2,6-dideoxyglucose <=> UDP-2-acetamido-4-amino-2,4,6-trideoxy-D-galactose
# R13088	UDP-N-acetyl-D-galactosaminuronic acid <=> UDP-2-acetamido-2-deoxy-L-altruronic acid
# R13089	alpha-D-ribose-1-phosphate 5-kinase (ATP)
# R13090	D-ribulose-1,5-bisphosphate 5-phosphohydrolase
# R13091	(-)-5-Oxo-1,2-campholide <=> [(1R)-2,2,3-Trimethyl-5-oxocyclopent-3-enyl]acetate
# R13092	(-)-camphor,reduced putidaredoxin:oxygen oxidoreductase
# R13093	3-exo-hydroxycamphor:NAD+ oxidoreductase
# R13094	(+)-6-endo-Hydroxycamphor <=> Bornane-2,6-dione
# R13095	(+)-6-exo-Hydroxycamphor <=> Bornane-2,6-dione
# R13096	D-Glutamate + Acetyl-CoA <=> N-Acetyl-D-glutamate + CoA
# R13097	N-Acetyl-D-glutamate <=> N-Acetyl-L-glutamate
# R13098	N-Acetyl-L-glutamate <=> L-Glutamate
# R13099	geranylgeranyl diphosphate-lyase [(-)-cyatha-3,12-diene-forming]
# R13100	geranylgeranyl- diphosphate diphosphate-lyase (neoverrucosan-5beta-ol-forming)
# R13101	geranylgeranyl-diphosphate diphosphate-lyase (verrucosan-2beta-ol-forming)
# R13102	geranylgeranyl-diphosphate diphosphate-lyase [(R)-axinyssene-forming]
# R13103	geranylgerany-diphosphate diphosphate-lyase (lydicene-forming)
# R13104	(2E,6E)-farnesyl-diphosphate diphosphate-lyase [(+)-exo-beta-bergamotene-forming]
# R13105	beta-L-fucopyranose:NADP+ 1-oxidoreductase
# R13106	fumagillol:NADP+ 5-oxidoreductase
# R13107	S-adenosyl-L-methionine S-methyl-5'-thioadenosine-lyase (cyclizing
# R13108	5-hydroxymethylcytosine in DNA,2-oxoglutarate:oxygen oxidoreductase
# R13109	5-formylcytosine in DNA,2-oxoglutarate:oxygen oxidoreductase
# R13110	cyclopeptine,2-oxoglutarate:oxygen oxidoreductase
# R13111	dehydrocyclopeptine,2-oxoglutarate:oxygen oxidoreductase ((-)-cyclopenine-forming)
# R13112	Canavanine <=> Vinylglycine + N-Hydroxyguanidine
# R13113	Vinylglycine <=> (2E)-2-Aminobut-2-enoate
# R13114	(2E)-2-Aminobut-2-enoate + H2O <=> L-Homoserine
# R13115	L-canavanine N-hydroxyguanidine-lyase (L-homoserine-forming)
# R13116	L-Mimosine <=> 3-Hydroxy-4H-pyrid-4-one + Dehydroalanine
# R13117	(+)-exo-beta-bergamotene,[reduced NADPH---hemoprotein reductase] oxidoreductase (5-dehydro-6-demethoxyfumagillol-producing)
# R13118	(+)-exo-beta-Bergamotene + [Reduced NADPH---hemoprotein reductase] + Oxygen <=> (5R)-Hydroxy-(+)-exo-beta-bergamotene + [Oxidized NADPH---hemoprotein reductase] + H2O
# R13119	(5R)-Hydroxy-(+)-exo-beta-bergamotene + Oxygen <=> (3S)-3-[2-Methyl-3-(3-methylbut-2-en-1-yl)oxiran-2-yl]-4-methylidenecyclohexan-1-one + H2O
# R13120	(3S)-3-[2-Methyl-3-(3-methylbut-2-en-1-yl)oxiran-2-yl]-4-methylidenecyclohexan-1-one + [Reduced NADPH---hemoprotein reductase] + Oxygen <=> 5-Dehydro-6-demethoxyfumagillol + [Oxidized NADPH---hemoprotein reductase] + H2O
# R13121	thiohydroximate-O-sulfate sulfate/sulfur-lyase (nitrile-forming)
# R13122	5-dehydro-6-demethoxyfumagillol,2-oxoglutarate:oxygen oxidoreductase (6-hydroxylating)
# R13123	S-adenosyl-L-methionine:5-dehydro-6-demethoxy-6-hydroxyfumagillol 6-O-methyltransferase
# R13124	1,2-beta-D-glucan:D-glucoside 2-beta-D-glucosyltransferase (configuration-retaining)
# R13125	3-O-beta-D-glucopyranosyl-beta-D-glucuronide:phosphate alpha-D-glucosyltransferase
# R13126	palatinose alpha-1,6-glucohydrolase
# R13127	3-methylbut-3-en-1-yl diphosphate phosphohydrolase
# R13128	3'-dehydrosucrose 3'-dehydroglucohydrolase
# R13129	N-(sulfonatooxy)alkenimidothioic acid sulfate-lyase (epithionitrile-forming)
# R13130	a 2,3-bis-O-phytanyl-sn-glycero-phospholipid:S-adenosyl-L-methionine,acceptor oxidoreductase (cyclyzing)
# R13131	a 2,3-bis-O-phytanyl-sn-glycero-phospholipid:S-adenosyl-L-methionine,acceptor oxidoreductase (cyclyzing)
# R13132	phenyl-N-(sulfonatooxy)methanimidothioate sulfate-lyase (benzylthiocyanate-forming)
# R13133	N-(sulfonatooxy)prop-2-enimidothioate sulfate-lyase (prop2-enylthiocyanate-forming)
# R13134	N-(sulfonatooxy)prop-2-enimidothioate sulfate-lyase
# R13136	propanoate:NAD+ oxidoreductase
# R13137	succinate:ferricytochrome-c oxidoreductase
# R13138	sym-Homospermidine + Oxygen + H+ <=> N-(4-Aminobutylpyrrolinium) ion + Hydrogen peroxide + Ammonia
# R13139	N-(4-Aminobutylpyrrolinium) ion + Oxygen + H2O <=> N-(4-Oxobutylpyrrolinium) ion + Ammonia + Hydrogen peroxide
# R13140	N-(4-Oxobutylpyrrolinium) ion <=> 1-Formylpyrrolizidine + H+
# R13141	homospermidine:oxygen oxidase (deaminating, cyclizing)
# R13142	2,6-Dichloro-p-benzoquinone + H2O <=> 2-Chloro-6-hydroxy-1,4-benzoquinone + Cl-
# R13143	2,4,6-Trichlorophenol + FADH2 + Oxygen <=> 2-Chloro-6-hydroxy-1,4-benzoquinone + 2 Cl- + FAD
# R13144	L-Fucose <=> beta-L-Fucopyranose

# %%
all_reactions = text.split('\n')
all_reactions = [reaction.split('\t') for reaction in all_reactions]
all_reactions
# Out:
# [['R00001', 'polyphosphate polyphosphohydrolase'],
#  ['R00002', 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)'],
#  ['R00004', 'diphosphate phosphohydrolase'],
#  ['R00005', 'urea-1-carboxylate amidohydrolase'],
#  ['R00006', 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)'],
#  ['R00008',
#   '4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)'],
#  ['R00009', 'hydrogen-peroxide:hydrogen-peroxide oxidoreductase'],
#  ['R00010', 'alpha,alpha-trehalose glucohydrolase'],
#  ['R00011', 'Mn(II):hydrogen-peroxide oxidoreductase'],
#  ['R00012', 'GTP:GTP guanylyltransferase'],
#  ['R00013', 'glyoxylate carboxy-lyase (dimerizing'],
#  ['R00014',
#   'pyruvate:thiamin diphosphate acetaldehydetransferase (decarboxylating)'],
#  ['R00015', "sucrose:sucrose 1'-beta-D-fructosyltransferase"],
#  ['R00017', 'ferrocytochrome-c:hydrogen-peroxide oxidoreductase'],
#  ['R00018', 'putrescine:putrescine 4-aminobutyltransferase (ammonia-forming)'],
#  ['R00019', 'hydrogen:ferredoxin oxidoreductase'],
#  ['R00021', 'L-glutamate:ferredoxin oxidoreductase (transaminating)'],
#  ['R00022', 'chitobiose N-acetylglucosaminohydrolase'],
#  ['R00023', 'hydroxylamine:NAD+ oxidoreductase'],
#  ['R00024', '3-phospho-D-glycerate carboxy-lyase (dimerizing'],
#  ['R00025', 'ethylnitronate:oxygen 2-oxidoreductase (nitrite-forming)'],
#  ['R00026', 'cellobiose glucohydrolase'],
#  ['R00027',
#   '2-hydroxy-1,2-diphenylethanone benzaldehyde-lyase (benzaldehyde-forming)'],
#  ['R00028', 'maltose glucohydrolase'],
#  ['R00029', 'thiosulfate:ferricytochrome-c oxidoreductase'],
#  ['R00031', '1,2-benzenediol:oxygen oxidoreductase'],
#  ['R00032', "beta-carotene:oxygen 15,15'-oxidoreductase (bond-cleaving)"],
#  ['R00033', 'thiamine:oxygen 5-oxidoreductase'],
#  ['R00034', 'Cyclobutadipyrimidine (in DNA) pyrimidine-lyase'],
#  ['R00036',
#   '5-aminolevulinate hydro-lyase (adding 5-aminolevulinate and cyclizing'],
#  ['R00038', '4-hydroxy-3-hexanone propanal-lyase (propanal-forming)'],
#  ['R00039', 'raffinose:raffinose 1F-alpha-D-galactosyltransferase'],
#  ['R00041', 'long-chain-alcohol:oxygen oxidoreductase'],
#  ['R00042', '4-hydroxyphenylpyruvate:oxygen oxidoreductase (decarboxylating)'],
#  ['R00043',
#   '1,2-bis(4-hydroxy-3-methoxyphenyl)ethylene:oxygen oxidoreductase (alpha-beta-bond-cleaving)'],
#  ['R00044', 'columbamine:oxygen oxidoreductase (cyclizing)'],
#  ['R00045', '3,4-dihydroxy-L-phenylalanine:oxygen oxidoreductase'],
#  ['R00047',
#   '6-hydroxynicotinate,hydrogen-donor:oxygen oxidoreductase (3-hydroxylating, decarboxylating)'],
#  ['R00048',
#   '(R)-3-((R)-3-Hydroxybutanoyloxy)-butanoate hydroxybutanoylhydrolase'],
#  ['R00049',
#   '1-O-galloyl-beta-D-glucose:1-O-galloyl-beta-D-glucose O-galloyltransferase'],
#  ['R00052', 'chloride:hydrogen-peroxide oxidoreductase'],
#  ['R00053', 'digallate acylhydrolase'],
#  ['R00054', 'orsellinate-depside hydrolase'],
#  ['R00055', "inosine:oxygen 5'-oxidoreductase"],
#  ['R00056', 'dinucleotide nucleotidohydrolase'],
#  ['R00057', 'thiol:oxygen oxidoreductase'],
#  ['R00058', 'catechol:oxygen oxidoreductase'],
#  ['R00059', 'N-(6-aminohexanoyl)-6-aminohexanoate amidohydrolase'],
#  ['R00060', 'Sulochrin:oxygen oxidoreductase (cyclizing, (+)-specific)'],
#  ['R00061', 'sulochrin:oxygen oxidoreductase (cyclizing, (-)-specific)'],
#  ['R00062',
#   'bilirubin-glucuronoside:bilirubin-glucuronoside D-glucuronosyltransferase'],
#  ['R00063',
#   '1-O-sinapoyl-beta-D-glucose:1-O-sinapoyl-beta-D-glucose 1-O-sinapoyltransferase'],
#  ['R00066',
#   '6,7-Dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase'],
#  ['R00067', 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)'],
#  ['R00068', 'L-ascorbate:oxygen oxidoreductase'],
#  ['R00069', '4-imidazolone-5-propanoate:oxygen oxidoreductase'],
#  ['R00070', 'D-urobilinogen:oxygen oxidoreductase'],
#  ['R00072', 'thiamine-aldehyde:oxygen 5-oxidoreductase'],
#  ['R00073', 'reduced acceptor:prostaglandin G2 oxidoreductase'],
#  ['R00074', '2-aminophenol:oxygen oxidoreductase (dimerizing)'],
#  ['R00075',
#   'S-adenosyl-L-methionine:S-adenosyl-L-methionine 3-amino-3-carboxypropyltransferase'],
#  ['R00076', 'ATP:phosphorylase-b phosphotransferase'],
#  ['R00077', '[Phosphorylase a] phosphohydrolase'],
#  ['R00078', 'Fe(II):oxygen oxidoreductase'],
#  ['R00080', 'Catechol:oxygen oxidoreductase (dimerizing)'],
#  ['R00081', 'ferrocytochrome-c:oxygen oxidoreductase'],
#  ['R00082', 'ferrocytochrome c2:oxygen oxidoreductase'],
#  ['R00083', 'Benzenediol:oxygen oxidoreductase'],
#  ['R00084',
#   'porphobilinogen:(4-[2-carboxyethyl]-3-[carboxymethyl]pyrrol-2-yl)methyltransferase (hydrolysing)'],
#  ['R00085', 'ATP diphosphohydrolase (phosphate-forming)'],
#  ['R00086', 'ATP phosphohydrolase'],
#  ['R00087', 'ATP diphosphohydrolase (diphosphate-forming)'],
#  ['R00088', 'ATP aminohydrolase'],
#  ['R00089', 'ATP diphosphate-lyase (cyclizing'],
#  ['R00090', 'NADH:hydrogen-peroxide oxidoreductase'],
#  ['R00091', 'CoA:NAD+ oxidoreductase'],
#  ['R00092', 'Fe2+:NAD+ oxidoreductase'],
#  ['R00093', 'L-glutamate:NAD+ oxidoreductase (transaminating)'],
#  ['R00094', 'glutathione:NAD+ oxidoreductase'],
#  ['R00095', 'NADH:monodehydroascorbate oxidoreductase'],
#  ['R00097', 'Cob(II)alamin <=> Aquacob(III)alamin'],
#  ['R00099', 'Cob(I)alamin <=> Cob(II)alamin'],
#  ['R00100', 'NADH:ferricytochrome-b5 oxidoreductase'],
#  ['R00101', 'NADH:ferrileghemoglobin oxidoreductase'],
#  ['R00102', 'NAD+ glycohydrolase'],
#  ['R00103', 'NAD+ phosphohydrolase'],
#  ['R00104', "ATP:NAD+ 2'-phosphotransferase"],
#  ['R00105', "ATP:NADH 2'-phosphotransferase"],
#  ['R00106', 'NADPH:ferricytochrome oxidoreductase'],
#  ['R00108', 'NADPH:ferricytochrome-c2 oxidoreductase'],
#  ['R00109', 'NADPH:ferrileghemoglobin oxidoreductase'],
#  ['R00111',
#   'N-(omega)-Hydroxyarginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)'],
#  ['R00112', 'NADPH:NAD+ oxidoreductase'],
#  ['R00113', 'NADPH:hydrogen-peroxide oxidoreductase'],
#  ['R00114', 'L-glutamate:NADP+ oxidoreductase (transaminating)'],
#  ['R00115', 'glutathione:NADP+ oxidoreductase'],
#  ['R00118', "NADP+ 2'-phosphohydrolase"],
#  ['R00119', 'NADP+:nicotinate ADP-ribosyltransferase'],
#  ['R00120', 'glutathione:oxygen oxidoreductase'],
#  ['R00122', 'ADP phosphohydrolase'],
#  ['R00123', 'ADP aminohydrolase'],
#  ['R00124', 'ATP:ADP phosphatransferase'],
#  ['R00125',
#   "P1,P4-bis(5'-adenosyl)-tetraphosphate nucleotidebisphosphohydrolase"],
#  ['R00126', 'ADP:ATP adenylyltransferase'],
#  ['R00127', 'ATP:AMP phosphotransferase'],
#  ['R00128', 'Adenosine-tetraphosphate phosphohydrolase'],
#  ['R00129',
#   '(6S)-6beta-hydroxy-1,4,5,6-tetrahydronicotinamide-adenine dinucleotide hydro-lyase (ATP-hydrolysing, NADH-forming)'],
#  ['R00130', "ATP:dephospho-CoA 3'-phosphotransferase"],
#  ['R00131', 'Urea amidohydrolase'],
#  ['R00132', 'carbonate hydro-lyase (carbon-dioxide-forming)'],
#  ['R00134', 'formate:NADP+ oxidoreductase'],
#  ['R00135', 'Peptide + H2O <=> L-Proline + Peptide'],
#  ['R00137', 'ATP:nicotinamide-nucleotide adenylyltransferase'],
#  ['R00138', 'Triphosphate phosphohydrolase'],
#  ['R00139',
#   "ATP:2'-deoxy-5-hydroxymethylcytidine-5'-diphosphate phosphotransferase"],
#  ['R00140', 'ATP:5-hydroxymethyldeoxycytidylate phosphotransferase'],
#  ['R00141', 'ATP:ammonia phosphotransferase'],
#  ['R00143', 'ammonia:NAD+ oxidoreductase'],
#  ['R00145', 'alpha-amino acid:NAD+ oxidoreductase (deaminating)'],
#  ['R00146', 'alpha-amino acid:NADP+ oxidoreductase (deaminating)'],
#  ['R00148', 'ammonia,ubiquinol:oxygen oxidoreductase'],
#  ['R00149',
#   'Carbon-dioxide:ammonia ligase (ADP-forming,carbamate-phosphorylating)'],
#  ['R00150', 'ATP:carbamate phosphotransferase'],
#  ['R00152', 'hydrogen cyanide aminohydrolase'],
#  ['R00153', 'Reduced ferredoxin:dinitrogen oxidoreductase (ATP-hydrolysing)'],
#  ['R00155', 'UDP phosphohydrolase'],
#  ['R00156', 'ATP:UDP phosphotransferase'],
#  ['R00157', 'Uridine triphosphate:AMP phosphotransferase'],
#  ['R00158', 'ATP:UMP phosphotransferase'],
#  ['R00159', 'UTP phosphohydrolase'],
#  ['R00160', 'FAD nucleotidohydrolase'],
#  ['R00161', 'ATP:FMN adenylyltransferase'],
#  ['R00162', 'ATP:protein phosphotransferase'],
#  ['R00164', 'Phosphoprotein phosphohydrolase'],
#  ['R00165', 'Protein <=> L-Alanyl-tRNA'],
#  ['R00166', 'Protein <=> L-Leucyl-tRNA'],
#  ['R00167', 'L-Arginyl-tRNA(Arg) <=> Protein-L-arginine'],
#  ['R00168', 'Protein <=> L-Valyl-tRNA(Val)'],
#  ['R00169', 'Protein <=> L-Glutamyl-tRNA(Glu)'],
#  ['R00170', 'Protein <=> L-Isoleucyl-tRNA(Ile)'],
#  ['R00172', 'Protein <=> Selenomethionyl-tRNA(Met)'],
#  ['R00173', "pyridoxal-5'-phosphate phosphohydrolase"],
#  ['R00174', "ATP:pyridoxal 5'-phosphotransferase"],
#  ['R00177', 'ATP:L-methionine S-adenosyltransferase'],
#  ['R00178',
#   'S-adenosyl-L-methionine carboxy-lyase [S-adenosyl 3-(methylsulfanyl)propylamine-forming]'],
#  ['R00179',
#   'S-adenosyl-L-methionine methylthioadenosine-lyase (1-aminocyclopropane-1-carboxylate-forming)'],
#  ['R00181', 'AMP aminohydrolase'],
#  ['R00182', 'AMP phosphoribohydrolase'],
#  ['R00183', "adenosine 5'-monophosphate phosphohydrolase"],
#  ['R00184', "P1,P4-bis(5'-adenosyl)-tetraphosphate adenylohydrolase"],
#  ['R00185', "ATP:adenosine 5'-phosphotransferase"],
#  ['R00187', "P1,P3-bis(5'-adenosyl)-triphosphate adenylohydrolase"],
#  ['R00188', "adenosine-3',5'-bisphosphate 3'-phosphohydrolase"],
#  ['R00189', 'deamido-NAD+:ammonia ligase (AMP-forming)'],
#  ['R00190', 'AMP:diphosphate phospho-D-ribosyltransferase'],
#  ['R00191', "adenosine 3',5'-phosphate 5'-nucleotidohydrolase"],
#  ['R00192', 'S-Adenosyl-L-homocysteine hydrolase'],
#  ['R00193', 'S-Adenosyl-L-homocysteine aminohydrolase'],
#  ['R00194', 'S-Adenosyl-L-homocysteine homocysteinylribohydrolase'],
#  ['R00195', '2,3-diaminopropanoate ammonia-lyase (adding water'],
#  ['R00196', '(S)-Lactate:ferricytochrome-c 2-oxidoreductase'],
#  ['R00197', '(R)-Lactate:ferricytochrome-c 2-oxidoreductase'],
#  ['R00198', '(R)-Lactate:ferricytochrome-c-553 2-oxidoreductase'],
#  ['R00199', 'ATP:pyruvate,water phosphotransferase'],
#  ['R00200', 'ATP:pyruvate 2-O-phosphotransferase'],
#  ['R00203', 'pyruvaldehyde:NAD+ oxidoreductase'],
#  ['R00205', '2-Oxopropanal:NADP+ oxidoreductase'],
#  ['R00206', 'ATP:pyruvate,phosphate phosphotransferase'],
#  ['R00207', 'Pyruvate:oxygen 2-oxidoreductase (phosphorylating)'],
#  ['R00208', 'Phosphoenolpyruvate phosphohydrolase'],
#  ['R00209', 'pyruvate:NAD+ 2-oxidoreductase (CoA-acetylating)'],
#  ['R00210', 'pyruvate:NADP+ 2-oxidoreductase (CoA-acetylating)'],
#  ['R00211', 'pyruvate:oxygen 2-oxidoreductase (CoA-acetylating)'],
#  ['R00212', 'Acetyl-CoA:formate C-acetyltransferase'],
#  ['R00213', 'O-carbamoyl-L-serine ammonia-lyase (decarboxylating'],
#  ['R00214', '(S)-malate:NAD+ oxidoreductase (decarboxylating)'],
#  ['R00215', '(R)-Malate:NAD+ oxidoreductase (decarboxylating)'],
#  ['R00216', '(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)'],
#  ['R00217', 'oxaloacetate carboxy-lyase (pyruvate-forming)'],
#  ['R00218', 'acetylenedicarboxylate carboxy-lyase (pyruvate-forming)'],
#  ['R00219', '2-Hydroxyethylenedicarboxylate carboxy-lyase (pyruvate-forming)'],
#  ['R00220', 'L-serine ammonia-lyase'],
#  ['R00221', 'D-serine ammonia-lyase'],
#  ['R00223', 'serine ammonia-lyase (pyruvate-forming)'],
#  ['R00224', 'pyruvate carboxy-lyase (acetaldehyde-forming)'],
#  ['R00226', 'pyruvate:pyruvate acetaldehydetransferase (decarboxylating)'],
#  ['R00227', 'Acetyl-CoA hydrolase'],
#  ['R00228', 'acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)'],
#  ['R00229', 'acetate:CoA ligase (ADP-forming)'],
#  ['R00230', 'acetyl-CoA:phosphate acetyltransferase'],
#  ['R00233', 'malonyl-CoA carboxy-lyase (acetyl-CoA-forming)'],
#  ['R00235', 'Acetate:CoA ligase (AMP-forming)'],
#  ['R00236', 'acetyl adenylate:CoA acetyltransferase'],
#  ['R00237', '(3S)-citramalyl-CoA pyruvate-lyase (acetyl-CoA-forming)'],
#  ['R00238', 'acetyl-CoA:acetyl-CoA C-acetyltransferase'],
#  ['R00239', 'ATP:L-glutamate 5-phosphotransferase'],
#  ['R00243', 'L-glutamate:NAD+ oxidoreductase (deaminating)'],
#  ['R00245', 'L-glutamate gamma-semialdehyde:NAD+ oxidoreductase'],
#  ['R00248', 'L-glutamate:NADP+ oxidoreductase (deaminating)'],
#  ['R00250', 'L-Glutamate:oxygen oxidoreductase (deaminating)'],
#  ['R00251', '5-oxo-L-proline amidohydrolase (ATP-hydrolysing)'],
#  ['R00253', 'L-Glutamate:ammonia ligase (ADP-forming)'],
#  ['R00254', 'N-carbamyl-L-glutamate amidohydrolase'],
#  ['R00256', 'L-glutamine amidohydrolase'],
#  ['R00257', 'Deamido-NAD+:L-glutamine amido-ligase (AMP-forming)'],
#  ['R00258', 'L-Alanine:2-oxoglutarate aminotransferase'],
#  ['R00259', 'acetyl-CoA:L-glutamate N-acetyltransferase'],
#  ['R00260', 'glutamate racemase'],
#  ['R00261', 'L-glutamate 1-carboxy-lyase (4-aminobutanoate-forming)'],
#  ['R00262', 'L-threo-3-methylaspartate carboxy-aminomethylmutase'],
#  ['R00263', 'L-Glutamate <=> Poly-gamma-D-glutamate'],
#  ['R00264', '2,5-dioxopentanoate:NADP+ 5-oxidoreductase'],
#  ['R00265', '2-oxoglutarate:NADP+ 2-oxidoreductase (CoA-succinylating)'],
#  ['R00267', 'Isocitrate:NADP+ oxidoreductase (decarboxylating)'],
#  ['R00268', 'oxalosuccinate carboxy-lyase (2-oxoglutarate-forming)'],
#  ['R00269', '2-oxoglutaramate amidohydrolase'],
#  ['R00270', '2-Oxoglutarate + Ammonia <=> 4-Oxoglutaramate + H2O'],
#  ['R00271',
#   'acetyl-CoA:2-oxoglutarate C-acetyltransferase (thioester-hydrolysing, carboxymethyl forming)'],
#  ['R00272', '2-Oxoglutarate carboxy-lyase'],
#  ['R00273', 'oxalate:oxygen oxidoreductase'],
#  ['R00274', 'glutathione:hydrogen-peroxide oxidoreductase'],
#  ['R00275', 'superoxide:superoxide oxidoreductase'],
#  ['R00277', "pyridoxamine-5'-phosphate:oxygen oxidoreductase (deaminating)"],
#  ['R00278', "pyridoxine 5'-phosphate:oxygen oxidoreductase"],
#  ['R00279', 'D-Glutamate:oxygen oxidoreductase (deaminating)'],
#  ['R00280', 'Nitric-oxide:acceptor oxidoreductase'],
#  ['R00282', 'NADPH:acceptor oxidoreductase'],
#  ['R00283', 'ammonium:acceptor oxidoreductase (ATP-forming)'],
#  ['R00284', 'ammonia:acceptor oxidoreductase'],
#  ['R00286', 'UDP-glucose:NAD+ 6-oxidoreductase'],
#  ['R00287', 'UDP-glucose glucophosphohydrolase'],
#  ['R00289', 'UTP:alpha-D-glucose-1-phosphate uridylyltransferase'],
#  ['R00291', 'UDP-glucose 4-epimerase'],
#  ['R00292', 'UDP-glucose:glycogen 4-alpha-D-glucosyltransferase'],
#  ['R00293',
#   'UDP-glucose 4,6-hydro-lyase (UDP-4-dehydro-6-deoxy-D-glucose-forming)'],
#  ['R00294', 'nitrous-oxide:ferricytochrome-c oxidoreductase'],
#  ['R00295', 'trithionate: (acceptor) oxidoreductase'],
#  ['R00297', '(R)-2-hydroxy-acid:acceptor 2-oxidoreductase'],
#  ['R00298', '(S)-2-hydroxyglutarate:acceptor 2-oxidoreductase'],
#  ['R00299', 'ATP:D-glucose 6-phosphotransferase'],
#  ['R00300', 'D-Glucose:NAD+ 1-oxidoreductase'],
#  ['R00301', 'D-Glucose:NADP+ 1-oxidoreductase'],
#  ['R00302', 'D-glucose:oxygen 2-oxidoreductase'],
#  ['R00303', 'D-Glucose-6-phosphate phosphohydrolase'],
#  ['R00304', 'D-Glucose-1-phosphate phosphohydrolase'],
#  ['R00305', 'D-glucose:quinone 1-oxidoreductase'],
#  ['R00306', 'cellobiose glucohydrolase'],
#  ['R00307', 'alpha-D-glucose aldose-ketose-isomerase'],
#  ['R00308', '1,3-beta-D-Glucan glucanohydrolase'],
#  ['R00310', 'protoheme ferro-lyase (protoporphyrin-forming)'],
#  ['R00311',
#   'protoheme,NADPH---hemoprotein reductase:oxygen oxidoreductase (alpha-methene-oxidizing, hydroxylating)'],
#  ['R00312', 'Heme <=> Cytochrome a'],
#  ['R00313', 'Heme <=> Catalase'],
#  ['R00314', 'Heme <=> Peroxidase'],
#  ['R00315', 'ATP:acetate phosphotransferase'],
#  ['R00316', 'ATP:acetate adenylyltransferase'],
#  ['R00317', 'Acetyl phosphate phosphohydrolase'],
#  ['R00318', 'Phosphonoacetate phosphonohydrolase'],
#  ['R00319', '(S)-lactate:oxygen 2-oxidoreductase (decarboxylating)'],
#  ['R00320', 'diphosphate:acetate phosphotransferase'],
#  ['R00321', 'Acetamide amidohydrolase'],
#  ['R00322', "5'-acetylphosphoadenosine acetylhydrolase"],
#  ['R00324', '2,4-dioxopentanoate acetylhydrolase'],
#  ['R00325',
#   '(2S)-2-hydroxy-2-methylbutanedioate pyruvate-lyase (acetate-forming)'],
#  ['R00326', 'acetaldehyde:acceptor oxidoreductase'],
#  ['R00327', '6-Acetyl-D-glucose acetylhydrolase'],
#  ['R00328', 'GDP phosphohydrolase'],
#  ['R00329', 'Nucleoside-diphosphate phosphohydrolase'],
#  ['R00330', 'ATP:GDP phosphotransferase'],
#  ['R00331', 'ATP:nucleoside-diphosphate phosphotransferase'],
#  ['R00332', 'ATP:GMP phosphotransferase'],
#  ['R00333', 'nucleoside-triphosphate:AMP phosphotransferase'],
#  ['R00334', 'ATP:nucleoside-phosphate phosphotransferase'],
#  ['R00335', 'GTP phosphohydrolase'],
#  ['R00336', "guanosine-3',5'-bis(diphosphate) 3'-diphosphohydrolase"],
#  ['R00337', 'GDP-glucose glucohydrolase'],
#  ['R00338', 'Oxaloacetate acetylhydrolase'],
#  ['R00339', '(R,R)-tartrate hydro-lyase (oxaloacetate-forming)'],
#  ['R00340', '(S,S)-tartrate hydro-lyase (oxaloacetate-forming)'],
#  ['R00341', 'ATP:oxaloacetate carboxy-lyase (transphosphorylating'],
#  ['R00342', '(S)-malate:NAD+ oxidoreductase'],
#  ['R00343', '(S)-malate:NADP+ oxidoreductase'],
#  ['R00344', 'Pyruvate:carbon-dioxide ligase (ADP-forming)'],
#  ['R00345', 'phosphate:oxaloacetate carboxy-lyase (adding phosphate'],
#  ['R00346', 'diphosphate:oxaloacetate carboxy-lyase (transphosphorylating'],
#  ['R00347',
#   'erythro-3-hydroxy-Ls-aspartate ammonia-lyase (oxaloacetate-forming)'],
#  ['R00348', '2-oxosuccinamate amidohydrolase'],
#  ['R00350',
#   '4-carboxy-4-hydroxy-2-oxoadipate oxaloacetate-lyase (pyruvate-forming)'],
#  ['R00351',
#   'acetyl-CoA:oxaloacetate C-acetyltransferase (thioester-hydrolysing)'],
#  ['R00352',
#   'acetyl-CoA:oxaloacetate C-acetyltransferase [(pro-S)-carboxymethyl-forming, ADP-phosphorylating]'],
#  ['R00353', 'malonyl-CoA:pyruvate carboxytransferase'],
#  ['R00354', '(3S)-citryl-CoA oxaloacetate-lyase (acetyl-CoA-forming)'],
#  ['R00355', 'L-Aspartate:2-oxoglutarate aminotransferase'],
#  ['R00357', 'L-Aspartic acid:oxygen oxidoreductase (deaminating)'],
#  ['R00359', 'D-Aspartate:oxygen oxidoreductase (deaminating)'],
#  ['R00360', '(S)-Malate:oxygen oxidoreductase'],
#  ['R00361', '(S)-malate:quinone oxidoreductase'],
#  ['R00362',
#   'citrate oxaloacetate-lyase (forming acetate from the pro-S carboxymethyl group of citrate)'],
#  ['R00363', 'Oxaloacetate keto-enol-isomerase'],
#  ['R00364', 'Glycine:ferricytochrome-c oxidoreductase (deaminating)'],
#  ['R00365', 'glycine:NAD+ oxidoreductase (deaminating)'],
#  ['R00366', 'glycine:oxygen oxidoreductase (deaminating)'],
#  ['R00367', 'S-Adenosyl-L-methionine:glycine N-methyltransferase'],
#  ['R00368',
#   'N-(carboxymethyl)-D-alanine:NAD+ oxidoreductase (glycine-forming)'],
#  ['R00369', 'L-Alanine:glyoxylate aminotransferase'],
#  ['R00371', 'Acetyl-CoA:glycine C-acetyltransferase'],
#  ['R00372', 'Glycine:2-oxoglutarate aminotransferase'],
#  ['R00373', 'Glycine:oxaloacetate aminotransferase'],
#  ['R00374', 'glycine:acceptor oxidoreductase (cyanide-forming)'],
#  ['R00375',
#   "Deoxyadenosine 5'-triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)"],
#  ['R00376',
#   "Deoxyguanosine 5'-triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)"],
#  ['R00377',
#   'Deoxycytidine triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)'],
#  ['R00378',
#   'deoxythymidine triphosphate:DNA deoxynucleotidyltransferase (DNA-directed)'],
#  ['R00379', 'Deoxynucleoside triphosphate:DNA deoxynucleotidyltransferase'],
#  ['R00380', 'S-Adenosyl-L-methionine:DNA (cytosine-5-)-methyltransferase'],
#  ['R00381',
#   "(deoxyribonucleotide)n:5'-phospho-(deoxyribonucleotide)m ligase (AMP-forming)"],
#  ['R00382',
#   "(deoxyribonucleotide)n:5'-phospho-(deoxyribonucleotide)m ligase (AMP-forming, NMN-forming)"],
#  ['R00383', 'Acyl-CoA hydrolase'],
#  ['R00384', 'acyl-CoA:NAD+ trans-2-oxidoreductase'],
#  ['R00385', 'acyl-CoA:NADP+ 2-oxidoreductase'],
#  ['R00387', 'acyl-CoA:NADP+ cis-2-oxidoreductase'],
#  ['R00388', 'Acyl-CoA:oxygen 2-oxidoreductase'],
#  ['R00389', 'medium-chain-fatty-acid:CoA ligase (AMP-forming)'],
#  ['R00390', 'long-chain-fatty-acid:CoA ligase (AMP-forming)'],
#  ['R00391', 'Acyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['R00392', 'acyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase'],
#  ['R00393', 'Acyl-CoA:acetate CoA-transferase'],
#  ['R00394', 'carboxylic acid:CoA ligase (GDP-forming)'],
#  ['R00395', 'Acyl-CoA:glycine N-acyltransferase'],
#  ['R00396', 'L-alanine:NAD+ oxidoreductase (deaminating)'],
#  ['R00397', 'L-aspartate 4-carboxy-lyase (L-alanine-forming)'],
#  ['R00398', "2,2'-iminodipropanoate:NAD+ oxidoreductase (L-alanine-forming)"],
#  ['R00399', '2-amino-4-ketopentanoate thiolase'],
#  ['R00400', 'L-alanine:oxaloacetate aminotransferase'],
#  ['R00401', 'alanine racemase'],
#  ['R00402', 'succinate:NAD+ oxidoreductase'],
#  ['R00405', 'Succinate:CoA ligase (ADP-forming)'],
#  ['R00406', 'succinyl-CoA:(S)-malate CoA-transferase'],
#  ['R00407', 'Succinyl-CoA hydrolase'],
#  ['R00408', 'succinate:FAD oxidoreductase'],
#  ['R00409',
#   '(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylate pyruvate-lyase (succinate-forming)'],
#  ['R00410', 'succinyl-CoA:acetoacetate CoA-transferase'],
#  ['R00411', 'N-succinyl-L-glutamate amidohydrolase'],
#  ['R00412', 'succinate:acceptor oxidoreductase'],
#  ['R00414', 'UDP-N-acetyl-D-glucosamine 2-epimerase'],
#  ['R00416',
#   'UTP:N-acetyl-alpha-D-glucosamine-1-phosphate uridylyltransferase'],
#  ['R00417',
#   'UDP-N-acetyl-D-glucosamine:protein beta-N-acetyl-D-glucosaminyltransferase'],
#  ['R00418', 'UDP-N-acetyl-D-glucosamine 4-epimerase'],
#  ['R00420', 'UDP-N-acetyl-D-glucosamine 2-epimerase'],
#  ['R00421', 'UDP-N-acetyl-D-glucosamine:NAD+ 6-oxidoreductase'],
#  ['R00422', 'UDP-N-acetyl-alpha-D-glucosamine <=> Glycolipid'],
#  ['R00423', 'UDP-N-acetyl-alpha-D-glucosamine <=> Mucopolysaccharide'],
#  ['R00424', 'GTP 7,8-8,9-dihydrolase'],
#  ['R00425', 'GTP 7,8-8,9-dihydrolase (diphosphate-forming)'],
#  ['R00426', 'GTP diphosphohydrolase (diphosphate-forming)'],
#  ['R00428', 'GTP 8,9-hydrolase'],
#  ['R00429', "ATP:GTP 3'-diphosphotransferase"],
#  ['R00430', 'GTP:pyruvate 2-O-phosphotransferase'],
#  ['R00431', 'GTP:oxaloacetate carboxy-lyase (adding GTP'],
#  ['R00432', 'Succinate:CoA ligase (GDP-forming)'],
#  ['R00434', 'GTP diphosphate-lyase (cyclizing'],
#  ['R00435', 'ATP:polynucleotide adenylyltransferase'],
#  ['R00436', 'polyribonucleotide ligase (cyclizing, AMP-forming)'],
#  ['R00437', 'polyribonucleotide:phosphate adenylyltransferase'],
#  ['R00438', 'polyribonucleotide:phosphate uridylyltransferase'],
#  ['R00439', 'polyribonucleotide:phosphate guanylyltransferase'],
#  ['R00440', 'polyribonucleotide:phosphate cytidylyltransferase'],
#  ['R00441', 'GTP:RNA guanylyltransferase (DNA-directed)'],
#  ['R00442', 'CTP:RNA cytidylyltransferase (DNA-directed)'],
#  ['R00443', 'UTP:RNA uridylyltransferase'],
#  ['R00444',
#   'nucleoside-triphosphate:RNA nucleotidyltransferase (DNA-directed)'],
#  ['R00445', 'L-lysine:NAD+ oxidoreductase (deaminating, cyclizing)'],
#  ['R00446', 'L-lysine:NAD+ 6-oxidoreductase (deaminating)'],
#  ['R00447', 'L-lysine:oxygen 2-oxidoreductase (deaminating)'],
#  ['R00448', 'L-lysine,NADPH:oxygen oxidoreductase (6-hydroxylating)'],
#  ['R00449', 'L-lysine:oxygen 2-oxidoreductase (decarboxylating)'],
#  ['R00451', 'meso-2,6-diaminoheptanedioate carboxy-lyase (L-lysine-forming)'],
#  ['R00452',
#   'N2-(D-1-carboxylethyl)-L-lysine:NADP+ oxidoreductase (L-lysine-forming)'],
#  ['R00453', 'L-Lysine:pyruvate aminotransferase'],
#  ['R00454', 'acetyl-CoA:L-lysine N6-acetyltransferase'],
#  ['R00457', 'L-Lysine:2-oxoglutarate 6-aminotransferase'],
#  ['R00458', 'N6-acetyl-L-lysine amidohydrolase'],
#  ['R00459', 'L-Lysine <=> L-Pipecolate'],
#  ['R00460', 'lysine racemase'],
#  ['R00461', 'L-Lysine 2,3-aminomutase'],
#  ['R00462', 'L-lysine carboxy-lyase (cadaverine-forming)'],
#  ['R00463', 'L-Lysine-1,6-lactam lactamhydrolase'],
#  ['R00465', 'glycolate:NADP+ oxidoreductase'],
#  ['R00466', 'Glyoxylate:oxygen oxidoreductase'],
#  ['R00468', 'Glyoxylate:NADP+ oxidoreductase (CoA-oxalylating)'],
#  ['R00469', '(S)-ureidoglycolate amidohydrolase (decarboxylating)'],
#  ['R00470', '4-hydroxy-2-oxoglutarate glyoxylate-lyase (pyruvate-forming)'],
#  ['R00471', '4-hydroxy-2-oxoglutarate glyoxylate-lyase (pyruvate-forming)'],
#  ['R00472',
#   'acetyl-CoA:glyoxylate C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)'],
#  ['R00473', 'L-malyl-CoA glyoxylate-lyase (acetyl-CoA-forming)'],
#  ['R00474',
#   '2-oxoglutarate:glyoxylate succinaldehydetransferase (decarboxylating)'],
#  ['R00475', 'glycolate:oxygen 2-oxidoreductase'],
#  ['R00476', 'glycolate:acceptor 2-oxidoreductase'],
#  ['R00477', '3-oxalomalate glyoxylate-lyase (oxaloacetate-forming)'],
#  ['R00478',
#   'erythro-3-hydroxy-Ls-aspartate glyoxylate-lyase (glycine-forming)'],
#  ['R00479', 'isocitrate glyoxylate-lyase (succinate-forming)'],
#  ['R00480', 'ATP:L-aspartate 4-phosphotransferase'],
#  ['R00481', 'L-aspartate:oxygen oxidoreductase'],
#  ['R00482', 'L-Aspartate:ammonia ligase (ADP-forming)'],
#  ['R00483', 'L-aspartate:ammonia ligase (AMP-forming)'],
#  ['R00484', 'N-Carbamoyl-L-aspartate amidohydrolase'],
#  ['R00485', 'L-asparagine amidohydrolase'],
#  ['R00486', '3-Cyano-L-alanine aminohydrolase'],
#  ['R00487', 'acetyl-CoA:L-aspartate N-acetyltransferase'],
#  ['R00488', 'N-Acetyl-L-aspartate amidohydrolase'],
#  ['R00489', 'L-aspartate 1-carboxy-lyase (beta-alanine-forming)'],
#  ['R00490', 'L-aspartate ammonia-lyase (fumarate-forming)'],
#  ['R00491', 'aspartate racemase'],
#  ['R00493', 'L-aspartate:2-oxo acid aminotransferase'],
#  ['R00494', 'glutathione gamma-glutamylaminopeptidase'],
#  ['R00497', 'gamma-L-glutamyl-L-cysteine:glycine ligase (ADP-forming)'],
#  ['R00499', 'S-Succinylglutathione hydrolase'],
#  ['R00501', 'UDP-alpha-D-galactose:NAD+ 6-oxidoreductase'],
#  ['R00502', 'UTP:alpha-D-galactose-1-phosphate uridylyltransferase'],
#  ['R00503', 'UDP-alpha-D-galactose:D-glucose 4-beta-D-galactosyltransferase'],
#  ['R00504',
#   'UDP-alpha-D-galactose:UDP-N-acetyl-alpha-D-glucosamine galactose phosphotransferase'],
#  ['R00505', 'UDP-alpha-D-galactopyranose furanomutase'],
#  ['R00506', 'UDP-alpha-D-galactose:galactan beta-1,4-D-galactosyltransferase'],
#  ['R00507', "3'-phosphoadenylyl-sulfate sulfohydrolase"],
#  ['R00508', "3'-phospho-5'-adenylyl sulfate 3'-phosphohydrolase"],
#  ['R00509', "ATP:adenylylsulfate 3'-phosphotransferase"],
#  ['R00510', "cytidine-5'-monophosphate phosphoribohydrolase"],
#  ['R00511', "cytidine-5'-monophosphate phosphohydrolase"],
#  ['R00512', 'ATP:CMP phosphotransferase'],
#  ['R00513', "ATP:cytidine 5'-phosphotransferase"],
#  ['R00514', 'CDP phosphohydrolase'],
#  ['R00515', 'CTP diphosphohydrolase (diphosphate-forming)'],
#  ['R00517', "GTP:cytidine 5'-phosphotransferase"],
#  ['R00518', 'ATP:formate phosphotransferase'],
#  ['R00519', 'formate:NAD+ oxidoreductase'],
#  ['R00521', 'Formyl-CoA hydrolase'],
#  ['R00522', 'Oxalate carboxy-lyase'],
#  ['R00524', 'Formamide amidohydrolase'],
#  ['R00525', 'N-Formyl-L-glutamate amidohydrolase'],
#  ['R00526', 'N-Formyl-L-aspartate amidohydrolase'],
#  ['R00527', 'S-Formylglutathione hydrolase'],
#  ['R00528', 'sulfite:ferricytochrome-c oxidoreductase'],
#  ['R00529', 'ATP:sulfate adenylyltransferase'],
#  ['R00530', 'ADP:sulfate adenylyltransferase'],
#  ['R00531', 'Adenylylsulfate sulfohydrolase'],
#  ['R00532', 'L-Serine-O-sulfate ammonia-lyase (pyruvate-forming)'],
#  ['R00533', 'Sulfite:oxygen oxidoreductase'],
#  ['R00534', 'D-Glucose 6-sulfate sulfohydrolase'],
#  ['R00535', "3'-Phosphoadenylylsulfate:17beta-estradiol 3-sulfotransferase"],
#  ['R00536', "3'-Phosphoadenylylsulfate:phenolic-steroid sulfotransferase"],
#  ['R00537', "3'-Phosphoadenylylsulfate:phenolic-steroid sulfotransferase"],
#  ['R00538', 'Aldehyde:NAD+ oxidoreductase'],
#  ['R00539', 'Acyl phosphate phosphohydrolase'],
#  ['R00540', 'Nitrile aminohydrolase'],
#  ['R00542', "5'-Acylphosphoadenosine acylhydrolase"],
#  ['R00543', '3-Acylpyruvate acylhydrolase'],
#  ['R00544', 'aldehyde:acceptor oxidoreductase'],
#  ['R00545', 'N6-Acyl-L-lysine amidohydrolase'],
#  ['R00546', 'N-Acyl-L-aspartate amidohydrolase'],
#  ['R00547', 'S-Acylglutathione hydrolase'],
#  ['R00548', 'riboflavin-5-phosphate phosphohydrolase'],
#  ['R00549', "ATP:riboflavin 5'-phosphotransferase"],
#  ['R00550', "D-Glucose-1-phosphate:riboflavin 5'-phosphotransferase"],
#  ['R00551', 'L-Arginine amidinohydrolase'],
#  ['R00552', 'L-Arginine iminohydrolase'],
#  ['R00554', 'ATP:L-arginine Nomega-phosphotransferase'],
#  ['R00555', 'NAD+:protein-L-arginine ADP-D-ribosyltransferase'],
#  ['R00557', 'L-arginine,NADPH:oxygen oxidoreductase (nitric-oxide-forming)'],
#  ['R00558',
#   'L-arginine,NADPH:oxygen oxidoreductase (N-(omega)-hydroxyarginine-forming)'],
#  ['R00559', 'L-Arginine:oxygen 2-oxidoreductase (decarboxylating)'],
#  ['R00562',
#   'N2-(D-1-carboxyethyl)-L-arginine:NAD+ oxidoreductase (L-arginine-forming)'],
#  ['R00563',
#   'N2-(D-1,3-dicarboxypropyl)-L-arginine:NADP+ oxidoreductase (L-arginine-forming)'],
#  ['R00565', 'L-Arginine:glycine amidinotransferase'],
#  ['R00566', 'L-arginine carboxy-lyase (agmatine-forming)'],
#  ['R00567', 'arginine racemase'],
#  ['R00569', 'CTP phosphohydrolase'],
#  ['R00570', 'ATP:CDP phosphotransferase'],
#  ['R00571', 'UTP:ammonia ligase (ADP-forming)'],
#  ['R00572', 'CTP:pyruvate 2-O-phosphotransferase'],
#  ['R00573', 'UTP:L-glutamine amido-ligase (ADP-forming)'],
#  ['R00574', 'CTP diphosphate-lyase (cyclizing'],
#  ['R00575',
#   'HCO3-:L-glutamine amido-ligase (ADP-forming, carbamate-phosphorylating)'],
#  ['R00576', 'L-Glutamine:pyruvate aminotransferase'],
#  ['R00577', 'acyl-CoA:L-glutamine N-acyltransferase'],
#  ['R00578', 'L-aspartate:L-glutamine amido-ligase (AMP-forming)'],
#  ['R00579', 'glutamine racemase'],
#  ['R00581', 'L-serine:NAD+ oxidoreductase (deaminating)'],
#  ['R00582', 'O-phospho-L-serine phosphohydrolase'],
#  ['R00584', 'diphosphate:L-serine O-phosphotransferase'],
#  ['R00585', 'L-Serine:pyruvate aminotransferase'],
#  ['R00586', 'acetyl-CoA:L-serine O-acetyltransferase'],
#  ['R00588', 'L-Serine:glyoxylate aminotransferase'],
#  ['R00589', 'serine racemase'],
#  ['R00590', 'L-serine hydro-lyase'],
#  ['R00594', 'S-Adenosyl-L-methionine:tRNA uracil 5-methyltransferase'],
#  ['R00595', 'S-adenosyl-L-methionine:tRNA (cytosine-C5)-methyltransferase'],
#  ['R00596', 'S-adenosyl-L-methionine:tRNA adenine N1-methyltransferase'],
#  ['R00597', 'S-adenosyl-L-methionine:tRNA guanine N1-methyltransferase'],
#  ['R00598', 'S-Adenosyl-L-methionine:tRNA guanine N2-methyltransferase'],
#  ['R00599', 'S-adenosyl-L-methionine:tRNA adenine N6-methyltransferase'],
#  ['R00600', 'S-Adenosyl-L-methionine:tRNA guanine N7-methyltransferase'],
#  ['R00601',
#   'S-adenosyl-L-methionine:tRNA 5-methylaminomethyl-2-thiouridine methyltransferase'],
#  ['R00602', 'methanol:hydrogen-peroxide oxidoreductase'],
#  ['R00603', 'dichloromethane chloride-lyase (adding H2O'],
#  ['R00604', 'Formaldehyde:NAD+ oxidoreductase'],
#  ['R00605', 'methanol:NAD+ oxidoreductase'],
#  ['R00606', 'methylamine:amicyanin oxidoreductase (deaminating)'],
#  ['R00608', 'Methanol:oxygen oxidereductase'],
#  ['R00609', 'N-methyl-L-glutamate:acceptor oxidoreductase (demethylating)'],
#  ['R00610', 'sarcosine:oxygen oxidoreductase (demethylating)'],
#  ['R00611',
#   'sarcosine:electron-transfer flavoprotein oxidoreductase (demethylating)'],
#  ['R00612', 'N6-Methyl-L-lysine:oxygen oxidoreductase (demethylating)'],
#  ['R00614', 'formaldehyde:formaldehyde oxidoreductase'],
#  ['R00615', 'Thiamin diphosphate phosphohydrolase'],
#  ['R00616', 'ATP:thiamine-diphosphate phosphotransferase'],
#  ['R00617', 'ATP:thiamin-phosphate phosphotransferase'],
#  ['R00618', 'Thiamin-triphosphate phosphohydrolase'],
#  ['R00619', 'ATP:thiamine diphosphotransferase'],
#  ['R00621',
#   '2-Oxoglutarate + Thiamin diphosphate <=> 3-Carboxy-1-hydroxypropyl-ThPP + CO2'],
#  ['R00623', 'primary_alcohol:NAD+ oxidoreductase'],
#  ['R00624', 'Secondary_alcohol:NAD+ oxidoreductase'],
#  ['R00625', 'primary_alcohol:NADP+ oxidoreductase'],
#  ['R00626', 'phosphate-monoester phosphohydrolase'],
#  ['R00627', 'Acetyl-CoA:alcohol O-acetyltransferase'],
#  ['R00628', 'Acetic-ester acetylhydrolase'],
#  ['R00629', "3'-phosphoadenylyl-sulfate:alcohol sulfotransferase"],
#  ['R00630', 'Carboxylic-ester hydrolase'],
#  ['R00631', 'aldehyde:NAD+ oxidoreductase'],
#  ['R00634', 'aldehyde:NADP+ oxidoreductase'],
#  ['R00635', 'Aldehyde:oxygen oxidoreductase'],
#  ['R00636', '2-oxo-acid carboxy-lyase (aldehyde-forming)'],
#  ['R00637', 'primary alcohol:oxygen oxidoreductase'],
#  ['R00638', 'aldehyde:acceptor oxidoreductase'],
#  ['R00639', 'primary alcohol:acceptor oxidoreductase'],
#  ['R00640', 'L-Galactono-1,4-lactone:ferricytochrome-c oxidoreductase'],
#  ['R00643', 'L-Galactono-1,4-lactone:oxygen 3-oxidoreductase'],
#  ['R00644', 'L-ascorbate:hydrogen-peroxide oxidoreductase'],
#  ['R00645', 'ascorbate:acceptor oxidoreductase'],
#  ['R00646', 'Ascorbate + Oxygen + H2O <=> Threonate + Oxalate'],
#  ['R00647', 'Ascorbate <=> L-xylo-Hexulonolactone'],
#  ['R00648', 'L-Methionine:oxygen oxidoreductase (deaminating)'],
#  ['R00649', 'S-Adenosyl-L-methionine:L-methionine S-methyltransferase'],
#  ['R00650', 'S-Adenosyl-L-methionine:L-homocysteine S-methyltransferase'],
#  ['R00651',
#   'O-acetyl-L-homoserine:methanethiol 3-amino-3-carboxypropyltransferase'],
#  ['R00652', 'L-Methionine:glyoxylate aminotransferase'],
#  ['R00653', 'N-formyl-L-methionine amidohydrolase'],
#  ['R00654', 'L-methionine methanethiol-lyase (deaminating'],
#  ['R00655', 'methionine racemase'],
#  ['R00656', 'L-methionine carboxy-lyase (3-methylthiopropanamine-forming)'],
#  ['R00657', 'Aminoacyl-L-methionine + H2O <=> L-Methionine'],
#  ['R00658', '2-phospho-D-glycerate hydro-lyase (phosphoenolpyruvate-forming)'],
#  ['R00659', 'UTP:pyruvate 2-O-phosphotransferase'],
#  ['R00660',
#   'Phosphoenolpyruvate:UDP-N-acetyl-D-glucosamine 1-carboxyvinyl-transferase'],
#  ['R00661', 'phosphoenolpyruvate 2,3-phosphonomutase'],
#  ['R00662', 'uridine triphosphate pyrophosphohydrolase'],
#  ['R00664', 'Bezoyl-CoA:L-ornithine N-benzoyltransferase'],
#  ['R00665', 'L-Citrulline N5-carbamoyldihydrolase'],
#  ['R00666',
#   'N5-(L-1-carboxyethyl)-L-ornithine:NADP+ oxidoreductase (L-ornithine-forming)'],
#  ['R00667', 'L-Ornithine:2-oxo-acid aminotransferase'],
#  ['R00668', 'L-ornithine:2-oxoglutarate aminotransferase'],
#  ['R00669', 'N2-Acetyl-L-ornithine amidohydrolase'],
#  ['R00670', 'L-ornithine carboxy-lyase (putrescine-forming)'],
#  ['R00671', 'L-ornithine ammonia-lyase (cyclizing'],
#  ['R00672', 'ornithine racemase'],
#  ['R00673', 'L-tryptophan indole-lyase (deaminating'],
#  ['R00674', 'L-serine hydro-lyase (adding indole'],
#  ['R00675', 'L-Tryptophan:NAD+ oxidoreductase (deaminating)'],
#  ['R00676', 'L-Tryptophan:NADP+ oxidoreductase (deaminating)'],
#  ['R00677', 'L-Tryptophan:oxygen oxidoreductase (deaminating)'],
#  ['R00678', 'L-tryptophan:oxygen 2,3-oxidoreductase (decyclizing)'],
#  ['R00679', 'L-tryptophan:oxygen 2-oxidoreductase (decarboxylating)'],
#  ['R00681', "L-Tryptophan:oxygen 2'-oxidoreductase (side-chain-cleaving)"],
#  ['R00682', 'L-Tryptophanamide amidohydrolase'],
#  ['R00683', 'S-Adenosyl-L-methionine:L-tryptophan N-methyltransferase'],
#  ['R00684', 'L-Tryptophan:2-oxoglutarate aminotransferase'],
#  ['R00685', 'L-tryptophan decarboxy-lyase'],
#  ['R00686', 'L-Phenylalanine racemase (ATP-hydrolysing)'],
#  ['R00688', 'L-phenylalanine:NAD+ oxidoreductase (deaminating)'],
#  ['R00689', 'L-Phenylalanine:oxygen oxidoreductase (deaminating)'],
#  ['R00690', 'L-phenylalanine:oxygen 2-oxidoreductase (decarboxylating)'],
#  ['R00691', 'L-arogenate hydro-lyase (decarboxylating'],
#  ['R00692', 'L-phenylalanine:pyruvate aminotransferase'],
#  ['R00693', 'Acetyl-CoA:L-phenylalanine N-acetyltransferase'],
#  ['R00694', 'L-Phenylalanine:2-oxoglutarate aminotransferase'],
#  ['R00695', 'L-Aspartate:phenylpyruvate aminotransferase'],
#  ['R00697', 'L-phenylalanine ammonia-lyase (trans-cinnamate-forming)'],
#  ['R00698', 'L-phenylalanine:oxygen oxidoreductase (decarboxylating)'],
#  ['R00699', 'L-phenylalanine carboxy-lyase (phenylethylamine-forming)'],
#  ['R00700', 'hydrogen:NAD+ oxidoreductase'],
#  ['R00702', 'farnesyl-diphosphate:farnesyl-diphosphate farnesyltransferase'],
#  ['R00703', '(S)-Lactate:NAD+ oxidoreductase'],
#  ['R00704', '(R)-Lactate:NAD+ oxidoreductase'],
#  ['R00705',
#   '3-Oxopropanoate:NAD+ oxidoreductase (decarboxylating, CoA-acetylating)'],
#  ['R00706',
#   '3-Oxopropanoate:NADP+ oxidoreductase (decarboxylating, CoA-acetylating)'],
#  ['R00707', '(S)-1-pyrroline-5-carboxylate:NAD+ oxidoreductase'],
#  ['R00708', '(S)-1-pyrroline-5-carboxylate:NADP+ oxidoreductase'],
#  ['R00709', 'isocitrate:NAD+ oxidoreductase (decarboxylating)'],
#  ['R00710', 'Acetaldehyde:NAD+ oxidoreductase'],
#  ['R00711', 'Acetaldehyde:NADP+ oxidoreductase'],
#  ['R00713', 'succinate-semialdehyde:NAD+ oxidoreductase'],
#  ['R00714', 'succinate-semialdehyde:NADP+ oxidoreductase'],
#  ['R00715',
#   'N6-(L-1,3-Dicarboxypropyl)-L-lysine:NAD+ oxidoreductase (L-lysine-forming)'],
#  ['R00716',
#   'N6-(L-1,3-Dicarboxypropyl)-L-lysine:NADP+ oxidoreductase (L-lysine-forming)'],
#  ['R00717', 'Glycolate:NAD+ oxidoreductase'],
#  ['R00719', 'ITP phosphohydrolase'],
#  ['R00720', "Inosine 5'-triphosphate pyrophosphohydrolase"],
#  ['R00722', 'ATP:IDP phosphotransferase'],
#  ['R00723', "Inosine 5'-tetraphosphate phosphohydrolase"],
#  ['R00724', 'ITP:pyruvate 2-O-phosphotransferase'],
#  ['R00725', 'ITP:D-glucose 6-phosphotransferase'],
#  ['R00726', 'ITP:oxaloacetate carboxy-lyase (adding ITP'],
#  ['R00727', 'Succinate:CoA ligase (IDP-forming)'],
#  ['R00728', 'L-tyrosine phenol-lyase (deaminating'],
#  ['R00729', 'L-Tyrosine:oxygen oxidoreductase (deaminating)'],
#  ['R00730',
#   'L-tyrosine,[reduced NADPH-hemoprotein reductase]:oxygen oxidoreductase (N-hydroxylating)'],
#  ['R00731', 'L-Tyrosine:oxygen oxidoreductase'],
#  ['R00732', 'L-arogenate:NAD+ oxidoreductase'],
#  ['R00733', 'L-arogenate:NADP+ oxidoreductase'],
#  ['R00734', 'L-tyrosine:2-oxoglutarate aminotransferase'],
#  ['R00735', 'L-Tyrosine:L-arginine ligase (AMP-forming)'],
#  ['R00736', 'L-tyrosine carboxy-lyase (tyramine-forming)'],
#  ['R00737', 'L-tyrosine ammonia-lyase (trans-p-hydroxycinnamate-forming)'],
#  ['R00739', 'L-Tyrosine 2,3-aminomutase'],
#  ['R00740', '3-oxopropanoate:NADP+ oxidoreductase (CoA-malonylating)'],
#  ['R00742', 'acetyl-CoA:carbon-dioxide ligase (ADP-forming)'],
#  ['R00743', 'Acetyl-CoA:malonate CoA-transferase'],
#  ['R00744', '3-oxopropionyl-CoA:NAD+ oxidoreductase'],
#  ['R00746', 'Ethanol:NADP+ oxidoreductase'],
#  ['R00747', '2-Phosphonoacetaldehyde phosphonohydrolase'],
#  ['R00748', 'ethanolamine-phosphate phosphate-lyase (deaminating'],
#  ['R00749', 'ethanolamine ammonia-lyase (acetaldehyde-forming)'],
#  ['R00750', '4-hydroxy-2-oxopentanoate pyruvate-lyase (acetaldehyde-forming)'],
#  ['R00751', 'L-threonine acetaldehyde-lyase (glycine-forming)'],
#  ['R00753', '(S)-lactate acetaldehyde-lyase (formate-forming)'],
#  ['R00754', 'ethanol:NAD+ oxidoreductase'],
#  ['R00755',
#   'Acetaldehyde + Thiamin diphosphate <=> 2-(alpha-Hydroxyethyl)thiamine diphosphate'],
#  ['R00756', 'ATP:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['R00758', 'D-Mannitol-1-phosphate:NAD+ 5-oxidoreductase'],
#  ['R00760', 'ATP:D-fructose 6-phosphotransferase'],
#  ['R00761',
#   'D-fructose-6-phosphate D-erythrose-4-phosphate-lyase (adding phosphate'],
#  ['R00762', 'D-Fructose-1,6-bisphosphate 1-phosphohydrolase'],
#  ['R00763', 'beta-D-fructose-2,6-bisphosphate 2-phosphohydrolase'],
#  ['R00764', 'diphosphate:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['R00765', 'D-glucosamine-6-phosphate aminohydrolase (ketol isomerizing)'],
#  ['R00766',
#   'UDP-glucose:D-fructose-6-phosphate 2-alpha-D-glucosyltransferase'],
#  ['R00767', 'CTP:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['R00768', 'L-glutamine:D-fructose-6-phosphate isomerase (deaminating)'],
#  ['R00769', 'UTP:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['R00770', 'ITP:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['R00771', 'D-glucose-6-phosphate aldose-ketose-isomerase'],
#  ['R00772', 'D-mannose-6-phosphate aldose-ketose-isomerase'],
#  ['R00774', 'Urea:carbon-dioxide ligase (ADP-forming)'],
#  ['R00775', 'Guanidinoacetate amidohydrolase'],
#  ['R00776', '(S)-ureidoglycolate urea-lyase (glyoxylate-forming)'],
#  ['R00777', 'N-Amidino-L-aspartate amidinohydrolase'],
#  ['R00778', 'urea hydro-lyase (cyanamide-forming)'],
#  ['R00782', 'L-cysteine hydrogen-sulfide-lyase (deaminating'],
#  ['R00783', 'nitric-oxide:ferricytochrome-c oxidoreductase'],
#  ['R00784', 'nitric-oxide:ferricytochrome-c2 oxidoreductase'],
#  ['R00785', 'nitric-oxide:oxidized azurin oxidoreductase'],
#  ['R00787', 'ammonia:NAD+ oxidoreductase'],
#  ['R00789', 'ammonia:NADP+ oxidoreductase'],
#  ['R00790', 'Ammonia:ferredoxin oxidoreductase'],
#  ['R00791', 'nitrite:ferredoxin oxidoreductase'],
#  ['R00792', 'ferrocytochrome-b:nitrate oxidoreductase'],
#  ['R00793', 'Hydroxylamine:oxygen oxidoreductase'],
#  ['R00794', 'nitrite:NAD+ oxidoreductase'],
#  ['R00796', 'nitrite:NADP+ oxidoreductase'],
#  ['R00798', 'nitrite:acceptor oxidoreductase'],
#  ['R00799', 'Nitroethane:oxygen oxidoreductase'],
#  ['R00800', 'nitrite oxidase'],
#  ['R00801', 'sucrose glucohydrolase'],
#  ['R00802', 'sucrose alpha-glucohydrolase'],
#  ['R00803', 'sucrose:phosphate alpha-D-glucosyltransferase'],
#  ['R00804', 'Sugar-phosphate phosphohydrolase'],
#  ['R00805', 'sucrose-6F-phosphate phosphohydrolase'],
#  ['R00806', 'UDP-glucose:D-fructose 2-alpha-D-glucosyltransferase'],
#  ['R00807', 'Sucrose:(acceptor) 3-oxidoreductase'],
#  ['R00808', 'Sucrose:(acceptor) 3-oxidoreductase'],
#  ['R00809', 'UDP-alpha-D-galactose:sucrose 6F-alpha-D-galactosyltransferase'],
#  ['R00810', 'Sucrose glucosylmutase'],
#  ['R00811', 'protein-Npi-phospho-L-histidine:sugar phosphotransferase'],
#  ['R00812', 'cis-1,2-dihydrobenzene-1,2-diol:NAD+ oxidoreductase'],
#  ['R00813',
#   '(1R,6S)-1,6-dihydroxycyclohexa-2,4-diene-1-carboxylate:NAD+ oxidoreductase (decarboxylating)'],
#  ['R00814', 'trans-1,2-dihydrobenzene-1,2-diol:NADP+ oxidoreductase'],
#  ['R00815', 'phenol,NADPH:oxogen oxidoreductase (2-hydroxylating)'],
#  ['R00816', 'catechol:oxygen 2,3-oxidoreductase (decyclizing)'],
#  ['R00817', 'Catechol:oxygen 1,2-oxidoreductase(decyclizing)'],
#  ['R00818',
#   'salicylate,NADH:oxygen oxidoreductase (1-hydroxylating, decarboxylating)'],
#  ['R00821', '2,3-dihydroxybenzoate carboxy-lyase'],
#  ['R00822', '3,4-dihydroxybenzoate carboxy-lyase (catechol-forming)'],
#  ['R00823',
#   'Anthranilate,NADH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)'],
#  ['R00825',
#   'anthranilate,NADPH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)'],
#  ['R00827', 'S-Adenosyl-L-methionine:catechol O-methyltransferase'],
#  ['R00828',
#   '2-nitrophenol,NADPH:oxygen 2-oxidoreductase (2-hydroxylating, nitrite-forming)'],
#  ['R00829', 'succinyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['R00830', 'succinyl-CoA:glycine C-succinyltransferase (decarboxylating)'],
#  ['R00832', 'succinyl-CoA:L-arginine N2-succinyltransferase'],
#  ['R00833', '(R)-Methylmalonyl-CoA CoA-carbonylmutase'],
#  ['R00834', 'D-Sorbitol 6-phosphate:NADP+ 1-oxidoreductase'],
#  ['R00835', 'D-glucose-6-phosphate:NADP+ 1-oxidoreductase'],
#  ['R00836', 'UDP-glucose:D-glucose-6-phosphate 1-alpha-D-glucosyltransferase'],
#  ['R00837', 'alpha,alpha-Trehalose-6-phosphate phosphoglucohydrolase'],
#  ['R00838', "Maltose-6'-phosphate 6-phosphoglucohydrolase"],
#  ['R00839',
#   '6-phospho-beta-D-glucosyl-(1->4)-D-glucose 6-phosphoglucohydrolase'],
#  ['R00841', 'sn-glycerol-3-phosphate phosphohydrolase'],
#  ['R00842', 'sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase'],
#  ['R00844', 'sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase'],
#  ['R00845', 'sn-glycerol-3-phosphate:NADP+ 1-oxidoreductase'],
#  ['R00846', 'sn-Glycerol-3-phosphate:oxygen 2-oxidoreductase'],
#  ['R00847', 'ATP:glycerol 3-phosphotransferase'],
#  ['R00848', 'sn-Glycerol-3-phosphate:(acceptor) 2-oxidoreductase'],
#  ['R00849', 'sn-glycerol 3-phosphate:quinone oxidoreductase'],
#  ['R00850', 'sn-Glycerol-3-phosphate:D-glucose 6-phosphotransferase'],
#  ['R00851', 'acyl-CoA:sn-glycerol-3-phosphate 1-O-acyltransferase'],
#  ['R00853',
#   'UDP-alpha-D-galactose:sn-glycerol-3-phosphate 2-alpha-D-galactosyltransferase'],
#  ['R00854',
#   'UDP-alpha-D-galactose:sn-glycerol-3-phosphate 1-alpha-D-galactosyltransferase'],
#  ['R00855', 'CDPglycerol phosphoglycerohydrolase'],
#  ['R00856', 'CTP:sn-glycerol-3-phosphate cytidylyltransferase'],
#  ['R00857', 'Glycerophosphodiester glycerophosphohydrolase'],
#  ['R00858', 'hydrogen-sulfide:NADP+ oxidoreductase'],
#  ['R00859', 'Hydrogen-sulfide:ferredoxin oxidoreductase'],
#  ['R00860',
#   "AMP,sulfite:acceptor oxidoreductase (adenosine-5'-phosphosulfate-forming)"],
#  ['R00861',
#   'hydrogen-sulfide:[DsrC sulfur-carrier protein],acceptor oxidoreductase'],
#  ['R00863', '3-Sulfino-L-alanine 4-carboxy-lyase'],
#  ['R00864', 'Sulfite + Sulfur <=> Thiosulfate'],
#  ['R00865', 'D-Mannitol:ferricytochrome-c 2-oxidoreductase'],
#  ['R00866', 'ATP:D-fructose 1-phosphotransferase'],
#  ['R00867', 'ATP:D-fructose 6-phosphotransferase'],
#  ['R00868', 'D-Mannitol:NAD+ 2-oxidoreductase'],
#  ['R00870', 'D-Mannitol:NADP+ 2-oxidoreductase'],
#  ['R00871', 'D-Fructose:NADP+ 5-oxidoreductase'],
#  ['R00872', 'D-fructose 2-phosphate phosphatase'],
#  ['R00873', 'D-fructose:ubiquinone 5-oxidoreductase'],
#  ['R00874', 'D-Glucose:D-fructose oxidoreductase'],
#  ['R00875', 'D-Glucitol:NAD+ 2-oxidoreductase'],
#  ['R00876', 'ITP:D-fructose 6-phosphotransferase'],
#  ['R00877', 'D-mannose aldose-ketose-isomerase'],
#  ['R00878', 'alpha-D-Glucose aldose-ketose-isomerase'],
#  ['R00879', 'beta-D-Fructan fructohydrolase'],
#  ['R00880', 'GDP-D-mannose:NAD+ 6-oxidoreductase'],
#  ['R00881', 'GDP-mannose mannophosphohydrolase'],
#  ['R00883', 'GDP:D-mannose-1-phosphate guanylyltransferase'],
#  ['R00885', 'GTP:alpha-D-mannose-1-phosphate guanylyltransferase'],
#  ['R00887', 'GDP-mannose + Mannan(n) <=> GDP + Mannan(n+1)'],
#  ['R00888',
#   'GDP-alpha-D-mannose 4,6-hydro-lyase (GDP-4-dehydro-alpha-D-rhamnose-forming)'],
#  ['R00889', 'GDP-mannose 3,5-epimerase'],
#  ['R00890', 'GDPmannose:mannan 1,4-beta-D-mannosyltransferase'],
#  ['R00891',
#   'L-serine hydro-lyase (adding hydrogen sulfide, L-cysteine-forming)'],
#  ['R00892', 'L-cysteine:NAD+ oxidoreductase'],
#  ['R00893', 'L-Cysteine:oxygen oxidoreductase'],
#  ['R00894', 'L-glutamate:L-cysteine gamma-ligase (ADP-forming)'],
#  ['R00895', 'L-Cysteine:2-oxoglutarate aminotransferase'],
#  ['R00896', 'L-cysteine:2-oxoglutarate aminotransferase'],
#  ['R00897',
#   'O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase'],
#  ['R00899', 'L-cysteinylglycine dipeptidase'],
#  ['R00900', 'L-cysteine,glutathione:NADP+ oxidoreductase (disulfide-forming)'],
#  ['R00901', 'L-cysteine hydrogen-sulfide-lyase (adding sulfite'],
#  ['R00903', 'cysteine racemase'],
#  ['R00904', '3-aminopropanal:NAD+ oxidoreductase'],
#  ['R00905', '3-ureidopropanoate amidohydrolase'],
#  ['R00906',
#   'N-(D-1-carboxyethyl)-beta-alanine:NAD+ oxidoreductase (beta-alanine-forming)'],
#  ['R00907', 'L-Alanine:3-oxopropanoate aminotransferase'],
#  ['R00908', 'beta-alanine:2-oxoglutarate aminotransferase'],
#  ['R00909', 'N-Acetyl-beta-alanine amidohydrolase'],
#  ['R00910', 'L-lysine:beta-alanine ligase (ADP-forming)'],
#  ['R00911', 'beta-Alanyl-L-lysine hydrolase'],
#  ['R00912', 'L-arginine:beta-alanine ligase (ADP-forming)'],
#  ['R00913', '3-Guanidinopropanoate amidinopropionase'],
#  ['R00914', 'beta-alanine CoA-transferase'],
#  ['R00915', 'beta-Alanine <=> Quinolinate'],
#  ['R00916', 'beta-Alanine <=> beta-Nitropropanoate'],
#  ['R00917', 'beta-aminopropionitrile aminohydrolase'],
#  ['R00918',
#   'propanoyl-CoA:(2S)-methylmalonyl-CoA malonyltransferase (cyclizing)'],
#  ['R00919', 'propanoyl-CoA:NADP+ 2-oxidoreductase'],
#  ['R00920', 'propanoate:CoA ligase (ADP-forming)'],
#  ['R00921', 'propanoyl-CoA:phosphate propanoyltransferase'],
#  ['R00922',
#   '2-Methyl-3-oxopropanoate:NAD+ oxidoreductase (CoA-propanoylating)'],
#  ['R00923', '(S)-methylmalonyl-CoA carboxy-lyase (propanoyl-CoA-forming)'],
#  ['R00925', 'Propanoate:CoA ligase (AMP-forming)'],
#  ['R00926', 'Propionyladenylate:CoA propionyltransferase'],
#  ['R00927', 'acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase'],
#  ['R00928', 'Acetyl-CoA:propanoate CoA-transferase'],
#  ['R00930', '(S)-2-Methyl-3-oxopropanoyl-CoA:pyruvate carboxyltransferase'],
#  ['R00931',
#   'propanoyl-CoA:oxaloacetate C-propanoyltransferase (thioester-hydrolysing, 1-carboxyethyl-forming)'],
#  ['R00932',
#   'propanoyl-CoA:glyoxylate C-propanoyltransferase (thioester-hydrolysing, 2-carboxyethyl-forming)'],
#  ['R00934',
#   'L-erythro-3-methylmalyl-CoA glyoxylate-lyase (propanoyl-CoA-forming)'],
#  ['R00935',
#   '(S)-Methylmalonate semialdehyde:NAD+ oxidoreductase (CoA-propanoylating)'],
#  ['R00936', '5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase'],
#  ['R00937', '5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase'],
#  ['R00939', '5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase'],
#  ['R00940', '5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase'],
#  ['R00941', '10-formyltetrahydrofolate:NADP+ oxidoreductase'],
#  ['R00942', 'Tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)'],
#  ['R00943', 'Formate:tetrahydrofolate ligase (ADP-forming)'],
#  ['R00944', '10-Formyltetrahydrofolate amidohydrolase'],
#  ['R00945', '5,10-Methylenetetrahydrofolate:glycine hydroxymethyltransferase'],
#  ['R00946', '5-methyltetrahydrofolate:L-homocysteine S-methyltransferase'],
#  ['R00947', 'alpha-D-glucose-1-phosphate phosphohydrolase'],
#  ['R00948', 'ATP:alpha-D-glucose-1-phosphate adenylyltransferase'],
#  ['R00949', 'ATP:D-glucose-1-phosphate 6-phosphotransferase'],
#  ['R00951', 'ADP-glucose glucose-1-phosphohydrolase'],
#  ['R00952', 'cellobiose:phosphate alpha-D-glucosyltransferase'],
#  ['R00953',
#   '3-beta-D-glucosyl-D-glucose:phosphate alpha-D-glucosyltransferase'],
#  ['R00954', 'GTP:alpha-D-glucose-1-phosphate guanylyltransferase'],
#  ['R00955', 'UDP-glucose:alpha-D-galactose-1-phosphate uridylyltransferase'],
#  ['R00956', 'CTP:alpha-D-glucose-1-phosphate cytidylyltransferase'],
#  ['R00957',
#   'alpha-D-Glucose-1-phosphate:alpha-D-glucose-1-phosphate 4-alpha-D-glucosyltransferase (dephosphorylating)'],
#  ['R00959', 'alpha-D-Glucose 1-phosphate 1,6-phosphomutase'],
#  ['R00960',
#   'D-Glucose-1-phosphate:D-glucose-1-phosphate 6-phosphotransferase'],
#  ['R00961', 'IDP phosphohydrolase'],
#  ['R00963', "uridine 5'-monophosphate phosphohydrolase"],
#  ['R00964', "ATP:uridine 5'-phosphotransferase"],
#  ['R00965', "orotidine-5'-phosphate carboxy-lyase (UMP-forming)"],
#  ['R00966', 'UMP:diphosphate phospho-alpha-D-ribosyltransferase'],
#  ['R00968', "GTP:uridine 5'-phosphotransferase"],
#  ['R00969', "P1,P4-bis(5'-uridyl)-tetraphosphate uridylohydrolase"],
#  ['R00973', 'uracil-5-carboxylate carboxy-lyase (uracil-forming)'],
#  ['R00974', 'Cytosine aminohydrolase'],
#  ['R00975', '5,6-Dihydrouracil:oxygen oxidoreductase'],
#  ['R00976', 'uracil:acceptor oxidoreductase'],
#  ['R00977', '5,6-dihydrouracil:NAD+ oxidoreductase'],
#  ['R00978', '5,6-Dihydrouracil:NADP+ oxidoreductase'],
#  ['R00980',
#   'Anthranilate,NADPH:oxygen oxidoreductase (3-hydroxylating, deaminating)'],
#  ['R00982', 'Anthranilate:CoA ligase (AMP-forming)'],
#  ['R00983', '2,3-Dihydroxyindole:oxygen 2,3-oxidoreductase (decyclizing)'],
#  ['R00984', 'S-Adenosyl-L-methionine:anthranilate N-methyltransferase'],
#  ['R00985', 'chorismate pyruvate-lyase (amino-accepting'],
#  ['R00986', 'Chorismate pyruvate-lyase (amino-accepting)'],
#  ['R00987', 'L-Kynurenine hydrolase'],
#  ['R00988', 'N-Formylanthranilate amidohydrolase'],
#  ['R00989', 'Malonyl-CoA:anthranilate N-malonyltransferase'],
#  ['R00990', '2-Aminobenzoate carboxy-lyase'],
#  ['R00991', 'Anthranilate <=> 2-Formaminobenzoylacetate'],
#  ['R00993', '2-oxobutanoate:oxygen 2-oxidoreductase (phosphorylating)'],
#  ['R00994', '(2R,3S)-3-methylmalate:NAD+ oxidoreductase'],
#  ['R00995', 'methyloxaloacetate carboxy-lyase (2-oxobutanoate-forming)'],
#  ['R00996', 'L-threonine ammonia-lyase (2-oxobutanoate-forming)'],
#  ['R00997', '1-aminocyclopropane-1-carboxylate aminohydrolase (isomerizing)'],
#  ['R00998',
#   'acetyl-CoA:2-oxobutanoate C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)'],
#  ['R00999', 'O-Succinyl-L-homoserine succinate-lyase (deaminating'],
#  ['R01000', '2-hydroxybutyrate:NAD+ oxidoreductase'],
#  ['R01001', 'L-cystathionine cysteine-lyase (deaminating'],
#  ['R01003', 'dolichyl-phosphate phosphohydrolase'],
#  ['R01004', 'Dolichyl-diphosphate phosphohydrolase'],
#  ['R01005', 'UDPglucose:dolichyl-phosphate beta-D-glucosyltransferase'],
#  ['R01006', 'Dolichyl-beta-D-glucosyl-phosphate dolichylphosphohydrolase'],
#  ['R01007',
#   'UDP-N-acetyl-D-glucosamine:dolichyl-phosphate N-acetyl-D-glucosamine phosphotransferase'],
#  ['R01008',
#   'UDP-N-acetyl-D-glucosamine:dolichyl-phosphate alpha-N-acetyl-D-glucosaminyltransferase'],
#  ['R01009', 'GDPmannose:dolichyl-phosphate O-beta-D-mannosyltransferase'],
#  ['R01010', 'Glycerone phosphate phosphohydrolase'],
#  ['R01011', 'ATP:glycerone phosphotransferase'],
#  ['R01012', 'phosphoenolpyruvate:glycerone phosphotransferase'],
#  ['R01013', 'Acyl-CoA:glycerone-phosphate O-acyltransferase'],
#  ['R01014',
#   'erythrulose-1-phosphate formaldehyde-lyase (glycerone-phosphate-forming)'],
#  ['R01015', 'D-glyceraldehyde-3-phosphate aldose-ketose-isomerase'],
#  ['R01016', 'glycerone-phosphate phosphate-lyase (methylglyoxal-forming)'],
#  ['R01018', 'CTP:dolichol O-phosphotransferase'],
#  ['R01019', 'acetaldehyde:pyrroloquinoline-quinone oxidoreductase'],
#  ['R01021', 'ATP:choline phosphotransferase'],
#  ['R01022', 'choline:oxygen 1-oxidoreductase'],
#  ['R01023', 'Acetyl-CoA:choline O-acetyltransferase'],
#  ['R01025', 'choline:acceptor 1-oxidoreductase'],
#  ['R01026', 'Acetylcholine aectylhydrolase'],
#  ['R01027', "3'-phosphoadenylyl-sulfate:choline sulfotransferase"],
#  ['R01028', 'Choline sulfate sulfohydrolase'],
#  ['R01029', 'Acylcholine acylhydrolase'],
#  ['R01030', 'sn-Glycero-3-phosphocholine glycerophosphohydrolase'],
#  ['R01031', '3-chloro-D-alanine chloride-lyase (deaminating'],
#  ['R01032', '3-chloro-L-alanine chloride-lyase (deaminating'],
#  ['R01033',
#   '2-chlorobenzoate,NADH:oxygen oxidoreductase (1,2-hydroxylating, dechlorinating, decarboxylating)'],
#  ['R01034', 'glycerol:NAD+ 2-oxidoreductase'],
#  ['R01036', 'Glycerol:NAD+ oxidoreductase'],
#  ['R01039', 'glycerol:NADP+ 2-oxidoreductase (glycerone-forming)'],
#  ['R01041', 'glycerol:NADP+ oxidoreductase'],
#  ['R01043', 'Glycerol-2-phosphate phosphohydrolase'],
#  ['R01044', 'diphosphate:glycerol 1-phosphotransferase'],
#  ['R01045', 'Glycerol:(acceptor) 1-oxidoreductase'],
#  ['R01047', 'glycerol hydro-lyase (3-hydroxypropanal-forming)'],
#  ['R01049', 'ATP:D-ribose-5-phosphate diphosphotransferase'],
#  ['R01050', 'ATP:D-ribose-5-phosphate 1-phosphotransferase'],
#  ['R01051', 'ATP:D-ribose 5-phosphotransferase'],
#  ['R01052', 'ADP:D-ribose-5-phosphate adenylyltransferase'],
#  ['R01053', 'Ribose-5-phosphate:ammonia ligase (ADP-forming)'],
#  ['R01054', 'ADP-ribose ribophosphohydrolase'],
#  ['R01055', 'uracil hydro-lyase (adding D-ribose 5-phosphate'],
#  ['R01056', 'D-ribose-5-phosphate aldose-ketose-isomerase'],
#  ['R01057', 'D-Ribose 1,5-phosphomutase'],
#  ['R01058', 'D-glyceraldehyde 3-phosphate:NADP+ oxidoreductase'],
#  ['R01059', 'ATP:D-glyceraldehyde 3-phosphotransferase'],
#  ['R01061',
#   'D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)'],
#  ['R01063',
#   'D-glyceraldehyde-3-phosphate:NADP+ oxidoreductase (phosphorylating)'],
#  ['R01064',
#   '2-dehydro-3-deoxy-6-phospho-D-galactonate D-glyceraldehyde-3-phospho-lyase (pyruvate-forming)'],
#  ['R01066',
#   '2-deoxy-D-ribose-5-phosphate acetaldehyde-lyase (D-glyceraldehyde-3-phosphate-forming)'],
#  ['R01067',
#   'D-Fructose 6-phosphate:D-glyceraldehyde-3-phosphate glycolaldehyde transferase'],
#  ['R01068',
#   'D-fructose-1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)'],
#  ['R01069',
#   'D-tagatose 1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)'],
#  ['R01070',
#   'beta-D-fructose-1,6-bisphosphate D-glyceraldehyde-3-phosphate-lyase (glycerone-phosphate-forming)'],
#  ['R01071',
#   '1-(5-phospho-D-ribosyl)-ATP:diphosphate phospho-alpha-D-ribosyl-transferase'],
#  ['R01072',
#   '5-phosphoribosylamine:diphosphate phospho-alpha-D-ribosyltransferase (glutamate-amidating)'],
#  ['R01073',
#   'N-(5-Phospho-D-ribosyl)anthranilate:pyrophosphate phosphoribosyl-transferase'],
#  ['R01074', 'biotin:CoA ligase (AMP-forming)'],
#  ['R01075', 'biotin:CoA ligase (AMP-forming)'],
#  ['R01076', 'Biotin-amide amidohydrolase'],
#  ['R01077', 'N6-D-Biotinyl-L-lysine amidohydrolase'],
#  ['R01078', 'dethiobiotin:sulfur sulfurtransferase'],
#  ['R01079', 'D-Ribose:NADP+ 1-oxidoreductase'],
#  ['R01080', 'uridine ribohydrolase'],
#  ['R01081', 'D-ribose aldose-ketose-isomerase'],
#  ['R01082', '(S)-malate hydro-lyase (fumarate-forming)'],
#  ['R01083', 'N6-(1,2-dicarboxyethyl)AMP AMP-lyase (fumarate-forming)'],
#  ['R01085', '3-fumarylpyruvate fumarylhydrolase'],
#  ['R01086',
#   '2-(Nomega-L-arginino)succinate arginine-lyase (fumarate-forming)'],
#  ['R01087', 'Maleate cis-trans-isomerase'],
#  ['R01088', 'L-leucine:NAD+ oxidoreductase (deaminating)'],
#  ['R01089', 'Acetyl-CoA:L-leucine N-acetyltransferase'],
#  ['R01090', 'L-Leucine:2-oxoglutarate aminotransferase'],
#  ['R01091', '(2S)-alpha-leucine 2,3-aminomutase'],
#  ['R01092', 'ATP:alpha-D-galactose 1-phosphotransferase'],
#  ['R01093', 'galactitol:NAD+ 1-oxidoreductase'],
#  ['R01094', 'D-galactose:NAD+ 1-oxidoreductase'],
#  ['R01095', 'galactitol:NADP+ 1-oxidoreductase'],
#  ['R01096', 'D-galactose:NADP+ 1-oxidoreductase'],
#  ['R01097', 'D-Galactose:NADP+ 1-oxidoreductase'],
#  ['R01098', 'D-Galactose:oxygen 6-oxidoreductase'],
#  ['R01099', 'D-Galactose:oxygen 6-oxidoreductase'],
#  ['R01100', 'Lactose galactohydrolase'],
#  ['R01101', 'melibiose galactohydrolase'],
#  ['R01103', 'Raffinose galactohydrolase'],
#  ['R01104', 'Galactosylglycerol galactohydrolase'],
#  ['R01105', 'Galactan galactohydrolase'],
#  ['R01106', 'nitrite:(acceptor) oxidoreductase'],
#  ['R01108', 'glutathione:dehydroascorbate oxidoreductase'],
#  ['R01109', 'Glutathione:cystine oxidoreductase'],
#  ['R01110', 'glutathione:homocystine oxidoreductase'],
#  ['R01111', 'coenzyme A:glutathione-disulfide oxidoreductase'],
#  ['R01113', 'Glutathione:L-cystine oxidoreductase'],
#  ['R01115',
#   'CMP-N-acetylneuraminate,ferrocytochrome-b5:oxygen oxidoreductase (N-acetyl-hydroxylating)'],
#  ['R01117', 'CTP:N-acetylneuraminate cytidylyltransferase'],
#  ['R01119',
#   'CMP-N-acetylneuraminate <=> Colominic acid(non-reducing N- or O-acylneuraminyl residue)'],
#  ['R01120', 'CMP-N-acetylneuraminate <=> Glycolipid'],
#  ['R01121', 'ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP'],
#  ['R01122', 'delta2-isopentenyl-diphosphate:tRNA isopentenyltransferase'],
#  ['R01123', 'isopentenyl-diphosphate Delta3-Delta2-isomerase'],
#  ['R01126', "inosine 5'-monophosphate phosphohydrolase"],
#  ['R01127', 'IMP 1,2-hydrolase (decyclizing)'],
#  ['R01128', "5'-Inosinate phosphoribohydrolase"],
#  ['R01130', 'IMP:NAD+ oxidoreductase'],
#  ['R01131', "ATP:inosine 5'-phosphotransferase"],
#  ['R01132', 'IMP:diphosphate phospho-D-ribosyltransferase'],
#  ['R01134', "inosine-5'-phosphate:NADP+ oxidoreductase (aminating)"],
#  ['R01135', 'IMP:L-aspartate ligase (GDP-forming)'],
#  ['R01137', 'ATP:dADP phosphotransferase'],
#  ['R01138', 'dATP:pyruvate 2-O-phosphotransferase'],
#  ['R01139', 'dATP:D-glucose 6-phosphotransferase'],
#  ['R01140', 'dATP:D-fructose 6-phosphotransferase'],
#  ['R01142', 'Methane,NADH:oxygen oxidoreductase (hydroxylating)'],
#  ['R01143', 'methane,NADPH:oxygen oxidoreductase (hydroxylating)'],
#  ['R01144', 'Oxaloacetate-4-methyl-ester oxaloacetohydrolase'],
#  ['R01145', 'Monomethyl-sulfate sulfohydrolase'],
#  ['R01146', 'methanol:ferricytochrome-c oxidoreductase'],
#  ['R01147', "Pyridoxamine-5'-phosphate:2-oxoglutarate aminotransferase"],
#  ['R01148', 'D-Alanine:2-oxoglutarate aminotransferase'],
#  ['R01149', 'L-Glutamine:D-alanine gamma-glutamyltransferase'],
#  ['R01150', 'D-alanine:D-alanine ligase (ADP-forming)'],
#  ['R01151', 'Putrescine:oxygen oxidoreductase (deaminating)'],
#  ['R01152', 'N-Carbamoylputrescine amidohydrolase'],
#  ['R01153', 'S-Adenosyl-L-methionine:putrescine N-methyltransferase'],
#  ['R01154', 'acetyl-CoA:putrescine N-acetyltransferase'],
#  ['R01155', 'putrescine:2-oxoglutarate aminotransferase'],
#  ['R01156', 'N-Acetylputrescine acetylhydrolase'],
#  ['R01157', 'Agmatine amidinohydrolase'],
#  ['R01158', 'L-histidinol:NAD+ oxidoreductase'],
#  ['R01159', 'S-adenosyl-L-methionine:L-histidine N-methyltransferase'],
#  ['R01160', 'acetyl-CoA:L-histidine N-acetyltransferase'],
#  ['R01161', 'L-histidine:2-oxoglutarate aminotransferase'],
#  ['R01163', 'L-histidinal:NAD+ oxidoreductase'],
#  ['R01164', 'L-histidine:beta-alanine ligase (ADP-forming)'],
#  ['R01166', 'Nalpha-(beta-alanyl)-L-histidine hydrolase'],
#  ['R01167', 'L-histidine carboxy-lyase (histamine-forming)'],
#  ['R01168', 'L-histidine ammonia-lyase (urocanate-forming)'],
#  ['R01169', 'S-adenosyl-L-methionine:L-histidine Nalpha-methyltransferase'],
#  ['R01171', 'butanoyl-CoA:NAD+ trans-2-oxidoreductase'],
#  ['R01172', 'butanal:NAD+ oxidoreductase (CoA-acylating)'],
#  ['R01173', 'butanal:NADP+ oxidoreductase (CoA-acylating)'],
#  ['R01174', 'butanoyl-CoA:phosphate butanoyltransferase'],
#  ['R01175', 'butanoyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase'],
#  ['R01176', 'Butanoate:CoA ligase (AMP-forming)'],
#  ['R01177', 'butanoyl-CoA:acetyl-CoA C-butanoyltransferase'],
#  ['R01178',
#   'short-chain acyl-CoA:electron-transfer flavoprotein 2,3-oxidoreductase'],
#  ['R01179', 'butanoyl-CoA:acetate CoA-transferase'],
#  ['R01180',
#   'butanoyl-CoA:glyoxylate C-butanoyltransferase (thioester-hydrolysing, 1-carboxypropyl-forming)'],
#  ['R01181', '2-Methylpropanoyl-CoA CoA-carbonylmutase'],
#  ['R01183', 'myo-Inositol:NAD+ 2-oxidoreductase'],
#  ['R01184', 'myo-Inositol:oxygen oxidoreductase'],
#  ['R01185', '1D-myo-inositol 1-phosphate phosphohydrolase'],
#  ['R01186', '1D-myo-inositol 4-phosphate phosphohydrolase'],
#  ['R01187', '1D-myo-inositol 3-phosphate phosphohydrolase'],
#  ['R01188', 'S-adenosyl-L-methionine:1D-myo-inositol 1-O-methyltransferase'],
#  ['R01189', 'S-adenosyl-L-methionine:1D-myo-inositol 3-O-methyltransferase'],
#  ...]

# %%
len(all_reactions)
# Out:
# 11911

# %%
entry_re = re.compile(r'(?<=ENTRY       )R[0-9]{5}(?=\s*Reaction\nNAME)')

name_re = re.compile(r'(?<=NAME        ).+(?=;\n)|'
                     r'(?<=NAME        ).+(?=\n)')

class_re = re.compile(r'(?<=CLASS       ).+(?=;\n)|'
                      r'(?<=CLASS       ).+(?=\n)')

reaction_re = re.compile(r'(?<=ALL_REAC    )R[0-9]{5}(?= )|'
                         r'(?<=ALL_REAC    )R[0-9]{5}(?=;)|'
                         r'(?<= )R[0-9]{5}(?= R)|'
                         r'(?<= )R[0-9]{5}(?=;)|'
                         r'(?<= )R[0-9]{5}(?= \n            R)|'
                         r'(?<= )R[0-9]{5}(?=\nSUBSTRATE)')

substrates_re = re.compile(r'(?<=SUBSTRATE   ).+ \[CPD:C[0-9]{5}\];(?=;)|'
                           r'(?<=SUBSTRATE   ).+ \[CPD:C[0-9]{5}\];(?=\n)|'
                           r'(?<=            ).+ \[CPD:C[0-9]{5}\](?=;)|'
                           r'(?<=            ).+ \[CPD:C[0-9]{5}\](?=\n)')

products_re = re.compile(r'(?<=PRODUCT     ).+ \[CPD:C[0-9]{5}\];(?=;)|'
                         r'(?<=PRODUCT     ).+ \[CPD:C[0-9]{5}\];(?=\n)|'
                         r'(?<=            ).+ \[CPD:C[0-9]{5}\](?=;)|'
                         r'(?<=            ).+ \[CPD:C[0-9]{5}\](?=\n)')

enzymes_re = re.compile(r'(?<=ENZYME      )[0-9]+\.[0-9]+\.[0-9]+\.[0-9]+(?= )|'
                        r'(?<= )[0-9]+\.[0-9]+\.[0-9]+\.[0-9]+(?=\n)|'
                        r'(?<= )[0-9]+\.[0-9]+\.[0-9]+\.[0-9]+(?= )')

pathway_re = re.compile(r'(?<=PATHWAY     )rn[0-9]{5}  .+(?=\n)|'
                        r'(?<=            )rn[0-9]{5}  .+(?=\n)')

compound_re = re.compile(r'C[0-9]{5}')

# %%
def get_reaction_details(reaction):
    url_kegg_reaction_get = f'http://rest.kegg.jp/get/rn:{reaction}'
    response = requests.request("GET", url_kegg_reaction_get)
    entry = response.text

    # ENTRY
    entry_id = entry_re.findall(entry)

    if entry_id:
        entry_id = entry_id[0]

        # NAME
        name = name_re.findall(entry)[0]

        reaction_info = [entry_id, name]

        # EQUATION
        equation_split = entry.split('EQUATION')[1]

        if 'REMARK' in entry:
            equation = equation_split.split('REMARK')[0].strip()
        elif 'COMMENT' in entry:
            equation = equation_split.split('COMMENT')[0].strip()
        elif 'RCLASS' in entry:
            equation = equation_split.split('RCLASS')[0].strip()
        elif 'ENZYME' in entry:
            equation = equation_split.split('ENZYME')[0].strip()
        else:
            equation = equation_split.split('\n')[0].strip()

        substrates_temp = equation.split('<=>')[0].strip()
        products_temp = equation.split('<=>')[1].strip()

        substrates = compound_re.findall(substrates_temp)
        products = compound_re.findall(products_temp)

        substrates = list(map(lambda s: (s, entry_id), substrates))
        products = list(map(lambda p: (p, entry_id), products))

        # ENZYME
        enzymes = enzymes_re.findall(entry)
        enzymes = list(map(lambda e: (e, entry_id), enzymes))

        # PATHWAY
        pathways = pathway_re.findall(entry)
        pathways = list(map(lambda p: (p, entry_id), pathways))

        return reaction_info, substrates, products, enzymes, pathways

    else:
        return None, None, None, None, None

# %%
reaction_info, substrates, products, enzymes, pathways = get_reaction_details(all_reactions[1500][0])

# %%
parsed_reaction_entries = [['reaction_id', 'reaction_name']]
parsed_reaction_enzymes = [['enzyme_id', 'reaction_id']]
parsed_reaction_substrates = [['substrate', 'reaction_id']]
parsed_reaction_products = [['product', 'reaction_id']]
parsed_reaction_pathways = [['pathway', 'reaction_id']]

for reaction in all_reactions:
    reaction_info, substrates, products, enzymes, pathways = get_reaction_details(reaction[0])
    if reaction_info:
        parsed_reaction_entries.append(reaction_info)

    if substrates:
        parsed_reaction_substrates.extend(substrates)

    if products:
        parsed_reaction_products.extend(products)

    if enzymes:
        parsed_reaction_enzymes.extend(enzymes)

    if pathways:
        parsed_reaction_pathways.extend(pathways)

# %%
parsed_reaction_entries_df = pd.DataFrame(parsed_reaction_entries[1:], columns=parsed_reaction_entries[0])
parsed_reaction_entries_df
# Out:
#      reaction_id                                      reaction_name
# 0         R00001                 polyphosphate polyphosphohydrolase
# 1         R00002  Reduced ferredoxin:dinitrogen oxidoreductase (...
# 2         R00004                       diphosphate phosphohydrolase
# 3         R00005                  urea-1-carboxylate amidohydrolase
# 4         R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# ...          ...                                                ...
# 8949      R13133  N-(sulfonatooxy)prop-2-enimidothioate sulfate-...
# 8950      R13134  N-(sulfonatooxy)prop-2-enimidothioate sulfate-...
# 8951      R13136                     propanoate:NAD+ oxidoreductase
# 8952      R13137         succinate:ferricytochrome-c oxidoreductase
# 8953      R13141  homospermidine:oxygen oxidase (deaminating, cy...
#
# [8954 rows x 2 columns]

# %%
parsed_reaction_substrates_df = pd.DataFrame(parsed_reaction_substrates[1:], columns=parsed_reaction_substrates[0])
parsed_reaction_substrates_df
# Out:
#       substrate reaction_id
# 0        C00404      R00001
# 1        C00001      R00001
# 2        C00002      R00002
# 3        C00001      R00002
# 4        C00138      R00002
# ...         ...         ...
# 19680    C00042      R13137
# 19681    C00125      R13137
# 19682    C06366      R13141
# 19683    C00007      R13141
# 19684    C00001      R13141
#
# [19685 rows x 2 columns]

# %%
parsed_reaction_products_df = pd.DataFrame(parsed_reaction_products[1:], columns=parsed_reaction_products[0])
parsed_reaction_products_df
# Out:
#       product reaction_id
# 0      C02174      R00001
# 1      C05359      R00002
# 2      C00009      R00002
# 3      C00008      R00002
# 4      C00139      R00002
# ...       ...         ...
# 20781  C00122      R13137
# 20782  C00126      R13137
# 20783  C22648      R13141
# 20784  C00027      R13141
# 20785  C00014      R13141
#
# [20786 rows x 2 columns]

# %%
parsed_reaction_enzymes_df = pd.DataFrame(parsed_reaction_enzymes[1:], columns=parsed_reaction_enzymes[0])
parsed_reaction_enzymes_df
# Out:
#        enzyme_id reaction_id
# 0       3.6.1.10      R00001
# 1       1.18.6.1      R00002
# 2        3.6.1.1      R00004
# 3        6.3.4.6      R00005
# 4       3.5.1.54      R00005
# ...          ...         ...
# 10041    4.8.1.8      R13133
# 10042    4.8.1.8      R13134
# 10043  1.3.1.125      R13136
# 10044    1.3.2.4      R13137
# 10045   1.4.3.27      R13141
#
# [10046 rows x 2 columns]

# %%
parsed_reaction_pathways_df = pd.DataFrame(parsed_reaction_pathways[1:], columns=parsed_reaction_pathways[0])
parsed_reaction_pathways_df
# Out:
#                                                  pathway reaction_id
# 0                         rn00220  Arginine biosynthesis      R00005
# 1                          rn00791  Atrazine degradation      R00005
# 2                            rn01100  Metabolic pathways      R00005
# 3      rn01120  Microbial metabolism in diverse envir...      R00005
# 4                          rn00362  Benzoate degradation      R00008
# ...                                                  ...         ...
# 14236                       rn00620  Pyruvate metabolism      R13137
# 14237                      rn00650  Butanoate metabolism      R13137
# 14238   rn00720  Carbon fixation pathways in prokaryotes      R13137
# 14239                        rn01100  Metabolic pathways      R13137
# 14240  rn01120  Microbial metabolism in diverse envir...      R13137
#
# [14241 rows x 2 columns]

# %%
kegg_folder = '/path/to/kegg/data/folder/'

parsed_reaction_entries_df.to_csv(os.path.join(kegg_folder, "kegg_reactions.csv"), index=False)
parsed_reaction_enzymes_df.to_csv(os.path.join(kegg_folder, "kegg_reaction_enzymes.csv"), index=False)
parsed_reaction_substrates_df.to_csv(os.path.join(kegg_folder, "kegg_reaction_substrates.csv"), index=False)
parsed_reaction_products_df.to_csv(os.path.join(kegg_folder, "kegg_reaction_products.csv"), index=False)
parsed_reaction_pathways_df.to_csv(os.path.join(kegg_folder, "kegg_reaction_pathways.csv"), index=False)
